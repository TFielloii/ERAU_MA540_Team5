# %%
import os
from PIL import Image
import torch
from torch.utils.data import DataLoader,Dataset
import torch.nn as nn
from torch import Tensor
import torchvision
import torchvision.transforms as transforms
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import torch.nn.functional as F
import seaborn as sns
from datetime import datetime
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from einops import rearrange
from sklearn import svm
from sklearn.metrics import classification_report, accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF, Matern
from torch.autograd import Variable
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense
import warnings
warnings.filterwarnings("ignore")

SEED = 17
torch.manual_seed(SEED)

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
torch.backends.cudnn.benchmark = True

# %% [markdown]
# # A Compact Convolutional Vision Transformer or CCT
# *Created using the walkthrough from https://medium.com/pytorch/training-compact-transformers-from-scratch-in-30-minutes-with-pytorch-ff5c21668ed5 and Dr Prashant's Vision_Transformer file

# %% [markdown]
# ## Building the Transformer block by block

# %% [markdown]
# Every part/layer of the transformer is built using the Pytorch nn.module class which allows for easy creation of maching learning models. Each layer should be made up of at least two parts: An initialization function which uses the given information to build the class and then the 'Forward' function defines how the class will run when it is called.

# %% [markdown]
# ### Transformer Constructor
#
# First, the actual ViT Constructor which essentially acts as a hub. It ensures that each part of the transformer is called in the correct order and that local variables can be passed along.

# %% [markdown]
# ### What makes it more Compact/Lite than the CVT?
#
# The only difference between this and the original Vision Transformer is a Sequence Pooling layer and a convolutional layer instead of patching. Previously the classes were embedded separately and then passed to the MLP for classification. Sequence Pooling ties the class information in with every other parameter.. I think.

# %%
class CCT(nn.Module):
    '''
    Simplified implementation of the Vision transformer.

    Parameters
    ----------
    img_size: int
        Both height and width of the image (if it is a square)
    in_channels: int
        Number of input channels
    patch_size: int
        Both height and width of the patch (if it is a square)
    embed_dim: int
        The embedding size for each token
    n_layers: int
        Number of transformer blocks
    n_heads: int
        Number of attention heads
    attn_dropout, proj_dropout, mlp_dropout: float
        Dropout probability
    mlp_ratio: float
        Determine the hidden dimension of the MLP module
    qkv_bias: bool
        If true then we add bias to the query, key and value projections
    n_classes: int
        Number of classes

    Attributes
    -----------
    n_patches: int
        Number of patches that can be taken from each image based on size.
    patch_embed: PatchEmbed
        Sets up the `Patching' layer.
    class_embed: nn.Parameter
        Learnable parameter that will represent the first class token in the sequence.
        It has `embed_dim' elements.
    pos_embed: nn.Parameter
        Adds a positional encoding to every token.
    pos_drop: nn.Dropout
        Dropout layer.
    tr_block: nn.ModuleList
        Instance of 'TransformerEncoderLayer'.
    norm: nn.Layernorm
        Layer normalization.
    '''
    def __init__(self,
                 img_size=32,   # The square size of each image
                 in_channels=3, # Number of channels for each image (eg: Grayscale=1, RGB=3)
                 patch_size=4,  # The square size of each patch
                 embed_dim=768,  # Embedding dimension
                 n_layers=3, # How many times to run the transformer encoder
                 n_conv=2, # How many times to run the convolutional filter
                 n_heads=3,   # Number of attention heads,
                 attn_dropout=0.,  # Attention Dropout
                 proj_dropout=0.,   # (MHA) Projection Dropout
                 mlp_dropout=0.,   # (MHA) last layer dropout
                 mlp_ratio=4,   # (MHA) Projection FF dimension
                 qkv_bias = True,
                 n_class=10   # Number of classes to classify
    ):
        super().__init__()
        # Provides an error if the patching size is not divisible by the image size.
        assert img_size % patch_size == 0, \
            print("Given image size ({}) has to be divisible by given patch size ({})".format(img_size, patch_size))
        
        self.conv_embed = Conv_Embed(img_size, in_channels, embed_dim, n_conv)
        n_patches = self.conv_embed.sequence_length(in_channels=in_channels, height=img_size, width=img_size)
        hidden_dim = int(embed_dim * mlp_ratio)
        
        
        self.pos_embed = nn.Parameter(torch.zeros(1, n_patches, embed_dim)) # nn.Parameter makes this learnable weights
        
        # Can use this to enable Sinusoidal PE
        #self.pos_embed = PositionalEmbedding(1, n_patches + 1, embed_dim)

        self.pos_drop = nn.Dropout(p=proj_dropout)
        self.tr_block = nn.ModuleList(
            [
                TransformerEncoderLayer(
                    embed_dim,
                    n_heads,
                    qkv_bias,
                    attn_dropout,
                    proj_dropout,
                    mlp_dropout,
                    hidden_dim
                    )
                for _ in range(n_layers)
            ]   # Sends data through the encoder n times
        )
        self.norm = nn.LayerNorm(embed_dim, eps=1e-6)
        
        self.attention_pool = nn.Linear(embed_dim, 1)
                                    
        self.head = nn.Linear(embed_dim, n_class)

    def forward(self, x):
        '''
        Defines how the class will run

        Parameters
        ----------
        x: torch.Tensor
            shape: n_samples, in_chains, img_size, img_size

        Returns
        ---------
        logits: torch.Tensor
            Logits over all the classes: n_samples, n_samples
        '''
        x = self.conv_embed(x)
        #x = self.pos_embed(x)
        
        x += self.pos_embed
        x = self.pos_drop(x)
        for tr_block in self.tr_block:
            x = tr_block(x)
        x = self.norm(x)
        
        #Added Sequence Pooling instead of Class embedding
        x = torch.matmul(F.softmax(self.attention_pool(x), dim=1).transpose(-1, -2), x).squeeze(-2)
        y = self.head(x)
        
        return [y, x]

# %% [markdown]
# ### Positional Embedding
#
# This is the sinusoidal positional encoding layer as seen in the original 'Attention is All You Need' paper. It basically uses a sin/cos waveform to provide a unique positional offset that is given to a token at the corresponding position in its embedding space.
#
# By default, this is disabled and we instead use a trainable matrix of zeros. This adds another dimension to our data that the model then uses to find the best weights for the data's position itself. This is called "learnable" positional encoding.
#
# There are pros-and-cons to either, but essentially: sinusoidal is better when there are not a lot of data samples to learn the positional data from but you can get better results from "learnable" with larger datasets.

# %%
class PositionalEmbedding(nn.Module):
    '''
    Applies Learnable Sinusoidal Positional Encoding

    Parameters
    ----------
    embed_dim: int
        The positional embedding dimension (How big embedding for each patch.Constant across entire network)
    max_len: int 
        Max number of instances for positions
    freq: int 
        The base frequency for Sin/Cos calculations. Higher values (eg 10000) are more stable
    '''
    def __init__(self, 
                 embed_dim,
                 max_len=5000,
                 freq=10000.,
                ):
        super().__init__()
        pe = torch.zeros(max_len, embed_dim)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div = torch.exp(torch.arange(0, embed_dim, 2).float() *
                        (-math.log(freq) / embed_dim))
        pe[:, 0::2] = torch.sin(position * div) # Even terms
        pe[:, 1::2] = torch.cos(position * div) # Odd terms
        pe = pe.unsqueeze(0).transpose(0,1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        '''
        Defines how the class will run

        Parameters
        -----------

        Returns
        -----------
        '''
        x = x + self.pe[:x.size(0), :]
        return x

# %% [markdown]
# ### Convolutional Embedding Layer
#
# The patching used by the previous models was a problem because, while it took more samples of the input data, it also created what were essentially bordered segments which made it harder for the model to learn how they connected to the other segments and the bigger picture.
#
# The new convolutional layer helps to eliminate that problem by using convolutional filters to create many different overlapping segments.

# %%
class Conv_Embed(nn.Module):
    def __init__(self,
                 img_size=32,
                 in_channels=3,
                 out_channels=64,
                 n_conv=2,
                 kernel_size=3,
                 stride=None,
                 padding=None,
                 pool_kernel_size=3,
                 pool_stride=2,
                 pool_padding=1
                 ):
        super().__init__()
        
        stride = stride if stride is not None else max(1, (kernel_size // 2) - 1)
        padding = padding if padding is not None else max(1, (kernel_size // 2))

        self.img_size = img_size
        if n_conv == 1:
            self.conv_layers = nn.Sequential(
                nn.Conv2d(in_channels,
                        out_channels,
                        kernel_size=kernel_size,
                        stride=stride,
                        padding=padding,
                        bias=False),
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=pool_kernel_size,
                            stride=pool_stride,
                            padding=pool_padding)
            )
        else:
            n_filter_list = [in_channels] + \
                            [64 for _ in range(n_conv - 1)] + \
                            [out_channels]
            
            self.conv_layers = nn.Sequential(
                *[nn.Sequential(
                    nn.Conv2d(n_filter_list[i],
                        n_filter_list[i+1],
                        kernel_size=kernel_size,
                        stride=stride,
                        padding=padding,
                        bias=False),
                    nn.ReLU(),
                    nn.MaxPool2d(kernel_size=pool_kernel_size,
                            stride=pool_stride,
                            padding=pool_padding)
                            )
                    for i in range(n_conv)
                ])
        self.flattener = nn.Flatten(2, 3)
        
        # This, along with the @staticmethod below, help to normalize the convolutional filter by picking better starting weights for optimization.
        self.apply(self.init_weight)

    def sequence_length(self, in_channels=3, height=32, width=32):
        return self.forward(torch.zeros((1, in_channels, height, width))).shape[1]

    def forward(self, x):
        return self.flattener(self.conv_layers(x)).transpose(-2, -1)

    @staticmethod
    def init_weight(m):
        if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight)

# %% [markdown]
# ### This is the Transformer Encoder block which applies all of the actual normalization, attention, etc that make a Transformer what it is.

# %%
class TransformerEncoderLayer(nn.Module):
    '''
    Transformer Block/Encoder Layer

    Parameter
    ---------
    embed_dim: int
        embedding dimension
    n_heads: int
        number of attention heads
    mlp_ratio: float
        determines the hidden dimension size of the MLP module with respect to 'dim'
    qkv_bias: bool
        If true then we include bias to the query, key and value projections
    mlp_dropout, proj_dropout, attn_droupout: float
        dropout probability
    dim_feedforward: int
        The feature number of hidden layer of the FFN

    Attributes
    ----------
    norm_1, norm_2: LayerNorm
        Layer normalization
    MHA: Attention
        Multi-Headed Attention module
    mlp: MLP
        MLP module
    ''' 
    def __init__(self,
                 embed_dim=768,
                 n_heads=12,
                 qkv_bias=True,
                 attn_dropout=0.,
                 proj_dropout=0.,
                 mlp_dropout=0.,
                 hidden_dim=2048
    ):
        super().__init__()
        self.norm_1 = nn.LayerNorm(embed_dim, eps = 1e-6)
        self.norm_2 = nn.LayerNorm(embed_dim, eps = 1e-6)
        self.MHA = MultiheadedSelfAttention(embed_dim,
                                        n_heads,
                                        qkv_bias,
                                        attn_dropout,
                                        proj_dropout
        )
        self.MLP = MLP(embed_dim, hidden_dim, mlp_dropout)

    def forward(self, x):
        '''
        Defines how the class will run
        
        Parameter
        ---------
        x: torch.Tensor
            shape: n_samples, n_patches + 1, dim

        Returns
        --------
        torch.Tensor
            shape: n_samples, n_patches + 1, dim
        '''
        x = x + self.MHA(self.norm_1(x))    # Residual connection (Add)
        x = x + self.MLP(self.norm_2(x))    # Residual connection (Add)
        return x

# %% [markdown]
# ### Multiheaded Attention Layer
#
# The heart of the Transformer model; the reason behind the original title of "attention is all you need".

# %%
class MultiheadedSelfAttention(nn.Module):
    '''
    Multi-Headed Attention Mechanism

    Parameters
    ----------
    embed_dim: int
        The input and out dimension of per token feature
    n_heads: int
        Number of attention heads 
    qkv_bias: bool
        if true then we include bias to the query, key and value projections
    attn_p: float
        Dropout probability applied to the query, key and value tensors.
    proj_p: float
        Dropout probability applied to output tensor
        
    Attributes
    ----------
    scale: float
        Normalizing constant for the dot product
    qkv: nn.Linear
        Linear projection for the query, key and value
    proj: nn.Linear
        Linear mapping that takes in the concatenated output of all attention
        heads and maps into the new space
    attn_drop, proj_drop: nn.Dropout
        Dropout layers.
    '''
    def __init__(self, 
                 embed_dim, 
                 n_heads=2,
                 qkv_bias = True,
                 attn_dropout=0.,
                 proj_dropout=0.
    ):
        super().__init__()
        self.n_heads = n_heads
        assert embed_dim % n_heads == 0, \
            print('Embedding dim must be divisible by number of heads.')
        self.head_dim = embed_dim // n_heads
        self.scale = self.head_dim ** -0.5
        self.dim = embed_dim
        self.qkv = nn.Linear(embed_dim, embed_dim * 3, bias=qkv_bias)
        self.attn_dropout = nn.Dropout(attn_dropout)
        self.proj = nn.Linear(embed_dim, embed_dim)
        self.proj_dropout = nn.Dropout(proj_dropout)
        
    def forward(self, x):
        '''
        Defines how the class will run
        
        Parameters
        ----------
        x: torch.Tensor
            shape: n_samples (B), n_patches + 1 (N), embed_dim (C)
            N is also equal to the number of tokens.
        Returns
        --------
        torch.Tensor
            shape: n_samples, n_patches + 1, embed_dim
        '''
        B, N, C = x.shape
        qkv = self.qkv(x)
        qkv = qkv.reshape(B, N, 3,
            self.n_heads,
            self.head_dim
            )
        qkv = qkv.permute(
            2,    # qkv (3)
            0,    # batch (n_samples)
            3,    # channel (n_heads)
            1,    # n_patches + 1
            4     # head_dim (embed_dim / n_heads)
            )
        q, k, v = qkv[0], qkv[1], qkv[2]
        attn = (q @ k.transpose(-2, -1)) * self.scale # <q,k> / sqrt(d)
        attn = attn.softmax(dim=-1) # Softmax over embedding dim
        attn = self.attn_dropout(attn)

        weighted_avg = (attn @ v)
        weighted_avg = weighted_avg.transpose(1, 2)
        weighted_avg = weighted_avg.flatten(2)

        x = self.proj(weighted_avg)
        x = self.proj_dropout(x)

        return x

# %% [markdown]
# ### The MLP layer
#
# (At the end of the Transformer Encoder). Not to be confused with the mlp head which adds class encodings at the very end of the transformer.

# %%
class MLP(nn.Module):
    '''
    Multilayer perceptron 
    
    Parameters
    ----------
    embed_dim: int
        embedding dimension
    feedforward_dim: int
      Number of nodes in the hidden layer
    mlp_dropout: float
      Dropout probability

    Attribute
    ---------
    fc: nn.Linear
      The first linear layer
    act: nn. GELU
      GELU activation function
    fc2: nn.Linear
      The second linear layer
    drop: nn.Dropout
      Dropout layer
    '''

    def __init__(self, embed_dim, hidden_dim, mlp_dropout):
        super().__init__()
        self.fc1 = nn.Linear(embed_dim, hidden_dim)
        self.act = nn.GELU()
        self.fc2 = nn.Linear(hidden_dim, embed_dim)
        self.drop = nn.Dropout(mlp_dropout)

    def forward(self,x):
        '''
        Defines how the class will run
        
        Parameters
        ----------
        x: torch.Tensor
          shape: n_samples, n_patches + 1, in_features

        Returns
        ----------
        torch.Tensor
          n_samples, n_patches+ 1, out_features
        '''
        x = self.fc1(x) # n_samples, n_patches+1, hidden_features
        x = self.act(x) # n_samples, n_patches+1, hidden_features
        x = self.drop(x) # n_samples, n_patches+1, hidden_features
        x = self.fc2(x) # n_samples, n_patches+1, output_features
        x = self.drop(x) # n_samples, n_patches+1, output_features
        return x

# %% [markdown]
# ## Training with custom dataset

# %%
def sipakmed_prep():
    root = "../../Python Scripts/Datasets/CervicalCancer/Sipakmed/"

    all_img = []
    for path, subdirs, files in os.walk(root):
        for name in files:
            curr_img = os.path.join(path,name)
            all_img.append(curr_img)

    sipakmed_df = pd.DataFrame()
    sipakmed_df['LocalPath'] = all_img
    sipakmed_df['ID'] = sipakmed_df['LocalPath'].apply(lambda x: str(x.split("\\")[-1]))
    sipakmed_df['Slide'] = sipakmed_df['LocalPath'].apply(lambda x: 'False' if (str(x.split("\\")[1])) == 'CROPPED' else 'True')
    sipakmed_df['Specific_Status'] = sipakmed_df['LocalPath'].apply(lambda x: str((x.split("im_")[1]).split("\\")[0]))
    sipakmed_df['Status'] = sipakmed_df['Specific_Status'].apply(lambda x: 'Benign' if x == 'Metaplastic' else
    ('Normal' if x == 'Superficial-Intermediate' or x == 'Parabasal' else 'Abnormal'))

    sp_class = {'Metaplastic':4, 'Superficial-Intermediate':0, 'Parabasal':1, 'Koilocytotic':2, 'Dyskeratotic':3}
    sipakmed_df['Specific_Class'] = sipakmed_df['Specific_Status'].map(sp_class)
    gen_class = {'Benign':0, 'Normal':1, 'Abnormal':2}
    sipakmed_df['Class'] = sipakmed_df['Status'].map(gen_class)
    
    sipakmed_df = sipakmed_df.loc[sipakmed_df['ID'].str.contains('bmp')].reset_index(drop=True)
    
    return sipakmed_df

# %%
def herlev_prep(n_class):
    root = '../../Python Scripts/Datasets/CervicalCancer/Herlev/smear2005/results.csv'
    img_folder = '../../Python Scripts/Datasets/CervicalCancer/Herlev/smear2005/Images/'

    herlev_df=pd.read_csv(root)
    herlev_df = herlev_df.rename(columns={'Class':'Specific_Class'})

    if n_class == 12:
        spec_class = {1:5, 2:6, 3:7, 4:8, 5:9, 6:10, 7:11}
    else:
        spec_class = {1:0, 2:1, 3:2, 4:3, 5:4, 6:5, 7:6}
    
    gen_class = {1:1, 2:1, 3:1, 4:2, 5:2, 6:2, 7:2}
    herlev_df['Class'] = herlev_df['Specific_Class'].map(gen_class)
    herlev_df['Specific_Class'] = herlev_df['Specific_Class'].map(spec_class)
    herlev_df['LocalPath'] = herlev_df['ID'].apply(lambda x: str(img_folder + x))
    return herlev_df

# %%
def gan_prep():
    root = '../../Python Scripts/Datasets/CervicalCancer/Generated/'

    all_img = []
    for path, subdirs, files in os.walk(root):
        for name in files:
            curr_img = os.path.join(path,name)
            all_img.append(curr_img)

    generated_df = pd.DataFrame()
    generated_df['LocalPath'] = all_img
    generated_df['Specific_Class'] = (generated_df['LocalPath'].apply(lambda x: str(x.split("/")[-1]))).apply(lambda x: int(x.split("\\")[-2]))
    
    gen_class = {0:1, 1:1, 2:2, 3:2, 4:0, 5:1, 6:1, 7:1, 8:2, 9:2, 10:2, 11:2}
    generated_df['Class'] = generated_df['Specific_Class'].map(gen_class)
    return generated_df

# %%
class DatasetSample(Dataset):
    def __init__(self, df, transform):
        # Initialization
        self.transform = transform
        
        self.image_names = df['LocalPath']
        self.img_class = np.array(df['Class'])

    def __len__(self):
        # Denotes the total number of samples
        return len(self.image_names)
    
    def __getitem__(self, index):
        # Retrieves the data
        image=cv2.imread(self.image_names.iloc[index])
        image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

        image = self.transform(image)
        label = self.img_class[index]

        return image, label

# %%
def concat_data(batch_size=128, img_size=32, n_class=3, GAN=True):
    kwargs = {'num_workers': 1, 'pin_memory': True} if device=='cuda' else {}
    # Load the dataframes
    sipakmed_df = sipakmed_prep()
    herlev_df = herlev_prep(n_class)

    # Final adjustments to make sure they're attributes match
    sipakmed_df = sipakmed_df.loc[sipakmed_df['Slide'] == 'False']

    if n_class == 2:
        classes = ('Normal', 'Abnormal')
        herlev_df = herlev_df.loc[:,['LocalPath', 'Class']]
        sipakmed_df = sipakmed_df.loc[:,['LocalPath', 'Class']]
        concat_df = pd.concat([sipakmed_df,herlev_df], ignore_index=True)
        bin_class = {0:0, 1:0, 2:1}
        concat_df['Class'] = concat_df['Class'].map(bin_class)

    elif n_class == 3:
        classes = ('Benign', 'Normal', 'Abnormal')
        herlev_df = herlev_df.loc[:,['LocalPath', 'Class']]
        sipakmed_df = sipakmed_df.loc[:,['LocalPath', 'Class']]
        concat_df = pd.concat([sipakmed_df,herlev_df], ignore_index=True)

    elif n_class == 5:
        classes = ('Superficial-Intermediate','Parabasal','Koilocytotic','Dyskeratotic','Metaplastic')
        concat_df = pd.DataFrame()
        concat_df['LocalPath'] = sipakmed_df['LocalPath']
        concat_df['Class'] = sipakmed_df['Specific_Class']

    elif n_class == 7:
        classes = ('Superficial-Squamous-Epithelial','Intermediate-Squamous-Epithelial','Columnar-Epithelial','Mild-Squamous-Non-Keratinizing-Dysplasia',
           'Moderate-Squamous-Non-Keratinizing-Dysplasia','Severe-Squamous-Non-Keratinizing-Dysplasia','Squamous-Cell-Carcinoma-in-situ-Intermediate')
        concat_df = pd.DataFrame()
        concat_df['LocalPath'] = herlev_df['LocalPath']
        concat_df['Class'] = herlev_df['Specific_Class']

    elif n_class == 12:
        classes = ('Superficial-Intermediate','Parabasal','Koilocytotic','Dyskeratotic','Metaplastic','Superficial-Squamous-Epithelial','Intermediate-Squamous-Epithelial','Columnar-Epithelial','Mild-Squamous-Non-Keratinizing-Dysplasia',
           'Moderate-Squamous-Non-Keratinizing-Dysplasia','Severe-Squamous-Non-Keratinizing-Dysplasia','Squamous-Cell-Carcinoma-in-situ-Intermediate')
        herlev_df = herlev_df.loc[:,['LocalPath', 'Specific_Class']]
        sipakmed_df = sipakmed_df.loc[:,['LocalPath', 'Specific_Class']]
        concat_df = pd.concat([sipakmed_df,herlev_df], ignore_index=True).rename(columns={'Specific_Class':'Class'})

    # Split them into training, validation, and testing sets
    train_set,val_test_set = train_test_split(concat_df, random_state=SEED, test_size=0.40)
    val_set,test_set = train_test_split(val_test_set, random_state=SEED, test_size=0.50)

    if GAN == True:
        generated_df = gan_prep()
        # Add the generated images to the train_set
        if n_class == 2:
            bin_class = {0:0, 1:0, 2:1}
            generated_df = generated_df.loc[:,['LocalPath', 'Class']]
            generated_df['Class'] = generated_df['Class'].map(bin_class)
            train_set = pd.concat([train_set,generated_df], ignore_index=True)

        elif n_class == 3:
            generated_df = generated_df.loc[:,['LocalPath', 'Class']]
            train_set = pd.concat([train_set,generated_df], ignore_index=True)

        elif n_class == 5:
            generated_df = generated_df.loc[:,['LocalPath', 'Specific_Class']]
            generated_df = generated_df.loc[generated_df['Specific_Class'] <= 4]
            generated_df = generated_df.rename(columns={'Specific_Class':'Class'})
            train_set = pd.concat([train_set,generated_df], ignore_index=True)

        elif n_class == 7:
            generated_df = generated_df.loc[generated_df['Specific_Class'] >= 5]
            spec_class = {5:0, 6:1, 7:2, 8:3, 9:4, 10:5, 11:6}
            generated_df['Specific_Class'] = generated_df['Specific_Class'].map(spec_class)
            generated_df = generated_df.rename(columns={'Specific_Class':'Class'})
            train_set = pd.concat([train_set,generated_df], ignore_index=True)

        elif n_class == 12:
            generated_df = generated_df.loc[:,['LocalPath', 'Specific_Class']]
            generated_df = generated_df.rename(columns={'Specific_Class':'Class'})
            train_set = pd.concat([train_set,generated_df], ignore_index=True)
            
    # Set it up to alter random training images for better results
    train_transform = transforms.Compose([
                    transforms.ToPILImage(),
                    transforms.Resize((img_size, img_size)),
                    transforms.RandomHorizontalFlip(p=0.75),
                    transforms.RandomRotation(degrees=60),
                    transforms.transforms.ColorJitter(brightness=.2, hue=.2),
                    transforms.ToTensor()])

    test_transform = transforms.Compose([
                    transforms.ToPILImage(),
                    transforms.Resize((img_size, img_size)),
                    transforms.ToTensor()])

    train_dataset = DatasetSample(train_set, train_transform)
    val_dataset = DatasetSample(val_set, test_transform)
    test_dataset = DatasetSample(test_set, test_transform)
    
    Dtr = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        generator=torch.Generator().manual_seed(SEED),
        **kwargs
    )
    
    Dva = DataLoader(
        val_dataset, 
        batch_size=batch_size,
        shuffle=False,
        **kwargs
    )

    Dte = DataLoader(
        test_dataset, 
        batch_size=batch_size,
        shuffle=False,
        **kwargs
    )

    return(Dtr, Dva, Dte, classes, train_set, val_set, test_set)

# %% [markdown]
# ### Function for viewing batches of the dataset

# %%
def img_vis(images, labels, predicted_labels=None):
    
    if images.is_cuda == True:
        images = images.to("cpu")
    if labels.is_cuda == True:
        labels = labels.to("cpu")

    # Using torchvision to make a grid of the images
    img = torchvision.utils.make_grid(images)

    # Inverting the normalization
    img = img.numpy().transpose((1, 2, 0))
    img = np.clip(img, 0, 1)

    # Plotting the grid
    fig, ax = plt.subplots(figsize=(12, 24))
    plt.imshow(img)

    if predicted_labels is not None:
        if predicted_labels.is_cuda == True:
            predicted_labels = predicted_labels.to("cpu")
        # Outputing the predicted labels
        ax.set_xlabel('Predicted labels', fontsize=18, labelpad=12)
        ax.set_xticks(torch.arange(len(images)) * img_size + (img_size/1.8))
        ax.set_xticklabels([classes[predicted_labels[j]] 
                            for j in range(len(images))], fontsize=12, rotation=30)
    
    # Outputing the True labels
    gax = ax.secondary_xaxis('top')
    gax.set_xlabel('True Labels', fontsize=18, labelpad=12)
    gax.set_xticks(torch.arange(len(images)) * img_size + (img_size/1.8))
    gax.set_xticklabels([classes[labels[j]] 
                         for j in range(len(images))], fontsize=12, rotation=30)
    plt.show()

# %% [markdown]
# ### This function was made by Dr Prashant to train the model that's built above

# %%
# A function to encapsulate the training loop
def batch_gd(model, loss_fn, optimizer, train_loader, val_loader, epochs):
  model.to(device)
  train_losses = np.zeros(epochs)
  val_losses = np.zeros(epochs)
  avg_epoch = []
  
  for it in range(epochs):
    model.train()
    t0 = datetime.now()
    train_loss = []
    n_correct = 0.
    n_total = 0.
    for inputs, targets in train_loader:
      # move data to GPU if available
      inputs, targets = inputs.to(device), targets.to(device)

      # zero the parameter gradients
      optimizer.zero_grad()

      # Forward pass
      outputs = model(inputs)[0]
      
      # Get the predictions
      # torch.max returns both max and argmax
      __, out_label = outputs.max(dim=1)
      # Updates the accuracy with every pass
      n_correct += (out_label == targets).sum().item()
      n_total += targets.shape[0]
      tr_acc = n_correct / n_total

      loss = loss_fn(outputs, targets)
      # Backward and optimize
      loss.backward()
      optimizer.step()

      train_loss.append(loss.item())

    # Get train loss and val loss
    train_loss = np.mean(train_loss) # a little misleading
    
    model.eval()
    val_loss = []
    n_correct = 0.
    n_total = 0.
    for inputs, targets in val_loader:
      inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)[0]

      # Get the predictions
      # torch.max returns both max and argmax
      __, out_label = outputs.max(dim=1)
      # Updates the accuracy with every pass
      n_correct += (out_label == targets).sum().item()
      n_total += targets.shape[0]
      val_acc = n_correct / n_total

      loss = loss_fn(outputs, targets)
      val_loss.append(loss.item())
    val_loss = np.mean(val_loss)

    # Save losses
    train_losses[it] = train_loss
    val_losses[it] = val_loss
    
    dt = datetime.now() - t0
    avg_epoch.append(dt)

    print('Epoch: [{:d}/{:d}]   Train Loss: {:.4f}   Train Accuracy: {:.3f}   Val Loss: {:.4f}   Val Accuracy: {:.3f}   Duration: {:.2f}s   Avg Duration: {:.2f}s' \
          .format(it+1, epochs, train_loss, 100*tr_acc, val_loss, 100*val_acc, dt.total_seconds(), np.mean(avg_epoch).total_seconds()))    

  return train_losses, val_losses

# %% [markdown]
# ### Initializes the Transformer and selects the loss function and optimizer we want

# %%
'''
For n_class:
        2 uses both datasets. Classes are normal and abnormal.
        3 uses both datasets. Classes are benign, normal, and abnormal.
        5 uses the Sipakmed dataset. Classes are Superficial-Intermediate, Parabasal, Koilocytotic, Dyskeratotic, and Metaplastic.
        7 uses the Herlev dataset. Classes are Superficial Squamous Epithelial, Intermediate Squamous Epithelial, Columnar Epithelial, Mild Squamous Non-Keratinizing Dysplasia,
                Moderate Squamous Non-Keratinizing Dysplasia, Severe Squamous Non-Keratinizing Dysplasia, and Squamous Cell Carcinoma in-situ Intermediate.
        12 uses both datasets. Classes are the two above.
'''
batch_size = 192
img_size = 64
n_class = 12
GAN = True

model = CCT(
        img_size=img_size,      # Input image size
        in_channels=3,  # Number of channels for the image
        patch_size=16,   # Patch Size
        embed_dim=129,   # Embedding dim
        n_layers=3,     # Number of transformer encoders
        n_conv=2,       # Number of convolutional layers
        n_heads=3,      # Number of attention heads
        attn_dropout=0.,        # Attention Dropout
        proj_dropout=0.,        # (MHA) Projection Dropout
        mlp_dropout=0.1,        # (MHA) last layer dropout
        mlp_ratio=1,    # (MHA) Projection FF dimension
        qkv_bias = True,
        n_class=n_class     # Number of classes to classify
        )
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())

# %%
Dtr, Dva, Dte, classes, train_set, val_set, test_set = concat_data(batch_size, img_size, n_class, GAN)
train_losses, val_losses = batch_gd(model, loss_fn, optimizer, Dtr, Dva, epochs=200)
# Out:
# Epoch: [1/200]   Train Loss: 2.4538   Train Accuracy: 15.660   Val Loss: 2.0297   Val Accuracy: 38.973   Duration: 21.33s   Avg Duration: 21.33s
# Epoch: [2/200]   Train Loss: 2.3096   Train Accuracy: 21.373   Val Loss: 1.9150   Val Accuracy: 44.109   Duration: 13.55s   Avg Duration: 17.44s
# Epoch: [3/200]   Train Loss: 2.2543   Train Accuracy: 24.512   Val Loss: 1.8261   Val Accuracy: 53.676   Duration: 14.01s   Avg Duration: 16.30s
# Epoch: [4/200]   Train Loss: 2.1207   Train Accuracy: 28.764   Val Loss: 1.8307   Val Accuracy: 50.252   Duration: 13.54s   Avg Duration: 15.61s
# Epoch: [5/200]   Train Loss: 2.0010   Train Accuracy: 31.374   Val Loss: 1.5383   Val Accuracy: 55.891   Duration: 13.61s   Avg Duration: 15.21s
# Epoch: [6/200]   Train Loss: 1.8436   Train Accuracy: 36.247   Val Loss: 1.2303   Val Accuracy: 63.041   Duration: 13.46s   Avg Duration: 14.92s
# Epoch: [7/200]   Train Loss: 1.7543   Train Accuracy: 37.726   Val Loss: 1.1551   Val Accuracy: 62.840   Duration: 13.71s   Avg Duration: 14.74s
# Epoch: [8/200]   Train Loss: 1.6643   Train Accuracy: 40.774   Val Loss: 1.2095   Val Accuracy: 60.926   Duration: 13.53s   Avg Duration: 14.59s
# Epoch: [9/200]   Train Loss: 1.6241   Train Accuracy: 41.559   Val Loss: 1.0831   Val Accuracy: 64.854   Duration: 13.56s   Avg Duration: 14.48s
# Epoch: [10/200]   Train Loss: 1.5783   Train Accuracy: 43.201   Val Loss: 1.0396   Val Accuracy: 66.566   Duration: 13.46s   Avg Duration: 14.38s
# Epoch: [11/200]   Train Loss: 1.5700   Train Accuracy: 42.964   Val Loss: 1.0425   Val Accuracy: 65.861   Duration: 13.42s   Avg Duration: 14.29s
# Epoch: [12/200]   Train Loss: 1.5296   Train Accuracy: 44.442   Val Loss: 1.0402   Val Accuracy: 67.271   Duration: 13.44s   Avg Duration: 14.22s
# Epoch: [13/200]   Train Loss: 1.4692   Train Accuracy: 45.921   Val Loss: 0.8721   Val Accuracy: 71.400   Duration: 13.42s   Avg Duration: 14.16s
# Epoch: [14/200]   Train Loss: 1.4291   Train Accuracy: 47.326   Val Loss: 0.8071   Val Accuracy: 74.924   Duration: 13.45s   Avg Duration: 14.11s
# Epoch: [15/200]   Train Loss: 1.4138   Train Accuracy: 47.344   Val Loss: 0.8200   Val Accuracy: 72.306   Duration: 13.48s   Avg Duration: 14.07s
# Epoch: [16/200]   Train Loss: 1.4055   Train Accuracy: 48.805   Val Loss: 0.7393   Val Accuracy: 76.234   Duration: 13.67s   Avg Duration: 14.04s
# Epoch: [17/200]   Train Loss: 1.3793   Train Accuracy: 48.987   Val Loss: 0.7147   Val Accuracy: 76.234   Duration: 13.70s   Avg Duration: 14.02s
# Epoch: [18/200]   Train Loss: 1.3547   Train Accuracy: 49.973   Val Loss: 0.7267   Val Accuracy: 77.039   Duration: 14.70s   Avg Duration: 14.06s
# Epoch: [19/200]   Train Loss: 1.3450   Train Accuracy: 50.429   Val Loss: 0.7624   Val Accuracy: 75.126   Duration: 14.76s   Avg Duration: 14.10s
# Epoch: [20/200]   Train Loss: 1.3407   Train Accuracy: 50.338   Val Loss: 0.6528   Val Accuracy: 80.363   Duration: 14.97s   Avg Duration: 14.14s
# Epoch: [21/200]   Train Loss: 1.3020   Train Accuracy: 51.177   Val Loss: 0.7159   Val Accuracy: 76.435   Duration: 14.77s   Avg Duration: 14.17s
# Epoch: [22/200]   Train Loss: 1.2972   Train Accuracy: 51.597   Val Loss: 0.5918   Val Accuracy: 81.470   Duration: 14.70s   Avg Duration: 14.19s
# Epoch: [23/200]   Train Loss: 1.2668   Train Accuracy: 52.108   Val Loss: 0.5987   Val Accuracy: 80.665   Duration: 14.74s   Avg Duration: 14.22s
# Epoch: [24/200]   Train Loss: 1.2757   Train Accuracy: 52.656   Val Loss: 0.6035   Val Accuracy: 80.665   Duration: 14.84s   Avg Duration: 14.24s
# Epoch: [25/200]   Train Loss: 1.2766   Train Accuracy: 52.309   Val Loss: 0.7172   Val Accuracy: 76.435   Duration: 14.91s   Avg Duration: 14.27s
# Epoch: [26/200]   Train Loss: 1.2668   Train Accuracy: 52.692   Val Loss: 0.6449   Val Accuracy: 79.557   Duration: 14.81s   Avg Duration: 14.29s
# Epoch: [27/200]   Train Loss: 1.2403   Train Accuracy: 53.258   Val Loss: 0.5981   Val Accuracy: 81.470   Duration: 14.75s   Avg Duration: 14.31s
# Epoch: [28/200]   Train Loss: 1.2258   Train Accuracy: 54.189   Val Loss: 0.5489   Val Accuracy: 81.571   Duration: 15.12s   Avg Duration: 14.34s
# Epoch: [29/200]   Train Loss: 1.2634   Train Accuracy: 52.911   Val Loss: 0.6476   Val Accuracy: 76.536   Duration: 14.85s   Avg Duration: 14.35s
# Epoch: [30/200]   Train Loss: 1.2121   Train Accuracy: 54.974   Val Loss: 0.6491   Val Accuracy: 79.355   Duration: 14.79s   Avg Duration: 14.37s
# Epoch: [31/200]   Train Loss: 1.2152   Train Accuracy: 54.663   Val Loss: 0.5487   Val Accuracy: 80.866   Duration: 14.74s   Avg Duration: 14.38s
# Epoch: [32/200]   Train Loss: 1.1820   Train Accuracy: 56.142   Val Loss: 0.5404   Val Accuracy: 82.477   Duration: 14.70s   Avg Duration: 14.39s
# Epoch: [33/200]   Train Loss: 1.1895   Train Accuracy: 55.302   Val Loss: 0.5619   Val Accuracy: 80.463   Duration: 14.78s   Avg Duration: 14.40s
# Epoch: [34/200]   Train Loss: 1.1633   Train Accuracy: 57.164   Val Loss: 0.5387   Val Accuracy: 81.672   Duration: 14.65s   Avg Duration: 14.41s
# Epoch: [35/200]   Train Loss: 1.1816   Train Accuracy: 56.488   Val Loss: 0.5291   Val Accuracy: 82.276   Duration: 14.65s   Avg Duration: 14.42s
# Epoch: [36/200]   Train Loss: 1.1559   Train Accuracy: 57.200   Val Loss: 0.5431   Val Accuracy: 81.470   Duration: 14.71s   Avg Duration: 14.42s
# Epoch: [37/200]   Train Loss: 1.1203   Train Accuracy: 58.624   Val Loss: 0.4988   Val Accuracy: 83.686   Duration: 14.94s   Avg Duration: 14.44s
# Epoch: [38/200]   Train Loss: 1.1624   Train Accuracy: 57.638   Val Loss: 0.4807   Val Accuracy: 82.276   Duration: 14.80s   Avg Duration: 14.45s
# Epoch: [39/200]   Train Loss: 1.1492   Train Accuracy: 57.364   Val Loss: 0.5335   Val Accuracy: 82.880   Duration: 14.70s   Avg Duration: 14.45s
# Epoch: [40/200]   Train Loss: 1.1864   Train Accuracy: 56.507   Val Loss: 0.6335   Val Accuracy: 79.255   Duration: 14.88s   Avg Duration: 14.47s
# Epoch: [41/200]   Train Loss: 1.1352   Train Accuracy: 58.587   Val Loss: 0.4992   Val Accuracy: 82.477   Duration: 14.90s   Avg Duration: 14.48s
# Epoch: [42/200]   Train Loss: 1.1099   Train Accuracy: 58.679   Val Loss: 0.4507   Val Accuracy: 84.491   Duration: 14.82s   Avg Duration: 14.48s
# Epoch: [43/200]   Train Loss: 1.1003   Train Accuracy: 59.774   Val Loss: 0.4529   Val Accuracy: 84.995   Duration: 14.68s   Avg Duration: 14.49s
# Epoch: [44/200]   Train Loss: 1.0966   Train Accuracy: 60.157   Val Loss: 0.4496   Val Accuracy: 84.290   Duration: 14.76s   Avg Duration: 14.49s
# Epoch: [45/200]   Train Loss: 1.0734   Train Accuracy: 60.102   Val Loss: 0.5320   Val Accuracy: 83.182   Duration: 14.83s   Avg Duration: 14.50s
# Epoch: [46/200]   Train Loss: 1.0673   Train Accuracy: 60.960   Val Loss: 0.4374   Val Accuracy: 85.901   Duration: 14.68s   Avg Duration: 14.51s
# Epoch: [47/200]   Train Loss: 1.0715   Train Accuracy: 60.632   Val Loss: 0.4504   Val Accuracy: 84.894   Duration: 14.81s   Avg Duration: 14.51s
# Epoch: [48/200]   Train Loss: 1.0401   Train Accuracy: 61.873   Val Loss: 0.5149   Val Accuracy: 83.484   Duration: 14.75s   Avg Duration: 14.52s
# Epoch: [49/200]   Train Loss: 1.0489   Train Accuracy: 62.347   Val Loss: 0.5533   Val Accuracy: 83.887   Duration: 14.99s   Avg Duration: 14.53s
# Epoch: [50/200]   Train Loss: 1.0729   Train Accuracy: 61.015   Val Loss: 0.5208   Val Accuracy: 83.585   Duration: 14.80s   Avg Duration: 14.53s
# Epoch: [51/200]   Train Loss: 1.0523   Train Accuracy: 61.635   Val Loss: 0.4638   Val Accuracy: 84.189   Duration: 14.74s   Avg Duration: 14.54s
# Epoch: [52/200]   Train Loss: 1.0207   Train Accuracy: 62.712   Val Loss: 0.5006   Val Accuracy: 83.686   Duration: 14.87s   Avg Duration: 14.54s
# Epoch: [53/200]   Train Loss: 0.9876   Train Accuracy: 64.282   Val Loss: 0.4737   Val Accuracy: 85.498   Duration: 14.74s   Avg Duration: 14.55s
# Epoch: [54/200]   Train Loss: 0.9847   Train Accuracy: 63.880   Val Loss: 0.4631   Val Accuracy: 85.196   Duration: 14.78s   Avg Duration: 14.55s
# Epoch: [55/200]   Train Loss: 1.0071   Train Accuracy: 62.767   Val Loss: 0.4935   Val Accuracy: 83.182   Duration: 14.66s   Avg Duration: 14.55s
# Epoch: [56/200]   Train Loss: 0.9951   Train Accuracy: 64.026   Val Loss: 0.4591   Val Accuracy: 86.103   Duration: 14.76s   Avg Duration: 14.56s
# Epoch: [57/200]   Train Loss: 0.9647   Train Accuracy: 64.537   Val Loss: 0.5385   Val Accuracy: 82.779   Duration: 14.81s   Avg Duration: 14.56s
# Epoch: [58/200]   Train Loss: 0.9692   Train Accuracy: 64.884   Val Loss: 0.4845   Val Accuracy: 84.290   Duration: 14.74s   Avg Duration: 14.56s
# Epoch: [59/200]   Train Loss: 0.9600   Train Accuracy: 65.523   Val Loss: 0.4895   Val Accuracy: 84.391   Duration: 14.64s   Avg Duration: 14.57s
# Epoch: [60/200]   Train Loss: 0.9450   Train Accuracy: 66.125   Val Loss: 0.4775   Val Accuracy: 85.096   Duration: 14.78s   Avg Duration: 14.57s
# Epoch: [61/200]   Train Loss: 0.9527   Train Accuracy: 65.961   Val Loss: 0.4325   Val Accuracy: 85.498   Duration: 14.76s   Avg Duration: 14.57s
# Epoch: [62/200]   Train Loss: 0.9529   Train Accuracy: 65.140   Val Loss: 0.4531   Val Accuracy: 84.894   Duration: 14.49s   Avg Duration: 14.57s
# Epoch: [63/200]   Train Loss: 0.9421   Train Accuracy: 65.651   Val Loss: 0.4704   Val Accuracy: 84.491   Duration: 14.22s   Avg Duration: 14.57s
# Epoch: [64/200]   Train Loss: 0.9024   Train Accuracy: 67.275   Val Loss: 0.3850   Val Accuracy: 87.311   Duration: 14.23s   Avg Duration: 14.56s
# Epoch: [65/200]   Train Loss: 0.9137   Train Accuracy: 67.111   Val Loss: 0.5500   Val Accuracy: 83.182   Duration: 14.26s   Avg Duration: 14.56s
# Epoch: [66/200]   Train Loss: 0.9133   Train Accuracy: 66.490   Val Loss: 0.4660   Val Accuracy: 84.290   Duration: 14.15s   Avg Duration: 14.55s
# Epoch: [67/200]   Train Loss: 0.9248   Train Accuracy: 66.782   Val Loss: 0.4936   Val Accuracy: 83.887   Duration: 14.25s   Avg Duration: 14.54s
# Epoch: [68/200]   Train Loss: 0.9289   Train Accuracy: 66.600   Val Loss: 0.4272   Val Accuracy: 86.506   Duration: 14.21s   Avg Duration: 14.54s
# Epoch: [69/200]   Train Loss: 0.8886   Train Accuracy: 67.658   Val Loss: 0.4502   Val Accuracy: 85.498   Duration: 14.22s   Avg Duration: 14.54s
# Epoch: [70/200]   Train Loss: 0.8882   Train Accuracy: 68.315   Val Loss: 0.4980   Val Accuracy: 83.988   Duration: 14.26s   Avg Duration: 14.53s
# Epoch: [71/200]   Train Loss: 0.8831   Train Accuracy: 68.954   Val Loss: 0.4603   Val Accuracy: 86.203   Duration: 13.13s   Avg Duration: 14.51s
# Epoch: [72/200]   Train Loss: 0.8462   Train Accuracy: 69.812   Val Loss: 0.4794   Val Accuracy: 85.398   Duration: 13.01s   Avg Duration: 14.49s
# Epoch: [73/200]   Train Loss: 0.8378   Train Accuracy: 69.922   Val Loss: 0.4817   Val Accuracy: 84.995   Duration: 13.04s   Avg Duration: 14.47s
# Epoch: [74/200]   Train Loss: 0.8178   Train Accuracy: 70.323   Val Loss: 0.4322   Val Accuracy: 86.707   Duration: 13.05s   Avg Duration: 14.45s
# Epoch: [75/200]   Train Loss: 0.8291   Train Accuracy: 70.706   Val Loss: 0.4202   Val Accuracy: 87.915   Duration: 13.01s   Avg Duration: 14.43s
# Epoch: [76/200]   Train Loss: 0.8217   Train Accuracy: 70.962   Val Loss: 0.4172   Val Accuracy: 86.103   Duration: 13.09s   Avg Duration: 14.41s
# Epoch: [77/200]   Train Loss: 0.8176   Train Accuracy: 70.177   Val Loss: 0.4452   Val Accuracy: 86.908   Duration: 13.09s   Avg Duration: 14.40s
# Epoch: [78/200]   Train Loss: 0.8077   Train Accuracy: 71.053   Val Loss: 0.4261   Val Accuracy: 85.297   Duration: 13.05s   Avg Duration: 14.38s
# Epoch: [79/200]   Train Loss: 0.7867   Train Accuracy: 71.655   Val Loss: 0.4884   Val Accuracy: 85.297   Duration: 13.13s   Avg Duration: 14.36s
# Epoch: [80/200]   Train Loss: 0.7772   Train Accuracy: 72.093   Val Loss: 0.4103   Val Accuracy: 86.405   Duration: 13.05s   Avg Duration: 14.35s
# Epoch: [81/200]   Train Loss: 0.7345   Train Accuracy: 74.466   Val Loss: 0.4476   Val Accuracy: 86.103   Duration: 13.08s   Avg Duration: 14.33s
# Epoch: [82/200]   Train Loss: 0.7603   Train Accuracy: 72.751   Val Loss: 0.4126   Val Accuracy: 87.009   Duration: 13.09s   Avg Duration: 14.32s
# Epoch: [83/200]   Train Loss: 0.7399   Train Accuracy: 73.700   Val Loss: 0.4702   Val Accuracy: 84.794   Duration: 13.17s   Avg Duration: 14.30s
# Epoch: [84/200]   Train Loss: 0.7657   Train Accuracy: 71.966   Val Loss: 0.5152   Val Accuracy: 85.599   Duration: 13.06s   Avg Duration: 14.29s
# Epoch: [85/200]   Train Loss: 0.7328   Train Accuracy: 74.119   Val Loss: 0.4826   Val Accuracy: 85.901   Duration: 13.05s   Avg Duration: 14.27s
# Epoch: [86/200]   Train Loss: 0.7217   Train Accuracy: 74.904   Val Loss: 0.4747   Val Accuracy: 85.901   Duration: 13.12s   Avg Duration: 14.26s
# Epoch: [87/200]   Train Loss: 0.6993   Train Accuracy: 74.813   Val Loss: 0.4531   Val Accuracy: 86.506   Duration: 13.04s   Avg Duration: 14.25s
# Epoch: [88/200]   Train Loss: 0.7101   Train Accuracy: 74.448   Val Loss: 0.5361   Val Accuracy: 84.794   Duration: 13.04s   Avg Duration: 14.23s
# Epoch: [89/200]   Train Loss: 0.6950   Train Accuracy: 75.014   Val Loss: 0.4289   Val Accuracy: 86.506   Duration: 13.03s   Avg Duration: 14.22s
# Epoch: [90/200]   Train Loss: 0.6856   Train Accuracy: 75.251   Val Loss: 0.4987   Val Accuracy: 84.894   Duration: 13.16s   Avg Duration: 14.21s
# Epoch: [91/200]   Train Loss: 0.6853   Train Accuracy: 75.872   Val Loss: 0.4668   Val Accuracy: 86.405   Duration: 13.04s   Avg Duration: 14.19s
# Epoch: [92/200]   Train Loss: 0.6509   Train Accuracy: 76.912   Val Loss: 0.4717   Val Accuracy: 86.707   Duration: 13.10s   Avg Duration: 14.18s
# Epoch: [93/200]   Train Loss: 0.6467   Train Accuracy: 77.149   Val Loss: 0.4852   Val Accuracy: 87.412   Duration: 13.29s   Avg Duration: 14.17s
# Epoch: [94/200]   Train Loss: 0.6583   Train Accuracy: 76.164   Val Loss: 0.5149   Val Accuracy: 84.290   Duration: 13.10s   Avg Duration: 14.16s
# Epoch: [95/200]   Train Loss: 0.6355   Train Accuracy: 77.350   Val Loss: 0.4931   Val Accuracy: 86.203   Duration: 13.13s   Avg Duration: 14.15s
# Epoch: [96/200]   Train Loss: 0.6500   Train Accuracy: 76.565   Val Loss: 0.4363   Val Accuracy: 87.110   Duration: 13.06s   Avg Duration: 14.14s
# Epoch: [97/200]   Train Loss: 0.6181   Train Accuracy: 77.295   Val Loss: 0.5017   Val Accuracy: 85.297   Duration: 13.07s   Avg Duration: 14.13s
# Epoch: [98/200]   Train Loss: 0.6106   Train Accuracy: 78.098   Val Loss: 0.4944   Val Accuracy: 86.103   Duration: 13.08s   Avg Duration: 14.12s
# Epoch: [99/200]   Train Loss: 0.5885   Train Accuracy: 79.230   Val Loss: 0.4765   Val Accuracy: 86.908   Duration: 13.07s   Avg Duration: 14.11s
# Epoch: [100/200]   Train Loss: 0.5879   Train Accuracy: 79.157   Val Loss: 0.5234   Val Accuracy: 86.405   Duration: 13.01s   Avg Duration: 14.10s
# Epoch: [101/200]   Train Loss: 0.6097   Train Accuracy: 78.481   Val Loss: 0.5391   Val Accuracy: 85.196   Duration: 13.16s   Avg Duration: 14.09s
# Epoch: [102/200]   Train Loss: 0.5692   Train Accuracy: 79.212   Val Loss: 0.4382   Val Accuracy: 87.613   Duration: 13.16s   Avg Duration: 14.08s
# Epoch: [103/200]   Train Loss: 0.5732   Train Accuracy: 79.029   Val Loss: 0.6291   Val Accuracy: 84.189   Duration: 13.06s   Avg Duration: 14.07s
# Epoch: [104/200]   Train Loss: 0.5617   Train Accuracy: 79.832   Val Loss: 0.4727   Val Accuracy: 87.412   Duration: 13.06s   Avg Duration: 14.06s
# Epoch: [105/200]   Train Loss: 0.5346   Train Accuracy: 80.872   Val Loss: 0.4961   Val Accuracy: 87.412   Duration: 13.02s   Avg Duration: 14.05s
# Epoch: [106/200]   Train Loss: 0.5452   Train Accuracy: 80.690   Val Loss: 0.4883   Val Accuracy: 87.714   Duration: 13.06s   Avg Duration: 14.04s
# Epoch: [107/200]   Train Loss: 0.5235   Train Accuracy: 81.164   Val Loss: 0.5171   Val Accuracy: 84.693   Duration: 13.03s   Avg Duration: 14.03s
# Epoch: [108/200]   Train Loss: 0.4958   Train Accuracy: 82.643   Val Loss: 0.5213   Val Accuracy: 86.405   Duration: 13.01s   Avg Duration: 14.02s
# Epoch: [109/200]   Train Loss: 0.5266   Train Accuracy: 81.329   Val Loss: 0.5344   Val Accuracy: 85.196   Duration: 13.04s   Avg Duration: 14.01s
# Epoch: [110/200]   Train Loss: 0.5105   Train Accuracy: 81.785   Val Loss: 0.5646   Val Accuracy: 85.196   Duration: 13.48s   Avg Duration: 14.01s
# Epoch: [111/200]   Train Loss: 0.5038   Train Accuracy: 81.822   Val Loss: 0.5574   Val Accuracy: 85.398   Duration: 14.21s   Avg Duration: 14.01s
# Epoch: [112/200]   Train Loss: 0.5014   Train Accuracy: 82.205   Val Loss: 0.4805   Val Accuracy: 87.613   Duration: 14.16s   Avg Duration: 14.01s
# Epoch: [113/200]   Train Loss: 0.4768   Train Accuracy: 82.880   Val Loss: 0.5511   Val Accuracy: 85.700   Duration: 14.24s   Avg Duration: 14.01s
# Epoch: [114/200]   Train Loss: 0.4736   Train Accuracy: 83.245   Val Loss: 0.5938   Val Accuracy: 85.498   Duration: 14.21s   Avg Duration: 14.01s
# Epoch: [115/200]   Train Loss: 0.4770   Train Accuracy: 82.369   Val Loss: 0.6225   Val Accuracy: 84.089   Duration: 14.39s   Avg Duration: 14.02s
# Epoch: [116/200]   Train Loss: 0.4703   Train Accuracy: 83.263   Val Loss: 0.5073   Val Accuracy: 87.412   Duration: 14.23s   Avg Duration: 14.02s
# Epoch: [117/200]   Train Loss: 0.4691   Train Accuracy: 83.537   Val Loss: 0.5618   Val Accuracy: 86.103   Duration: 14.24s   Avg Duration: 14.02s
# Epoch: [118/200]   Train Loss: 0.4508   Train Accuracy: 83.920   Val Loss: 0.5655   Val Accuracy: 86.606   Duration: 14.21s   Avg Duration: 14.02s
# Epoch: [119/200]   Train Loss: 0.4605   Train Accuracy: 83.263   Val Loss: 0.5186   Val Accuracy: 86.405   Duration: 14.22s   Avg Duration: 14.02s
# Epoch: [120/200]   Train Loss: 0.4510   Train Accuracy: 84.267   Val Loss: 0.5139   Val Accuracy: 87.311   Duration: 14.26s   Avg Duration: 14.03s
# Epoch: [121/200]   Train Loss: 0.4150   Train Accuracy: 85.381   Val Loss: 0.5396   Val Accuracy: 86.304   Duration: 14.43s   Avg Duration: 14.03s
# Epoch: [122/200]   Train Loss: 0.3929   Train Accuracy: 86.257   Val Loss: 0.5954   Val Accuracy: 87.815   Duration: 14.16s   Avg Duration: 14.03s
# Epoch: [123/200]   Train Loss: 0.3880   Train Accuracy: 86.603   Val Loss: 0.5670   Val Accuracy: 86.707   Duration: 14.47s   Avg Duration: 14.03s
# Epoch: [124/200]   Train Loss: 0.4083   Train Accuracy: 85.800   Val Loss: 0.5382   Val Accuracy: 86.506   Duration: 14.18s   Avg Duration: 14.04s
# Epoch: [125/200]   Train Loss: 0.3926   Train Accuracy: 86.001   Val Loss: 0.5995   Val Accuracy: 86.203   Duration: 14.15s   Avg Duration: 14.04s
# Epoch: [126/200]   Train Loss: 0.3743   Train Accuracy: 86.950   Val Loss: 0.5616   Val Accuracy: 86.203   Duration: 14.15s   Avg Duration: 14.04s
# Epoch: [127/200]   Train Loss: 0.3704   Train Accuracy: 86.676   Val Loss: 0.6054   Val Accuracy: 86.304   Duration: 14.24s   Avg Duration: 14.04s
# Epoch: [128/200]   Train Loss: 0.3700   Train Accuracy: 87.005   Val Loss: 0.5769   Val Accuracy: 86.103   Duration: 14.20s   Avg Duration: 14.04s
# Epoch: [129/200]   Train Loss: 0.3653   Train Accuracy: 86.932   Val Loss: 0.5420   Val Accuracy: 85.297   Duration: 14.15s   Avg Duration: 14.04s
# Epoch: [130/200]   Train Loss: 0.3871   Train Accuracy: 86.676   Val Loss: 0.6447   Val Accuracy: 83.484   Duration: 14.20s   Avg Duration: 14.04s
# Epoch: [131/200]   Train Loss: 0.3736   Train Accuracy: 86.822   Val Loss: 0.6078   Val Accuracy: 86.002   Duration: 14.16s   Avg Duration: 14.04s
# Epoch: [132/200]   Train Loss: 0.4095   Train Accuracy: 85.016   Val Loss: 0.5570   Val Accuracy: 85.901   Duration: 14.26s   Avg Duration: 14.04s
# Epoch: [133/200]   Train Loss: 0.3821   Train Accuracy: 86.421   Val Loss: 0.6713   Val Accuracy: 82.377   Duration: 14.24s   Avg Duration: 14.05s
# Epoch: [134/200]   Train Loss: 0.3384   Train Accuracy: 88.100   Val Loss: 0.6352   Val Accuracy: 85.801   Duration: 14.19s   Avg Duration: 14.05s
# Epoch: [135/200]   Train Loss: 0.3257   Train Accuracy: 88.648   Val Loss: 0.5831   Val Accuracy: 86.506   Duration: 14.18s   Avg Duration: 14.05s
# Epoch: [136/200]   Train Loss: 0.3239   Train Accuracy: 88.885   Val Loss: 0.5816   Val Accuracy: 85.801   Duration: 14.32s   Avg Duration: 14.05s
# Epoch: [137/200]   Train Loss: 0.3356   Train Accuracy: 88.027   Val Loss: 0.5602   Val Accuracy: 85.901   Duration: 14.45s   Avg Duration: 14.05s
# Epoch: [138/200]   Train Loss: 0.3476   Train Accuracy: 87.297   Val Loss: 0.5999   Val Accuracy: 86.304   Duration: 14.25s   Avg Duration: 14.05s
# Epoch: [139/200]   Train Loss: 0.3542   Train Accuracy: 87.479   Val Loss: 0.6509   Val Accuracy: 83.887   Duration: 14.19s   Avg Duration: 14.06s
# Epoch: [140/200]   Train Loss: 0.3113   Train Accuracy: 88.921   Val Loss: 0.7085   Val Accuracy: 83.787   Duration: 14.26s   Avg Duration: 14.06s
# Epoch: [141/200]   Train Loss: 0.3355   Train Accuracy: 88.210   Val Loss: 0.5885   Val Accuracy: 85.901   Duration: 14.20s   Avg Duration: 14.06s
# Epoch: [142/200]   Train Loss: 0.3246   Train Accuracy: 88.629   Val Loss: 0.5471   Val Accuracy: 85.801   Duration: 14.22s   Avg Duration: 14.06s
# Epoch: [143/200]   Train Loss: 0.2968   Train Accuracy: 89.122   Val Loss: 0.6214   Val Accuracy: 86.405   Duration: 14.23s   Avg Duration: 14.06s
# Epoch: [144/200]   Train Loss: 0.2813   Train Accuracy: 89.889   Val Loss: 0.5093   Val Accuracy: 88.016   Duration: 14.45s   Avg Duration: 14.06s
# Epoch: [145/200]   Train Loss: 0.2801   Train Accuracy: 90.126   Val Loss: 0.5921   Val Accuracy: 85.096   Duration: 14.35s   Avg Duration: 14.06s
# Epoch: [146/200]   Train Loss: 0.2820   Train Accuracy: 90.016   Val Loss: 0.5933   Val Accuracy: 85.801   Duration: 14.35s   Avg Duration: 14.07s
# Epoch: [147/200]   Train Loss: 0.2755   Train Accuracy: 90.728   Val Loss: 0.5913   Val Accuracy: 86.405   Duration: 14.22s   Avg Duration: 14.07s
# Epoch: [148/200]   Train Loss: 0.2698   Train Accuracy: 90.856   Val Loss: 0.6281   Val Accuracy: 86.103   Duration: 14.48s   Avg Duration: 14.07s
# Epoch: [149/200]   Train Loss: 0.2504   Train Accuracy: 91.842   Val Loss: 0.6452   Val Accuracy: 86.506   Duration: 14.26s   Avg Duration: 14.07s
# Epoch: [150/200]   Train Loss: 0.2374   Train Accuracy: 91.422   Val Loss: 0.6185   Val Accuracy: 87.009   Duration: 14.29s   Avg Duration: 14.07s
# Epoch: [151/200]   Train Loss: 0.2568   Train Accuracy: 91.239   Val Loss: 0.6611   Val Accuracy: 86.606   Duration: 14.31s   Avg Duration: 14.07s
# Epoch: [152/200]   Train Loss: 0.3099   Train Accuracy: 89.396   Val Loss: 0.6181   Val Accuracy: 85.599   Duration: 14.22s   Avg Duration: 14.08s
# Epoch: [153/200]   Train Loss: 0.2955   Train Accuracy: 89.359   Val Loss: 0.6601   Val Accuracy: 86.103   Duration: 14.20s   Avg Duration: 14.08s
# Epoch: [154/200]   Train Loss: 0.2690   Train Accuracy: 90.929   Val Loss: 0.6161   Val Accuracy: 87.210   Duration: 14.20s   Avg Duration: 14.08s
# Epoch: [155/200]   Train Loss: 0.2466   Train Accuracy: 91.988   Val Loss: 0.6164   Val Accuracy: 86.707   Duration: 14.20s   Avg Duration: 14.08s
# Epoch: [156/200]   Train Loss: 0.2573   Train Accuracy: 91.130   Val Loss: 0.6623   Val Accuracy: 86.203   Duration: 14.27s   Avg Duration: 14.08s
# Epoch: [157/200]   Train Loss: 0.2540   Train Accuracy: 91.203   Val Loss: 0.6966   Val Accuracy: 84.995   Duration: 14.23s   Avg Duration: 14.08s
# Epoch: [158/200]   Train Loss: 0.2733   Train Accuracy: 89.943   Val Loss: 0.5762   Val Accuracy: 86.405   Duration: 14.37s   Avg Duration: 14.08s
# Epoch: [159/200]   Train Loss: 0.2166   Train Accuracy: 92.444   Val Loss: 0.6202   Val Accuracy: 86.304   Duration: 14.23s   Avg Duration: 14.08s
# Epoch: [160/200]   Train Loss: 0.2380   Train Accuracy: 91.531   Val Loss: 0.6763   Val Accuracy: 84.894   Duration: 14.30s   Avg Duration: 14.08s
# Epoch: [161/200]   Train Loss: 0.2457   Train Accuracy: 91.513   Val Loss: 0.6492   Val Accuracy: 86.002   Duration: 14.33s   Avg Duration: 14.09s
# Epoch: [162/200]   Train Loss: 0.2304   Train Accuracy: 91.969   Val Loss: 0.6662   Val Accuracy: 86.606   Duration: 14.27s   Avg Duration: 14.09s
# Epoch: [163/200]   Train Loss: 0.2104   Train Accuracy: 92.718   Val Loss: 0.7050   Val Accuracy: 86.002   Duration: 14.28s   Avg Duration: 14.09s
# Epoch: [164/200]   Train Loss: 0.2182   Train Accuracy: 92.480   Val Loss: 0.7692   Val Accuracy: 83.686   Duration: 14.34s   Avg Duration: 14.09s
# Epoch: [165/200]   Train Loss: 0.2179   Train Accuracy: 92.572   Val Loss: 0.5931   Val Accuracy: 87.009   Duration: 14.45s   Avg Duration: 14.09s
# Epoch: [166/200]   Train Loss: 0.2599   Train Accuracy: 91.221   Val Loss: 0.7059   Val Accuracy: 86.304   Duration: 14.24s   Avg Duration: 14.09s
# Epoch: [167/200]   Train Loss: 0.2285   Train Accuracy: 91.933   Val Loss: 0.6159   Val Accuracy: 87.110   Duration: 14.27s   Avg Duration: 14.09s
# Epoch: [168/200]   Train Loss: 0.2078   Train Accuracy: 92.590   Val Loss: 0.7279   Val Accuracy: 85.196   Duration: 14.27s   Avg Duration: 14.09s
# Epoch: [169/200]   Train Loss: 0.2100   Train Accuracy: 92.955   Val Loss: 0.6987   Val Accuracy: 84.894   Duration: 14.38s   Avg Duration: 14.10s
# Epoch: [170/200]   Train Loss: 0.1979   Train Accuracy: 93.101   Val Loss: 0.6827   Val Accuracy: 86.606   Duration: 14.25s   Avg Duration: 14.10s
# Epoch: [171/200]   Train Loss: 0.1919   Train Accuracy: 93.448   Val Loss: 0.7021   Val Accuracy: 87.009   Duration: 14.25s   Avg Duration: 14.10s
# Epoch: [172/200]   Train Loss: 0.1886   Train Accuracy: 93.338   Val Loss: 0.7364   Val Accuracy: 86.203   Duration: 14.29s   Avg Duration: 14.10s
# Epoch: [173/200]   Train Loss: 0.2007   Train Accuracy: 92.918   Val Loss: 0.7180   Val Accuracy: 85.901   Duration: 14.66s   Avg Duration: 14.10s
# Epoch: [174/200]   Train Loss: 0.2028   Train Accuracy: 93.174   Val Loss: 0.6708   Val Accuracy: 86.606   Duration: 14.34s   Avg Duration: 14.10s
# Epoch: [175/200]   Train Loss: 0.1905   Train Accuracy: 93.648   Val Loss: 0.7478   Val Accuracy: 85.801   Duration: 14.22s   Avg Duration: 14.10s
# Epoch: [176/200]   Train Loss: 0.1948   Train Accuracy: 92.973   Val Loss: 0.6697   Val Accuracy: 86.203   Duration: 14.32s   Avg Duration: 14.11s
# Epoch: [177/200]   Train Loss: 0.2156   Train Accuracy: 92.626   Val Loss: 0.7572   Val Accuracy: 86.606   Duration: 14.31s   Avg Duration: 14.11s
# Epoch: [178/200]   Train Loss: 0.2220   Train Accuracy: 92.444   Val Loss: 0.6901   Val Accuracy: 86.808   Duration: 14.23s   Avg Duration: 14.11s
# Epoch: [179/200]   Train Loss: 0.2083   Train Accuracy: 92.772   Val Loss: 0.7463   Val Accuracy: 85.901   Duration: 14.63s   Avg Duration: 14.11s
# Epoch: [180/200]   Train Loss: 0.2163   Train Accuracy: 92.170   Val Loss: 0.8075   Val Accuracy: 84.189   Duration: 14.25s   Avg Duration: 14.11s
# Epoch: [181/200]   Train Loss: 0.2001   Train Accuracy: 92.772   Val Loss: 0.6749   Val Accuracy: 86.908   Duration: 14.17s   Avg Duration: 14.11s
# Epoch: [182/200]   Train Loss: 0.1757   Train Accuracy: 94.160   Val Loss: 0.6504   Val Accuracy: 86.606   Duration: 14.22s   Avg Duration: 14.11s
# Epoch: [183/200]   Train Loss: 0.1543   Train Accuracy: 94.762   Val Loss: 0.6722   Val Accuracy: 86.707   Duration: 14.27s   Avg Duration: 14.11s
# Epoch: [184/200]   Train Loss: 0.1819   Train Accuracy: 93.539   Val Loss: 0.7633   Val Accuracy: 85.196   Duration: 14.24s   Avg Duration: 14.11s
# Epoch: [185/200]   Train Loss: 0.1826   Train Accuracy: 93.685   Val Loss: 0.6902   Val Accuracy: 86.808   Duration: 14.27s   Avg Duration: 14.11s
# Epoch: [186/200]   Train Loss: 0.1788   Train Accuracy: 93.594   Val Loss: 0.8413   Val Accuracy: 84.693   Duration: 14.29s   Avg Duration: 14.12s
# Epoch: [187/200]   Train Loss: 0.2077   Train Accuracy: 92.736   Val Loss: 0.6911   Val Accuracy: 84.290   Duration: 14.28s   Avg Duration: 14.12s
# Epoch: [188/200]   Train Loss: 0.2150   Train Accuracy: 92.608   Val Loss: 0.8205   Val Accuracy: 84.391   Duration: 14.20s   Avg Duration: 14.12s
# Epoch: [189/200]   Train Loss: 0.1970   Train Accuracy: 93.119   Val Loss: 0.7908   Val Accuracy: 85.196   Duration: 14.21s   Avg Duration: 14.12s
# Epoch: [190/200]   Train Loss: 0.2006   Train Accuracy: 92.937   Val Loss: 0.7506   Val Accuracy: 83.686   Duration: 14.26s   Avg Duration: 14.12s
# Epoch: [191/200]   Train Loss: 0.2210   Train Accuracy: 92.042   Val Loss: 0.6648   Val Accuracy: 85.901   Duration: 14.23s   Avg Duration: 14.12s
# Epoch: [192/200]   Train Loss: 0.1852   Train Accuracy: 93.210   Val Loss: 0.6562   Val Accuracy: 87.311   Duration: 14.23s   Avg Duration: 14.12s
# Epoch: [193/200]   Train Loss: 0.1591   Train Accuracy: 94.817   Val Loss: 0.6905   Val Accuracy: 87.110   Duration: 14.19s   Avg Duration: 14.12s
# Epoch: [194/200]   Train Loss: 0.1588   Train Accuracy: 94.397   Val Loss: 0.7416   Val Accuracy: 87.009   Duration: 13.46s   Avg Duration: 14.12s
# Epoch: [195/200]   Train Loss: 0.1635   Train Accuracy: 94.214   Val Loss: 0.7040   Val Accuracy: 85.901   Duration: 13.08s   Avg Duration: 14.11s
# Epoch: [196/200]   Train Loss: 0.1461   Train Accuracy: 94.744   Val Loss: 0.7335   Val Accuracy: 85.196   Duration: 13.07s   Avg Duration: 14.11s
# Epoch: [197/200]   Train Loss: 0.1394   Train Accuracy: 95.255   Val Loss: 0.6235   Val Accuracy: 87.613   Duration: 13.12s   Avg Duration: 14.10s
# Epoch: [198/200]   Train Loss: 0.1431   Train Accuracy: 95.218   Val Loss: 0.7162   Val Accuracy: 86.808   Duration: 13.04s   Avg Duration: 14.10s
# Epoch: [199/200]   Train Loss: 0.1403   Train Accuracy: 95.218   Val Loss: 0.7184   Val Accuracy: 86.405   Duration: 13.12s   Avg Duration: 14.09s
# Epoch: [200/200]   Train Loss: 0.1545   Train Accuracy: 95.036   Val Loss: 0.6418   Val Accuracy: 87.915   Duration: 13.07s   Avg Duration: 14.09s

# %%
dataiter = iter(Dtr)
val_dataiter = iter(Dva)
test_dataiter = iter(Dte)
images, labels = val_dataiter.next()
out_img, predicted = torch.max(model(images.to(device))[0], 1)
img_vis(images[:7], labels[:7], predicted[:7])

# %%
# Plot the train loss and test loss per iteration
plt.figure(figsize=(12, 6))
plt.plot(train_losses, label='train loss')
plt.plot(val_losses, label='val loss')
plt.title('Training vs Validation Cross-Entropy Loss')
plt.xlabel('Epochs')
plt.ylabel('Average Loss')
plt.legend()
plt.show()

# %%
test_loss = []
test_acc = []
n_correct = 0.
n_total = 0.
confusion_matrix = np.zeros((n_class, n_class))
raw_train = []
true_train = []
raw_val = []
true_val = []
raw_test = []
true_test = []

model.eval()
with torch.no_grad():
    for inputs, targets in Dtr:
        inputs, targets = inputs.to(device), targets.to(device)
        raw_train.append(model(inputs)[1].to('cpu')) # List of 129 x 12 matrices
        true_train.append(targets.to('cpu'))

    for inputs, targets in Dva:
        inputs, targets = inputs.to(device), targets.to(device)
        raw_val.append(model(inputs)[1].to('cpu')) # List of 129 x 12 matrices
        true_val.append(targets.to('cpu'))

    for inputs, targets in Dte:
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = model(inputs)[0]
        raw_test.append(model(inputs)[1].to('cpu')) # List of 129 x 12 matrices
        true_test.append(targets.to('cpu'))
        # Get the predictions
        # torch.max returns both max and argmax
        __, out_label = outputs.max(dim=1)
        # Updates the accuracy with every pass
        n_correct += (out_label == targets).sum().item()
        n_total += targets.shape[0]
        for t, p in zip(targets.view(-1), out_label.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1
        test_acc.append(n_correct / n_total)

        loss = loss_fn(outputs, targets)
        test_loss.append(loss.item())

x_tr = np.array(raw_train[0])
for i in range(1,len(raw_train)):
        x_tr = np.concatenate((x_tr, raw_train[i]), axis=0)
y_tr = np.array(true_train[0])
for i in range(1,len(true_train)):
        y_tr = np.concatenate((y_tr, true_train[i]), axis=0)

x_va = np.array(raw_val[0])
for i in range(1,len(raw_val)):
        x_va = np.concatenate((x_va, raw_val[i]), axis=0)
y_va = np.array(true_val[0])
for i in range(1,len(true_val)):
        y_va = np.concatenate((y_va, true_val[i]), axis=0)

x_te = np.array(raw_test[0])
for i in range(1,len(raw_test)):
        x_te = np.concatenate((x_te, raw_test[i]), axis=0)
y_te = np.array(true_test[0])
for i in range(1,len(true_test)):
        y_te = np.concatenate((y_te, true_test[i]), axis=0)

test_loss = np.mean(test_loss)
avg_acc = np.mean(test_acc)*100
print('The total number of samples for Training is: {}, Validation: {}, and Testing: {}'.format(len(Dtr)*batch_size, len(Dva)*batch_size, len(Dte)*batch_size))
print('Average loss across the testing data: {:.4f}, Average testing accuracy: {:.3f}'.format(test_loss, avg_acc))
# Out:
# The total number of samples for Training is: 5568, Validation: 1152, and Testing: 1152
# Average loss across the testing data: 0.6501, Average testing accuracy: 86.244

# %%
plt.figure(figsize=(15,10))

class_names = list(classes)
cm_df = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(cm_df, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

for i in cm_df:
    TP = cm_df[i][i]
    TN = 0
    for j in cm_df:
        TN += cm_df[j][j]
    TN = TN - TP
    FP = (cm_df.sum(axis=0)[i]) - TP
    FN = (cm_df.sum(axis=1)[i]) - TP
    sens = TP / (FN + TP)
    spec = TN / (TN + FP)
    prec = TP / (TP + FP)
    print('Analysis of class {}:'.format(i))
    print('Sensitivity:    {:.4f}, Specificity:  {:.4f}, Precision: {:.4f}\n'.format(sens, spec, prec))
# Out:
# Analysis of class Superficial-Intermediate:
# Sensitivity:    0.9470, Specificity:  0.9905, Precision: 0.9533
#
# Analysis of class Parabasal:
# Sensitivity:    0.9879, Specificity:  0.9944, Precision: 0.9760
#
# Analysis of class Koilocytotic:
# Sensitivity:    0.8810, Specificity:  0.9810, Precision: 0.9136
#
# Analysis of class Dyskeratotic:
# Sensitivity:    0.9636, Specificity:  0.9875, Precision: 0.9464
#
# Analysis of class Metaplastic:
# Sensitivity:    0.8947, Specificity:  0.9768, Precision: 0.9000
#
# Analysis of class Superficial-Squamous-Epithelial:
# Sensitivity:    0.8000, Specificity:  0.9988, Precision: 0.9231
#
# Analysis of class Intermediate-Squamous-Epithelial:
# Sensitivity:    0.6364, Specificity:  0.9988, Precision: 0.8750
#
# Analysis of class Columnar-Epithelial:
# Sensitivity:    0.5000, Specificity:  0.9851, Precision: 0.4348
#
# Analysis of class Mild-Squamous-Non-Keratinizing-Dysplasia:
# Sensitivity:    0.6286, Specificity:  0.9872, Precision: 0.6667
#
# Analysis of class Moderate-Squamous-Non-Keratinizing-Dysplasia:
# Sensitivity:    0.3333, Specificity:  0.9874, Precision: 0.4500
#
# Analysis of class Severe-Squamous-Non-Keratinizing-Dysplasia:
# Sensitivity:    0.6316, Specificity:  0.9669, Precision: 0.4528
#
# Analysis of class Squamous-Cell-Carcinoma-in-situ-Intermediate:
# Sensitivity:    0.7143, Specificity:  0.9918, Precision: 0.7407

# %% [markdown]
# If the CCT was trained on 12 classes, this changes the classification back to 3

# %%
if n_class == 12:
    generalize = {0:1, 1:1, 2:2, 3:2, 4:0, 5:1, 6:1, 7:1, 8:2, 9:2, 10:2, 11:2}
    y_tr = pd.DataFrame(y_tr, columns=['y'])
    y_tr['y'] = y_tr['y'].map(generalize).to_numpy()
    y_va = pd.DataFrame(y_va, columns=['y'])
    y_va['y'] = y_va['y'].map(generalize).to_numpy()
    y_te = pd.DataFrame(y_te, columns=['y'])
    y_te['y'] = y_te['y'].map(generalize).to_numpy()
    y_tr = y_tr['y'].to_numpy()
    y_va = y_va['y'].to_numpy()
    y_te = y_te['y'].to_numpy()

# %%
def conf_mat(y_te,y_pred):
    plt.figure(figsize=(15,10))

    confusion_matrix = np.zeros((3, 3))
    for i in range(len(y_pred)):
        confusion_matrix[y_te[i]][y_pred[i]] += 1

    three_class = ['Benign', 'Normal', 'Abnormal']
    cm_df = pd.DataFrame(confusion_matrix, index=three_class, columns=three_class).astype(int)
    heatmap = sns.heatmap(cm_df, annot=True, fmt="d")

    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

    for i in cm_df:
        TP = cm_df[i][i]
        TN = 0
        for j in cm_df:
            TN += cm_df[j][j]
        TN = TN - TP
        FP = (cm_df.sum(axis=0)[i]) - TP
        FN = (cm_df.sum(axis=1)[i]) - TP
        sens = TP / (FN + TP)
        spec = TN / (TN + FP)
        prec = TP / (TP + FP)
        print('Analysis of class {}:'.format(i))
        print('Sensitivity:    {:.4f}, Specificity:  {:.4f}, Precision: {:.4f}\n'.format(sens, spec, prec))
        
    return accuracy_score(y_pred,y_te)

# %% [markdown]
# ## Support Vector Classification

# %%
clf = svm.SVC()
clf.fit(x_tr, y_tr)
y_pred = clf.predict(x_te)
acc = conf_mat(y_te,y_pred)

print('The SVM was {:.3f}% accurate.'.format(acc*100))
# Out:
# Analysis of class Benign:
# Sensitivity:    0.8713, Specificity:  0.9823, Precision: 0.9141
#
# Analysis of class Normal:
# Sensitivity:    0.9420, Specificity:  0.9637, Precision: 0.9394
#
# Analysis of class Abnormal:
# Sensitivity:    0.9436, Specificity:  0.9369, Precision: 0.9295
#
# The SVM was 93.058% accurate.

# %% [markdown]
# ## Random Forest Classification

# %%
clf = RandomForestClassifier(random_state=SEED)
clf.fit(x_tr, y_tr)
y_pred = clf.predict(x_te)
acc = conf_mat(y_te,y_pred)

print('The RFC was {:.3f}% accurate.'.format(acc*100))
# Out:
# Analysis of class Benign:
# Sensitivity:    0.7895, Specificity:  0.9810, Precision: 0.9000
#
# Analysis of class Normal:
# Sensitivity:    0.9254, Specificity:  0.9664, Precision: 0.9437
#
# Analysis of class Abnormal:
# Sensitivity:    0.9544, Specificity:  0.9056, Precision: 0.8998
#
# The RFC was 91.549% accurate.

# %% [markdown]
# ## Gaussian Process Classification

# %% [markdown]
# ### RBF

# %%
kernel = 1.0 * RBF(1.0)
gpc = GaussianProcessClassifier(kernel=kernel,random_state=SEED, n_jobs=-1)
gpc.fit(x_tr, y_tr)
y_pred = gpc.predict(x_te)
acc = conf_mat(y_te,y_pred)

print('The GPC with RBF kernel was {:.3f}% accurate.'.format(acc*100))
# Out:
# Analysis of class Benign:
# Sensitivity:    0.8538, Specificity:  0.9848, Precision: 0.9241
#
# Analysis of class Normal:
# Sensitivity:    0.9475, Specificity:  0.9652, Precision: 0.9423
#
# Analysis of class Abnormal:
# Sensitivity:    0.9479, Specificity:  0.9332, Precision: 0.9258
#
# The GPC with RBF kernel was 93.159% accurate.

# %% [markdown]
# ### Matern

# %%
kernel = 1.0 * Matern(length_scale=1.0, nu=1.5)
gpc = GaussianProcessClassifier(kernel=kernel,random_state=SEED, n_jobs=-1)
gpc.fit(x_tr, y_tr)
y_pred = gpc.predict(x_te)
acc = conf_mat(y_te,y_pred)

print('The GPC with Matern kernel was {:.3f}% accurate.'.format(acc*100))
# Out:
# Analysis of class Benign:
# Sensitivity:    0.8363, Specificity:  0.9836, Precision: 0.9167
#
# Analysis of class Normal:
# Sensitivity:    0.9420, Specificity:  0.9683, Precision: 0.9472
#
# Analysis of class Abnormal:
# Sensitivity:    0.9479, Specificity:  0.9219, Precision: 0.9142
#
# The GPC with Matern kernel was 92.656% accurate.

# %% [markdown]
# ## Simple ANN

# %%
class Simple_ANN(nn.Module):
        def __init__(self, input_dim, hidden_dim, n_class):
            super().__init__()
            self.input_dim = input_dim
            self.hidden_dim  = hidden_dim
            self.n_class  = n_class
            self.fc1 = torch.nn.Linear(self.input_dim, self.hidden_dim)
            self.relu = torch.nn.ReLU()
            self.fc2 = torch.nn.Linear(self.hidden_dim, self.n_class)
        def forward(self, x):
            x = self.fc1(x)
            x = self.relu(x)
            x = self.fc2(x)
            return x

# %%
# A function to encapsulate the training loop
def ann_batch_gd(model, loss_fn, optimizer, x_tr, y_tr, x_va, y_va, x_te, y_te, epochs):
  model.to(device)
  x_tr = torch.FloatTensor(x_tr).to(device)
  y_tr = torch.LongTensor(y_tr).to(device)
  x_va = torch.FloatTensor(x_te).to(device)
  y_va = torch.LongTensor(y_te).to(device)
  x_te = torch.FloatTensor(x_te).to(device)
  y_te = torch.LongTensor(y_te).to(device)
  train_losses = np.zeros(epochs)
  test_losses = np.zeros(epochs)
  avg_epoch = []
  
  for it in range(epochs):
    model.train()
    t0 = datetime.now()
    train_loss = []
    n_correct = 0.
    n_total = 0.

    # zero the parameter gradients
    optimizer.zero_grad()

    # Get the predictions
    y_prob = model(x_tr)

    ___, y_pred = y_prob.max(dim=1)
    
    # Updates the accuracy with every pass
    n_correct = (y_pred == y_tr).sum().item()
    n_total = len(y_tr)
    tr_acc = n_correct / n_total
    loss = loss_fn(y_prob, y_tr)
    
    # Backward and optimize
    loss.backward()
    optimizer.step()
    train_loss.append(loss.item())
    # Get train loss and test loss
    train_loss = np.mean(train_loss) # a little misleading
    
    model.eval()
    val_loss = []
    n_correct = 0.
    n_total = 0.
    # Get the predictions
    y_prob = model(x_va)
    ___, y_pred = y_prob.max(dim=1)
    # Updates the accuracy with every pass
    n_correct = (y_pred == y_va).sum().item()
    n_total = len(y_va)
    val_acc = n_correct / n_total
    loss = loss_fn(y_prob, y_va)
    val_loss.append(loss.item())
    # Get train loss and val loss
    val_loss = np.mean(val_loss) # a little misleading

    # Save losses
    train_losses[it] = train_loss
    val_losses[it] = val_loss
    
    dt = datetime.now() - t0
    avg_epoch.append(dt)

    print('Epoch: [{:d}/{:d}]   Train Loss: {:.4f}   Train Accuracy: {:.3f}   Val Loss: {:.4f}   Val Accuracy: {:.3f}   Duration: {:.2f}s   Avg Duration: {:.2f}s' \
          .format(it+1, epochs, train_loss, 100*tr_acc, val_loss, 100*val_acc, dt.total_seconds(), np.mean(avg_epoch).total_seconds()))    

  model.eval()
  test_loss = []
  n_correct = 0.
  n_total = 0.
  # Get the predictions
  y_prob = model(x_te)
  ___, y_pred = y_prob.max(dim=1)

  # Grabs the accuracy
  acc = conf_mat(y_te.to('cpu'),y_pred.to('cpu'))
  print('The Simple ANN was {:.3f}% accurate.'.format(acc*100))
  return train_losses, val_losses

# %%
input_dim = x_tr.shape[1]
hidden_dim = 258
n_class = 12

model = Simple_ANN(
        input_dim=input_dim,
        hidden_dim=hidden_dim,
        n_class=n_class     # Number of classes to classify
        )
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())

# %%
train_losses, val_losses = ann_batch_gd(model, loss_fn, optimizer, x_tr, y_tr, x_va, y_va, x_te, y_te, epochs=200)
# Out:
# Epoch: [1/200]   Train Loss: 2.6246   Train Accuracy: 1.953   Val Loss: 2.3399   Val Accuracy: 20.423   Duration: 0.07s   Avg Duration: 0.07s
# Epoch: [2/200]   Train Loss: 2.3820   Train Accuracy: 18.909   Val Loss: 2.0917   Val Accuracy: 59.859   Duration: 0.02s   Avg Duration: 0.04s
# Epoch: [3/200]   Train Loss: 2.1494   Train Accuracy: 51.688   Val Loss: 1.8553   Val Accuracy: 77.968   Duration: 0.02s   Avg Duration: 0.03s
# Epoch: [4/200]   Train Loss: 1.9278   Train Accuracy: 68.680   Val Loss: 1.6322   Val Accuracy: 84.205   Duration: 0.02s   Avg Duration: 0.03s
# Epoch: [5/200]   Train Loss: 1.7182   Train Accuracy: 74.448   Val Loss: 1.4242   Val Accuracy: 87.223   Duration: 0.01s   Avg Duration: 0.03s
# Epoch: [6/200]   Train Loss: 1.5220   Train Accuracy: 77.806   Val Loss: 1.2334   Val Accuracy: 88.833   Duration: 0.02s   Avg Duration: 0.03s
# Epoch: [7/200]   Train Loss: 1.3406   Train Accuracy: 80.380   Val Loss: 1.0616   Val Accuracy: 89.839   Duration: 0.01s   Avg Duration: 0.02s
# Epoch: [8/200]   Train Loss: 1.1756   Train Accuracy: 82.077   Val Loss: 0.9103   Val Accuracy: 90.342   Duration: 0.02s   Avg Duration: 0.02s
# Epoch: [9/200]   Train Loss: 1.0282   Train Accuracy: 83.537   Val Loss: 0.7800   Val Accuracy: 90.946   Duration: 0.01s   Avg Duration: 0.02s
# Epoch: [10/200]   Train Loss: 0.8989   Train Accuracy: 84.377   Val Loss: 0.6701   Val Accuracy: 90.845   Duration: 0.01s   Avg Duration: 0.02s
# Epoch: [11/200]   Train Loss: 0.7875   Train Accuracy: 84.815   Val Loss: 0.5795   Val Accuracy: 90.845   Duration: 0.02s   Avg Duration: 0.02s
# Epoch: [12/200]   Train Loss: 0.6931   Train Accuracy: 85.235   Val Loss: 0.5058   Val Accuracy: 90.644   Duration: 0.02s   Avg Duration: 0.02s
# Epoch: [13/200]   Train Loss: 0.6142   Train Accuracy: 85.709   Val Loss: 0.4468   Val Accuracy: 90.744   Duration: 0.02s   Avg Duration: 0.02s
# Epoch: [14/200]   Train Loss: 0.5490   Train Accuracy: 86.202   Val Loss: 0.3999   Val Accuracy: 90.845   Duration: 0.01s   Avg Duration: 0.02s
# Epoch: [15/200]   Train Loss: 0.4955   Train Accuracy: 86.786   Val Loss: 0.3629   Val Accuracy: 91.046   Duration: 0.00s   Avg Duration: 0.02s
# Epoch: [16/200]   Train Loss: 0.4516   Train Accuracy: 87.187   Val Loss: 0.3339   Val Accuracy: 90.946   Duration: 0.00s   Avg Duration: 0.02s
# Epoch: [17/200]   Train Loss: 0.4157   Train Accuracy: 87.333   Val Loss: 0.3112   Val Accuracy: 91.147   Duration: 0.00s   Avg Duration: 0.02s
# Epoch: [18/200]   Train Loss: 0.3862   Train Accuracy: 87.498   Val Loss: 0.2934   Val Accuracy: 91.348   Duration: 0.00s   Avg Duration: 0.02s
# Epoch: [19/200]   Train Loss: 0.3620   Train Accuracy: 87.936   Val Loss: 0.2795   Val Accuracy: 91.247   Duration: 0.00s   Avg Duration: 0.02s
# Epoch: [20/200]   Train Loss: 0.3419   Train Accuracy: 88.210   Val Loss: 0.2686   Val Accuracy: 91.348   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [21/200]   Train Loss: 0.3251   Train Accuracy: 88.447   Val Loss: 0.2602   Val Accuracy: 91.247   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [22/200]   Train Loss: 0.3110   Train Accuracy: 88.520   Val Loss: 0.2535   Val Accuracy: 91.549   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [23/200]   Train Loss: 0.2989   Train Accuracy: 88.885   Val Loss: 0.2483   Val Accuracy: 91.952   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [24/200]   Train Loss: 0.2885   Train Accuracy: 89.031   Val Loss: 0.2441   Val Accuracy: 91.952   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [25/200]   Train Loss: 0.2795   Train Accuracy: 89.305   Val Loss: 0.2409   Val Accuracy: 92.153   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [26/200]   Train Loss: 0.2714   Train Accuracy: 89.305   Val Loss: 0.2382   Val Accuracy: 92.153   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [27/200]   Train Loss: 0.2641   Train Accuracy: 89.542   Val Loss: 0.2361   Val Accuracy: 92.254   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [28/200]   Train Loss: 0.2575   Train Accuracy: 89.743   Val Loss: 0.2344   Val Accuracy: 92.153   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [29/200]   Train Loss: 0.2515   Train Accuracy: 89.962   Val Loss: 0.2330   Val Accuracy: 92.153   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [30/200]   Train Loss: 0.2459   Train Accuracy: 90.199   Val Loss: 0.2319   Val Accuracy: 92.153   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [31/200]   Train Loss: 0.2407   Train Accuracy: 90.272   Val Loss: 0.2310   Val Accuracy: 92.153   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [32/200]   Train Loss: 0.2358   Train Accuracy: 90.436   Val Loss: 0.2302   Val Accuracy: 92.254   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [33/200]   Train Loss: 0.2313   Train Accuracy: 90.637   Val Loss: 0.2297   Val Accuracy: 92.254   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [34/200]   Train Loss: 0.2271   Train Accuracy: 90.856   Val Loss: 0.2292   Val Accuracy: 92.153   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [35/200]   Train Loss: 0.2232   Train Accuracy: 91.075   Val Loss: 0.2289   Val Accuracy: 92.153   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [36/200]   Train Loss: 0.2195   Train Accuracy: 91.221   Val Loss: 0.2286   Val Accuracy: 92.254   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [37/200]   Train Loss: 0.2160   Train Accuracy: 91.495   Val Loss: 0.2284   Val Accuracy: 92.254   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [38/200]   Train Loss: 0.2127   Train Accuracy: 91.586   Val Loss: 0.2282   Val Accuracy: 92.254   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [39/200]   Train Loss: 0.2096   Train Accuracy: 91.714   Val Loss: 0.2281   Val Accuracy: 92.254   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [40/200]   Train Loss: 0.2066   Train Accuracy: 91.933   Val Loss: 0.2279   Val Accuracy: 92.254   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [41/200]   Train Loss: 0.2037   Train Accuracy: 92.188   Val Loss: 0.2278   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [42/200]   Train Loss: 0.2009   Train Accuracy: 92.407   Val Loss: 0.2277   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [43/200]   Train Loss: 0.1982   Train Accuracy: 92.517   Val Loss: 0.2276   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [44/200]   Train Loss: 0.1955   Train Accuracy: 92.718   Val Loss: 0.2274   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [45/200]   Train Loss: 0.1930   Train Accuracy: 92.809   Val Loss: 0.2273   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [46/200]   Train Loss: 0.1905   Train Accuracy: 92.973   Val Loss: 0.2272   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [47/200]   Train Loss: 0.1881   Train Accuracy: 93.028   Val Loss: 0.2270   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [48/200]   Train Loss: 0.1857   Train Accuracy: 93.156   Val Loss: 0.2269   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [49/200]   Train Loss: 0.1835   Train Accuracy: 93.192   Val Loss: 0.2268   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [50/200]   Train Loss: 0.1813   Train Accuracy: 93.229   Val Loss: 0.2267   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [51/200]   Train Loss: 0.1791   Train Accuracy: 93.429   Val Loss: 0.2266   Val Accuracy: 92.254   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [52/200]   Train Loss: 0.1770   Train Accuracy: 93.484   Val Loss: 0.2265   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [53/200]   Train Loss: 0.1749   Train Accuracy: 93.502   Val Loss: 0.2265   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [54/200]   Train Loss: 0.1729   Train Accuracy: 93.667   Val Loss: 0.2264   Val Accuracy: 92.354   Duration: 0.01s   Avg Duration: 0.01s
# Epoch: [55/200]   Train Loss: 0.1709   Train Accuracy: 93.703   Val Loss: 0.2264   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [56/200]   Train Loss: 0.1690   Train Accuracy: 93.813   Val Loss: 0.2264   Val Accuracy: 92.254   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [57/200]   Train Loss: 0.1671   Train Accuracy: 93.867   Val Loss: 0.2263   Val Accuracy: 92.153   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [58/200]   Train Loss: 0.1653   Train Accuracy: 93.995   Val Loss: 0.2263   Val Accuracy: 92.254   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [59/200]   Train Loss: 0.1634   Train Accuracy: 94.123   Val Loss: 0.2263   Val Accuracy: 92.254   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [60/200]   Train Loss: 0.1617   Train Accuracy: 94.251   Val Loss: 0.2263   Val Accuracy: 92.254   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [61/200]   Train Loss: 0.1599   Train Accuracy: 94.324   Val Loss: 0.2262   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [62/200]   Train Loss: 0.1582   Train Accuracy: 94.397   Val Loss: 0.2262   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [63/200]   Train Loss: 0.1565   Train Accuracy: 94.470   Val Loss: 0.2262   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [64/200]   Train Loss: 0.1548   Train Accuracy: 94.543   Val Loss: 0.2261   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [65/200]   Train Loss: 0.1531   Train Accuracy: 94.689   Val Loss: 0.2261   Val Accuracy: 92.254   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [66/200]   Train Loss: 0.1515   Train Accuracy: 94.853   Val Loss: 0.2260   Val Accuracy: 92.254   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [67/200]   Train Loss: 0.1499   Train Accuracy: 94.908   Val Loss: 0.2260   Val Accuracy: 92.254   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [68/200]   Train Loss: 0.1483   Train Accuracy: 94.963   Val Loss: 0.2259   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [69/200]   Train Loss: 0.1467   Train Accuracy: 95.036   Val Loss: 0.2259   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [70/200]   Train Loss: 0.1452   Train Accuracy: 95.090   Val Loss: 0.2258   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [71/200]   Train Loss: 0.1437   Train Accuracy: 95.163   Val Loss: 0.2258   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [72/200]   Train Loss: 0.1422   Train Accuracy: 95.182   Val Loss: 0.2257   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [73/200]   Train Loss: 0.1407   Train Accuracy: 95.255   Val Loss: 0.2257   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [74/200]   Train Loss: 0.1392   Train Accuracy: 95.309   Val Loss: 0.2257   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [75/200]   Train Loss: 0.1378   Train Accuracy: 95.419   Val Loss: 0.2257   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [76/200]   Train Loss: 0.1364   Train Accuracy: 95.401   Val Loss: 0.2257   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [77/200]   Train Loss: 0.1349   Train Accuracy: 95.419   Val Loss: 0.2257   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [78/200]   Train Loss: 0.1336   Train Accuracy: 95.455   Val Loss: 0.2257   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [79/200]   Train Loss: 0.1322   Train Accuracy: 95.601   Val Loss: 0.2257   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [80/200]   Train Loss: 0.1308   Train Accuracy: 95.620   Val Loss: 0.2257   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [81/200]   Train Loss: 0.1295   Train Accuracy: 95.693   Val Loss: 0.2257   Val Accuracy: 92.555   Duration: 0.01s   Avg Duration: 0.01s
# Epoch: [82/200]   Train Loss: 0.1282   Train Accuracy: 95.693   Val Loss: 0.2258   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [83/200]   Train Loss: 0.1269   Train Accuracy: 95.820   Val Loss: 0.2258   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [84/200]   Train Loss: 0.1256   Train Accuracy: 95.875   Val Loss: 0.2259   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [85/200]   Train Loss: 0.1243   Train Accuracy: 95.857   Val Loss: 0.2260   Val Accuracy: 92.656   Duration: 0.01s   Avg Duration: 0.01s
# Epoch: [86/200]   Train Loss: 0.1230   Train Accuracy: 95.893   Val Loss: 0.2261   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [87/200]   Train Loss: 0.1218   Train Accuracy: 95.893   Val Loss: 0.2263   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [88/200]   Train Loss: 0.1206   Train Accuracy: 95.948   Val Loss: 0.2264   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [89/200]   Train Loss: 0.1193   Train Accuracy: 95.948   Val Loss: 0.2266   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [90/200]   Train Loss: 0.1181   Train Accuracy: 96.076   Val Loss: 0.2268   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [91/200]   Train Loss: 0.1170   Train Accuracy: 96.131   Val Loss: 0.2270   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [92/200]   Train Loss: 0.1158   Train Accuracy: 96.204   Val Loss: 0.2272   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [93/200]   Train Loss: 0.1146   Train Accuracy: 96.295   Val Loss: 0.2274   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [94/200]   Train Loss: 0.1135   Train Accuracy: 96.386   Val Loss: 0.2277   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [95/200]   Train Loss: 0.1124   Train Accuracy: 96.441   Val Loss: 0.2280   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [96/200]   Train Loss: 0.1113   Train Accuracy: 96.459   Val Loss: 0.2282   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [97/200]   Train Loss: 0.1102   Train Accuracy: 96.459   Val Loss: 0.2285   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [98/200]   Train Loss: 0.1091   Train Accuracy: 96.532   Val Loss: 0.2288   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [99/200]   Train Loss: 0.1080   Train Accuracy: 96.587   Val Loss: 0.2291   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [100/200]   Train Loss: 0.1069   Train Accuracy: 96.605   Val Loss: 0.2294   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [101/200]   Train Loss: 0.1059   Train Accuracy: 96.733   Val Loss: 0.2297   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [102/200]   Train Loss: 0.1049   Train Accuracy: 96.788   Val Loss: 0.2300   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [103/200]   Train Loss: 0.1039   Train Accuracy: 96.806   Val Loss: 0.2303   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [104/200]   Train Loss: 0.1029   Train Accuracy: 96.879   Val Loss: 0.2307   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [105/200]   Train Loss: 0.1019   Train Accuracy: 96.897   Val Loss: 0.2310   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [106/200]   Train Loss: 0.1009   Train Accuracy: 96.934   Val Loss: 0.2313   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [107/200]   Train Loss: 0.0999   Train Accuracy: 97.025   Val Loss: 0.2316   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [108/200]   Train Loss: 0.0990   Train Accuracy: 97.080   Val Loss: 0.2320   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [109/200]   Train Loss: 0.0980   Train Accuracy: 97.098   Val Loss: 0.2323   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [110/200]   Train Loss: 0.0971   Train Accuracy: 97.171   Val Loss: 0.2326   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [111/200]   Train Loss: 0.0962   Train Accuracy: 97.226   Val Loss: 0.2330   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [112/200]   Train Loss: 0.0953   Train Accuracy: 97.262   Val Loss: 0.2333   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [113/200]   Train Loss: 0.0944   Train Accuracy: 97.299   Val Loss: 0.2337   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [114/200]   Train Loss: 0.0935   Train Accuracy: 97.317   Val Loss: 0.2340   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [115/200]   Train Loss: 0.0927   Train Accuracy: 97.317   Val Loss: 0.2344   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [116/200]   Train Loss: 0.0918   Train Accuracy: 97.390   Val Loss: 0.2347   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [117/200]   Train Loss: 0.0910   Train Accuracy: 97.445   Val Loss: 0.2351   Val Accuracy: 92.354   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [118/200]   Train Loss: 0.0901   Train Accuracy: 97.463   Val Loss: 0.2354   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [119/200]   Train Loss: 0.0893   Train Accuracy: 97.481   Val Loss: 0.2358   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [120/200]   Train Loss: 0.0885   Train Accuracy: 97.591   Val Loss: 0.2362   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [121/200]   Train Loss: 0.0877   Train Accuracy: 97.646   Val Loss: 0.2365   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [122/200]   Train Loss: 0.0869   Train Accuracy: 97.646   Val Loss: 0.2369   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [123/200]   Train Loss: 0.0861   Train Accuracy: 97.627   Val Loss: 0.2372   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [124/200]   Train Loss: 0.0853   Train Accuracy: 97.609   Val Loss: 0.2376   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [125/200]   Train Loss: 0.0845   Train Accuracy: 97.627   Val Loss: 0.2380   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [126/200]   Train Loss: 0.0838   Train Accuracy: 97.627   Val Loss: 0.2384   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [127/200]   Train Loss: 0.0830   Train Accuracy: 97.627   Val Loss: 0.2387   Val Accuracy: 92.455   Duration: 0.01s   Avg Duration: 0.01s
# Epoch: [128/200]   Train Loss: 0.0823   Train Accuracy: 97.646   Val Loss: 0.2391   Val Accuracy: 92.455   Duration: 0.00s   Avg Duration: 0.01s
# Epoch: [129/200]   Train Loss: 0.0816   Train Accuracy: 97.700   Val Loss: 0.2395   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [130/200]   Train Loss: 0.0808   Train Accuracy: 97.700   Val Loss: 0.2398   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [131/200]   Train Loss: 0.0801   Train Accuracy: 97.737   Val Loss: 0.2402   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [132/200]   Train Loss: 0.0794   Train Accuracy: 97.810   Val Loss: 0.2406   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [133/200]   Train Loss: 0.0787   Train Accuracy: 97.810   Val Loss: 0.2410   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [134/200]   Train Loss: 0.0781   Train Accuracy: 97.883   Val Loss: 0.2413   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [135/200]   Train Loss: 0.0774   Train Accuracy: 97.883   Val Loss: 0.2417   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [136/200]   Train Loss: 0.0767   Train Accuracy: 97.883   Val Loss: 0.2421   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [137/200]   Train Loss: 0.0761   Train Accuracy: 97.919   Val Loss: 0.2425   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [138/200]   Train Loss: 0.0754   Train Accuracy: 97.919   Val Loss: 0.2428   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [139/200]   Train Loss: 0.0748   Train Accuracy: 97.919   Val Loss: 0.2432   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [140/200]   Train Loss: 0.0741   Train Accuracy: 97.919   Val Loss: 0.2436   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [141/200]   Train Loss: 0.0735   Train Accuracy: 97.956   Val Loss: 0.2439   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [142/200]   Train Loss: 0.0729   Train Accuracy: 97.974   Val Loss: 0.2443   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [143/200]   Train Loss: 0.0723   Train Accuracy: 97.992   Val Loss: 0.2447   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [144/200]   Train Loss: 0.0717   Train Accuracy: 98.011   Val Loss: 0.2450   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [145/200]   Train Loss: 0.0711   Train Accuracy: 98.029   Val Loss: 0.2454   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [146/200]   Train Loss: 0.0705   Train Accuracy: 98.084   Val Loss: 0.2457   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [147/200]   Train Loss: 0.0699   Train Accuracy: 98.102   Val Loss: 0.2461   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [148/200]   Train Loss: 0.0693   Train Accuracy: 98.138   Val Loss: 0.2465   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [149/200]   Train Loss: 0.0688   Train Accuracy: 98.138   Val Loss: 0.2468   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [150/200]   Train Loss: 0.0682   Train Accuracy: 98.138   Val Loss: 0.2472   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [151/200]   Train Loss: 0.0677   Train Accuracy: 98.211   Val Loss: 0.2476   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [152/200]   Train Loss: 0.0671   Train Accuracy: 98.211   Val Loss: 0.2479   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [153/200]   Train Loss: 0.0666   Train Accuracy: 98.211   Val Loss: 0.2483   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [154/200]   Train Loss: 0.0660   Train Accuracy: 98.248   Val Loss: 0.2486   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [155/200]   Train Loss: 0.0655   Train Accuracy: 98.266   Val Loss: 0.2490   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [156/200]   Train Loss: 0.0650   Train Accuracy: 98.266   Val Loss: 0.2494   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [157/200]   Train Loss: 0.0645   Train Accuracy: 98.266   Val Loss: 0.2498   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [158/200]   Train Loss: 0.0639   Train Accuracy: 98.284   Val Loss: 0.2501   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [159/200]   Train Loss: 0.0634   Train Accuracy: 98.303   Val Loss: 0.2505   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [160/200]   Train Loss: 0.0629   Train Accuracy: 98.339   Val Loss: 0.2509   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [161/200]   Train Loss: 0.0624   Train Accuracy: 98.339   Val Loss: 0.2513   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [162/200]   Train Loss: 0.0620   Train Accuracy: 98.357   Val Loss: 0.2517   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [163/200]   Train Loss: 0.0615   Train Accuracy: 98.376   Val Loss: 0.2521   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [164/200]   Train Loss: 0.0610   Train Accuracy: 98.376   Val Loss: 0.2525   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [165/200]   Train Loss: 0.0605   Train Accuracy: 98.376   Val Loss: 0.2529   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [166/200]   Train Loss: 0.0600   Train Accuracy: 98.394   Val Loss: 0.2532   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [167/200]   Train Loss: 0.0596   Train Accuracy: 98.412   Val Loss: 0.2536   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [168/200]   Train Loss: 0.0591   Train Accuracy: 98.430   Val Loss: 0.2540   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [169/200]   Train Loss: 0.0587   Train Accuracy: 98.430   Val Loss: 0.2544   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [170/200]   Train Loss: 0.0582   Train Accuracy: 98.467   Val Loss: 0.2548   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [171/200]   Train Loss: 0.0578   Train Accuracy: 98.503   Val Loss: 0.2552   Val Accuracy: 92.555   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [172/200]   Train Loss: 0.0573   Train Accuracy: 98.540   Val Loss: 0.2556   Val Accuracy: 92.656   Duration: 0.01s   Avg Duration: 0.00s
# Epoch: [173/200]   Train Loss: 0.0569   Train Accuracy: 98.540   Val Loss: 0.2560   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [174/200]   Train Loss: 0.0565   Train Accuracy: 98.576   Val Loss: 0.2564   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [175/200]   Train Loss: 0.0561   Train Accuracy: 98.576   Val Loss: 0.2567   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [176/200]   Train Loss: 0.0556   Train Accuracy: 98.576   Val Loss: 0.2571   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [177/200]   Train Loss: 0.0552   Train Accuracy: 98.576   Val Loss: 0.2575   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [178/200]   Train Loss: 0.0548   Train Accuracy: 98.595   Val Loss: 0.2579   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [179/200]   Train Loss: 0.0544   Train Accuracy: 98.613   Val Loss: 0.2583   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [180/200]   Train Loss: 0.0540   Train Accuracy: 98.613   Val Loss: 0.2586   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [181/200]   Train Loss: 0.0536   Train Accuracy: 98.649   Val Loss: 0.2590   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [182/200]   Train Loss: 0.0532   Train Accuracy: 98.649   Val Loss: 0.2594   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [183/200]   Train Loss: 0.0528   Train Accuracy: 98.668   Val Loss: 0.2598   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [184/200]   Train Loss: 0.0524   Train Accuracy: 98.668   Val Loss: 0.2602   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [185/200]   Train Loss: 0.0520   Train Accuracy: 98.668   Val Loss: 0.2606   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [186/200]   Train Loss: 0.0517   Train Accuracy: 98.668   Val Loss: 0.2610   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [187/200]   Train Loss: 0.0513   Train Accuracy: 98.668   Val Loss: 0.2614   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [188/200]   Train Loss: 0.0509   Train Accuracy: 98.722   Val Loss: 0.2618   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [189/200]   Train Loss: 0.0505   Train Accuracy: 98.722   Val Loss: 0.2621   Val Accuracy: 92.656   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [190/200]   Train Loss: 0.0502   Train Accuracy: 98.722   Val Loss: 0.2625   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [191/200]   Train Loss: 0.0498   Train Accuracy: 98.722   Val Loss: 0.2629   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [192/200]   Train Loss: 0.0495   Train Accuracy: 98.759   Val Loss: 0.2633   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [193/200]   Train Loss: 0.0491   Train Accuracy: 98.777   Val Loss: 0.2637   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [194/200]   Train Loss: 0.0487   Train Accuracy: 98.795   Val Loss: 0.2641   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [195/200]   Train Loss: 0.0484   Train Accuracy: 98.795   Val Loss: 0.2645   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [196/200]   Train Loss: 0.0481   Train Accuracy: 98.795   Val Loss: 0.2649   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [197/200]   Train Loss: 0.0477   Train Accuracy: 98.795   Val Loss: 0.2652   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [198/200]   Train Loss: 0.0474   Train Accuracy: 98.814   Val Loss: 0.2656   Val Accuracy: 92.757   Duration: 0.01s   Avg Duration: 0.00s
# Epoch: [199/200]   Train Loss: 0.0470   Train Accuracy: 98.832   Val Loss: 0.2660   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.00s
# Epoch: [200/200]   Train Loss: 0.0467   Train Accuracy: 98.850   Val Loss: 0.2664   Val Accuracy: 92.757   Duration: 0.00s   Avg Duration: 0.00s
# Analysis of class Benign:
# Sensitivity:    0.8655, Specificity:  0.9847, Precision: 0.9250
#
# Analysis of class Normal:
# Sensitivity:    0.9392, Specificity:  0.9620, Precision: 0.9366
#
# Analysis of class Abnormal:
# Sensitivity:    0.9414, Specificity:  0.9295, Precision: 0.9214
#
# The Simple ANN was 92.757% accurate.

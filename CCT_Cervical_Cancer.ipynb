# %%
import os
from PIL import Image
import torch
from torch.utils.data import DataLoader,Dataset
import torch.nn as nn
from torch import Tensor
import torchvision
import torchvision.transforms as transforms
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import torch.nn.functional as F
from datetime import datetime
from sklearn.model_selection import train_test_split

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
torch.backends.cudnn.benchmark = True

# %% [markdown]
# # A Compact Convolutional Vision Transformer or CCT
# *Created using the walkthrough from https://medium.com/pytorch/training-compact-transformers-from-scratch-in-30-minutes-with-pytorch-ff5c21668ed5 and Dr Prashant's Vision_Transformer file

# %% [markdown]
# ## Building the Transformer block by block

# %% [markdown]
# Every part/layer of the transformer is built using the Pytorch nn.module class which allows for easy creation of maching learning models. Each layer should be made up of at least two parts: An initialization function which uses the given information to build the class and then the 'Forward' function defines how the class will run when it is called.

# %% [markdown]
# ### Transformer Constructor
#
# First, the actual ViT Constructor which essentially acts as a hub. It ensures that each part of the transformer is called in the correct order and that local variables can be passed along.

# %% [markdown]
# ### What makes it more Compact/Lite than the CVT?
#
# The only difference between this and the original Vision Transformer is a Sequence Pooling layer and a convolutional layer instead of patching. Previously the classes were embedded separately and then passed to the MLP for classification. Sequence Pooling ties the class information in with every other parameter.. I think.

# %%
class CCT(nn.Module):
    '''
    Simplified implementation of the Vision transformer.

    Parameters
    ----------
    img_size: int
        Both height and width of the image (if it is a square)
    in_channels: int
        Number of input channels
    patch_size: int
        Both height and width of the patch (if it is a square)
    embed_dim: int
        The embedding size for each token
    n_layers: int
        Number of transformer blocks
    n_heads: int
        Number of attention heads
    attn_dropout, proj_dropout, mlp_dropout: float
        Dropout probability
    mlp_ratio: float
        Determine the hidden dimension of the MLP module
    qkv_bias: bool
        If true then we add bias to the query, key and value projections
    n_classes: int
        Number of classes

    Attributes
    -----------
    n_patches: int
        Number of patches that can be taken from each image based on size.
    patch_embed: PatchEmbed
        Sets up the `Patching' layer.
    class_embed: nn.Parameter
        Learnable parameter that will represent the first class token in the sequence.
        It has `embed_dim' elements.
    pos_embed: nn.Parameter
        Adds a positional encoding to every token.
    pos_drop: nn.Dropout
        Dropout layer.
    tr_block: nn.ModuleList
        Instance of 'TransformerEncoderLayer'.
    norm: nn.Layernorm
        Layer normalization.
    '''
    def __init__(self,
                 img_size=32,   # The square size of each image
                 in_channels=3, # Number of channels for each image (eg: Grayscale=1, RGB=3)
                 patch_size=4,  # The square size of each patch
                 embed_dim=768,  # Embedding dimension
                 n_layers=3, # How many times to run the transformer encoder
                 n_conv=2, # How many times to run the convolutional filter
                 n_heads=3,   # Number of attention heads,
                 attn_dropout=0.,  # Attention Dropout
                 proj_dropout=0.,   # (MHA) Projection Dropout
                 mlp_dropout=0.,   # (MHA) last layer dropout
                 mlp_ratio=4,   # (MHA) Projection FF dimension
                 qkv_bias = True,
                 n_classes=10   # Number of classes to classify
    ):
        super().__init__()
        # Provides an error if the patching size is not divisible by the image size.
        assert img_size % patch_size == 0, \
            print("Given image size ({}) has to be divisible by given patch size ({})".format(img_size, patch_size))
        
        self.conv_embed = Conv_Embed(img_size, in_channels, embed_dim, n_conv)
        n_patches = self.conv_embed.sequence_length(in_channels=in_channels, height=img_size, width=img_size)
        hidden_dim = int(embed_dim * mlp_ratio)
        
        
        self.pos_embed = nn.Parameter(torch.zeros(1, n_patches, embed_dim))
        
        # Can use this to enable Sinusoidal PE
        #self.pos_embed = PositionalEmbedding(1, n_patches + 1, embed_dim)

        self.pos_drop = nn.Dropout(p=proj_dropout)
        self.tr_block = nn.ModuleList(
            [
                TransformerEncoderLayer(
                    embed_dim,
                    n_heads,
                    qkv_bias,
                    attn_dropout,
                    proj_dropout,
                    mlp_dropout,
                    hidden_dim
                    )
                for _ in range(n_layers)
            ]   # Sends data through the encoder n times
        )
        self.norm = nn.LayerNorm(embed_dim, eps=1e-6)
        
        self.attention_pool = nn.Linear(embed_dim, 1)
                                    
        self.head = nn.Linear(embed_dim, n_classes)

    def forward(self, x):
        '''
        Defines how the class will run

        Parameters
        ----------
        x: torch.Tensor
            shape: n_samples, in_chains, img_size, img_size

        Returns
        ---------
        logits: torch.Tensor
            Logits over all the classes: n_samples, n_samples
        '''
        x = self.conv_embed(x)
        #x = self.pos_embed(x)
        
        x += self.pos_embed
        x = self.pos_drop(x)
        for tr_block in self.tr_block:
            x = tr_block(x)
        x = self.norm(x)
        #Added Sequence Pooling instead of Class embedding
        x = torch.matmul(F.softmax(self.attention_pool(x), dim=1).transpose(-1, -2), x).squeeze(-2)
        x = self.head(x)
        return x

# %% [markdown]
# ### Positional Embedding
#
# This is the sinusoidal positional encoding layer as seen in the original 'Attention is All You Need' paper. It basically uses a sin/cos waveform to provide a unique positional offset that is given to a token at the corresponding position in its embedding space.
#
# By default, this is disabled and we instead use a trainable matrix of zeros. This adds another dimension to our data that the model then uses to find the best weights for the data's position itself. This is called "learnable" positional encoding.
#
# There are pros-and-cons to either, but essentially: sinusoidal is better when there are not a lot of data samples to learn the positional data from but you can get better results from "learnable" with larger datasets.

# %%
class PositionalEmbedding(nn.Module):
    '''
    Applies Learnable Sinusoidal Positional Encoding

    Parameters
    ----------
    embed_dim: int
        The positional embedding dimension (How big embedding for each patch.Constant across entire network)
    max_len: int 
        Max number of instances for positions
    freq: int 
        The base frequency for Sin/Cos calculations. Higher values (eg 10000) are more stable
    '''
    def __init__(self, 
                 embed_dim,
                 max_len=5000,
                 freq=10000.,
                ):
        super().__init__()
        pe = torch.zeros(max_len, embed_dim)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div = torch.exp(torch.arange(0, embed_dim, 2).float() *
                        (-math.log(freq) / embed_dim))
        pe[:, 0::2] = torch.sin(position * div) # Even terms
        pe[:, 1::2] = torch.cos(position * div) # Odd terms
        pe = pe.unsqueeze(0).transpose(0,1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        '''
        Defines how the class will run

        Parameters
        -----------

        Returns
        -----------
        '''
        x = x + self.pe[:x.size(0), :]
        return x

# %% [markdown]
# ### Convolutional Embedding Layer
#
# The patching used by the previous models was a problem because, while it took more samples of the input data, it also created what were essentially bordered segments which made it harder for the model to learn how they connected to the other segments and the bigger picture.
#
# The new convolutional layer helps to eliminate that problem by using convolutional filters to create many different overlapping segments.

# %%
class Conv_Embed(nn.Module):
    def __init__(self,
                 img_size=32,
                 in_channels=3,
                 out_channels=64,
                 n_conv=2,
                 kernel_size=3,
                 stride=None,
                 padding=None,
                 pool_kernel_size=3,
                 pool_stride=2,
                 pool_padding=1
                 ):
        super().__init__()
        
        stride = stride if stride is not None else max(1, (kernel_size // 2) - 1)
        padding = padding if padding is not None else max(1, (kernel_size // 2))

        self.img_size = img_size
        if n_conv == 1:
            self.conv_layers = nn.Sequential(
                nn.Conv2d(in_channels,
                        out_channels,
                        kernel_size=kernel_size,
                        stride=stride,
                        padding=padding,
                        bias=False),
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=pool_kernel_size,
                            stride=pool_stride,
                            padding=pool_padding)
            )
        else:
            n_filter_list = [in_channels] + \
                            [64 for _ in range(n_conv - 1)] + \
                            [out_channels]

            self.conv_layers = nn.Sequential(
                *[nn.Sequential(
                    nn.Conv2d(n_filter_list[i],
                        n_filter_list[i+1],
                        kernel_size=kernel_size,
                        stride=stride,
                        padding=padding,
                        bias=False),
                    nn.ReLU(),
                    nn.MaxPool2d(kernel_size=pool_kernel_size,
                            stride=pool_stride,
                            padding=pool_padding)
                            )
                    for i in range(n_conv)
                ])
        self.flattener = nn.Flatten(2, 3)
        
        # This, along with the staticmethod below, help to normalize the convolutional filter by picking better starting weights for optimization.
        self.apply(self.init_weight)

    def sequence_length(self, in_channels=3, height=32, width=32):
        return self.forward(torch.zeros((1, in_channels, height, width))).shape[1]

    def forward(self, x):
        return self.flattener(self.conv_layers(x)).transpose(-2, -1)

    @staticmethod
    def init_weight(m):
        if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight)

# %% [markdown]
# ### This is the Transformer Encoder block which applies all of the actual normalization, attention, etc that make a Transformer what it is.

# %%
class TransformerEncoderLayer(nn.Module):
    '''
    Transformer Block/Encoder Layer

    Parameter
    ---------
    embed_dim: int
        embedding dimension
    n_heads: int
        number of attention heads
    mlp_ratio: float
        determines the hidden dimension size of the MLP module with respect to 'dim'
    qkv_bias: bool
        If true then we include bias to the query, key and value projections
    mlp_dropout, proj_dropout, attn_droupout: float
        dropout probability
    dim_feedforward: int
        The feature number of hidden layer of the FFN

    Attributes
    ----------
    norm_1, norm_2: LayerNorm
        Layer normalization
    MHA: Attention
        Multi-Headed Attention module
    mlp: MLP
        MLP module
    ''' 
    def __init__(self,
                 embed_dim=768,
                 n_heads=12,
                 qkv_bias=True,
                 attn_dropout=0.,
                 proj_dropout=0.,
                 mlp_dropout=0.,
                 hidden_dim=2048
    ):
        super().__init__()
        self.norm_1 = nn.LayerNorm(embed_dim, eps = 1e-6)
        self.norm_2 = nn.LayerNorm(embed_dim, eps = 1e-6)
        self.MHA = MultiheadedSelfAttention(embed_dim,
                                        n_heads,
                                        qkv_bias,
                                        attn_dropout,
                                        proj_dropout
        )
        self.MLP = MLP(embed_dim, hidden_dim, mlp_dropout)

    def forward(self, x):
        '''
        Defines how the class will run
        
        Parameter
        ---------
        x: torch.Tensor
            shape: n_samples, n_patches + 1, dim

        Returns
        --------
        torch.Tensor
            shape: n_samples, n_patches + 1, dim
        '''
        x = x + self.MHA(self.norm_1(x))    # Residual connection (Add)
        x = x + self.MLP(self.norm_2(x))    # Residual connection (Add)
        return x

# %% [markdown]
# ### Multiheaded Attention Layer
#
# The heart of the Transformer model; the reason behind the original title of "attention is all you need".

# %%
class MultiheadedSelfAttention(nn.Module):
    '''
    Multi-Headed Attention Mechanism

    Parameters
    ----------
    embed_dim: int
        The input and out dimension of per token feature
    n_heads: int
        Number of attention heads 
    qkv_bias: bool
        if true then we include bias to the query, key and value projections
    attn_p: float
        Dropout probability applied to the query, key and value tensors.
    proj_p: float
        Dropout probability applied to output tensor
        
    Attributes
    ----------
    scale: float
        Normalizing constant for the dot product
    qkv: nn.Linear
        Linear projection for the query, key and value
    proj: nn.Linear
        Linear mapping that takes in the concatenated output of all attention
        heads and maps into the new space
    attn_drop, proj_drop: nn.Dropout
        Dropout layers.
    '''
    def __init__(self, 
                 embed_dim, 
                 n_heads=2,
                 qkv_bias = True,
                 attn_dropout=0.,
                 proj_dropout=0.
    ):
        super().__init__()
        self.n_heads = n_heads
        assert embed_dim % n_heads == 0, \
            print('Embedding dim must be divisible by number of heads.')
        self.head_dim = embed_dim // n_heads
        self.scale = self.head_dim ** -0.5
        self.dim = embed_dim
        self.qkv = nn.Linear(embed_dim, embed_dim * 3, bias=qkv_bias)
        self.attn_dropout = nn.Dropout(attn_dropout)
        self.proj = nn.Linear(embed_dim, embed_dim)
        self.proj_dropout = nn.Dropout(proj_dropout)
        
    def forward(self, x):
        '''
        Defines how the class will run
        
        Parameters
        ----------
        x: torch.Tensor
            shape: n_samples (B), n_patches + 1 (N), embed_dim (C)
            N is also equal to the number of tokens.
        Returns
        --------
        torch.Tensor
            shape: n_samples, n_patches + 1, embed_dim
        '''
        B, N, C = x.shape
        qkv = self.qkv(x)
        qkv = qkv.reshape(B, N, 3,
            self.n_heads,
            self.head_dim
            )
        qkv = qkv.permute(
            2,    # qkv (3)
            0,    # batch (n_samples)
            3,    # channel (n_heads)
            1,    # n_patches + 1
            4     # head_dim (embed_dim / n_heads)
            )
        q, k, v = qkv[0], qkv[1], qkv[2]
        attn = (q @ k.transpose(-2, -1)) * self.scale # <q,k> / sqrt(d)
        attn = attn.softmax(dim=-1) # Softmax over embedding dim
        attn = self.attn_dropout(attn)

        weighted_avg = (attn @ v)
        weighted_avg = weighted_avg.transpose(1, 2)
        weighted_avg = weighted_avg.flatten(2)

        x = self.proj(weighted_avg)
        x = self.proj_dropout(x)

        return x

# %% [markdown]
# ### The MLP layer
#
# (At the end of the Transformer Encoder). Not to be confused with the mlp head which adds class encodings at the very end of the transformer.

# %%
class MLP(nn.Module):
    '''
    Multilayer perceptron 
    
    Parameters
    ----------
    embed_dim: int
        embedding dimension
    feedforward_dim: int
      Number of nodes in the hidden layer
    mlp_dropout: float
      Dropout probability

    Attribute
    ---------
    fc: nn.Linear
      The first linear layer
    act: nn. GELU
      GELU activation function
    fc2: nn.Linear
      The second linear layer
    drop: nn.Dropout
      Dropout layer
    '''

    def __init__(self, embed_dim, hidden_dim, mlp_dropout):
        super().__init__()
        self.fc1 = nn.Linear(embed_dim, hidden_dim)
        self.act = nn.GELU()
        self.fc2 = nn.Linear(hidden_dim, embed_dim)
        self.drop = nn.Dropout(mlp_dropout)

    def forward(self,x):
        '''
        Defines how the class will run
        
        Parameters
        ----------
        x: torch.Tensor
          shape: n_samples, n_patches + 1, in_features

        Returns
        ----------
        torch.Tensor
          n_samples, n_patches+ 1, out_features
        '''
        x = self.fc1(x) # n_samples, n_patches+1, hidden_features
        x = self.act(x) # n_samples, n_patches+1, hidden_features
        x = self.drop(x) # n_samples, n_patches+1, hidden_features
        x = self.fc2(x) # n_samples, n_patches+1, output_features
        x = self.drop(x) # n_samples, n_patches+1, output_features
        return x

# %% [markdown]
# ## Training with custom dataset

# %%
def sipakmed_prep():
    root = "../../Python Scripts/Datasets/CervicalCancer/Sipakmed/"

    all_img = []
    for path, subdirs, files in os.walk(root):
        for name in files:
            curr_img = os.path.join(path,name)
            all_img.append(curr_img)

    sipakmed_df = pd.DataFrame()
    sipakmed_df['LocalPath'] = all_img
    sipakmed_df['ID'] = sipakmed_df['LocalPath'].apply(lambda x: str(x.split("\\")[-1]))
    sipakmed_df['Slide'] = sipakmed_df['LocalPath'].apply(lambda x: 'False' if (str(x.split("\\")[1])) == 'CROPPED' else 'True')
    sipakmed_df['Specific_Status'] = sipakmed_df['LocalPath'].apply(lambda x: str((x.split("im_")[1]).split("\\")[0]))
    sipakmed_df['Status'] = sipakmed_df['Specific_Status'].apply(lambda x: 'Benign' if x == 'Metaplastic' else
    ('Normal' if x == 'Superficial-Intermediate' or x == 'Parabasal' else 'Abnormal'))

    sp_class = {'Metaplastic':4, 'Superficial-Intermediate':0, 'Parabasal':1, 'Koilocytotic':2, 'Dyskeratotic':3}
    sipakmed_df['Specific_Class'] = sipakmed_df['Specific_Status'].map(sp_class)
    gen_class = {'Benign':0, 'Normal':1, 'Abnormal':2}
    sipakmed_df['Class'] = sipakmed_df['Status'].map(gen_class)

    sipakmed_df = sipakmed_df.loc[sipakmed_df['ID'].str.contains('bmp')].reset_index(drop=True)
    
    #Uploads the created file for future use. Recommended to not use.
    #sipakmed_df.to_csv(root + '/results.csv')
    return sipakmed_df

# %%
def herlev_prep():
    root = '../../Python Scripts/Datasets/CervicalCancer/Herlev/smear2005/results.csv'
    img_folder = '../../Python Scripts/Datasets/CervicalCancer/Herlev/smear2005/Images/'

    herlev_df=pd.read_csv(root)
    herlev_df = herlev_df.rename(columns={'Class':'Specific_Class'})

    spec_class = {1:0, 2:1, 3:2, 4:3, 5:4, 6:5, 7:6}
    gen_class = {1:1, 2:1, 3:1, 4:2, 5:2, 6:2, 7:2}
    
    herlev_df['Class'] = herlev_df['Specific_Class'].map(gen_class)
    herlev_df['Specific_Class'] = herlev_df['Specific_Class'].map(spec_class)
    herlev_df['LocalPath'] = herlev_df['ID'].apply(lambda x: str(img_folder + x))
    return herlev_df

# %%
class DatasetSample(Dataset):
    def __init__(self, df, transform):
        # Initialization
        self.transform = transform
        
        self.image_names = df['LocalPath']
        self.img_class = np.array(df['Class'])

    def __len__(self):
        # Denotes the total number of samples
        return len(self.image_names)
    
    def __getitem__(self, index):
        # Retrieves the data
        image=cv2.imread(self.image_names.iloc[index])
        image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

        image = self.transform(image)
        label = self.img_class[index]

        x, y = image, label
        
        # Enable to output as single variable instead
        #sample = {'image': image,'labels':label}

        return x, y

# %%
def concat_data(batch_size=128, img_size=32):
    # Load the dataframes
    sipakmed_df = sipakmed_prep()
    herlev_df = herlev_prep()

    # Final adjustments to make sure they're attributes match
    sipakmed_df = sipakmed_df.loc[sipakmed_df['Slide'] == 'False']
    herlev_df = herlev_df.loc[:,['LocalPath', 'Class']]
    sipakmed_df = sipakmed_df.loc[:,['LocalPath', 'Class']]
    
    concat_df = pd.concat([sipakmed_df,herlev_df], ignore_index=True)
    
    '''
    concat_df = pd.DataFrame()
    concat_df['LocalPath'] = sipakmed_df['LocalPath']
    concat_df['Class'] = sipakmed_df['Specific_Class']
    concat_df = pd.DataFrame()
    concat_df['LocalPath'] = herlev_df['LocalPath']
    concat_df['Class'] = herlev_df['Specific_Class']
    '''


    # Split them into training, validation, and testing sets
    train_set,val_test_set = train_test_split(concat_df, random_state=1, test_size=0.30)
    val_set,test_set = train_test_split(val_test_set, random_state=1, test_size=0.50)
    
    # Set it up to alter random training images for better results
    train_transform = transforms.Compose([
                    transforms.ToPILImage(),
                    transforms.Resize((img_size, img_size)),
                    transforms.RandomHorizontalFlip(p=0.75),
                    transforms.RandomRotation(degrees=60),
                    transforms.ToTensor()])

    test_transform = transforms.Compose([
                    transforms.ToPILImage(),
                    transforms.Resize((img_size, img_size)),
                    transforms.ToTensor()])

    train_dataset = DatasetSample(train_set, train_transform)
    val_dataset = DatasetSample(val_set, test_transform)
    test_dataset = DatasetSample(test_set, test_transform)
    
    Dtr = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True
    )
    
    Dva = DataLoader(
        val_dataset, 
        batch_size=batch_size,
        shuffle=True
    )

    Dte = DataLoader(
        test_dataset, 
        batch_size=batch_size,
        shuffle=True
    )

    return(Dtr, Dva, Dte)

# %%
#The corresponding class labels
batch_size=64
img_size=84
classes = ('Benign', 'Normal', 'Abnormal')
#classes = ('Superficial-Intermediate','Parabasal','Koilocytotic','Dyskeratotic','Metaplastic')
#classes = ('Superficial-Squamous-Epithelial','Intermediate-Squamous-Epithelial','Columnar-Epithelial','Mild-Squamous-Non-Keratinizing-Dysplasia',
#           'Moderate-Squamous-Non-Keratinizing-Dysplasia','Severe-Squamous-Non-Keratinizing-Dysplasia','Squamous-Cell-Carcinoma-in-situ-Intermediate')
Dtr, Dva, Dte = concat_data(batch_size=batch_size, img_size=img_size)
print('The total number of samples for Training is: {}, Validation: {}, and Testing: {}'.format(len(Dtr)*batch_size, len(Dva)*batch_size, len(Dte)*batch_size))
# Out:
# The total number of samples for Training is: 3520, Validation: 768, and Testing: 768

# %% [markdown]
# ### Builds the dataloaders for training and testing

# %%
# Turns the dataloaders into iterable objects. Useful for viewing
dataiter = iter(Dtr)
val_dataiter = iter(Dva)
test_dataiter = iter(Dte)

# %% [markdown]
# ### Function for viewing batches of the dataset

# %%
def imshow(images, labels, predicted_labels=None):
    
    if images.is_cuda == True:
        images = images.to("cpu")
    if labels.is_cuda == True:
        labels = labels.to("cpu")

    # Using torchvision to make a grid of the images
    img = torchvision.utils.make_grid(images)

    # Inverting the normalization
    img = img.numpy().transpose((1, 2, 0))
    img = np.clip(img, 0, 1)

    # Plotting the grid
    fig, ax = plt.subplots(figsize=(12, 24))
    plt.imshow(img)

    if predicted_labels is not None:
        if predicted_labels.is_cuda == True:
            predicted_labels = predicted_labels.to("cpu")
        # Outputing the predicted labels
        ax.set_xlabel('Predicted labels', fontsize=18, labelpad=12)
        ax.set_xticks(torch.arange(len(images)) * img_size + (img_size/1.8))
        ax.set_xticklabels([classes[predicted_labels[j]] 
                            for j in range(len(images))], fontsize=12, rotation=30)
    
    # Outputing the True labels
    gax = ax.secondary_xaxis('top')
    gax.set_xlabel('True Labels', fontsize=18, labelpad=12)
    gax.set_xticks(torch.arange(len(images)) * img_size + (img_size/1.8))
    gax.set_xticklabels([classes[labels[j]] 
                         for j in range(len(images))], fontsize=12, rotation=30)
    plt.show()

# %%
images, labels = dataiter.next()
imshow(images[:7], labels[:7])

# %% [markdown]
# ### This function was made by Dr Prashant to train the model that's built above

# %%
# A function to encapsulate the training loop
def batch_gd(model, loss_fn, optimizer, train_loader, val_loader, epochs):
  model.to(device)
  train_losses = np.zeros(epochs)
  val_losses = np.zeros(epochs)
  
  for it in range(epochs):
    model.train()
    t0 = datetime.now()
    train_loss = []
    n_correct = 0.
    n_total = 0.
    for inputs, targets in train_loader:
      # move data to GPU if available
      inputs, targets = inputs.to(device), targets.to(device)

      # zero the parameter gradients
      optimizer.zero_grad()

      # Forward pass
      outputs = model(inputs)
      
      # Get the predictions
      # torch.max returns both max and argmax
      __, out_label = outputs.max(dim=1)
      # Updates the accuracy with every pass
      n_correct += (out_label == targets).sum().item()
      n_total += targets.shape[0]
      tr_acc = n_correct / n_total

      loss = loss_fn(outputs, targets)
      # Backward and optimize
      loss.backward()
      optimizer.step()

      train_loss.append(loss.item())

    # Get train loss and test loss
    train_loss = np.mean(train_loss) # a little misleading
    
    model.eval()
    val_loss = []
    n_correct = 0.
    n_total = 0.
    for inputs, targets in val_loader:
      inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)

      # Get the predictions
      # torch.max returns both max and argmax
      __, out_label = outputs.max(dim=1)
      # Updates the accuracy with every pass
      n_correct += (out_label == targets).sum().item()
      n_total += targets.shape[0]
      val_acc = n_correct / n_total

      loss = loss_fn(outputs, targets)
      val_loss.append(loss.item())
    val_loss = np.mean(val_loss)

    # Save losses
    train_losses[it] = train_loss
    val_losses[it] = val_loss
    
    dt = datetime.now() - t0

    print(f'Epoch {it+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {(100*tr_acc):.3f} \
      Val Loss: {val_loss:.4f}, Val Accuracy: {(100*val_acc):.3f}, Duration: {dt}')
  
  return train_losses, val_losses

# %% [markdown]
# ### Initializes the Transformer and selects the loss function and optimizer we want

# %%
model = CCT(
        img_size=img_size,      # Input image size
        in_channels=3,  # Number of channels for the image
        patch_size=4,   # How big our patches are
        embed_dim=128,   # Embedding dim
        n_layers=2,     # Number of transformer encoders
        n_conv=2,       # Number of convolutional layers
        n_heads=2,      # Number of attention heads
        attn_dropout=0.,        # Attention Dropout
        proj_dropout=0.,        # (MHA) Projection Dropout
        mlp_dropout=0.1,        # (MHA) last layer dropout
        mlp_ratio=1,    # (MHA) Projection FF dimension
        qkv_bias = True,
        n_classes=3     # Number of classes to classify
        )
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())

# %%
train_losses, val_losses = batch_gd(model, loss_fn, optimizer, Dtr, Dva, epochs=400)
# Out:
# Epoch 1/400, Train Loss: 0.7803, Train Accuracy: 64.068       Val Loss: 0.5528, Val Accuracy: 80.268, Duration: 0:00:19.433144
# Epoch 2/400, Train Loss: 0.5593, Train Accuracy: 79.287       Val Loss: 0.5924, Val Accuracy: 71.544, Duration: 0:00:16.016829
# Epoch 3/400, Train Loss: 0.4967, Train Accuracy: 80.667       Val Loss: 0.4370, Val Accuracy: 83.758, Duration: 0:00:16.122906
# Epoch 4/400, Train Loss: 0.4354, Train Accuracy: 84.292       Val Loss: 0.4570, Val Accuracy: 83.758, Duration: 0:00:16.202695
# Epoch 5/400, Train Loss: 0.4379, Train Accuracy: 82.825       Val Loss: 0.4442, Val Accuracy: 83.490, Duration: 0:00:16.304422
# Epoch 6/400, Train Loss: 0.3850, Train Accuracy: 85.501       Val Loss: 0.3723, Val Accuracy: 86.711, Duration: 0:00:16.295444
# Epoch 7/400, Train Loss: 0.3960, Train Accuracy: 85.069       Val Loss: 0.3861, Val Accuracy: 85.503, Duration: 0:00:16.231617
# Epoch 8/400, Train Loss: 0.3489, Train Accuracy: 86.824       Val Loss: 0.3668, Val Accuracy: 86.980, Duration: 0:00:16.189728
# Epoch 9/400, Train Loss: 0.3331, Train Accuracy: 87.629       Val Loss: 0.3179, Val Accuracy: 88.456, Duration: 0:00:16.389197
# Epoch 10/400, Train Loss: 0.3039, Train Accuracy: 88.780       Val Loss: 0.3257, Val Accuracy: 88.859, Duration: 0:00:16.221643
# Epoch 11/400, Train Loss: 0.2956, Train Accuracy: 89.068       Val Loss: 0.3379, Val Accuracy: 87.651, Duration: 0:00:16.219650
# Epoch 12/400, Train Loss: 0.2874, Train Accuracy: 89.586       Val Loss: 0.4014, Val Accuracy: 85.369, Duration: 0:00:16.220645
# Epoch 13/400, Train Loss: 0.3061, Train Accuracy: 88.924       Val Loss: 0.3386, Val Accuracy: 87.383, Duration: 0:00:16.376231
# Epoch 14/400, Train Loss: 0.2755, Train Accuracy: 89.499       Val Loss: 0.2982, Val Accuracy: 89.128, Duration: 0:00:16.212667
# Epoch 15/400, Train Loss: 0.2665, Train Accuracy: 90.219       Val Loss: 0.2777, Val Accuracy: 90.336, Duration: 0:00:16.304422
# Epoch 16/400, Train Loss: 0.2565, Train Accuracy: 90.564       Val Loss: 0.3079, Val Accuracy: 89.530, Duration: 0:00:16.207681
# Epoch 17/400, Train Loss: 0.2346, Train Accuracy: 91.168       Val Loss: 0.3319, Val Accuracy: 88.322, Duration: 0:00:16.357282
# Epoch 18/400, Train Loss: 0.2296, Train Accuracy: 91.686       Val Loss: 0.3280, Val Accuracy: 89.396, Duration: 0:00:16.316390
# Epoch 19/400, Train Loss: 0.2466, Train Accuracy: 91.341       Val Loss: 0.2942, Val Accuracy: 89.933, Duration: 0:00:16.216657
# Epoch 20/400, Train Loss: 0.2271, Train Accuracy: 91.858       Val Loss: 0.2643, Val Accuracy: 90.336, Duration: 0:00:16.217654
# Epoch 21/400, Train Loss: 0.2270, Train Accuracy: 91.427       Val Loss: 0.2842, Val Accuracy: 91.007, Duration: 0:00:16.310406
# Epoch 22/400, Train Loss: 0.2226, Train Accuracy: 91.542       Val Loss: 0.3521, Val Accuracy: 87.651, Duration: 0:00:16.240593
# Epoch 23/400, Train Loss: 0.2379, Train Accuracy: 91.254       Val Loss: 0.2700, Val Accuracy: 90.872, Duration: 0:00:16.236604
# Epoch 24/400, Train Loss: 0.2185, Train Accuracy: 92.175       Val Loss: 0.2681, Val Accuracy: 91.141, Duration: 0:00:16.231616
# Epoch 25/400, Train Loss: 0.1933, Train Accuracy: 92.606       Val Loss: 0.3268, Val Accuracy: 88.591, Duration: 0:00:16.398172
# Epoch 26/400, Train Loss: 0.2000, Train Accuracy: 92.232       Val Loss: 0.2735, Val Accuracy: 89.530, Duration: 0:00:16.303425
# Epoch 27/400, Train Loss: 0.1897, Train Accuracy: 93.096       Val Loss: 0.2742, Val Accuracy: 91.141, Duration: 0:00:16.263531
# Epoch 28/400, Train Loss: 0.1945, Train Accuracy: 93.009       Val Loss: 0.2808, Val Accuracy: 91.409, Duration: 0:00:16.220646
# Epoch 29/400, Train Loss: 0.1841, Train Accuracy: 93.067       Val Loss: 0.2592, Val Accuracy: 91.007, Duration: 0:00:16.210672
# Epoch 30/400, Train Loss: 0.1807, Train Accuracy: 93.585       Val Loss: 0.2726, Val Accuracy: 89.664, Duration: 0:00:16.209676
# Epoch 31/400, Train Loss: 0.2107, Train Accuracy: 91.772       Val Loss: 0.2747, Val Accuracy: 90.872, Duration: 0:00:16.230619
# Epoch 32/400, Train Loss: 0.1912, Train Accuracy: 92.750       Val Loss: 0.2718, Val Accuracy: 91.275, Duration: 0:00:16.203692
# Epoch 33/400, Train Loss: 0.1518, Train Accuracy: 94.505       Val Loss: 0.2660, Val Accuracy: 91.544, Duration: 0:00:16.270512
# Epoch 34/400, Train Loss: 0.1747, Train Accuracy: 93.441       Val Loss: 0.2714, Val Accuracy: 91.544, Duration: 0:00:16.266524
# Epoch 35/400, Train Loss: 0.1558, Train Accuracy: 94.045       Val Loss: 0.2169, Val Accuracy: 93.289, Duration: 0:00:16.391190
# Epoch 36/400, Train Loss: 0.1513, Train Accuracy: 94.333       Val Loss: 0.3112, Val Accuracy: 90.604, Duration: 0:00:16.218652
# Epoch 37/400, Train Loss: 0.1644, Train Accuracy: 93.987       Val Loss: 0.2343, Val Accuracy: 93.423, Duration: 0:00:16.431084
# Epoch 38/400, Train Loss: 0.1394, Train Accuracy: 95.138       Val Loss: 0.2563, Val Accuracy: 91.275, Duration: 0:00:16.268518
# Epoch 39/400, Train Loss: 0.1372, Train Accuracy: 95.109       Val Loss: 0.2227, Val Accuracy: 92.886, Duration: 0:00:16.262534
# Epoch 40/400, Train Loss: 0.1470, Train Accuracy: 94.476       Val Loss: 0.2215, Val Accuracy: 92.617, Duration: 0:00:16.254556
# Epoch 41/400, Train Loss: 0.1254, Train Accuracy: 95.368       Val Loss: 0.2807, Val Accuracy: 91.409, Duration: 0:00:16.243585
# Epoch 42/400, Train Loss: 0.1456, Train Accuracy: 94.534       Val Loss: 0.2472, Val Accuracy: 92.349, Duration: 0:00:16.280486
# Epoch 43/400, Train Loss: 0.1274, Train Accuracy: 95.311       Val Loss: 0.2231, Val Accuracy: 92.752, Duration: 0:00:16.276496
# Epoch 44/400, Train Loss: 0.1263, Train Accuracy: 95.081       Val Loss: 0.3040, Val Accuracy: 90.336, Duration: 0:00:16.300434
# Epoch 45/400, Train Loss: 0.1465, Train Accuracy: 94.620       Val Loss: 0.2490, Val Accuracy: 92.483, Duration: 0:00:16.281483
# Epoch 46/400, Train Loss: 0.1324, Train Accuracy: 95.368       Val Loss: 0.2189, Val Accuracy: 93.289, Duration: 0:00:16.280486
# Epoch 47/400, Train Loss: 0.1272, Train Accuracy: 95.224       Val Loss: 0.2024, Val Accuracy: 93.826, Duration: 0:00:16.300433
# Epoch 48/400, Train Loss: 0.1130, Train Accuracy: 95.656       Val Loss: 0.2220, Val Accuracy: 93.289, Duration: 0:00:16.268519
# Epoch 49/400, Train Loss: 0.1321, Train Accuracy: 95.167       Val Loss: 0.2293, Val Accuracy: 92.483, Duration: 0:00:16.354289
# Epoch 50/400, Train Loss: 0.1269, Train Accuracy: 95.455       Val Loss: 0.2072, Val Accuracy: 92.886, Duration: 0:00:16.270513
# Epoch 51/400, Train Loss: 0.1212, Train Accuracy: 95.426       Val Loss: 0.2532, Val Accuracy: 91.946, Duration: 0:00:16.238599
# Epoch 52/400, Train Loss: 0.1031, Train Accuracy: 96.145       Val Loss: 0.2263, Val Accuracy: 92.886, Duration: 0:00:16.266524
# Epoch 53/400, Train Loss: 0.1106, Train Accuracy: 95.627       Val Loss: 0.2490, Val Accuracy: 92.617, Duration: 0:00:16.400166
# Epoch 54/400, Train Loss: 0.1326, Train Accuracy: 95.253       Val Loss: 0.2352, Val Accuracy: 92.617, Duration: 0:00:16.270514
# Epoch 55/400, Train Loss: 0.1023, Train Accuracy: 96.116       Val Loss: 0.3330, Val Accuracy: 91.275, Duration: 0:00:16.272507
# Epoch 56/400, Train Loss: 0.1362, Train Accuracy: 95.138       Val Loss: 0.2599, Val Accuracy: 92.483, Duration: 0:00:16.152828
# Epoch 57/400, Train Loss: 0.1104, Train Accuracy: 96.375       Val Loss: 0.1963, Val Accuracy: 93.557, Duration: 0:00:15.595318
# Epoch 58/400, Train Loss: 0.1030, Train Accuracy: 95.771       Val Loss: 0.2435, Val Accuracy: 92.752, Duration: 0:00:15.599307
# Epoch 59/400, Train Loss: 0.1153, Train Accuracy: 95.598       Val Loss: 0.2112, Val Accuracy: 93.289, Duration: 0:00:15.606288
# Epoch 60/400, Train Loss: 0.1048, Train Accuracy: 96.087       Val Loss: 0.2361, Val Accuracy: 93.691, Duration: 0:00:15.626235
# Epoch 61/400, Train Loss: 0.0976, Train Accuracy: 95.944       Val Loss: 0.2429, Val Accuracy: 92.617, Duration: 0:00:15.629227
# Epoch 62/400, Train Loss: 0.0782, Train Accuracy: 97.152       Val Loss: 0.2033, Val Accuracy: 94.631, Duration: 0:00:15.593323
# Epoch 63/400, Train Loss: 0.0752, Train Accuracy: 97.152       Val Loss: 0.2084, Val Accuracy: 93.826, Duration: 0:00:15.588336
# Epoch 64/400, Train Loss: 0.0784, Train Accuracy: 97.037       Val Loss: 0.2210, Val Accuracy: 94.765, Duration: 0:00:15.596315
# Epoch 65/400, Train Loss: 0.0988, Train Accuracy: 96.346       Val Loss: 0.2521, Val Accuracy: 93.020, Duration: 0:00:15.568390
# Epoch 66/400, Train Loss: 0.0903, Train Accuracy: 96.577       Val Loss: 0.2618, Val Accuracy: 92.215, Duration: 0:00:15.628229
# Epoch 67/400, Train Loss: 0.1075, Train Accuracy: 95.598       Val Loss: 0.2144, Val Accuracy: 93.154, Duration: 0:00:15.578363
# Epoch 68/400, Train Loss: 0.0618, Train Accuracy: 97.986       Val Loss: 0.2170, Val Accuracy: 93.423, Duration: 0:00:15.601302
# Epoch 69/400, Train Loss: 0.0612, Train Accuracy: 97.670       Val Loss: 0.2404, Val Accuracy: 93.826, Duration: 0:00:15.590331
# Epoch 70/400, Train Loss: 0.0863, Train Accuracy: 96.922       Val Loss: 0.2687, Val Accuracy: 92.081, Duration: 0:00:15.595318
# Epoch 71/400, Train Loss: 0.1043, Train Accuracy: 95.771       Val Loss: 0.2165, Val Accuracy: 93.423, Duration: 0:00:15.580358
# Epoch 72/400, Train Loss: 0.0863, Train Accuracy: 96.663       Val Loss: 0.2515, Val Accuracy: 93.960, Duration: 0:00:15.590331
# Epoch 73/400, Train Loss: 0.0831, Train Accuracy: 96.749       Val Loss: 0.2360, Val Accuracy: 94.228, Duration: 0:00:15.658149
# Epoch 74/400, Train Loss: 0.0618, Train Accuracy: 97.929       Val Loss: 0.2016, Val Accuracy: 94.631, Duration: 0:00:15.594321
# Epoch 75/400, Train Loss: 0.0791, Train Accuracy: 96.835       Val Loss: 0.3319, Val Accuracy: 90.738, Duration: 0:00:15.628229
# Epoch 76/400, Train Loss: 0.1087, Train Accuracy: 95.627       Val Loss: 0.2071, Val Accuracy: 94.228, Duration: 0:00:15.594320
# Epoch 77/400, Train Loss: 0.0665, Train Accuracy: 97.612       Val Loss: 0.2164, Val Accuracy: 94.765, Duration: 0:00:15.622246
# Epoch 78/400, Train Loss: 0.0565, Train Accuracy: 98.216       Val Loss: 0.2523, Val Accuracy: 93.289, Duration: 0:00:15.568389
# Epoch 79/400, Train Loss: 0.0706, Train Accuracy: 97.612       Val Loss: 0.2093, Val Accuracy: 94.362, Duration: 0:00:15.611276
# Epoch 80/400, Train Loss: 0.0593, Train Accuracy: 97.756       Val Loss: 0.2470, Val Accuracy: 94.094, Duration: 0:00:15.618256
# Epoch 81/400, Train Loss: 0.0671, Train Accuracy: 97.296       Val Loss: 0.2105, Val Accuracy: 94.899, Duration: 0:00:15.592326
# Epoch 82/400, Train Loss: 0.0596, Train Accuracy: 97.871       Val Loss: 0.2211, Val Accuracy: 94.631, Duration: 0:00:15.558416
# Epoch 83/400, Train Loss: 0.0624, Train Accuracy: 97.468       Val Loss: 0.2535, Val Accuracy: 93.020, Duration: 0:00:15.627232
# Epoch 84/400, Train Loss: 0.0625, Train Accuracy: 97.670       Val Loss: 0.2591, Val Accuracy: 93.691, Duration: 0:00:15.580358
# Epoch 85/400, Train Loss: 0.0647, Train Accuracy: 97.353       Val Loss: 0.2929, Val Accuracy: 92.886, Duration: 0:00:15.607285
# Epoch 86/400, Train Loss: 0.0888, Train Accuracy: 96.577       Val Loss: 0.2219, Val Accuracy: 93.154, Duration: 0:00:15.607287
# Epoch 87/400, Train Loss: 0.0567, Train Accuracy: 97.957       Val Loss: 0.2290, Val Accuracy: 94.362, Duration: 0:00:15.617258
# Epoch 88/400, Train Loss: 0.0536, Train Accuracy: 98.274       Val Loss: 0.3078, Val Accuracy: 92.617, Duration: 0:00:15.592326
# Epoch 89/400, Train Loss: 0.1033, Train Accuracy: 96.663       Val Loss: 0.2328, Val Accuracy: 94.899, Duration: 0:00:15.632219
# Epoch 90/400, Train Loss: 0.0729, Train Accuracy: 97.037       Val Loss: 0.2609, Val Accuracy: 92.349, Duration: 0:00:15.592326
# Epoch 91/400, Train Loss: 0.0415, Train Accuracy: 98.619       Val Loss: 0.2419, Val Accuracy: 94.899, Duration: 0:00:15.655157
# Epoch 92/400, Train Loss: 0.0281, Train Accuracy: 99.022       Val Loss: 0.2412, Val Accuracy: 94.497, Duration: 0:00:15.592326
# Epoch 93/400, Train Loss: 0.0333, Train Accuracy: 98.964       Val Loss: 0.3008, Val Accuracy: 92.483, Duration: 0:00:15.626235
# Epoch 94/400, Train Loss: 0.0680, Train Accuracy: 97.353       Val Loss: 0.2581, Val Accuracy: 94.765, Duration: 0:00:15.597313
# Epoch 95/400, Train Loss: 0.0442, Train Accuracy: 98.504       Val Loss: 0.2211, Val Accuracy: 95.168, Duration: 0:00:15.654160
# Epoch 96/400, Train Loss: 0.0515, Train Accuracy: 98.101       Val Loss: 0.2956, Val Accuracy: 92.752, Duration: 0:00:15.576368
# Epoch 97/400, Train Loss: 0.0798, Train Accuracy: 97.181       Val Loss: 0.2487, Val Accuracy: 94.497, Duration: 0:00:15.721979
# Epoch 98/400, Train Loss: 0.0462, Train Accuracy: 98.360       Val Loss: 0.3128, Val Accuracy: 92.483, Duration: 0:00:15.548443
# Epoch 99/400, Train Loss: 0.0731, Train Accuracy: 97.238       Val Loss: 0.2071, Val Accuracy: 95.302, Duration: 0:00:15.569387
# Epoch 100/400, Train Loss: 0.0688, Train Accuracy: 97.583       Val Loss: 0.2141, Val Accuracy: 94.228, Duration: 0:00:15.556422
# Epoch 101/400, Train Loss: 0.0237, Train Accuracy: 99.137       Val Loss: 0.2657, Val Accuracy: 94.631, Duration: 0:00:15.555424
# Epoch 102/400, Train Loss: 0.0366, Train Accuracy: 98.475       Val Loss: 0.2540, Val Accuracy: 93.691, Duration: 0:00:15.612273
# Epoch 103/400, Train Loss: 0.0653, Train Accuracy: 97.727       Val Loss: 0.2358, Val Accuracy: 94.631, Duration: 0:00:15.570383
# Epoch 104/400, Train Loss: 0.0517, Train Accuracy: 98.015       Val Loss: 0.2677, Val Accuracy: 93.154, Duration: 0:00:15.562406
# Epoch 105/400, Train Loss: 0.0361, Train Accuracy: 98.705       Val Loss: 0.2374, Val Accuracy: 94.228, Duration: 0:00:15.656155
# Epoch 106/400, Train Loss: 0.0308, Train Accuracy: 98.878       Val Loss: 0.2723, Val Accuracy: 94.362, Duration: 0:00:15.562406
# Epoch 107/400, Train Loss: 0.1049, Train Accuracy: 96.692       Val Loss: 0.2771, Val Accuracy: 92.215, Duration: 0:00:15.545451
# Epoch 108/400, Train Loss: 0.0542, Train Accuracy: 98.188       Val Loss: 0.2059, Val Accuracy: 94.765, Duration: 0:00:15.550437
# Epoch 109/400, Train Loss: 0.0303, Train Accuracy: 98.964       Val Loss: 0.2189, Val Accuracy: 94.765, Duration: 0:00:15.551436
# Epoch 110/400, Train Loss: 0.0384, Train Accuracy: 98.648       Val Loss: 0.2630, Val Accuracy: 94.362, Duration: 0:00:15.566394
# Epoch 111/400, Train Loss: 0.0279, Train Accuracy: 99.079       Val Loss: 0.2396, Val Accuracy: 94.899, Duration: 0:00:15.564401
# Epoch 112/400, Train Loss: 0.0262, Train Accuracy: 99.137       Val Loss: 0.2597, Val Accuracy: 94.497, Duration: 0:00:15.531488
# Epoch 113/400, Train Loss: 0.0495, Train Accuracy: 98.188       Val Loss: 0.2570, Val Accuracy: 93.960, Duration: 0:00:15.566395
# Epoch 114/400, Train Loss: 0.0476, Train Accuracy: 98.389       Val Loss: 0.2729, Val Accuracy: 94.899, Duration: 0:00:15.569388
# Epoch 115/400, Train Loss: 0.0708, Train Accuracy: 97.353       Val Loss: 0.2366, Val Accuracy: 94.094, Duration: 0:00:15.569386
# Epoch 116/400, Train Loss: 0.0409, Train Accuracy: 98.475       Val Loss: 0.2591, Val Accuracy: 94.094, Duration: 0:00:15.548443
# Epoch 117/400, Train Loss: 0.0419, Train Accuracy: 98.475       Val Loss: 0.2714, Val Accuracy: 94.497, Duration: 0:00:15.548444
# Epoch 118/400, Train Loss: 0.0248, Train Accuracy: 99.310       Val Loss: 0.2674, Val Accuracy: 93.960, Duration: 0:00:15.604293
# Epoch 119/400, Train Loss: 0.0192, Train Accuracy: 99.252       Val Loss: 0.3017, Val Accuracy: 93.423, Duration: 0:00:15.573377
# Epoch 120/400, Train Loss: 0.0787, Train Accuracy: 97.325       Val Loss: 0.3450, Val Accuracy: 91.544, Duration: 0:00:15.583349
# Epoch 121/400, Train Loss: 0.0570, Train Accuracy: 97.957       Val Loss: 0.2451, Val Accuracy: 94.228, Duration: 0:00:15.650171
# Epoch 122/400, Train Loss: 0.0277, Train Accuracy: 99.079       Val Loss: 0.2871, Val Accuracy: 93.960, Duration: 0:00:15.573376
# Epoch 123/400, Train Loss: 0.0209, Train Accuracy: 99.194       Val Loss: 0.2738, Val Accuracy: 94.497, Duration: 0:00:15.581355
# Epoch 124/400, Train Loss: 0.0379, Train Accuracy: 98.562       Val Loss: 0.2578, Val Accuracy: 94.899, Duration: 0:00:15.566396
# Epoch 125/400, Train Loss: 0.0619, Train Accuracy: 97.411       Val Loss: 0.2997, Val Accuracy: 92.483, Duration: 0:00:15.612272
# Epoch 126/400, Train Loss: 0.0359, Train Accuracy: 98.964       Val Loss: 0.2624, Val Accuracy: 95.034, Duration: 0:00:15.631222
# Epoch 127/400, Train Loss: 0.0379, Train Accuracy: 98.734       Val Loss: 0.4331, Val Accuracy: 89.262, Duration: 0:00:15.614266
# Epoch 128/400, Train Loss: 0.0642, Train Accuracy: 97.612       Val Loss: 0.2519, Val Accuracy: 94.899, Duration: 0:00:15.564401
# Epoch 129/400, Train Loss: 0.0397, Train Accuracy: 98.792       Val Loss: 0.2910, Val Accuracy: 93.826, Duration: 0:00:15.589334
# Epoch 130/400, Train Loss: 0.0243, Train Accuracy: 99.310       Val Loss: 0.2733, Val Accuracy: 94.362, Duration: 0:00:15.558417
# Epoch 131/400, Train Loss: 0.0552, Train Accuracy: 98.360       Val Loss: 0.2794, Val Accuracy: 94.497, Duration: 0:00:15.608283
# Epoch 132/400, Train Loss: 0.0375, Train Accuracy: 98.648       Val Loss: 0.2601, Val Accuracy: 93.289, Duration: 0:00:15.578363
# Epoch 133/400, Train Loss: 0.0452, Train Accuracy: 98.360       Val Loss: 0.2855, Val Accuracy: 94.094, Duration: 0:00:15.603295
# Epoch 134/400, Train Loss: 0.0340, Train Accuracy: 98.677       Val Loss: 0.2758, Val Accuracy: 93.423, Duration: 0:00:15.591329
# Epoch 135/400, Train Loss: 0.0166, Train Accuracy: 99.367       Val Loss: 0.3300, Val Accuracy: 92.886, Duration: 0:00:15.594321
# Epoch 136/400, Train Loss: 0.0622, Train Accuracy: 97.699       Val Loss: 0.2801, Val Accuracy: 92.886, Duration: 0:00:15.612271
# Epoch 137/400, Train Loss: 0.0723, Train Accuracy: 97.727       Val Loss: 0.2989, Val Accuracy: 92.886, Duration: 0:00:15.625238
# Epoch 138/400, Train Loss: 0.0386, Train Accuracy: 98.475       Val Loss: 0.2386, Val Accuracy: 95.436, Duration: 0:00:15.581356
# Epoch 139/400, Train Loss: 0.0218, Train Accuracy: 99.194       Val Loss: 0.2488, Val Accuracy: 94.765, Duration: 0:00:15.667125
# Epoch 140/400, Train Loss: 0.0122, Train Accuracy: 99.712       Val Loss: 0.2955, Val Accuracy: 95.034, Duration: 0:00:15.582353
# Epoch 141/400, Train Loss: 0.0193, Train Accuracy: 99.281       Val Loss: 0.2723, Val Accuracy: 95.302, Duration: 0:00:15.712005
# Epoch 142/400, Train Loss: 0.0467, Train Accuracy: 98.360       Val Loss: 0.3153, Val Accuracy: 93.826, Duration: 0:00:15.630225
# Epoch 143/400, Train Loss: 0.0196, Train Accuracy: 99.281       Val Loss: 0.2935, Val Accuracy: 94.631, Duration: 0:00:15.625238
# Epoch 144/400, Train Loss: 0.0405, Train Accuracy: 98.648       Val Loss: 0.3169, Val Accuracy: 93.691, Duration: 0:00:15.630509
# Epoch 145/400, Train Loss: 0.0487, Train Accuracy: 98.389       Val Loss: 0.2331, Val Accuracy: 95.302, Duration: 0:00:15.634609
# Epoch 146/400, Train Loss: 0.0358, Train Accuracy: 98.792       Val Loss: 0.2695, Val Accuracy: 94.631, Duration: 0:00:15.606214
# Epoch 147/400, Train Loss: 0.0284, Train Accuracy: 99.051       Val Loss: 0.2302, Val Accuracy: 94.497, Duration: 0:00:15.598310
# Epoch 148/400, Train Loss: 0.0189, Train Accuracy: 99.194       Val Loss: 0.2476, Val Accuracy: 94.631, Duration: 0:00:15.571382
# Epoch 149/400, Train Loss: 0.0258, Train Accuracy: 99.137       Val Loss: 0.3041, Val Accuracy: 94.094, Duration: 0:00:15.637205
# Epoch 150/400, Train Loss: 0.0380, Train Accuracy: 98.677       Val Loss: 0.2578, Val Accuracy: 94.899, Duration: 0:00:15.559414
# Epoch 151/400, Train Loss: 0.0333, Train Accuracy: 98.648       Val Loss: 0.2433, Val Accuracy: 95.034, Duration: 0:00:15.620251
# Epoch 152/400, Train Loss: 0.0194, Train Accuracy: 99.396       Val Loss: 0.2232, Val Accuracy: 95.436, Duration: 0:00:15.581355
# Epoch 153/400, Train Loss: 0.0312, Train Accuracy: 99.166       Val Loss: 0.2486, Val Accuracy: 94.362, Duration: 0:00:15.612272
# Epoch 154/400, Train Loss: 0.0378, Train Accuracy: 98.619       Val Loss: 0.2925, Val Accuracy: 94.362, Duration: 0:00:15.616262
# Epoch 155/400, Train Loss: 0.0534, Train Accuracy: 98.101       Val Loss: 0.2525, Val Accuracy: 93.289, Duration: 0:00:15.592326
# Epoch 156/400, Train Loss: 0.0328, Train Accuracy: 98.907       Val Loss: 0.2884, Val Accuracy: 93.826, Duration: 0:00:15.607286
# Epoch 157/400, Train Loss: 0.0557, Train Accuracy: 98.101       Val Loss: 0.2310, Val Accuracy: 95.034, Duration: 0:00:15.622245
# Epoch 158/400, Train Loss: 0.0296, Train Accuracy: 98.907       Val Loss: 0.2125, Val Accuracy: 95.168, Duration: 0:00:15.591329
# Epoch 159/400, Train Loss: 0.0162, Train Accuracy: 99.396       Val Loss: 0.2447, Val Accuracy: 95.570, Duration: 0:00:15.613270
# Epoch 160/400, Train Loss: 0.0153, Train Accuracy: 99.453       Val Loss: 0.2364, Val Accuracy: 95.705, Duration: 0:00:15.603297
# Epoch 161/400, Train Loss: 0.0247, Train Accuracy: 99.281       Val Loss: 0.3389, Val Accuracy: 93.557, Duration: 0:00:15.609280
# Epoch 162/400, Train Loss: 0.0666, Train Accuracy: 97.871       Val Loss: 0.2416, Val Accuracy: 93.826, Duration: 0:00:15.579360
# Epoch 163/400, Train Loss: 0.0369, Train Accuracy: 98.590       Val Loss: 0.3108, Val Accuracy: 94.094, Duration: 0:00:15.612273
# Epoch 164/400, Train Loss: 0.0460, Train Accuracy: 98.331       Val Loss: 0.2845, Val Accuracy: 94.631, Duration: 0:00:15.603296
# Epoch 165/400, Train Loss: 0.0423, Train Accuracy: 98.331       Val Loss: 0.2275, Val Accuracy: 95.570, Duration: 0:00:15.600305
# Epoch 166/400, Train Loss: 0.0131, Train Accuracy: 99.597       Val Loss: 0.2459, Val Accuracy: 95.034, Duration: 0:00:15.598310
# Epoch 167/400, Train Loss: 0.0077, Train Accuracy: 99.827       Val Loss: 0.2415, Val Accuracy: 95.436, Duration: 0:00:15.610278
# Epoch 168/400, Train Loss: 0.0042, Train Accuracy: 99.942       Val Loss: 0.2677, Val Accuracy: 95.839, Duration: 0:00:15.617258
# Epoch 169/400, Train Loss: 0.0057, Train Accuracy: 99.885       Val Loss: 0.2868, Val Accuracy: 95.570, Duration: 0:00:15.619254
# Epoch 170/400, Train Loss: 0.0190, Train Accuracy: 99.540       Val Loss: 0.3267, Val Accuracy: 93.557, Duration: 0:00:15.588337
# Epoch 171/400, Train Loss: 0.0861, Train Accuracy: 96.864       Val Loss: 0.2863, Val Accuracy: 93.691, Duration: 0:00:15.640198
# Epoch 172/400, Train Loss: 0.0458, Train Accuracy: 98.446       Val Loss: 0.2586, Val Accuracy: 94.228, Duration: 0:00:15.588337
# Epoch 173/400, Train Loss: 0.0337, Train Accuracy: 98.878       Val Loss: 0.2139, Val Accuracy: 95.168, Duration: 0:00:15.643189
# Epoch 174/400, Train Loss: 0.0227, Train Accuracy: 99.252       Val Loss: 0.2644, Val Accuracy: 95.168, Duration: 0:00:15.622245
# Epoch 175/400, Train Loss: 0.0109, Train Accuracy: 99.741       Val Loss: 0.2417, Val Accuracy: 94.765, Duration: 0:00:15.615266
# Epoch 176/400, Train Loss: 0.0063, Train Accuracy: 99.799       Val Loss: 0.2798, Val Accuracy: 95.034, Duration: 0:00:15.629226
# Epoch 177/400, Train Loss: 0.0329, Train Accuracy: 98.936       Val Loss: 0.2475, Val Accuracy: 95.034, Duration: 0:00:15.598310
# Epoch 178/400, Train Loss: 0.0205, Train Accuracy: 99.367       Val Loss: 0.2599, Val Accuracy: 95.302, Duration: 0:00:15.632219
# Epoch 179/400, Train Loss: 0.0776, Train Accuracy: 97.296       Val Loss: 0.2764, Val Accuracy: 94.497, Duration: 0:00:15.630224
# Epoch 180/400, Train Loss: 0.0613, Train Accuracy: 98.101       Val Loss: 0.2705, Val Accuracy: 93.020, Duration: 0:00:15.626235
# Epoch 181/400, Train Loss: 0.0429, Train Accuracy: 98.418       Val Loss: 0.2230, Val Accuracy: 94.094, Duration: 0:00:15.632219
# Epoch 182/400, Train Loss: 0.0451, Train Accuracy: 98.331       Val Loss: 0.2513, Val Accuracy: 95.034, Duration: 0:00:15.601302
# Epoch 183/400, Train Loss: 0.0415, Train Accuracy: 98.619       Val Loss: 0.2580, Val Accuracy: 94.497, Duration: 0:00:15.637205
# Epoch 184/400, Train Loss: 0.0127, Train Accuracy: 99.626       Val Loss: 0.2222, Val Accuracy: 95.839, Duration: 0:00:15.593323
# Epoch 185/400, Train Loss: 0.0126, Train Accuracy: 99.568       Val Loss: 0.2761, Val Accuracy: 94.631, Duration: 0:00:15.674107
# Epoch 186/400, Train Loss: 0.0156, Train Accuracy: 99.482       Val Loss: 0.2552, Val Accuracy: 95.168, Duration: 0:00:15.624241
# Epoch 187/400, Train Loss: 0.0189, Train Accuracy: 99.281       Val Loss: 0.2967, Val Accuracy: 93.557, Duration: 0:00:15.610277
# Epoch 188/400, Train Loss: 0.0280, Train Accuracy: 98.936       Val Loss: 0.2266, Val Accuracy: 95.168, Duration: 0:00:15.668123
# Epoch 189/400, Train Loss: 0.0351, Train Accuracy: 98.849       Val Loss: 0.2711, Val Accuracy: 95.034, Duration: 0:00:15.595318
# Epoch 190/400, Train Loss: 0.0113, Train Accuracy: 99.597       Val Loss: 0.2657, Val Accuracy: 95.436, Duration: 0:00:15.634214
# Epoch 191/400, Train Loss: 0.0130, Train Accuracy: 99.684       Val Loss: 0.2544, Val Accuracy: 95.436, Duration: 0:00:15.651168
# Epoch 192/400, Train Loss: 0.0083, Train Accuracy: 99.684       Val Loss: 0.2594, Val Accuracy: 95.302, Duration: 0:00:15.668123
# Epoch 193/400, Train Loss: 0.0120, Train Accuracy: 99.597       Val Loss: 0.2487, Val Accuracy: 94.899, Duration: 0:00:15.559413
# Epoch 194/400, Train Loss: 0.0160, Train Accuracy: 99.453       Val Loss: 0.2765, Val Accuracy: 94.631, Duration: 0:00:15.559414
# Epoch 195/400, Train Loss: 0.0100, Train Accuracy: 99.684       Val Loss: 0.2688, Val Accuracy: 95.839, Duration: 0:00:15.558416
# Epoch 196/400, Train Loss: 0.0250, Train Accuracy: 99.137       Val Loss: 0.2473, Val Accuracy: 95.168, Duration: 0:00:15.534482
# Epoch 197/400, Train Loss: 0.0362, Train Accuracy: 98.849       Val Loss: 0.2898, Val Accuracy: 94.228, Duration: 0:00:15.587338
# Epoch 198/400, Train Loss: 0.0360, Train Accuracy: 98.763       Val Loss: 0.2691, Val Accuracy: 94.228, Duration: 0:00:15.547445
# Epoch 199/400, Train Loss: 0.0384, Train Accuracy: 98.475       Val Loss: 0.2293, Val Accuracy: 95.436, Duration: 0:00:15.598311
# Epoch 200/400, Train Loss: 0.0430, Train Accuracy: 98.562       Val Loss: 0.3034, Val Accuracy: 94.497, Duration: 0:00:15.543455
# Epoch 201/400, Train Loss: 0.0086, Train Accuracy: 99.827       Val Loss: 0.2676, Val Accuracy: 95.436, Duration: 0:00:15.564401
# Epoch 202/400, Train Loss: 0.0217, Train Accuracy: 99.310       Val Loss: 0.2768, Val Accuracy: 94.497, Duration: 0:00:15.565397
# Epoch 203/400, Train Loss: 0.0355, Train Accuracy: 98.619       Val Loss: 0.2049, Val Accuracy: 95.973, Duration: 0:00:15.573377
# Epoch 204/400, Train Loss: 0.0209, Train Accuracy: 99.223       Val Loss: 0.2389, Val Accuracy: 95.839, Duration: 0:00:15.575371
# Epoch 205/400, Train Loss: 0.0060, Train Accuracy: 99.914       Val Loss: 0.3486, Val Accuracy: 94.094, Duration: 0:00:15.568389
# Epoch 206/400, Train Loss: 0.0385, Train Accuracy: 98.648       Val Loss: 0.2591, Val Accuracy: 95.034, Duration: 0:00:15.587339
# Epoch 207/400, Train Loss: 0.0095, Train Accuracy: 99.684       Val Loss: 0.2552, Val Accuracy: 94.899, Duration: 0:00:15.580358
# Epoch 208/400, Train Loss: 0.0034, Train Accuracy: 99.914       Val Loss: 0.2527, Val Accuracy: 95.436, Duration: 0:00:15.582353
# Epoch 209/400, Train Loss: 0.0024, Train Accuracy: 100.000       Val Loss: 0.2868, Val Accuracy: 95.705, Duration: 0:00:15.584347
# Epoch 210/400, Train Loss: 0.0060, Train Accuracy: 99.799       Val Loss: 0.2495, Val Accuracy: 95.839, Duration: 0:00:15.562405
# Epoch 211/400, Train Loss: 0.0130, Train Accuracy: 99.568       Val Loss: 0.3299, Val Accuracy: 93.557, Duration: 0:00:15.565398
# Epoch 212/400, Train Loss: 0.0297, Train Accuracy: 98.993       Val Loss: 0.2828, Val Accuracy: 94.497, Duration: 0:00:15.579360
# Epoch 213/400, Train Loss: 0.0365, Train Accuracy: 98.446       Val Loss: 0.2425, Val Accuracy: 94.362, Duration: 0:00:15.584347
# Epoch 214/400, Train Loss: 0.0191, Train Accuracy: 99.511       Val Loss: 0.2855, Val Accuracy: 94.631, Duration: 0:00:15.607286
# Epoch 215/400, Train Loss: 0.0214, Train Accuracy: 99.137       Val Loss: 0.2524, Val Accuracy: 95.436, Duration: 0:00:15.593323
# Epoch 216/400, Train Loss: 0.0569, Train Accuracy: 98.245       Val Loss: 0.2541, Val Accuracy: 94.631, Duration: 0:00:15.578363
# Epoch 217/400, Train Loss: 0.0412, Train Accuracy: 98.101       Val Loss: 0.2862, Val Accuracy: 93.826, Duration: 0:00:15.589334
# Epoch 218/400, Train Loss: 0.0139, Train Accuracy: 99.511       Val Loss: 0.2539, Val Accuracy: 95.168, Duration: 0:00:15.607285
# Epoch 219/400, Train Loss: 0.0064, Train Accuracy: 99.827       Val Loss: 0.2506, Val Accuracy: 95.973, Duration: 0:00:15.569387
# Epoch 220/400, Train Loss: 0.0057, Train Accuracy: 99.856       Val Loss: 0.2384, Val Accuracy: 95.436, Duration: 0:00:15.579360
# Epoch 221/400, Train Loss: 0.0103, Train Accuracy: 99.684       Val Loss: 0.2756, Val Accuracy: 95.436, Duration: 0:00:15.589334
# Epoch 222/400, Train Loss: 0.0147, Train Accuracy: 99.453       Val Loss: 0.3164, Val Accuracy: 96.242, Duration: 0:00:15.606288
# Epoch 223/400, Train Loss: 0.0218, Train Accuracy: 99.281       Val Loss: 0.2897, Val Accuracy: 94.765, Duration: 0:00:15.587340
# Epoch 224/400, Train Loss: 0.0206, Train Accuracy: 99.166       Val Loss: 0.2741, Val Accuracy: 95.436, Duration: 0:00:15.652165
# Epoch 225/400, Train Loss: 0.0226, Train Accuracy: 99.252       Val Loss: 0.2313, Val Accuracy: 96.107, Duration: 0:00:15.591328
# Epoch 226/400, Train Loss: 0.0176, Train Accuracy: 99.511       Val Loss: 0.2662, Val Accuracy: 95.570, Duration: 0:00:15.654161
# Epoch 227/400, Train Loss: 0.0117, Train Accuracy: 99.741       Val Loss: 0.2742, Val Accuracy: 95.034, Duration: 0:00:15.968767
# Epoch 228/400, Train Loss: 0.0287, Train Accuracy: 99.051       Val Loss: 0.2483, Val Accuracy: 95.839, Duration: 0:00:15.583349
# Epoch 229/400, Train Loss: 0.0112, Train Accuracy: 99.684       Val Loss: 0.2320, Val Accuracy: 95.973, Duration: 0:00:15.629227
# Epoch 230/400, Train Loss: 0.0481, Train Accuracy: 98.504       Val Loss: 0.2831, Val Accuracy: 94.631, Duration: 0:00:15.593323
# Epoch 231/400, Train Loss: 0.0302, Train Accuracy: 99.051       Val Loss: 0.3067, Val Accuracy: 94.228, Duration: 0:00:15.569387
# Epoch 232/400, Train Loss: 0.0430, Train Accuracy: 98.303       Val Loss: 0.2897, Val Accuracy: 93.557, Duration: 0:00:15.621248
# Epoch 233/400, Train Loss: 0.0390, Train Accuracy: 98.619       Val Loss: 0.2570, Val Accuracy: 95.034, Duration: 0:00:15.606289
# Epoch 234/400, Train Loss: 0.0185, Train Accuracy: 99.453       Val Loss: 0.2426, Val Accuracy: 95.436, Duration: 0:00:15.582353
# Epoch 235/400, Train Loss: 0.0297, Train Accuracy: 98.907       Val Loss: 0.2751, Val Accuracy: 94.497, Duration: 0:00:15.619253
# Epoch 236/400, Train Loss: 0.0065, Train Accuracy: 99.827       Val Loss: 0.2759, Val Accuracy: 94.899, Duration: 0:00:15.581355
# Epoch 237/400, Train Loss: 0.0111, Train Accuracy: 99.597       Val Loss: 0.2876, Val Accuracy: 95.168, Duration: 0:00:15.609280
# Epoch 238/400, Train Loss: 0.0080, Train Accuracy: 99.684       Val Loss: 0.2493, Val Accuracy: 96.107, Duration: 0:00:15.617259
# Epoch 239/400, Train Loss: 0.0033, Train Accuracy: 99.856       Val Loss: 0.2757, Val Accuracy: 95.034, Duration: 0:00:15.585345
# Epoch 240/400, Train Loss: 0.0033, Train Accuracy: 99.856       Val Loss: 0.2732, Val Accuracy: 96.107, Duration: 0:00:15.644187
# Epoch 241/400, Train Loss: 0.0013, Train Accuracy: 100.000       Val Loss: 0.3025, Val Accuracy: 95.168, Duration: 0:00:15.669120
# Epoch 242/400, Train Loss: 0.0027, Train Accuracy: 99.914       Val Loss: 0.3196, Val Accuracy: 95.705, Duration: 0:00:15.572380
# Epoch 243/400, Train Loss: 0.0094, Train Accuracy: 99.741       Val Loss: 0.2589, Val Accuracy: 95.705, Duration: 0:00:15.616261
# Epoch 244/400, Train Loss: 0.0130, Train Accuracy: 99.684       Val Loss: 0.3154, Val Accuracy: 95.168, Duration: 0:00:15.597313
# Epoch 245/400, Train Loss: 0.0017, Train Accuracy: 100.000       Val Loss: 0.3110, Val Accuracy: 95.436, Duration: 0:00:15.604293
# Epoch 246/400, Train Loss: 0.0009, Train Accuracy: 99.971       Val Loss: 0.3277, Val Accuracy: 94.899, Duration: 0:00:15.591330
# Epoch 247/400, Train Loss: 0.0053, Train Accuracy: 99.856       Val Loss: 0.2998, Val Accuracy: 95.436, Duration: 0:00:15.615263
# Epoch 248/400, Train Loss: 0.0212, Train Accuracy: 99.281       Val Loss: 0.3119, Val Accuracy: 94.094, Duration: 0:00:15.590331
# Epoch 249/400, Train Loss: 0.0359, Train Accuracy: 98.849       Val Loss: 0.3702, Val Accuracy: 92.752, Duration: 0:00:15.602299
# Epoch 250/400, Train Loss: 0.0856, Train Accuracy: 97.066       Val Loss: 0.2981, Val Accuracy: 93.154, Duration: 0:00:15.590331
# Epoch 251/400, Train Loss: 0.0277, Train Accuracy: 99.108       Val Loss: 0.2551, Val Accuracy: 95.436, Duration: 0:00:15.624241
# Epoch 252/400, Train Loss: 0.0223, Train Accuracy: 99.281       Val Loss: 0.3177, Val Accuracy: 93.423, Duration: 0:00:15.609280
# Epoch 253/400, Train Loss: 0.0164, Train Accuracy: 99.453       Val Loss: 0.2238, Val Accuracy: 94.765, Duration: 0:00:15.672113
# Epoch 254/400, Train Loss: 0.0093, Train Accuracy: 99.597       Val Loss: 0.2495, Val Accuracy: 94.899, Duration: 0:00:15.608283
# Epoch 255/400, Train Loss: 0.0072, Train Accuracy: 99.827       Val Loss: 0.2703, Val Accuracy: 94.631, Duration: 0:00:15.621248
# Epoch 256/400, Train Loss: 0.0126, Train Accuracy: 99.655       Val Loss: 0.2654, Val Accuracy: 95.168, Duration: 0:00:15.657153
# Epoch 257/400, Train Loss: 0.0183, Train Accuracy: 99.482       Val Loss: 0.2415, Val Accuracy: 95.436, Duration: 0:00:15.604294
# Epoch 258/400, Train Loss: 0.0292, Train Accuracy: 98.993       Val Loss: 0.2682, Val Accuracy: 94.899, Duration: 0:00:15.638202
# Epoch 259/400, Train Loss: 0.0162, Train Accuracy: 99.482       Val Loss: 0.2645, Val Accuracy: 94.899, Duration: 0:00:15.606289
# Epoch 260/400, Train Loss: 0.0256, Train Accuracy: 98.878       Val Loss: 0.3163, Val Accuracy: 94.631, Duration: 0:00:15.622245
# Epoch 261/400, Train Loss: 0.0236, Train Accuracy: 99.137       Val Loss: 0.2452, Val Accuracy: 94.362, Duration: 0:00:15.633216
# Epoch 262/400, Train Loss: 0.0094, Train Accuracy: 99.684       Val Loss: 0.2447, Val Accuracy: 94.899, Duration: 0:00:15.630225
# Epoch 263/400, Train Loss: 0.0056, Train Accuracy: 99.799       Val Loss: 0.2148, Val Accuracy: 96.107, Duration: 0:00:15.607286
# Epoch 264/400, Train Loss: 0.0048, Train Accuracy: 99.827       Val Loss: 0.3196, Val Accuracy: 94.631, Duration: 0:00:15.602299
# Epoch 265/400, Train Loss: 0.0198, Train Accuracy: 99.396       Val Loss: 0.3170, Val Accuracy: 94.631, Duration: 0:00:15.645184
# Epoch 266/400, Train Loss: 0.0232, Train Accuracy: 99.252       Val Loss: 0.3079, Val Accuracy: 94.497, Duration: 0:00:15.598310
# Epoch 267/400, Train Loss: 0.0452, Train Accuracy: 98.562       Val Loss: 0.2708, Val Accuracy: 94.228, Duration: 0:00:15.653163
# Epoch 268/400, Train Loss: 0.0381, Train Accuracy: 98.705       Val Loss: 0.3159, Val Accuracy: 94.228, Duration: 0:00:15.595317
# Epoch 269/400, Train Loss: 0.0142, Train Accuracy: 99.597       Val Loss: 0.2529, Val Accuracy: 95.034, Duration: 0:00:15.671116
# Epoch 270/400, Train Loss: 0.0258, Train Accuracy: 99.108       Val Loss: 0.2613, Val Accuracy: 94.228, Duration: 0:00:15.629227
# Epoch 271/400, Train Loss: 0.0104, Train Accuracy: 99.626       Val Loss: 0.2958, Val Accuracy: 94.497, Duration: 0:00:15.638204
# Epoch 272/400, Train Loss: 0.0115, Train Accuracy: 99.511       Val Loss: 0.2910, Val Accuracy: 94.631, Duration: 0:00:15.613268
# Epoch 273/400, Train Loss: 0.0031, Train Accuracy: 99.942       Val Loss: 0.2635, Val Accuracy: 95.302, Duration: 0:00:15.599308
# Epoch 274/400, Train Loss: 0.0019, Train Accuracy: 99.971       Val Loss: 0.2798, Val Accuracy: 95.302, Duration: 0:00:15.577365
# Epoch 275/400, Train Loss: 0.0017, Train Accuracy: 99.971       Val Loss: 0.2638, Val Accuracy: 95.839, Duration: 0:00:15.621249
# Epoch 276/400, Train Loss: 0.0006, Train Accuracy: 100.000       Val Loss: 0.2651, Val Accuracy: 95.973, Duration: 0:00:15.603296
# Epoch 277/400, Train Loss: 0.0003, Train Accuracy: 100.000       Val Loss: 0.2727, Val Accuracy: 95.705, Duration: 0:00:15.606288
# Epoch 278/400, Train Loss: 0.0002, Train Accuracy: 100.000       Val Loss: 0.2883, Val Accuracy: 95.705, Duration: 0:00:15.628230
# Epoch 279/400, Train Loss: 0.0003, Train Accuracy: 100.000       Val Loss: 0.2864, Val Accuracy: 95.570, Duration: 0:00:15.613270
# Epoch 280/400, Train Loss: 0.0003, Train Accuracy: 100.000       Val Loss: 0.2848, Val Accuracy: 95.570, Duration: 0:00:15.605291
# Epoch 281/400, Train Loss: 0.0002, Train Accuracy: 100.000       Val Loss: 0.2954, Val Accuracy: 95.436, Duration: 0:00:15.586341
# Epoch 282/400, Train Loss: 0.0002, Train Accuracy: 100.000       Val Loss: 0.2933, Val Accuracy: 95.302, Duration: 0:00:15.617259
# Epoch 283/400, Train Loss: 0.0021, Train Accuracy: 99.942       Val Loss: 0.3269, Val Accuracy: 94.765, Duration: 0:00:15.599307
# Epoch 284/400, Train Loss: 0.0467, Train Accuracy: 98.619       Val Loss: 0.3885, Val Accuracy: 92.617, Duration: 0:00:15.642192
# Epoch 285/400, Train Loss: 0.1195, Train Accuracy: 95.857       Val Loss: 0.2505, Val Accuracy: 94.497, Duration: 0:00:15.589333
# Epoch 286/400, Train Loss: 0.0354, Train Accuracy: 98.619       Val Loss: 0.2387, Val Accuracy: 94.631, Duration: 0:00:15.612272
# Epoch 287/400, Train Loss: 0.0207, Train Accuracy: 99.281       Val Loss: 0.2441, Val Accuracy: 94.765, Duration: 0:00:15.695051
# Epoch 288/400, Train Loss: 0.0102, Train Accuracy: 99.684       Val Loss: 0.2422, Val Accuracy: 95.436, Duration: 0:00:15.530491
# Epoch 289/400, Train Loss: 0.0028, Train Accuracy: 99.971       Val Loss: 0.2466, Val Accuracy: 95.302, Duration: 0:00:15.540465
# Epoch 290/400, Train Loss: 0.0099, Train Accuracy: 99.827       Val Loss: 0.2560, Val Accuracy: 94.765, Duration: 0:00:15.548443
# Epoch 291/400, Train Loss: 0.0256, Train Accuracy: 99.166       Val Loss: 0.2972, Val Accuracy: 94.899, Duration: 0:00:15.557419
# Epoch 292/400, Train Loss: 0.0204, Train Accuracy: 99.137       Val Loss: 0.2620, Val Accuracy: 94.899, Duration: 0:00:15.536475
# Epoch 293/400, Train Loss: 0.0126, Train Accuracy: 99.655       Val Loss: 0.2670, Val Accuracy: 94.899, Duration: 0:00:15.526501
# Epoch 294/400, Train Loss: 0.0091, Train Accuracy: 99.856       Val Loss: 0.2502, Val Accuracy: 95.705, Duration: 0:00:15.590331
# Epoch 295/400, Train Loss: 0.0701, Train Accuracy: 97.814       Val Loss: 0.2776, Val Accuracy: 94.631, Duration: 0:00:15.552433
# Epoch 296/400, Train Loss: 0.0282, Train Accuracy: 98.792       Val Loss: 0.2721, Val Accuracy: 94.631, Duration: 0:00:15.531487
# Epoch 297/400, Train Loss: 0.0158, Train Accuracy: 99.597       Val Loss: 0.2222, Val Accuracy: 95.839, Duration: 0:00:15.532486
# Epoch 298/400, Train Loss: 0.0082, Train Accuracy: 99.741       Val Loss: 0.2236, Val Accuracy: 95.705, Duration: 0:00:15.524507
# Epoch 299/400, Train Loss: 0.0084, Train Accuracy: 99.741       Val Loss: 0.2224, Val Accuracy: 95.168, Duration: 0:00:15.543456
# Epoch 300/400, Train Loss: 0.0200, Train Accuracy: 99.310       Val Loss: 0.2566, Val Accuracy: 95.302, Duration: 0:00:15.536476
# Epoch 301/400, Train Loss: 0.0077, Train Accuracy: 99.827       Val Loss: 0.2457, Val Accuracy: 95.168, Duration: 0:00:15.552432
# Epoch 302/400, Train Loss: 0.0048, Train Accuracy: 99.827       Val Loss: 0.2546, Val Accuracy: 95.705, Duration: 0:00:15.532485
# Epoch 303/400, Train Loss: 0.0109, Train Accuracy: 99.712       Val Loss: 0.2564, Val Accuracy: 95.034, Duration: 0:00:15.534481
# Epoch 304/400, Train Loss: 0.0031, Train Accuracy: 99.914       Val Loss: 0.3037, Val Accuracy: 95.839, Duration: 0:00:15.530491
# Epoch 305/400, Train Loss: 0.0038, Train Accuracy: 99.885       Val Loss: 0.2477, Val Accuracy: 95.839, Duration: 0:00:15.549441
# Epoch 306/400, Train Loss: 0.0013, Train Accuracy: 100.000       Val Loss: 0.2744, Val Accuracy: 95.570, Duration: 0:00:15.574373
# Epoch 307/400, Train Loss: 0.0004, Train Accuracy: 100.000       Val Loss: 0.2817, Val Accuracy: 95.302, Duration: 0:00:15.552433
# Epoch 308/400, Train Loss: 0.0016, Train Accuracy: 99.942       Val Loss: 0.3070, Val Accuracy: 94.765, Duration: 0:00:15.570384
# Epoch 309/400, Train Loss: 0.0016, Train Accuracy: 99.942       Val Loss: 0.3008, Val Accuracy: 95.570, Duration: 0:00:15.543456
# Epoch 310/400, Train Loss: 0.0132, Train Accuracy: 99.741       Val Loss: 0.3185, Val Accuracy: 94.094, Duration: 0:00:15.593323
# Epoch 311/400, Train Loss: 0.0685, Train Accuracy: 97.986       Val Loss: 0.2430, Val Accuracy: 93.960, Duration: 0:00:15.593323
# Epoch 312/400, Train Loss: 0.0536, Train Accuracy: 98.188       Val Loss: 0.2901, Val Accuracy: 94.094, Duration: 0:00:15.540465
# Epoch 313/400, Train Loss: 0.0334, Train Accuracy: 99.022       Val Loss: 0.2307, Val Accuracy: 95.168, Duration: 0:00:15.576368
# Epoch 314/400, Train Loss: 0.0128, Train Accuracy: 99.568       Val Loss: 0.2092, Val Accuracy: 95.973, Duration: 0:00:15.640198
# Epoch 315/400, Train Loss: 0.0038, Train Accuracy: 99.914       Val Loss: 0.2374, Val Accuracy: 95.168, Duration: 0:00:15.579360
# Epoch 316/400, Train Loss: 0.0043, Train Accuracy: 99.914       Val Loss: 0.2491, Val Accuracy: 95.302, Duration: 0:00:15.612272
# Epoch 317/400, Train Loss: 0.0018, Train Accuracy: 99.971       Val Loss: 0.2491, Val Accuracy: 95.973, Duration: 0:00:15.554427
# Epoch 318/400, Train Loss: 0.0008, Train Accuracy: 100.000       Val Loss: 0.2620, Val Accuracy: 95.973, Duration: 0:00:15.617259
# Epoch 319/400, Train Loss: 0.0012, Train Accuracy: 99.971       Val Loss: 0.2658, Val Accuracy: 95.973, Duration: 0:00:15.585344
# Epoch 320/400, Train Loss: 0.0007, Train Accuracy: 100.000       Val Loss: 0.2680, Val Accuracy: 95.839, Duration: 0:00:15.598310
# Epoch 321/400, Train Loss: 0.0004, Train Accuracy: 100.000       Val Loss: 0.2565, Val Accuracy: 95.973, Duration: 0:00:15.600305
# Epoch 322/400, Train Loss: 0.0004, Train Accuracy: 100.000       Val Loss: 0.2747, Val Accuracy: 95.839, Duration: 0:00:15.644187
# Epoch 323/400, Train Loss: 0.0003, Train Accuracy: 100.000       Val Loss: 0.2813, Val Accuracy: 96.107, Duration: 0:00:15.877565
# Epoch 324/400, Train Loss: 0.0002, Train Accuracy: 100.000       Val Loss: 0.2954, Val Accuracy: 95.839, Duration: 0:00:15.948372
# Epoch 325/400, Train Loss: 0.0002, Train Accuracy: 100.000       Val Loss: 0.2942, Val Accuracy: 95.570, Duration: 0:00:16.002230
# Epoch 326/400, Train Loss: 0.0002, Train Accuracy: 100.000       Val Loss: 0.2769, Val Accuracy: 95.570, Duration: 0:00:16.355286
# Epoch 327/400, Train Loss: 0.0112, Train Accuracy: 99.511       Val Loss: 0.3670, Val Accuracy: 93.691, Duration: 0:00:16.346310
# Epoch 328/400, Train Loss: 0.0458, Train Accuracy: 98.504       Val Loss: 0.2940, Val Accuracy: 94.362, Duration: 0:00:15.870582
# Epoch 329/400, Train Loss: 0.0677, Train Accuracy: 97.699       Val Loss: 0.3034, Val Accuracy: 94.899, Duration: 0:00:15.586342
# Epoch 330/400, Train Loss: 0.0253, Train Accuracy: 99.252       Val Loss: 0.2715, Val Accuracy: 95.034, Duration: 0:00:15.565398
# Epoch 331/400, Train Loss: 0.0111, Train Accuracy: 99.626       Val Loss: 0.2712, Val Accuracy: 95.302, Duration: 0:00:15.598309
# Epoch 332/400, Train Loss: 0.0254, Train Accuracy: 99.223       Val Loss: 0.2443, Val Accuracy: 95.839, Duration: 0:00:15.642192
# Epoch 333/400, Train Loss: 0.0422, Train Accuracy: 98.475       Val Loss: 0.2825, Val Accuracy: 93.289, Duration: 0:00:15.570384
# Epoch 334/400, Train Loss: 0.0272, Train Accuracy: 99.108       Val Loss: 0.3153, Val Accuracy: 93.557, Duration: 0:00:15.569387
# Epoch 335/400, Train Loss: 0.0117, Train Accuracy: 99.597       Val Loss: 0.2508, Val Accuracy: 95.839, Duration: 0:00:15.583350
# Epoch 336/400, Train Loss: 0.0250, Train Accuracy: 99.079       Val Loss: 0.3242, Val Accuracy: 94.094, Duration: 0:00:15.578363
# Epoch 337/400, Train Loss: 0.0176, Train Accuracy: 99.281       Val Loss: 0.2659, Val Accuracy: 94.228, Duration: 0:00:15.603297
# Epoch 338/400, Train Loss: 0.0177, Train Accuracy: 99.338       Val Loss: 0.3053, Val Accuracy: 94.497, Duration: 0:00:15.552432
# Epoch 339/400, Train Loss: 0.0075, Train Accuracy: 99.712       Val Loss: 0.2230, Val Accuracy: 95.570, Duration: 0:00:15.623242
# Epoch 340/400, Train Loss: 0.0072, Train Accuracy: 99.770       Val Loss: 0.2121, Val Accuracy: 96.107, Duration: 0:00:15.568390
# Epoch 341/400, Train Loss: 0.0042, Train Accuracy: 99.914       Val Loss: 0.2493, Val Accuracy: 95.973, Duration: 0:00:15.595318
# Epoch 342/400, Train Loss: 0.0063, Train Accuracy: 99.856       Val Loss: 0.2731, Val Accuracy: 95.839, Duration: 0:00:15.593323
# Epoch 343/400, Train Loss: 0.0024, Train Accuracy: 99.942       Val Loss: 0.2307, Val Accuracy: 95.570, Duration: 0:00:15.626235
# Epoch 344/400, Train Loss: 0.0156, Train Accuracy: 99.568       Val Loss: 0.2504, Val Accuracy: 95.570, Duration: 0:00:15.570384
# Epoch 345/400, Train Loss: 0.0503, Train Accuracy: 98.418       Val Loss: 0.2268, Val Accuracy: 95.436, Duration: 0:00:15.585344
# Epoch 346/400, Train Loss: 0.0162, Train Accuracy: 99.367       Val Loss: 0.2885, Val Accuracy: 95.436, Duration: 0:00:15.603297
# Epoch 347/400, Train Loss: 0.0082, Train Accuracy: 99.712       Val Loss: 0.3069, Val Accuracy: 94.631, Duration: 0:00:15.585344
# Epoch 348/400, Train Loss: 0.0074, Train Accuracy: 99.770       Val Loss: 0.2770, Val Accuracy: 95.705, Duration: 0:00:15.598309
# Epoch 349/400, Train Loss: 0.0060, Train Accuracy: 99.856       Val Loss: 0.2608, Val Accuracy: 95.168, Duration: 0:00:15.593323
# Epoch 350/400, Train Loss: 0.0130, Train Accuracy: 99.597       Val Loss: 0.3384, Val Accuracy: 94.631, Duration: 0:00:15.638203
# Epoch 351/400, Train Loss: 0.0356, Train Accuracy: 98.820       Val Loss: 0.2517, Val Accuracy: 93.960, Duration: 0:00:15.624241
# Epoch 352/400, Train Loss: 0.0129, Train Accuracy: 99.453       Val Loss: 0.2402, Val Accuracy: 95.168, Duration: 0:00:15.601303
# Epoch 353/400, Train Loss: 0.0183, Train Accuracy: 99.396       Val Loss: 0.2413, Val Accuracy: 95.168, Duration: 0:00:15.612271
# Epoch 354/400, Train Loss: 0.0026, Train Accuracy: 99.942       Val Loss: 0.2761, Val Accuracy: 95.168, Duration: 0:00:15.597313
# Epoch 355/400, Train Loss: 0.0021, Train Accuracy: 99.971       Val Loss: 0.2759, Val Accuracy: 95.436, Duration: 0:00:15.564399
# Epoch 356/400, Train Loss: 0.0027, Train Accuracy: 99.914       Val Loss: 0.2534, Val Accuracy: 95.705, Duration: 0:00:15.608284
# Epoch 357/400, Train Loss: 0.0007, Train Accuracy: 100.000       Val Loss: 0.2702, Val Accuracy: 95.302, Duration: 0:00:15.734944
# Epoch 358/400, Train Loss: 0.0003, Train Accuracy: 100.000       Val Loss: 0.2767, Val Accuracy: 95.436, Duration: 0:00:15.564400
# Epoch 359/400, Train Loss: 0.0039, Train Accuracy: 99.856       Val Loss: 0.2525, Val Accuracy: 95.705, Duration: 0:00:15.587340
# Epoch 360/400, Train Loss: 0.0026, Train Accuracy: 99.885       Val Loss: 0.2206, Val Accuracy: 95.705, Duration: 0:00:15.575371
# Epoch 361/400, Train Loss: 0.0049, Train Accuracy: 99.827       Val Loss: 0.2714, Val Accuracy: 95.705, Duration: 0:00:15.608283
# Epoch 362/400, Train Loss: 0.0134, Train Accuracy: 99.338       Val Loss: 0.2746, Val Accuracy: 95.570, Duration: 0:00:15.622246
# Epoch 363/400, Train Loss: 0.0172, Train Accuracy: 99.367       Val Loss: 0.2888, Val Accuracy: 95.436, Duration: 0:00:15.609280
# Epoch 364/400, Train Loss: 0.0116, Train Accuracy: 99.597       Val Loss: 0.2937, Val Accuracy: 95.302, Duration: 0:00:15.635211
# Epoch 365/400, Train Loss: 0.0336, Train Accuracy: 99.079       Val Loss: 0.2979, Val Accuracy: 93.960, Duration: 0:00:15.622246
# Epoch 366/400, Train Loss: 0.0346, Train Accuracy: 98.533       Val Loss: 0.3114, Val Accuracy: 94.631, Duration: 0:00:15.588336
# Epoch 367/400, Train Loss: 0.0897, Train Accuracy: 97.037       Val Loss: 0.2461, Val Accuracy: 94.497, Duration: 0:00:15.609281
# Epoch 368/400, Train Loss: 0.0182, Train Accuracy: 99.338       Val Loss: 0.2158, Val Accuracy: 95.973, Duration: 0:00:15.610278
# Epoch 369/400, Train Loss: 0.0035, Train Accuracy: 99.942       Val Loss: 0.2340, Val Accuracy: 95.705, Duration: 0:00:15.697538
# Epoch 370/400, Train Loss: 0.0021, Train Accuracy: 99.971       Val Loss: 0.2262, Val Accuracy: 95.839, Duration: 0:00:15.619254
# Epoch 371/400, Train Loss: 0.0027, Train Accuracy: 99.942       Val Loss: 0.2030, Val Accuracy: 96.242, Duration: 0:00:15.597312
# Epoch 372/400, Train Loss: 0.0011, Train Accuracy: 100.000       Val Loss: 0.2230, Val Accuracy: 96.644, Duration: 0:00:15.632220
# Epoch 373/400, Train Loss: 0.0006, Train Accuracy: 100.000       Val Loss: 0.2296, Val Accuracy: 96.242, Duration: 0:00:15.634214
# Epoch 374/400, Train Loss: 0.0005, Train Accuracy: 100.000       Val Loss: 0.2214, Val Accuracy: 96.242, Duration: 0:00:15.592325
# Epoch 375/400, Train Loss: 0.0004, Train Accuracy: 100.000       Val Loss: 0.2266, Val Accuracy: 96.242, Duration: 0:00:15.621249
# Epoch 376/400, Train Loss: 0.0004, Train Accuracy: 100.000       Val Loss: 0.2454, Val Accuracy: 96.242, Duration: 0:00:15.620251
# Epoch 377/400, Train Loss: 0.0005, Train Accuracy: 100.000       Val Loss: 0.2530, Val Accuracy: 95.973, Duration: 0:00:15.581355
# Epoch 378/400, Train Loss: 0.0006, Train Accuracy: 99.971       Val Loss: 0.2478, Val Accuracy: 96.107, Duration: 0:00:15.651168
# Epoch 379/400, Train Loss: 0.0008, Train Accuracy: 100.000       Val Loss: 0.2652, Val Accuracy: 95.705, Duration: 0:00:15.585345
# Epoch 380/400, Train Loss: 0.0004, Train Accuracy: 100.000       Val Loss: 0.2713, Val Accuracy: 95.570, Duration: 0:00:15.668123
# Epoch 381/400, Train Loss: 0.0002, Train Accuracy: 100.000       Val Loss: 0.2775, Val Accuracy: 95.973, Duration: 0:00:15.607285
# Epoch 382/400, Train Loss: 0.0002, Train Accuracy: 100.000       Val Loss: 0.2980, Val Accuracy: 95.302, Duration: 0:00:15.620252
# Epoch 383/400, Train Loss: 0.0001, Train Accuracy: 100.000       Val Loss: 0.2793, Val Accuracy: 95.839, Duration: 0:00:15.712005
# Epoch 384/400, Train Loss: 0.0002, Train Accuracy: 100.000       Val Loss: 0.2700, Val Accuracy: 95.705, Duration: 0:00:15.577366
# Epoch 385/400, Train Loss: 0.0002, Train Accuracy: 100.000       Val Loss: 0.2805, Val Accuracy: 95.973, Duration: 0:00:15.535478
# Epoch 386/400, Train Loss: 0.0001, Train Accuracy: 100.000       Val Loss: 0.2739, Val Accuracy: 95.973, Duration: 0:00:15.538469
# Epoch 387/400, Train Loss: 0.0001, Train Accuracy: 100.000       Val Loss: 0.2860, Val Accuracy: 95.973, Duration: 0:00:15.577366
# Epoch 388/400, Train Loss: 0.0002, Train Accuracy: 100.000       Val Loss: 0.2887, Val Accuracy: 95.705, Duration: 0:00:15.557419
# Epoch 389/400, Train Loss: 0.0047, Train Accuracy: 99.885       Val Loss: 0.3465, Val Accuracy: 95.034, Duration: 0:00:15.564401
# Epoch 390/400, Train Loss: 0.0867, Train Accuracy: 97.325       Val Loss: 0.2268, Val Accuracy: 94.899, Duration: 0:00:15.544453
# Epoch 391/400, Train Loss: 0.0593, Train Accuracy: 97.929       Val Loss: 0.2370, Val Accuracy: 94.899, Duration: 0:00:15.570384
# Epoch 392/400, Train Loss: 0.0226, Train Accuracy: 99.108       Val Loss: 0.2206, Val Accuracy: 95.839, Duration: 0:00:15.550438
# Epoch 393/400, Train Loss: 0.0066, Train Accuracy: 99.914       Val Loss: 0.2527, Val Accuracy: 95.570, Duration: 0:00:15.535478
# Epoch 394/400, Train Loss: 0.0091, Train Accuracy: 99.684       Val Loss: 0.2738, Val Accuracy: 95.034, Duration: 0:00:15.563403
# Epoch 395/400, Train Loss: 0.0402, Train Accuracy: 98.792       Val Loss: 0.2290, Val Accuracy: 94.899, Duration: 0:00:15.564400
# Epoch 396/400, Train Loss: 0.0122, Train Accuracy: 99.568       Val Loss: 0.2661, Val Accuracy: 95.302, Duration: 0:00:15.561409
# Epoch 397/400, Train Loss: 0.0043, Train Accuracy: 99.942       Val Loss: 0.2481, Val Accuracy: 95.436, Duration: 0:00:15.558416
# Epoch 398/400, Train Loss: 0.0034, Train Accuracy: 99.942       Val Loss: 0.2525, Val Accuracy: 95.034, Duration: 0:00:15.547446
# Epoch 399/400, Train Loss: 0.0052, Train Accuracy: 99.827       Val Loss: 0.2746, Val Accuracy: 95.705, Duration: 0:00:15.576368
# Epoch 400/400, Train Loss: 0.0193, Train Accuracy: 99.482       Val Loss: 0.2407, Val Accuracy: 95.436, Duration: 0:00:15.561409

# %%
images, labels = val_dataiter.next()
out_img, predicted = torch.max(model(images.to(device)), 1)
imshow(images[:7], labels[:7], predicted[:7])

# %%
# Plot the train loss and test loss per iteration
plt.plot(train_losses, label='train loss')
plt.plot(val_losses, label='val loss')
plt.legend()
plt.show()

# %%
test_loss = []
test_acc = []
n_correct = 0.
n_total = 0.
model.eval()
with torch.no_grad():
    for inputs, targets in Dte:
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = model(inputs)

        # Get the predictions
        # torch.max returns both max and argmax
        __, out_label = outputs.max(dim=1)
        # Updates the accuracy with every pass
        n_correct += (out_label == targets).sum().item()
        n_total += targets.shape[0]
        test_acc.append(n_correct / n_total)

        loss = loss_fn(outputs, targets)
        test_loss.append(loss.item())
test_loss = np.mean(test_loss)
avg_acc = np.mean(test_acc)*100
print('Average loss across the testing data: {}, Average testing accuracy: {}'.format(test_loss, avg_acc))
# Out:
# Average loss across the testing data: 0.19015280219415823, Average testing accuracy: 95.77926904446147

# %% [markdown]
# Same but horizontal flip is 0.6
# val loss = 2.9, acc = 90, min val loss= 0.207
# -------------
# back to first settings without vertical flip
# n_layers=5
# average loss across testing data: 0.2088
# average test acc = 92.42
# -------------
# Same.
# n_layers =4
# average loss: 0.1977
# avg acc: 93.62
# -------------
# Same.
# n_layers=3
# avg loss: 0.1905
# avg acc: 92.67
# -------------
# Same.
# n_layers=2
# avg loss: 0.1897
# avg acc: 93.19
# -------------
# Same.
# n_layers=1
# avg loss: 0.2689
# avg acc: 93.03
# -------------
# Same.
# n_layers=4
# n_heads=2
# avg loss: 0.1886
# avg acc: 91.93
# -------------
# Same.
# embed_dim=48
# n_layers=4
# n_heads=6
# avg loss: 0.1704
# avg acc: 94.53
# -------------
# Same.
# embed_dim=48
# n_layers=4
# n_heads=8
# avg loss: 0.2473
# avg acc: 92.14
# -------------
# Same.
# embed_dim=48
# n_layers=4
# n_heads=6
# mlp_ratio=3
# avg loss: 0.2230
# avg acc: 93.37
# -------------
# Same.
# embed_dim=48
# n_layers=4
# n_heads=6
# mlp_ratio=4
# avg loss: 0.2096
# avg acc: 95.14
# -------------
# Same.
# embed_dim=48
# n_layers=4
# n_heads=6
# mlp_ratio=2
# epochs=300
# avg loss: 0.2462
# avg acc: 95.10
# -------------
# Same.
# Switched train/val/test to 70/15/15
# epochs=100
# avg loss: 0.3025
# avg acc: 93
# -------------
# Same.
# Activated a Normalizing thing in convolutional layer
# epochs=100
# avg loss: 0.2050
# avg acc: 95.17
# -------------
# Same.
# epochs=300
# avg loss: 0.1853
# avg acc: 95.97
# -------------
# Same.
# embedded dimensions set to 36
# epochs=300
# avg loss: 0.2114
# avg acc: 96.18
# -------------
# Same.
# embedded dimensions set to 42
# epochs=300
# avg loss: 0.2116
# avg acc: 94.52
# -------------
# Same.
# epochs=600
# avg loss: 0.2193
# avg acc: 96.69

# %% [markdown]
# ### 5 Class Sipakmed
#
# batches = 96, image size = 160
# model = CCT(
#         img_size=img_size,      # Input image size
#         in_channels=3,  # Number of channels for the image
#         patch_size=4,   # How big our patches are
#         embed_dim=42,   # Embedding dim
#         n_layers=4,     # Number of transformer encoders
#         n_conv=2,       # Number of convolutional layers
#         n_heads=6,      # Number of attention heads
#         attn_dropout=0.,        # Attention Dropout
#         proj_dropout=0.,        # (MHA) Projection Dropout
#         mlp_dropout=0.1,        # (MHA) last layer dropout
#         mlp_ratio=2,    # (MHA) Projection FF dimension
#         qkv_bias = True,
#         n_classes=5     # Number of classes to classify
#         )
# epochs = 300, avg loss = 0.1707, avg acc = 95.27
#
# ### 3 Class Sipakmed and Herlev
#
# batches = 96, image size = 160
# model = CCT(
#         img_size=img_size,      # Input image size
#         in_channels=3,  # Number of channels for the image
#         patch_size=4,   # How big our patches are
#         embed_dim=42,   # Embedding dim
#         n_layers=4,     # Number of transformer encoders
#         n_conv=2,       # Number of convolutional layers
#         n_heads=6,      # Number of attention heads
#         attn_dropout=0.,        # Attention Dropout
#         proj_dropout=0.,        # (MHA) Projection Dropout
#         mlp_dropout=0.1,        # (MHA) last layer dropout
#         mlp_ratio=2,    # (MHA) Projection FF dimension
#         qkv_bias = True,
#         n_classes=3     # Number of classes to classify
#         )
# epochs = 300, avg loss = 0.1668, avg acc = 95.41
#
# ### 7 Class Herlev
#
# batches = 64, image size = 84model = CCT(
#         img_size=img_size,      # Input image size
#         in_channels=3,  # Number of channels for the image
#         patch_size=4,   # How big our patches are
#         embed_dim=128,   # Embedding dim
#         n_layers=2,     # Number of transformer encoders
#         n_conv=2,       # Number of convolutional layers
#         n_heads=2,      # Number of attention heads
#         attn_dropout=0.,        # Attention Dropout
#         proj_dropout=0.,        # (MHA) Projection Dropout
#         mlp_dropout=0.1,        # (MHA) last layer dropout
#         mlp_ratio=1,    # (MHA) Projection FF dimension
#         qkv_bias = True,
#         n_classes=7     # Number of classes to classify
#         )
# epochs = 100, avg loss = 1.520, avg acc = 62.20

# %%
import os
from PIL import Image
import torch
from torch.utils.data import DataLoader,Dataset
import torch.nn as nn
from torch import Tensor
import torchvision
import torchvision.transforms as transforms
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import torch.nn.functional as F
from datetime import datetime
from sklearn.model_selection import train_test_split

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
torch.backends.cudnn.benchmark = True

# %% [markdown]
# # A Compact Convolutional Vision Transformer or CCT
# *Created using the walkthrough from https://medium.com/pytorch/training-compact-transformers-from-scratch-in-30-minutes-with-pytorch-ff5c21668ed5 and Dr Prashant's Vision_Transformer file

# %% [markdown]
# ## Building the Transformer block by block

# %% [markdown]
# Every part/layer of the transformer is built using the Pytorch nn.module class which allows for easy creation of maching learning models. Each layer should be made up of at least two parts: An initialization function which uses the given information to build the class and then the 'Forward' function defines how the class will run when it is called.

# %% [markdown]
# ### Transformer Constructor
#
# First, the actual ViT Constructor which essentially acts as a hub. It ensures that each part of the transformer is called in the correct order and that local variables can be passed along.

# %% [markdown]
# ### What makes it more Compact/Lite than the CVT?
#
# The only difference between this and the original Vision Transformer is a Sequence Pooling layer and a convolutional layer instead of patching. Previously the classes were embedded separately and then passed to the MLP for classification. Sequence Pooling ties the class information in with every other parameter.. I think.

# %%
class CCT(nn.Module):
    '''
    Simplified implementation of the Vision transformer.

    Parameters
    ----------
    img_size: int
        Both height and width of the image (if it is a square)
    in_channels: int
        Number of input channels
    patch_size: int
        Both height and width of the patch (if it is a square)
    embed_dim: int
        The embedding size for each token
    n_layers: int
        Number of transformer blocks
    n_heads: int
        Number of attention heads
    attn_dropout, proj_dropout, mlp_dropout: float
        Dropout probability
    mlp_ratio: float
        Determine the hidden dimension of the MLP module
    qkv_bias: bool
        If true then we add bias to the query, key and value projections
    n_classes: int
        Number of classes

    Attributes
    -----------
    n_patches: int
        Number of patches that can be taken from each image based on size.
    patch_embed: PatchEmbed
        Sets up the `Patching' layer.
    class_embed: nn.Parameter
        Learnable parameter that will represent the first class token in the sequence.
        It has `embed_dim' elements.
    pos_embed: nn.Parameter
        Adds a positional encoding to every token.
    pos_drop: nn.Dropout
        Dropout layer.
    tr_block: nn.ModuleList
        Instance of 'TransformerEncoderLayer'.
    norm: nn.Layernorm
        Layer normalization.
    '''
    def __init__(self,
                 img_size=32,   # The square size of each image
                 in_channels=3, # Number of channels for each image (eg: Grayscale=1, RGB=3)
                 patch_size=4,  # The square size of each patch
                 embed_dim=768,  # Embedding dimension
                 n_layers=3, # How many times to run the transformer encoder
                 n_conv=2,
                 n_heads=3,   # Number of attention heads,
                 attn_dropout=0.,  # Attention Dropout
                 proj_dropout=0.,   # (MHA) Projection Dropout
                 mlp_dropout=0.,   # (MHA) last layer dropout
                 mlp_ratio=4,   # (MHA) Projection FF dimension
                 qkv_bias = True,
                 n_classes=10   # Number of classes to classify
    ):
        super().__init__()
        # Provides an error if the patching size is not divisible by the image size.
        assert img_size % patch_size == 0, \
            print("Given image size ({}) has to be divisible by given patch size ({})".format(img_size, patch_size))
        
        self.conv_embed = Conv_Embed(img_size, in_channels, embed_dim, n_conv)
        n_patches = self.conv_embed.sequence_length(in_channels=in_channels, height=img_size, width=img_size)
        hidden_dim = int(embed_dim * mlp_ratio)
        
        
        self.pos_embed = nn.Parameter(torch.zeros(1, n_patches, embed_dim))
        
        # Can use this to enable Sinusoidal PE
        #self.pos_embed = PositionalEmbedding(1, n_patches + 1, embed_dim)

        self.pos_drop = nn.Dropout(p=proj_dropout)
        self.tr_block = nn.ModuleList(
            [
                TransformerEncoderLayer(
                    embed_dim,
                    n_heads,
                    qkv_bias,
                    attn_dropout,
                    proj_dropout,
                    mlp_dropout,
                    hidden_dim
                    )
                for _ in range(n_layers)
            ]   # Sends data through the encoder n times
        )
        self.norm = nn.LayerNorm(embed_dim, eps=1e-6)
        
        self.attention_pool = nn.Linear(embed_dim, 1)
                                    
        self.head = nn.Linear(embed_dim, n_classes)

    def forward(self, x):
        '''
        Defines how the class will run

        Parameters
        ----------
        x: torch.Tensor
            shape: n_samples, in_chains, img_size, img_size

        Returns
        ---------
        logits: torch.Tensor
            Logits over all the classes: n_samples, n_samples
        '''
        x = self.conv_embed(x)
        #x = self.pos_embed(x)
        
        x += self.pos_embed
        x = self.pos_drop(x)
        for tr_block in self.tr_block:
            x = tr_block(x)
        x = self.norm(x)
        #Added Sequence Pooling instead of Class embedding
        x = torch.matmul(F.softmax(self.attention_pool(x), dim=1).transpose(-1, -2), x).squeeze(-2)
        x = self.head(x)
        return x

# %% [markdown]
# ### Positional Embedding
#
# This is the sinusoidal positional encoding layer as seen in the original 'Attention is All You Need' paper. It basically uses a sin/cos waveform to provide a unique positional offset that is given to a token at the corresponding position in its embedding space.
#
# By default, this is disabled and we instead use a trainable matrix of zeros. This adds another dimension to our data that the model then uses to find the best weights for the data's position itself. This is called "learnable" positional encoding.
#
# There are pros-and-cons to either, but essentially: sinusoidal is better when there are not a lot of data samples to learn the positional data from but you can get better results from "learnable" with larger datasets.

# %%
class PositionalEmbedding(nn.Module):
    '''
    Applies Learnable Sinusoidal Positional Encoding

    Parameters
    ----------
    embed_dim: int
        The positional embedding dimension (How big embedding for each patch.Constant across entire network)
    max_len: int 
        Max number of instances for positions
    freq: int 
        The base frequency for Sin/Cos calculations. Higher values (eg 10000) are more stable
    '''
    def __init__(self, 
                 embed_dim,
                 max_len=5000,
                 freq=10000.,
                ):
        super().__init__()
        pe = torch.zeros(max_len, embed_dim)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div = torch.exp(torch.arange(0, embed_dim, 2).float() *
                        (-math.log(freq) / embed_dim))
        pe[:, 0::2] = torch.sin(position * div) # Even terms
        pe[:, 1::2] = torch.cos(position * div) # Odd terms
        pe = pe.unsqueeze(0).transpose(0,1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        '''
        Defines how the class will run

        Parameters
        -----------

        Returns
        -----------
        '''
        x = x + self.pe[:x.size(0), :]
        return x

# %% [markdown]
# ### Convolutional Embedding Layer
#
# The patching used by the previous models was a problem because, while it took more samples of the input data, it also created what were essentially bordered segments which made it harder for the model to learn how they connected to the other segments and the bigger picture.
#
# The new convolutional layer helps to eliminate that problem by using convolutional filters to create many different overlapping segments.

# %%
class Conv_Embed(nn.Module):
    def __init__(self,
                 img_size=32,
                 in_channels=3,
                 out_channels=64,
                 n_conv=2,
                 kernel_size=3,
                 stride=2,
                 padding=3,
                 pool_kernel_size=3,
                 pool_stride=2,
                 pool_padding=1
                 ):
        super().__init__()
        self.img_size = img_size
        if n_conv == 1:
            self.conv_layers = nn.Sequential(
                nn.Conv2d(in_channels,
                        out_channels,
                        kernel_size=kernel_size,
                        stride=stride,
                        padding=padding,
                        bias=False),
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=pool_kernel_size,
                            stride=pool_stride,
                            padding=pool_padding)
            )
        else:
            n_filter_list = [in_channels] + \
                            [64 for _ in range(n_conv - 1)] + \
                            [out_channels]

            self.conv_layers = nn.Sequential(
                *[nn.Sequential(
                    nn.Conv2d(n_filter_list[i],
                        n_filter_list[i+1],
                        kernel_size=kernel_size,
                        stride=stride,
                        padding=padding,
                        bias=False),
                    nn.ReLU(),
                    nn.MaxPool2d(kernel_size=pool_kernel_size,
                            stride=pool_stride,
                            padding=pool_padding)
                            )
                    for i in range(n_conv)
                ])
        self.flattener = nn.Flatten(2, 3)
        
        # This, along with the staticmethod below, help to normalize the convolutional filter by picking better starting weights for optimization.
        self.apply(self.init_weight)

    def sequence_length(self, in_channels=3, height=32, width=32):
        return self.forward(torch.zeros((1, in_channels, height, width))).shape[1]

    def forward(self, x):
        return self.flattener(self.conv_layers(x)).transpose(-2, -1)

    @staticmethod
    def init_weight(m):
        if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight)

# %% [markdown]
# ### This is the Transformer Encoder block which applies all of the actual normalization, attention, etc that make a Transformer what it is.

# %%
class TransformerEncoderLayer(nn.Module):
    '''
    Transformer Block/Encoder Layer

    Parameter
    ---------
    embed_dim: int
        embedding dimension
    n_heads: int
        number of attention heads
    mlp_ratio: float
        determines the hidden dimension size of the MLP module with respect to 'dim'
    qkv_bias: bool
        If true then we include bias to the query, key and value projections
    mlp_dropout, proj_dropout, attn_droupout: float
        dropout probability
    dim_feedforward: int
        The feature number of hidden layer of the FFN

    Attributes
    ----------
    norm_1, norm_2: LayerNorm
        Layer normalization
    MHA: Attention
        Multi-Headed Attention module
    mlp: MLP
        MLP module
    ''' 
    def __init__(self,
                 embed_dim=768,
                 n_heads=12,
                 qkv_bias=True,
                 attn_dropout=0.,
                 proj_dropout=0.,
                 mlp_dropout=0.,
                 hidden_dim=2048
    ):
        super().__init__()
        self.norm_1 = nn.LayerNorm(embed_dim, eps = 1e-6)
        self.norm_2 = nn.LayerNorm(embed_dim, eps = 1e-6)
        self.MHA = MultiheadedSelfAttention(embed_dim,
                                        n_heads,
                                        qkv_bias,
                                        attn_dropout,
                                        proj_dropout
        )
        self.MLP = MLP(embed_dim, hidden_dim, mlp_dropout)

    def forward(self, x):
        '''
        Defines how the class will run
        
        Parameter
        ---------
        x: torch.Tensor
            shape: n_samples, n_patches + 1, dim

        Returns
        --------
        torch.Tensor
            shape: n_samples, n_patches + 1, dim
        '''
        x = x + self.MHA(self.norm_1(x))    # Residual connection (Add)
        x = x + self.MLP(self.norm_2(x))    # Residual connection (Add)
        return x

# %% [markdown]
# ### Multiheaded Attention Layer
#
# The heart of the Transformer model; the reason behind the original title of "attention is all you need".

# %%
class MultiheadedSelfAttention(nn.Module):
    '''
    Multi-Headed Attention Mechanism

    Parameters
    ----------
    embed_dim: int
        The input and out dimension of per token feature
    n_heads: int
        Number of attention heads 
    qkv_bias: bool
        if true then we include bias to the query, key and value projections
    attn_p: float
        Dropout probability applied to the query, key and value tensors.
    proj_p: float
        Dropout probability applied to output tensor
        
    Attributes
    ----------
    scale: float
        Normalizing constant for the dot product
    qkv: nn.Linear
        Linear projection for the query, key and value
    proj: nn.Linear
        Linear mapping that takes in the concatenated output of all attention
        heads and maps into the new space
    attn_drop, proj_drop: nn.Dropout
        Dropout layers.
    '''
    def __init__(self, 
                 embed_dim, 
                 n_heads=2,
                 qkv_bias = True,
                 attn_dropout=0.,
                 proj_dropout=0.
    ):
        super().__init__()
        self.n_heads = n_heads
        assert embed_dim % n_heads == 0, \
            print('Embedding dim must be divisible by number of heads.')
        self.head_dim = embed_dim // n_heads
        self.scale = self.head_dim ** -0.5
        self.dim = embed_dim
        self.qkv = nn.Linear(embed_dim, embed_dim * 3, bias=qkv_bias)
        self.attn_dropout = nn.Dropout(attn_dropout)
        self.proj = nn.Linear(embed_dim, embed_dim)
        self.proj_dropout = nn.Dropout(proj_dropout)
        
    def forward(self, x):
        '''
        Defines how the class will run
        
        Parameters
        ----------
        x: torch.Tensor
            shape: n_samples (B), n_patches + 1 (N), embed_dim (C)
            N is also equal to the number of tokens.
        Returns
        --------
        torch.Tensor
            shape: n_samples, n_patches + 1, embed_dim
        '''
        B, N, C = x.shape
        qkv = self.qkv(x)
        qkv = qkv.reshape(B, N, 3,
            self.n_heads,
            self.head_dim
            )
        qkv = qkv.permute(
            2,    # qkv (3)
            0,    # batch (n_samples)
            3,    # channel (n_heads)
            1,    # n_patches + 1
            4     # head_dim (embed_dim / n_heads)
            )
        q, k, v = qkv[0], qkv[1], qkv[2]
        attn = (q @ k.transpose(-2, -1)) * self.scale # <q,k> / sqrt(d)
        attn = attn.softmax(dim=-1) # Softmax over embedding dim
        attn = self.attn_dropout(attn)

        weighted_avg = (attn @ v)
        weighted_avg = weighted_avg.transpose(1, 2)
        weighted_avg = weighted_avg.flatten(2)

        x = self.proj(weighted_avg)
        x = self.proj_dropout(x)

        return x

# %% [markdown]
# ### The MLP layer
#
# (At the end of the Transformer Encoder). Not to be confused with the mlp head which adds class encodings at the very end of the transformer.

# %%
class MLP(nn.Module):
    '''
    Multilayer perceptron 
    
    Parameters
    ----------
    embed_dim: int
        embedding dimension
    feedforward_dim: int
      Number of nodes in the hidden layer
    mlp_dropout: float
      Dropout probability

    Attribute
    ---------
    fc: nn.Linear
      The first linear layer
    act: nn. GELU
      GELU activation function
    fc2: nn.Linear
      The second linear layer
    drop: nn.Dropout
      Dropout layer
    '''

    def __init__(self, embed_dim, hidden_dim, mlp_dropout):
        super().__init__()
        self.fc1 = nn.Linear(embed_dim, hidden_dim)
        self.act = nn.GELU()
        self.fc2 = nn.Linear(hidden_dim, embed_dim)
        self.drop = nn.Dropout(mlp_dropout)

    def forward(self,x):
        '''
        Defines how the class will run
        
        Parameters
        ----------
        x: torch.Tensor
          shape: n_samples, n_patches + 1, in_features

        Returns
        ----------
        torch.Tensor
          n_samples, n_patches+ 1, out_features
        '''
        x = self.fc1(x) # n_samples, n_patches+1, hidden_features
        x = self.act(x) # n_samples, n_patches+1, hidden_features
        x = self.drop(x) # n_samples, n_patches+1, hidden_features
        x = self.fc2(x) # n_samples, n_patches+1, output_features
        x = self.drop(x) # n_samples, n_patches+1, output_features
        return x

# %% [markdown]
# # Training the ViT with the CIFAR10 dataset

# %% [markdown]
# ### Setup needed variables

# %%
def sipakmed_prep():
    root = "../../Python Scripts/Datasets/CervicalCancer/Sipakmed/"

    all_img = []
    for path, subdirs, files in os.walk(root):
        for name in files:
            curr_img = os.path.join(path,name)
            all_img.append(curr_img)

    sipakmed_df = pd.DataFrame()
    sipakmed_df['LocalPath'] = all_img
    sipakmed_df['ID'] = sipakmed_df['LocalPath'].apply(lambda x: str(x.split("\\")[-1]))
    sipakmed_df['Slide'] = sipakmed_df['LocalPath'].apply(lambda x: 'False' if (str(x.split("\\")[1])) == 'CROPPED' else 'True')
    sipakmed_df['Specific_Status'] = sipakmed_df['LocalPath'].apply(lambda x: str((x.split("im_")[1]).split("\\")[0]))
    sipakmed_df['Status'] = sipakmed_df['Specific_Status'].apply(lambda x: 'Benign' if x == 'Metaplastic' else
    ('Normal' if x == 'Superficial-Intermediate' or x == 'Parabasal' else 'Abnormal'))

    sp_class = {'Metaplastic':4, 'Superficial-Intermediate':0, 'Parabasal':1, 'Koilocytotic':2, 'Dyskeratotic':3}
    sipakmed_df['Specific_Class'] = sipakmed_df['Specific_Status'].map(sp_class)
    gen_class = {'Benign':0, 'Normal':1, 'Abnormal':2}
    sipakmed_df['Class'] = sipakmed_df['Status'].map(gen_class)

    sipakmed_df = sipakmed_df.loc[sipakmed_df['ID'].str.contains('bmp')].reset_index(drop=True)
    
    #Uploads the created file for future use. Recommended to not use.
    #sipakmed_df.to_csv(root + '/results.csv')
    return sipakmed_df

# %%
def herlev_prep():
    root = '../../Python Scripts/Datasets/CervicalCancer/Herlev/smear2005/results.csv'
    img_folder = '../../Python Scripts/Datasets/CervicalCancer/Herlev/smear2005/Images/'

    herlev_df=pd.read_csv(root)
    herlev_df = herlev_df.rename(columns={'Class':'Specific_Class'})

    spec_class = {1:0, 2:1, 3:2, 4:3, 5:4, 6:5, 7:6}
    gen_class = {1:1, 2:1, 3:1, 4:2, 5:2, 6:2, 7:2}
    
    herlev_df['Class'] = herlev_df['Specific_Class'].map(gen_class)
    herlev_df['Specific_Class'] = herlev_df['Specific_Class'].map(spec_class)
    herlev_df['LocalPath'] = herlev_df['ID'].apply(lambda x: str(img_folder + x))
    return herlev_df

# %%
class DatasetSample(Dataset):
    def __init__(self, df, transform):
        # Initialization
        self.transform = transform
        
        self.image_names = df['LocalPath']
        self.img_class = np.array(df['Class'])

    def __len__(self):
        # Denotes the total number of samples
        return len(self.image_names)
    
    def __getitem__(self, index):
        # Retrieves the data
        image=cv2.imread(self.image_names.iloc[index])
        image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

        image = self.transform(image)
        label = self.img_class[index]

        x, y = image, label
        
        # Enable to output as single variable instead
        #sample = {'image': image,'labels':label}

        return x, y

# %%
def concat_data(batch_size=128, img_size=32):
    # Load the dataframes
    sipakmed_df = sipakmed_prep()
    herlev_df = herlev_prep()

    # Final adjustments to make sure they're attributes match
    sipakmed_df = sipakmed_df.loc[sipakmed_df['Slide'] == 'False']
    herlev_df = herlev_df.loc[:,['LocalPath', 'Class']]
    sipakmed_df = sipakmed_df.loc[:,['LocalPath', 'Class']]
    
    concat_df = pd.concat([sipakmed_df,herlev_df], ignore_index=True)
    '''
    concat_df = pd.DataFrame()
    concat_df['LocalPath'] = sipakmed_df['LocalPath']
    concat_df['Class'] = sipakmed_df['Specific_Class']
    '''
    # Split them into training, validation, and testing sets
    tr_va_set,test_set = train_test_split(concat_df, random_state=1, test_size=0.15)
    train_set,val_set = train_test_split(tr_va_set, random_state=1, test_size=0.15)
    
    # Set it up to alter random training images for better results
    train_transform = transforms.Compose([
                    transforms.ToPILImage(),
                    transforms.Resize((img_size, img_size)),
                    transforms.RandomHorizontalFlip(p=0.75),
                    transforms.RandomRotation(degrees=60),
                    transforms.ToTensor()])

    test_transform = transforms.Compose([
                    transforms.ToPILImage(),
                    transforms.Resize((img_size, img_size)),
                    transforms.ToTensor()])

    train_dataset = DatasetSample(train_set, train_transform)
    val_dataset = DatasetSample(val_set, test_transform)
    test_dataset = DatasetSample(test_set, test_transform)
    
    Dtr = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True
    )
    
    Dva = DataLoader(
        val_dataset, 
        batch_size=batch_size,
        shuffle=True
    )

    Dte = DataLoader(
        test_dataset, 
        batch_size=batch_size,
        shuffle=True
    )

    return(Dtr, Dva, Dte)

# %%
#The corresponding class labels
batch_size=96
img_size=160
classes = ('Benign', 'Normal', 'Abnormal')
#classes = ('Superficial-Intermediate','Parabasal','Koilocytotic','Dyskeratotic','Metaplastic')
#classes = ('Superficial-Squamous-Epithelial','Intermediate-Squamous-Epithelial','Columnar-Epithelial','Mild-Squamous-Non-Keratinizing-Dysplasia',
#           'Moderate-Squamous-Non-Keratinizing-Dysplasia','Severe-Squamous-Non-Keratinizing-Dysplasia','Squamous-Cell-Carcinoma-in-situ-Intermediate)
Dtr, Dva, Dte = concat_data(batch_size=batch_size, img_size=img_size)
print('The total number of samples for Training is: {}, Validation: {}, and Testing: {}'.format(len(Dtr)*batch_size, len(Dva)*batch_size, len(Dte)*batch_size))
# Out:
# The total number of samples for Training is: 3648, Validation: 672, and Testing: 768

# %% [markdown]
# ### Builds the dataloaders for training and testing

# %%
# Turns the dataloaders into iterable objects. Useful for viewing
dataiter = iter(Dtr)
val_dataiter = iter(Dva)
test_dataiter = iter(Dte)

# %% [markdown]
# ### Function for viewing batches of the dataset

# %%
def imshow(images, labels, predicted_labels=None):
    
    if images.is_cuda == True:
        images = images.to("cpu")
    if labels.is_cuda == True:
        labels = labels.to("cpu")

    # Using torchvision to make a grid of the images
    img = torchvision.utils.make_grid(images)

    # Inverting the normalization
    img = img.numpy().transpose((1, 2, 0))
    img = np.clip(img, 0, 1)

    # Plotting the grid
    fig, ax = plt.subplots(figsize=(12, 24))
    plt.imshow(img)

    if predicted_labels is not None:
        if predicted_labels.is_cuda == True:
            predicted_labels = predicted_labels.to("cpu")
        # Outputing the predicted labels
        ax.set_xlabel('Predicted labels', fontsize=18, labelpad=12)
        ax.set_xticks(torch.arange(len(images)) * img_size + (img_size/1.8))
        ax.set_xticklabels([classes[predicted_labels[j]] 
                            for j in range(len(images))], fontsize=12, rotation=30)
    
    # Outputing the True labels
    gax = ax.secondary_xaxis('top')
    gax.set_xlabel('True Labels', fontsize=18, labelpad=12)
    gax.set_xticks(torch.arange(len(images)) * img_size + (img_size/1.8))
    gax.set_xticklabels([classes[labels[j]] 
                         for j in range(len(images))], fontsize=12, rotation=30)
    plt.show()

# %%
images, labels = dataiter.next()
imshow(images[:7], labels[:7])

# %% [markdown]
# ### This function was made by Dr Prashant to train the model that's built above

# %%
# A function to encapsulate the training loop
def batch_gd(model, loss_fn, optimizer, train_loader, val_loader, epochs):
  model.to(device)
  train_losses = np.zeros(epochs)
  val_losses = np.zeros(epochs)
  
  for it in range(epochs):
    model.train()
    t0 = datetime.now()
    train_loss = []
    n_correct = 0.
    n_total = 0.
    for inputs, targets in train_loader:
      # move data to GPU if available
      inputs, targets = inputs.to(device), targets.to(device)

      # zero the parameter gradients
      optimizer.zero_grad()

      # Forward pass
      outputs = model(inputs)
      
      # Get the predictions
      # torch.max returns both max and argmax
      __, out_label = outputs.max(dim=1)
      # Updates the accuracy with every pass
      n_correct += (out_label == targets).sum().item()
      n_total += targets.shape[0]
      tr_acc = n_correct / n_total

      loss = loss_fn(outputs, targets)
      # Backward and optimize
      loss.backward()
      optimizer.step()

      train_loss.append(loss.item())

    # Get train loss and test loss
    train_loss = np.mean(train_loss) # a little misleading
    
    model.eval()
    val_loss = []
    n_correct = 0.
    n_total = 0.
    for inputs, targets in val_loader:
      inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)

      # Get the predictions
      # torch.max returns both max and argmax
      __, out_label = outputs.max(dim=1)
      # Updates the accuracy with every pass
      n_correct += (out_label == targets).sum().item()
      n_total += targets.shape[0]
      val_acc = n_correct / n_total

      loss = loss_fn(outputs, targets)
      val_loss.append(loss.item())
    val_loss = np.mean(val_loss)

    # Save losses
    train_losses[it] = train_loss
    val_losses[it] = val_loss
    
    dt = datetime.now() - t0

    print(f'Epoch {it+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {(100*tr_acc):.3f} \
      Val Loss: {val_loss:.4f}, Val Accuracy: {(100*val_acc):.3f}, Duration: {dt}')
  
  return train_losses, val_losses

# %% [markdown]
# ### Initializes the Transformer and selects the loss function and optimizer we want

# %%
model = CCT(
        img_size=img_size,      # Input image size
        in_channels=3,  # Number of channels for the image
        patch_size=4,   # How big our patches are
        embed_dim=42,   # Embedding dim
        n_layers=4,     # Number of transformer encoders
        n_conv=2,       # Number of convolutional layers
        n_heads=6,      # Number of attention heads
        attn_dropout=0.,        # Attention Dropout
        proj_dropout=0.,        # (MHA) Projection Dropout
        mlp_dropout=0.1,        # (MHA) last layer dropout
        mlp_ratio=2,    # (MHA) Projection FF dimension
        qkv_bias = True,
        n_classes=3     # Number of classes to classify
        )
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())

# %%
train_losses, val_losses = batch_gd(model, loss_fn, optimizer, Dtr, Dva, epochs=300)
# Out:
# Epoch 1/300, Train Loss: 0.8693, Train Accuracy: 56.008       Val Loss: 0.7068, Val Accuracy: 66.404, Duration: 0:00:14.362329
# Epoch 2/300, Train Loss: 0.7401, Train Accuracy: 64.873       Val Loss: 0.6780, Val Accuracy: 70.032, Duration: 0:00:11.791484
# Epoch 3/300, Train Loss: 0.6889, Train Accuracy: 69.083       Val Loss: 0.6049, Val Accuracy: 70.505, Duration: 0:00:11.481313
# Epoch 4/300, Train Loss: 0.6321, Train Accuracy: 72.484       Val Loss: 0.5753, Val Accuracy: 73.344, Duration: 0:00:11.549132
# Epoch 5/300, Train Loss: 0.5470, Train Accuracy: 77.558       Val Loss: 0.4358, Val Accuracy: 84.543, Duration: 0:00:11.512231
# Epoch 6/300, Train Loss: 0.4529, Train Accuracy: 83.217       Val Loss: 0.4177, Val Accuracy: 84.700, Duration: 0:00:11.416487
# Epoch 7/300, Train Loss: 0.4272, Train Accuracy: 83.440       Val Loss: 0.4511, Val Accuracy: 83.912, Duration: 0:00:11.418481
# Epoch 8/300, Train Loss: 0.3878, Train Accuracy: 86.144       Val Loss: 0.3207, Val Accuracy: 89.590, Duration: 0:00:12.035832
# Epoch 9/300, Train Loss: 0.3909, Train Accuracy: 85.280       Val Loss: 0.3389, Val Accuracy: 87.539, Duration: 0:00:15.314545
# Epoch 10/300, Train Loss: 0.3431, Train Accuracy: 86.953       Val Loss: 0.3123, Val Accuracy: 88.644, Duration: 0:00:17.934067
# Epoch 11/300, Train Loss: 0.3345, Train Accuracy: 87.566       Val Loss: 0.3053, Val Accuracy: 89.117, Duration: 0:00:13.110957
# Epoch 12/300, Train Loss: 0.3079, Train Accuracy: 88.430       Val Loss: 0.3113, Val Accuracy: 89.274, Duration: 0:00:17.777485
# Epoch 13/300, Train Loss: 0.3204, Train Accuracy: 87.733       Val Loss: 0.3323, Val Accuracy: 87.539, Duration: 0:00:12.510562
# Epoch 14/300, Train Loss: 0.3089, Train Accuracy: 88.709       Val Loss: 0.2574, Val Accuracy: 91.640, Duration: 0:00:12.112627
# Epoch 15/300, Train Loss: 0.2760, Train Accuracy: 89.713       Val Loss: 0.2706, Val Accuracy: 90.536, Duration: 0:00:11.876258
# Epoch 16/300, Train Loss: 0.2676, Train Accuracy: 90.967       Val Loss: 0.2529, Val Accuracy: 91.798, Duration: 0:00:12.067746
# Epoch 17/300, Train Loss: 0.2531, Train Accuracy: 90.438       Val Loss: 0.2524, Val Accuracy: 90.694, Duration: 0:00:11.995939
# Epoch 18/300, Train Loss: 0.2448, Train Accuracy: 90.800       Val Loss: 0.2898, Val Accuracy: 88.644, Duration: 0:00:11.709702
# Epoch 19/300, Train Loss: 0.2395, Train Accuracy: 90.856       Val Loss: 0.2507, Val Accuracy: 91.483, Duration: 0:00:11.749596
# Epoch 20/300, Train Loss: 0.2373, Train Accuracy: 90.995       Val Loss: 0.2411, Val Accuracy: 91.640, Duration: 0:00:11.895207
# Epoch 21/300, Train Loss: 0.2214, Train Accuracy: 91.971       Val Loss: 0.2281, Val Accuracy: 91.956, Duration: 0:00:11.771538
# Epoch 22/300, Train Loss: 0.2182, Train Accuracy: 91.525       Val Loss: 0.2281, Val Accuracy: 91.640, Duration: 0:00:11.753586
# Epoch 23/300, Train Loss: 0.2047, Train Accuracy: 92.584       Val Loss: 0.2812, Val Accuracy: 90.852, Duration: 0:00:12.653179
# Epoch 24/300, Train Loss: 0.2204, Train Accuracy: 91.636       Val Loss: 0.2322, Val Accuracy: 91.798, Duration: 0:00:11.984967
# Epoch 25/300, Train Loss: 0.1950, Train Accuracy: 92.975       Val Loss: 0.2354, Val Accuracy: 91.009, Duration: 0:00:12.265217
# Epoch 26/300, Train Loss: 0.1845, Train Accuracy: 93.170       Val Loss: 0.2258, Val Accuracy: 91.325, Duration: 0:00:11.576060
# Epoch 27/300, Train Loss: 0.2094, Train Accuracy: 91.748       Val Loss: 0.1972, Val Accuracy: 92.587, Duration: 0:00:11.471340
# Epoch 28/300, Train Loss: 0.1970, Train Accuracy: 92.863       Val Loss: 0.1856, Val Accuracy: 92.744, Duration: 0:00:11.512231
# Epoch 29/300, Train Loss: 0.1664, Train Accuracy: 94.146       Val Loss: 0.2184, Val Accuracy: 92.587, Duration: 0:00:11.990952
# Epoch 30/300, Train Loss: 0.1612, Train Accuracy: 94.146       Val Loss: 0.2062, Val Accuracy: 91.167, Duration: 0:00:12.269207
# Epoch 31/300, Train Loss: 0.1769, Train Accuracy: 93.532       Val Loss: 0.2055, Val Accuracy: 91.956, Duration: 0:00:11.686765
# Epoch 32/300, Train Loss: 0.1683, Train Accuracy: 93.839       Val Loss: 0.2584, Val Accuracy: 90.694, Duration: 0:00:11.548135
# Epoch 33/300, Train Loss: 0.1632, Train Accuracy: 94.731       Val Loss: 0.1802, Val Accuracy: 92.429, Duration: 0:00:13.806099
# Epoch 34/300, Train Loss: 0.1305, Train Accuracy: 95.093       Val Loss: 0.2023, Val Accuracy: 93.218, Duration: 0:00:12.278184
# Epoch 35/300, Train Loss: 0.1484, Train Accuracy: 94.592       Val Loss: 0.2078, Val Accuracy: 92.902, Duration: 0:00:11.553122
# Epoch 36/300, Train Loss: 0.1488, Train Accuracy: 94.369       Val Loss: 0.2303, Val Accuracy: 92.587, Duration: 0:00:13.093006
# Epoch 37/300, Train Loss: 0.1405, Train Accuracy: 94.592       Val Loss: 0.2180, Val Accuracy: 92.429, Duration: 0:00:12.322066
# Epoch 38/300, Train Loss: 0.1431, Train Accuracy: 94.926       Val Loss: 0.1946, Val Accuracy: 93.849, Duration: 0:00:12.156508
# Epoch 39/300, Train Loss: 0.1527, Train Accuracy: 94.062       Val Loss: 0.1983, Val Accuracy: 93.218, Duration: 0:00:11.625927
# Epoch 40/300, Train Loss: 0.1256, Train Accuracy: 95.428       Val Loss: 0.1785, Val Accuracy: 94.006, Duration: 0:00:11.327725
# Epoch 41/300, Train Loss: 0.1628, Train Accuracy: 94.006       Val Loss: 0.1754, Val Accuracy: 94.322, Duration: 0:00:11.688758
# Epoch 42/300, Train Loss: 0.1317, Train Accuracy: 95.428       Val Loss: 0.1780, Val Accuracy: 94.322, Duration: 0:00:12.814750
# Epoch 43/300, Train Loss: 0.1108, Train Accuracy: 95.958       Val Loss: 0.1983, Val Accuracy: 93.691, Duration: 0:00:12.785827
# Epoch 44/300, Train Loss: 0.1233, Train Accuracy: 95.790       Val Loss: 0.1944, Val Accuracy: 93.375, Duration: 0:00:12.169475
# Epoch 45/300, Train Loss: 0.1190, Train Accuracy: 95.623       Val Loss: 0.1703, Val Accuracy: 94.795, Duration: 0:00:11.881244
# Epoch 46/300, Train Loss: 0.1235, Train Accuracy: 95.679       Val Loss: 0.1881, Val Accuracy: 94.006, Duration: 0:00:11.950061
# Epoch 47/300, Train Loss: 0.1235, Train Accuracy: 95.595       Val Loss: 0.2048, Val Accuracy: 94.164, Duration: 0:00:11.539158
# Epoch 48/300, Train Loss: 0.0990, Train Accuracy: 95.958       Val Loss: 0.1591, Val Accuracy: 94.479, Duration: 0:00:11.589025
# Epoch 49/300, Train Loss: 0.1059, Train Accuracy: 96.320       Val Loss: 0.1807, Val Accuracy: 94.164, Duration: 0:00:11.864291
# Epoch 50/300, Train Loss: 0.1171, Train Accuracy: 95.902       Val Loss: 0.1602, Val Accuracy: 94.953, Duration: 0:00:12.065185
# Epoch 51/300, Train Loss: 0.1171, Train Accuracy: 95.679       Val Loss: 0.1636, Val Accuracy: 95.268, Duration: 0:00:11.777521
# Epoch 52/300, Train Loss: 0.0890, Train Accuracy: 96.850       Val Loss: 0.1986, Val Accuracy: 94.006, Duration: 0:00:11.659836
# Epoch 53/300, Train Loss: 0.0922, Train Accuracy: 96.571       Val Loss: 0.1728, Val Accuracy: 93.691, Duration: 0:00:11.781511
# Epoch 54/300, Train Loss: 0.0868, Train Accuracy: 96.878       Val Loss: 0.1900, Val Accuracy: 93.691, Duration: 0:00:12.058770
# Epoch 55/300, Train Loss: 0.0911, Train Accuracy: 97.101       Val Loss: 0.1567, Val Accuracy: 94.637, Duration: 0:00:12.299127
# Epoch 56/300, Train Loss: 0.1297, Train Accuracy: 95.205       Val Loss: 0.1686, Val Accuracy: 93.375, Duration: 0:00:12.047800
# Epoch 57/300, Train Loss: 0.0963, Train Accuracy: 96.878       Val Loss: 0.1370, Val Accuracy: 95.426, Duration: 0:00:12.242280
# Epoch 58/300, Train Loss: 0.0784, Train Accuracy: 97.156       Val Loss: 0.1486, Val Accuracy: 94.322, Duration: 0:00:12.159500
# Epoch 59/300, Train Loss: 0.0659, Train Accuracy: 97.686       Val Loss: 0.1569, Val Accuracy: 94.953, Duration: 0:00:11.962030
# Epoch 60/300, Train Loss: 0.0982, Train Accuracy: 96.682       Val Loss: 0.1910, Val Accuracy: 94.322, Duration: 0:00:12.194406
# Epoch 61/300, Train Loss: 0.0684, Train Accuracy: 97.268       Val Loss: 0.1895, Val Accuracy: 94.479, Duration: 0:00:12.094674
# Epoch 62/300, Train Loss: 0.0631, Train Accuracy: 97.686       Val Loss: 0.1985, Val Accuracy: 94.006, Duration: 0:00:11.914157
# Epoch 63/300, Train Loss: 0.0969, Train Accuracy: 96.571       Val Loss: 0.1763, Val Accuracy: 95.426, Duration: 0:00:12.129582
# Epoch 64/300, Train Loss: 0.0783, Train Accuracy: 97.129       Val Loss: 0.1908, Val Accuracy: 94.164, Duration: 0:00:12.238289
# Epoch 65/300, Train Loss: 0.0728, Train Accuracy: 97.324       Val Loss: 0.1614, Val Accuracy: 94.953, Duration: 0:00:12.094675
# Epoch 66/300, Train Loss: 0.0684, Train Accuracy: 97.435       Val Loss: 0.1662, Val Accuracy: 95.426, Duration: 0:00:12.442743
# Epoch 67/300, Train Loss: 0.0699, Train Accuracy: 97.519       Val Loss: 0.1661, Val Accuracy: 94.795, Duration: 0:00:11.935101
# Epoch 68/300, Train Loss: 0.0821, Train Accuracy: 96.933       Val Loss: 0.1451, Val Accuracy: 95.426, Duration: 0:00:12.217346
# Epoch 69/300, Train Loss: 0.0661, Train Accuracy: 97.937       Val Loss: 0.1693, Val Accuracy: 94.795, Duration: 0:00:12.256242
# Epoch 70/300, Train Loss: 0.0518, Train Accuracy: 98.272       Val Loss: 0.1628, Val Accuracy: 95.268, Duration: 0:00:12.001921
# Epoch 71/300, Train Loss: 0.0617, Train Accuracy: 97.770       Val Loss: 0.1952, Val Accuracy: 94.479, Duration: 0:00:12.698062
# Epoch 72/300, Train Loss: 0.0475, Train Accuracy: 98.272       Val Loss: 0.1328, Val Accuracy: 95.741, Duration: 0:00:12.090686
# Epoch 73/300, Train Loss: 0.0763, Train Accuracy: 97.129       Val Loss: 0.1987, Val Accuracy: 93.849, Duration: 0:00:12.407836
# Epoch 74/300, Train Loss: 0.0797, Train Accuracy: 97.129       Val Loss: 0.2102, Val Accuracy: 94.322, Duration: 0:00:12.023864
# Epoch 75/300, Train Loss: 0.0599, Train Accuracy: 97.686       Val Loss: 0.1807, Val Accuracy: 94.479, Duration: 0:00:12.246268
# Epoch 76/300, Train Loss: 0.0733, Train Accuracy: 97.407       Val Loss: 0.1782, Val Accuracy: 95.426, Duration: 0:00:12.640216
# Epoch 77/300, Train Loss: 0.0527, Train Accuracy: 98.160       Val Loss: 0.1302, Val Accuracy: 96.688, Duration: 0:00:12.277187
# Epoch 78/300, Train Loss: 0.0492, Train Accuracy: 98.272       Val Loss: 0.1621, Val Accuracy: 95.741, Duration: 0:00:12.054780
# Epoch 79/300, Train Loss: 0.0876, Train Accuracy: 96.738       Val Loss: 0.1949, Val Accuracy: 94.322, Duration: 0:00:11.825394
# Epoch 80/300, Train Loss: 0.0391, Train Accuracy: 98.634       Val Loss: 0.1621, Val Accuracy: 95.741, Duration: 0:00:11.475329
# Epoch 81/300, Train Loss: 0.0482, Train Accuracy: 98.327       Val Loss: 0.1631, Val Accuracy: 95.110, Duration: 0:00:11.508242
# Epoch 82/300, Train Loss: 0.0439, Train Accuracy: 98.578       Val Loss: 0.1404, Val Accuracy: 96.530, Duration: 0:00:11.520210
# Epoch 83/300, Train Loss: 0.0718, Train Accuracy: 97.407       Val Loss: 0.1428, Val Accuracy: 95.110, Duration: 0:00:11.837361
# Epoch 84/300, Train Loss: 0.0391, Train Accuracy: 98.522       Val Loss: 0.1357, Val Accuracy: 96.372, Duration: 0:00:12.396867
# Epoch 85/300, Train Loss: 0.0817, Train Accuracy: 97.184       Val Loss: 0.2064, Val Accuracy: 94.479, Duration: 0:00:11.658840
# Epoch 86/300, Train Loss: 0.0406, Train Accuracy: 98.439       Val Loss: 0.1453, Val Accuracy: 95.741, Duration: 0:00:11.917148
# Epoch 87/300, Train Loss: 0.0429, Train Accuracy: 98.662       Val Loss: 0.1750, Val Accuracy: 94.795, Duration: 0:00:11.615953
# Epoch 88/300, Train Loss: 0.0514, Train Accuracy: 98.327       Val Loss: 0.1723, Val Accuracy: 95.268, Duration: 0:00:11.879250
# Epoch 89/300, Train Loss: 0.0620, Train Accuracy: 97.658       Val Loss: 0.2139, Val Accuracy: 94.322, Duration: 0:00:11.915154
# Epoch 90/300, Train Loss: 0.0599, Train Accuracy: 97.937       Val Loss: 0.1535, Val Accuracy: 95.426, Duration: 0:00:12.293144
# Epoch 91/300, Train Loss: 0.0359, Train Accuracy: 98.801       Val Loss: 0.1616, Val Accuracy: 95.584, Duration: 0:00:12.495602
# Epoch 92/300, Train Loss: 0.0289, Train Accuracy: 99.080       Val Loss: 0.1632, Val Accuracy: 96.215, Duration: 0:00:11.978983
# Epoch 93/300, Train Loss: 0.0330, Train Accuracy: 98.829       Val Loss: 0.1556, Val Accuracy: 95.741, Duration: 0:00:12.248264
# Epoch 94/300, Train Loss: 0.0377, Train Accuracy: 98.634       Val Loss: 0.2085, Val Accuracy: 94.164, Duration: 0:00:12.285165
# Epoch 95/300, Train Loss: 0.0593, Train Accuracy: 97.993       Val Loss: 0.1756, Val Accuracy: 94.795, Duration: 0:00:12.102653
# Epoch 96/300, Train Loss: 0.0645, Train Accuracy: 97.575       Val Loss: 0.2083, Val Accuracy: 94.953, Duration: 0:00:12.209367
# Epoch 97/300, Train Loss: 0.0618, Train Accuracy: 97.658       Val Loss: 0.1778, Val Accuracy: 94.479, Duration: 0:00:17.067119
# Epoch 98/300, Train Loss: 0.0269, Train Accuracy: 98.968       Val Loss: 0.1644, Val Accuracy: 96.530, Duration: 0:00:14.004044
# Epoch 99/300, Train Loss: 0.0294, Train Accuracy: 98.968       Val Loss: 0.2027, Val Accuracy: 95.426, Duration: 0:00:14.771737
# Epoch 100/300, Train Loss: 0.0353, Train Accuracy: 98.662       Val Loss: 0.1737, Val Accuracy: 95.899, Duration: 0:00:13.022289
# Epoch 101/300, Train Loss: 0.0411, Train Accuracy: 98.439       Val Loss: 0.1696, Val Accuracy: 95.741, Duration: 0:00:12.882348
# Epoch 102/300, Train Loss: 0.0368, Train Accuracy: 98.885       Val Loss: 0.1535, Val Accuracy: 96.372, Duration: 0:00:12.587958
# Epoch 103/300, Train Loss: 0.0396, Train Accuracy: 98.467       Val Loss: 0.1597, Val Accuracy: 96.215, Duration: 0:00:12.773747
# Epoch 104/300, Train Loss: 0.0462, Train Accuracy: 98.327       Val Loss: 0.1584, Val Accuracy: 95.899, Duration: 0:00:13.076513
# Epoch 105/300, Train Loss: 0.0293, Train Accuracy: 99.052       Val Loss: 0.1804, Val Accuracy: 94.795, Duration: 0:00:13.506692
# Epoch 106/300, Train Loss: 0.0465, Train Accuracy: 98.411       Val Loss: 0.1912, Val Accuracy: 94.953, Duration: 0:00:13.536462
# Epoch 107/300, Train Loss: 0.0411, Train Accuracy: 98.550       Val Loss: 0.1872, Val Accuracy: 95.741, Duration: 0:00:12.825678
# Epoch 108/300, Train Loss: 0.0571, Train Accuracy: 97.881       Val Loss: 0.1809, Val Accuracy: 96.057, Duration: 0:00:13.281889
# Epoch 109/300, Train Loss: 0.0500, Train Accuracy: 98.104       Val Loss: 0.1673, Val Accuracy: 96.057, Duration: 0:00:13.260049
# Epoch 110/300, Train Loss: 0.0332, Train Accuracy: 98.829       Val Loss: 0.1521, Val Accuracy: 96.372, Duration: 0:00:15.374987
# Epoch 111/300, Train Loss: 0.0255, Train Accuracy: 99.219       Val Loss: 0.1647, Val Accuracy: 94.795, Duration: 0:00:13.398793
# Epoch 112/300, Train Loss: 0.0259, Train Accuracy: 99.303       Val Loss: 0.1693, Val Accuracy: 96.688, Duration: 0:00:13.108604
# Epoch 113/300, Train Loss: 0.0230, Train Accuracy: 99.136       Val Loss: 0.1607, Val Accuracy: 96.057, Duration: 0:00:13.585318
# Epoch 114/300, Train Loss: 0.0424, Train Accuracy: 98.383       Val Loss: 0.1960, Val Accuracy: 95.426, Duration: 0:00:13.276758
# Epoch 115/300, Train Loss: 0.0541, Train Accuracy: 98.104       Val Loss: 0.1896, Val Accuracy: 94.953, Duration: 0:00:12.851630
# Epoch 116/300, Train Loss: 0.0458, Train Accuracy: 98.522       Val Loss: 0.2328, Val Accuracy: 93.533, Duration: 0:00:12.891370
# Epoch 117/300, Train Loss: 0.0250, Train Accuracy: 99.080       Val Loss: 0.1516, Val Accuracy: 95.584, Duration: 0:00:16.065848
# Epoch 118/300, Train Loss: 0.0113, Train Accuracy: 99.721       Val Loss: 0.1829, Val Accuracy: 95.426, Duration: 0:00:12.803483
# Epoch 119/300, Train Loss: 0.0165, Train Accuracy: 99.442       Val Loss: 0.2290, Val Accuracy: 94.953, Duration: 0:00:12.837335
# Epoch 120/300, Train Loss: 0.0341, Train Accuracy: 98.968       Val Loss: 0.1508, Val Accuracy: 96.688, Duration: 0:00:12.979496
# Epoch 121/300, Train Loss: 0.0464, Train Accuracy: 98.216       Val Loss: 0.1742, Val Accuracy: 95.741, Duration: 0:00:13.767535
# Epoch 122/300, Train Loss: 0.0264, Train Accuracy: 99.136       Val Loss: 0.1858, Val Accuracy: 95.899, Duration: 0:00:12.637328
# Epoch 123/300, Train Loss: 0.0199, Train Accuracy: 99.331       Val Loss: 0.1400, Val Accuracy: 97.161, Duration: 0:00:13.937595
# Epoch 124/300, Train Loss: 0.0250, Train Accuracy: 99.052       Val Loss: 0.2708, Val Accuracy: 94.322, Duration: 0:00:12.724491
# Epoch 125/300, Train Loss: 0.0327, Train Accuracy: 98.913       Val Loss: 0.1885, Val Accuracy: 95.741, Duration: 0:00:13.494401
# Epoch 126/300, Train Loss: 0.0359, Train Accuracy: 98.690       Val Loss: 0.2166, Val Accuracy: 94.795, Duration: 0:00:13.911404
# Epoch 127/300, Train Loss: 0.0352, Train Accuracy: 98.718       Val Loss: 0.1746, Val Accuracy: 95.268, Duration: 0:00:13.223513
# Epoch 128/300, Train Loss: 0.0344, Train Accuracy: 98.857       Val Loss: 0.1875, Val Accuracy: 96.372, Duration: 0:00:12.535846
# Epoch 129/300, Train Loss: 0.0199, Train Accuracy: 99.275       Val Loss: 0.1905, Val Accuracy: 95.899, Duration: 0:00:12.485994
# Epoch 130/300, Train Loss: 0.0479, Train Accuracy: 98.383       Val Loss: 0.2109, Val Accuracy: 94.322, Duration: 0:00:13.340831
# Epoch 131/300, Train Loss: 0.0374, Train Accuracy: 98.801       Val Loss: 0.1755, Val Accuracy: 95.268, Duration: 0:00:12.745519

# %%
images, labels = val_dataiter.next()
out_img, predicted = torch.max(model(images.to(device)), 1)
imshow(images[:7], labels[:7], predicted[:7])

# %%
# Plot the train loss and test loss per iteration
plt.plot(train_losses, label='train loss')
plt.plot(val_losses, label='val loss')
plt.legend()
plt.show()

# %%
test_loss = []
test_acc = []
n_correct = 0.
n_total = 0.
model.eval()
with torch.no_grad():
    for inputs, targets in Dte:
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = model(inputs)

        # Get the predictions
        # torch.max returns both max and argmax
        __, out_label = outputs.max(dim=1)
        # Updates the accuracy with every pass
        n_correct += (out_label == targets).sum().item()
        n_total += targets.shape[0]
        test_acc.append(n_correct / n_total)

        loss = loss_fn(outputs, targets)
        test_loss.append(loss.item())
test_loss = np.mean(test_loss)
avg_acc = np.mean(test_acc)*100
print('Average loss across the testing data: {}, Average testing accuracy: {}'.format(test_loss, avg_acc))
# Out:
# Average loss across the testing data: 0.1707478884075369, Average testing accuracy: 95.26824874686717

# %% [markdown]
# Same but horizontal flip is 0.6
# val loss = 2.9, acc = 90, min val loss= 0.207
# -------------
# back to first settings without vertical flip
# n_layers=5
# average loss across testing data: 0.2088
# average test acc = 92.42
# -------------
# Same.
# n_layers =4
# average loss: 0.1977
# avg acc: 93.62
# -------------
# Same.
# n_layers=3
# avg loss: 0.1905
# avg acc: 92.67
# -------------
# Same.
# n_layers=2
# avg loss: 0.1897
# avg acc: 93.19
# -------------
# Same.
# n_layers=1
# avg loss: 0.2689
# avg acc: 93.03
# -------------
# Same.
# n_layers=4
# n_heads=2
# avg loss: 0.1886
# avg acc: 91.93
# -------------
# Same.
# embed_dim=48
# n_layers=4
# n_heads=6
# avg loss: 0.1704
# avg acc: 94.53
# -------------
# Same.
# embed_dim=48
# n_layers=4
# n_heads=8
# avg loss: 0.2473
# avg acc: 92.14
# -------------
# Same.
# embed_dim=48
# n_layers=4
# n_heads=6
# mlp_ratio=3
# avg loss: 0.2230
# avg acc: 93.37
# -------------
# Same.
# embed_dim=48
# n_layers=4
# n_heads=6
# mlp_ratio=4
# avg loss: 0.2096
# avg acc: 95.14
# -------------
# Same.
# embed_dim=48
# n_layers=4
# n_heads=6
# mlp_ratio=2
# epochs=300
# avg loss: 0.2462
# avg acc: 95.10
# -------------
# Same.
# Switched train/val/test to 70/15/15
# epochs=100
# avg loss: 0.3025
# avg acc: 93
# -------------
# Same.
# Activated a Normalizing thing in convolutional layer
# epochs=100
# avg loss: 0.2050
# avg acc: 95.17
# -------------
# Same.
# epochs=300
# avg loss: 0.1853
# avg acc: 95.97
# -------------
# Same.
# embedded dimensions set to 36
# epochs=300
# avg loss: 0.2114
# avg acc: 96.18
# -------------
# Same.
# embedded dimensions set to 42
# epochs=300
# avg loss: 0.2116
# avg acc: 94.52
# -------------
# Same.
# epochs=600
# avg loss: 0.2193
# avg acc: 96.69

# %% [markdown]
# ### 5 Class Sipakmed
#
# batches = 96, image size = 160
# model = CCT(
#         img_size=img_size,      # Input image size
#         in_channels=3,  # Number of channels for the image
#         patch_size=4,   # How big our patches are
#         embed_dim=42,   # Embedding dim
#         n_layers=4,     # Number of transformer encoders
#         n_conv=2,       # Number of convolutional layers
#         n_heads=6,      # Number of attention heads
#         attn_dropout=0.,        # Attention Dropout
#         proj_dropout=0.,        # (MHA) Projection Dropout
#         mlp_dropout=0.1,        # (MHA) last layer dropout
#         mlp_ratio=2,    # (MHA) Projection FF dimension
#         qkv_bias = True,
#         n_classes=5     # Number of classes to classify
#         )
# epochs = 300, avg loss = 0.1707, avg acc = 95.27

# %%
import os
from PIL import Image
import torch
from torch.utils.data import DataLoader,Dataset
import torch.nn as nn
from torch import Tensor
import torchvision
import torchvision.transforms as transforms
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import torch.nn.functional as F
from datetime import datetime
from sklearn.model_selection import train_test_split

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
torch.backends.cudnn.benchmark = True

# %% [markdown]
# # A Compact Convolutional Vision Transformer or CCT
# *Created using the walkthrough from https://medium.com/pytorch/training-compact-transformers-from-scratch-in-30-minutes-with-pytorch-ff5c21668ed5 and Dr Prashant's Vision_Transformer file

# %% [markdown]
# ## Building the Transformer block by block

# %% [markdown]
# Every part/layer of the transformer is built using the Pytorch nn.module class which allows for easy creation of maching learning models. Each layer should be made up of at least two parts: An initialization function which uses the given information to build the class and then the 'Forward' function defines how the class will run when it is called.

# %% [markdown]
# ### Transformer Constructor
#
# First, the actual ViT Constructor which essentially acts as a hub. It ensures that each part of the transformer is called in the correct order and that local variables can be passed along.

# %% [markdown]
# ### What makes it more Compact/Lite than the CVT?
#
# The only difference between this and the original Vision Transformer is a Sequence Pooling layer and a convolutional layer instead of patching. Previously the classes were embedded separately and then passed to the MLP for classification. Sequence Pooling ties the class information in with every other parameter.. I think.

# %%
class CCT(nn.Module):
    '''
    Simplified implementation of the Vision transformer.

    Parameters
    ----------
    img_size: int
        Both height and width of the image (if it is a square)
    in_channels: int
        Number of input channels
    patch_size: int
        Both height and width of the patch (if it is a square)
    embed_dim: int
        The embedding size for each token
    n_layers: int
        Number of transformer blocks
    n_heads: int
        Number of attention heads
    attn_dropout, proj_dropout, mlp_dropout: float
        Dropout probability
    mlp_ratio: float
        Determine the hidden dimension of the MLP module
    qkv_bias: bool
        If true then we add bias to the query, key and value projections
    n_classes: int
        Number of classes

    Attributes
    -----------
    n_patches: int
        Number of patches that can be taken from each image based on size.
    patch_embed: PatchEmbed
        Sets up the `Patching' layer.
    class_embed: nn.Parameter
        Learnable parameter that will represent the first class token in the sequence.
        It has `embed_dim' elements.
    pos_embed: nn.Parameter
        Adds a positional encoding to every token.
    pos_drop: nn.Dropout
        Dropout layer.
    tr_block: nn.ModuleList
        Instance of 'TransformerEncoderLayer'.
    norm: nn.Layernorm
        Layer normalization.
    '''
    def __init__(self,
                 img_size=32,   # The square size of each image
                 in_channels=3, # Number of channels for each image (eg: Grayscale=1, RGB=3)
                 patch_size=4,  # The square size of each patch
                 embed_dim=768,  # Embedding dimension
                 n_layers=3, # How many times to run the transformer encoder
                 n_conv=2,
                 n_heads=3,   # Number of attention heads,
                 attn_dropout=0.,  # Attention Dropout
                 proj_dropout=0.,   # (MHA) Projection Dropout
                 mlp_dropout=0.,   # (MHA) last layer dropout
                 mlp_ratio=4,   # (MHA) Projection FF dimension
                 qkv_bias = True,
                 n_classes=10   # Number of classes to classify
    ):
        super().__init__()
        # Provides an error if the patching size is not divisible by the image size.
        assert img_size % patch_size == 0, \
            print("Given image size ({}) has to be divisible by given patch size ({})".format(img_size, patch_size))

        self.conv_embed = nn.ModuleList(
            [
                Conv_Embed(img_size, in_channels, embed_dim)
                for _ in range(n_conv)
            ]   # Sends data through the encoder n times
        )

        n_patches = self.conv_embed.sequence_length(in_channels=in_channels, height=img_size, width=img_size)
        hidden_dim = int(embed_dim * mlp_ratio)
        
        self.pos_embed = nn.Parameter(torch.zeros(1, n_patches, embed_dim))
        #nn.init.trunc_normal_(self.pos_embed, std=0.2)
        
        # Can use this to enable Sinusoidal PE
        #self.pos_embed = PositionalEmbedding(1, n_patches + 1, embed_dim)

        self.pos_drop = nn.Dropout(p=proj_dropout)
        self.tr_block = nn.ModuleList(
            [
                TransformerEncoderLayer(
                    embed_dim,
                    n_heads,
                    qkv_bias,
                    attn_dropout,
                    proj_dropout,
                    mlp_dropout,
                    hidden_dim
                    )
                for _ in range(n_layers)
            ]   # Sends data through the encoder n times
        )
        self.norm = nn.LayerNorm(embed_dim, eps=1e-6)
        
        self.attention_pool = nn.Linear(embed_dim, 1)
                                    
        self.head = nn.Linear(embed_dim, n_classes)

    def forward(self, x):
        '''
        Defines how the class will run

        Parameters
        ----------
        x: torch.Tensor
            shape: n_samples, in_chains, img_size, img_size

        Returns
        ---------
        logits: torch.Tensor
            Logits over all the classes: n_samples, n_samples
        '''
        for conv_embed in self.conv_embed:
            x = conv_embed(x)
        #x = self.pos_embed(x)
        x += self.pos_embed
        x = self.pos_drop(x)
        for tr_block in self.tr_block:
            x = tr_block(x)
        x = self.norm(x)
        #Added Sequence Pooling instead of Class embedding
        x = torch.matmul(F.softmax(self.attention_pool(x), dim=1).transpose(-1, -2), x).squeeze(-2)
        x = self.head(x)
        return x

# %% [markdown]
# ### Positional Embedding
#
# This is the sinusoidal positional encoding layer as seen in the original 'Attention is All You Need' paper. It basically uses a sin/cos waveform to provide a unique positional offset that is given to a token at the corresponding position in its embedding space.
#
# By default, this is disabled and we instead use a trainable matrix of zeros. This adds another dimension to our data that the model then uses to find the best weights for the data's position itself. This is called "learnable" positional encoding.
#
# There are pros-and-cons to either, but essentially: sinusoidal is better when there are not a lot of data samples to learn the positional data from but you can get better results from "learnable" with larger datasets.

# %%
class PositionalEmbedding(nn.Module):
    '''
    Applies Learnable Sinusoidal Positional Encoding

    Parameters
    ----------
    embed_dim: int
        The positional embedding dimension (How big embedding for each patch.Constant across entire network)
    max_len: int 
        Max number of instances for positions
    freq: int 
        The base frequency for Sin/Cos calculations. Higher values (eg 10000) are more stable
    '''
    def __init__(self, 
                 embed_dim,
                 max_len=5000,
                 freq=10000.,
                ):
        super().__init__()
        pe = torch.zeros(max_len, embed_dim)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div = torch.exp(torch.arange(0, embed_dim, 2).float() *
                        (-math.log(freq) / embed_dim))
        pe[:, 0::2] = torch.sin(position * div) # Even terms
        pe[:, 1::2] = torch.cos(position * div) # Odd terms
        pe = pe.unsqueeze(0).transpose(0,1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        '''
        Defines how the class will run

        Parameters
        -----------

        Returns
        -----------
        '''
        x = x + self.pe[:x.size(0), :]
        return x

# %% [markdown]
# ### Convolutional Embedding Layer
#
# The patching used by the previous models was a problem because, while it took more samples of the input data, it also created what were essentially bordered segments which made it harder for the model to learn how they connected to the other segments and the bigger picture.
#
# The new convolutional layer helps to eliminate that problem by using convolutional filters to create many different overlapping segments.

# %% [markdown]
# !!! Things to do: Make it iterable n number of times for greater hyper-parameter fine tuning !!!

# %%
class Conv_Embed(nn.Module):
    def __init__(self,
                 img_size=32,
                 in_channels=3,
                 out_channels=64,
                 kernel_size=7,
                 stride=2,
                 padding=3,
                 pool_kernel_size=3,
                 pool_stride=2,
                 pool_padding=1
                 ):
        super().__init__()
        self.img_size = img_size
        self.conv_layers = nn.Sequential(
            nn.Conv2d(in_channels,
                      out_channels,
                      kernel_size=kernel_size,
                      stride=stride,
                      padding=padding,
                      bias=False),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=pool_kernel_size,
                         stride=pool_stride,
                         padding=pool_padding)
        )
        self.flattener = nn.Flatten(2, 3)
        
    def sequence_length(self, in_channels=3, height=32, width=32):
        return self.forward(torch.zeros((1, in_channels, height, width))).shape[1]

    def forward(self, x):
        return self.flattener(self.conv_layers(x)).transpose(-2, -1)

# %% [markdown]
# ### This is the Transformer Encoder block which applies all of the actual normalization, attention, etc that make a Transformer what it is.

# %%
class TransformerEncoderLayer(nn.Module):
    '''
    Transformer Block/Encoder Layer

    Parameter
    ---------
    embed_dim: int
        embedding dimension
    n_heads: int
        number of attention heads
    mlp_ratio: float
        determines the hidden dimension size of the MLP module with respect to 'dim'
    qkv_bias: bool
        If true then we include bias to the query, key and value projections
    mlp_dropout, proj_dropout, attn_droupout: float
        dropout probability
    dim_feedforward: int
        The feature number of hidden layer of the FFN

    Attributes
    ----------
    norm_1, norm_2: LayerNorm
        Layer normalization
    MHA: Attention
        Multi-Headed Attention module
    mlp: MLP
        MLP module
    ''' 
    def __init__(self,
                 embed_dim=768,
                 n_heads=12,
                 qkv_bias=True,
                 attn_dropout=0.,
                 proj_dropout=0.,
                 mlp_dropout=0.,
                 hidden_dim=2048
    ):
        super().__init__()
        self.norm_1 = nn.LayerNorm(embed_dim, eps = 1e-6)
        self.norm_2 = nn.LayerNorm(embed_dim, eps = 1e-6)
        self.MHA = MultiheadedSelfAttention(embed_dim,
                                        n_heads,
                                        qkv_bias,
                                        attn_dropout,
                                        proj_dropout
        )
        self.MLP = MLP(embed_dim, hidden_dim, mlp_dropout)

    def forward(self, x):
        '''
        Defines how the class will run
        
        Parameter
        ---------
        x: torch.Tensor
            shape: n_samples, n_patches + 1, dim

        Returns
        --------
        torch.Tensor
            shape: n_samples, n_patches + 1, dim
        '''
        x = x + self.MHA(self.norm_1(x))    # Residual connection (Add)
        x = x + self.MLP(self.norm_2(x))    # Residual connection (Add)
        return x

# %% [markdown]
# ### Multiheaded Attention Layer
#
# The heart of the Transformer model; the reason behind the original title of "attention is all you need".

# %%
class MultiheadedSelfAttention(nn.Module):
    '''
    Multi-Headed Attention Mechanism

    Parameters
    ----------
    embed_dim: int
        The input and out dimension of per token feature
    n_heads: int
        Number of attention heads 
    qkv_bias: bool
        if true then we include bias to the query, key and value projections
    attn_p: float
        Dropout probability applied to the query, key and value tensors.
    proj_p: float
        Dropout probability applied to output tensor
        
    Attributes
    ----------
    scale: float
        Normalizing constant for the dot product
    qkv: nn.Linear
        Linear projection for the query, key and value
    proj: nn.Linear
        Linear mapping that takes in the concatenated output of all attention
        heads and maps into the new space
    attn_drop, proj_drop: nn.Dropout
        Dropout layers.
    '''
    def __init__(self, 
                 embed_dim, 
                 n_heads=2,
                 qkv_bias = True,
                 attn_dropout=0.,
                 proj_dropout=0.
    ):
        super().__init__()
        self.n_heads = n_heads
        assert embed_dim % n_heads == 0, \
            print('Embedding dim must be divisible by number of heads.')
        self.head_dim = embed_dim // n_heads
        self.scale = self.head_dim ** -0.5
        self.dim = embed_dim
        self.qkv = nn.Linear(embed_dim, embed_dim * 3, bias=qkv_bias)
        self.attn_dropout = nn.Dropout(attn_dropout)
        self.proj = nn.Linear(embed_dim, embed_dim)
        self.proj_dropout = nn.Dropout(proj_dropout)
        
    def forward(self, x):
        '''
        Defines how the class will run
        
        Parameters
        ----------
        x: torch.Tensor
            shape: n_samples (B), n_patches + 1 (N), embed_dim (C)
            N is also equal to the number of tokens.
        Returns
        --------
        torch.Tensor
            shape: n_samples, n_patches + 1, embed_dim
        '''
        B, N, C = x.shape
        qkv = self.qkv(x)
        qkv = qkv.reshape(B, N, 3,
            self.n_heads,
            self.head_dim
            )
        qkv = qkv.permute(
            2,    # qkv (3)
            0,    # batch (n_samples)
            3,    # channel (n_heads)
            1,    # n_patches + 1
            4     # head_dim (embed_dim / n_heads)
            )
        q, k, v = qkv[0], qkv[1], qkv[2]
        attn = (q @ k.transpose(-2, -1)) * self.scale # <q,k> / sqrt(d)
        attn = attn.softmax(dim=-1) # Softmax over embedding dim
        attn = self.attn_dropout(attn)

        weighted_avg = (attn @ v)
        weighted_avg = weighted_avg.transpose(1, 2)
        weighted_avg = weighted_avg.flatten(2)

        x = self.proj(weighted_avg)
        x = self.proj_dropout(x)

        return x

# %% [markdown]
# ### The MLP layer
#
# (At the end of the Transformer Encoder). Not to be confused with the mlp head which adds class encodings at the very end of the transformer.

# %%
class MLP(nn.Module):
    '''
    Multilayer perceptron 
    
    Parameters
    ----------
    embed_dim: int
        embedding dimension
    feedforward_dim: int
      Number of nodes in the hidden layer
    mlp_dropout: float
      Dropout probability

    Attribute
    ---------
    fc: nn.Linear
      The first linear layer
    act: nn. GELU
      GELU activation function
    fc2: nn.Linear
      The second linear layer
    drop: nn.Dropout
      Dropout layer
    '''

    def __init__(self, embed_dim, hidden_dim, mlp_dropout):
        super().__init__()
        self.fc1 = nn.Linear(embed_dim, hidden_dim)
        self.act = nn.GELU()
        self.fc2 = nn.Linear(hidden_dim, embed_dim)
        self.drop = nn.Dropout(mlp_dropout)

    def forward(self,x):
        '''
        Defines how the class will run
        
        Parameters
        ----------
        x: torch.Tensor
          shape: n_samples, n_patches + 1, in_features

        Returns
        ----------
        torch.Tensor
          n_samples, n_patches+ 1, out_features
        '''
        x = self.fc1(x) # n_samples, n_patches+1, hidden_features
        x = self.act(x) # n_samples, n_patches+1, hidden_features
        x = self.drop(x) # n_samples, n_patches+1, hidden_features
        x = self.fc2(x) # n_samples, n_patches+1, output_features
        x = self.drop(x) # n_samples, n_patches+1, output_features
        return x

# %% [markdown]
# # Training the ViT with the CIFAR10 dataset

# %% [markdown]
# ### Setup needed variables

# %%
def sipakmed_prep():
    root = "../../Python Scripts/Datasets/CervicalCancer/Sipakmed/"

    all_img = []
    for path, subdirs, files in os.walk(root):
        for name in files:
            curr_img = os.path.join(path,name)
            all_img.append(curr_img)

    sipakmed_df = pd.DataFrame()
    sipakmed_df['LocalPath'] = all_img
    sipakmed_df['ID'] = sipakmed_df['LocalPath'].apply(lambda x: str(x.split("\\")[-1]))
    sipakmed_df['Slide'] = sipakmed_df['LocalPath'].apply(lambda x: 'False' if (str(x.split("\\")[1])) == 'CROPPED' else 'True')
    sipakmed_df['Specific_Status'] = sipakmed_df['LocalPath'].apply(lambda x: str((x.split("im_")[1]).split("\\")[0]))
    sipakmed_df['Status'] = sipakmed_df['Specific_Status'].apply(lambda x: 'Benign' if x == 'Metaplastic' else
    ('Normal' if x == 'Superficial-Intermediate' or x == 'Parabasal' else 'Abnormal'))

    sp_class = {'Metaplastic':4, 'Superficial-Intermediate':0, 'Parabasal':1, 'Koilocytotic':2, 'Dyskeratotic':3}
    sipakmed_df['Specific_Class'] = sipakmed_df['Specific_Status'].map(sp_class)
    gen_class = {'Benign':0, 'Normal':1, 'Abnormal':2}
    sipakmed_df['Class'] = sipakmed_df['Status'].map(gen_class)

    sipakmed_df = sipakmed_df.loc[sipakmed_df['ID'].str.contains('bmp')].reset_index(drop=True)
    
    #Uploads the created file for future use. Recommended to not use.
    #sipakmed_df.to_csv(root + '/results.csv')
    return sipakmed_df

# %%
def herlev_prep():
    root = '../../Python Scripts/Datasets/CervicalCancer/Herlev/smear2005/results.csv'
    img_folder = '../../Python Scripts/Datasets/CervicalCancer/Herlev/smear2005/Images/'

    herlev_df=pd.read_csv(root)
    herlev_df = herlev_df.rename(columns={'Class':'Specific_Class'})

    gen_class = {1:1, 2:1, 3:1, 4:2, 5:2, 6:2, 7:2}
    herlev_df['Class'] = herlev_df['Specific_Class'].map(gen_class)
    herlev_df['LocalPath'] = herlev_df['ID'].apply(lambda x: str(img_folder + x))
    return herlev_df

# %%
class DatasetSample(Dataset):
    def __init__(self, df, transform):
        # Initialization
        self.transform = transform
        
        self.image_names = df['LocalPath']
        self.img_class = np.array(df['Class'])

    def __len__(self):
        # Denotes the total number of samples
        return len(self.image_names)
    
    def __getitem__(self, index):
        # Retrieves the data
        image=cv2.imread(self.image_names.iloc[index])
        image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

        image = self.transform(image)
        label = self.img_class[index]

        x, y = image, label
        
        # Enable to output as single variable instead
        #sample = {'image': image,'labels':label}

        return x, y

# %%
def concat_data(batch_size=128, img_size=32):
    # Load the dataframes
    sipakmed_df = sipakmed_prep()
    herlev_df = herlev_prep()

    # Final adjustments to make sure they're attributes match
    sipakmed_df = sipakmed_df.loc[sipakmed_df['Slide'] == 'False']
    herlev_df = herlev_df.loc[:,['LocalPath', 'Class']]
    sipakmed_df = sipakmed_df.loc[:,['LocalPath', 'Class']]
    
    concat_df = pd.concat([sipakmed_df,herlev_df], ignore_index=True)
    
    # Split them into training and testing sets
    train_set,test_set = train_test_split(concat_df,test_size=0.15)
    
    # Set it up to alter random training images for better results
    train_transform = transforms.Compose([
                    transforms.ToPILImage(),
                    transforms.Resize((img_size, img_size)),
                    transforms.RandomHorizontalFlip(p=0.75),
                    transforms.RandomRotation(degrees=60),
                    transforms.ToTensor()])

    test_transform = transforms.Compose([
                    transforms.ToPILImage(),
                    transforms.Resize((img_size, img_size)),
                    transforms.ToTensor()])

    train_dataset = DatasetSample(train_set, train_transform)
    test_dataset = DatasetSample(test_set, test_transform)
    
    Dtr = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True
    )
    
    Dte = DataLoader(
        test_dataset, 
        batch_size=batch_size,
        shuffle=True
    )

    return(Dtr, Dte)

# %%
#The corresponding class labels
batch_size=28
img_size=84
classes = ('Benign', 'Normal', 'Abnormal')
Dtr, Dte = concat_data(batch_size=batch_size, img_size=img_size)

# %% [markdown]
# ### Builds the dataloaders for training and testing

# %%
# Turns the dataloaders into iterable objects. Useful for viewing
dataiter = iter(Dtr)
test_dataiter = iter(Dte)

# %% [markdown]
# ### Function for viewing batches of the dataset

# %%
def imshow(images, labels, predicted_labels=None):
    
    if images.is_cuda == True:
        images = images.to("cpu")
    if labels.is_cuda == True:
        labels = labels.to("cpu")

    # Using torchvision to make a grid of the images
    img = torchvision.utils.make_grid(images)

    # Inverting the normalization
    img = img.numpy().transpose((1, 2, 0))
    img = np.clip(img, 0, 1)

    # Plotting the grid
    fig, ax = plt.subplots(figsize=(12, 24))
    plt.imshow(img)

    if predicted_labels is not None:
        if predicted_labels.is_cuda == True:
            predicted_labels = predicted_labels.to("cpu")
        # Outputing the predicted labels
        ax.set_xlabel('Predicted labels', fontsize=18, labelpad=12)
        ax.set_xticks(torch.arange(len(images)) * img_size + (img_size/1.8))
        ax.set_xticklabels([classes[predicted_labels[j]] 
                            for j in range(len(images))], fontsize=12, rotation=30)
    
    # Outputing the True labels
    gax = ax.secondary_xaxis('top')
    gax.set_xlabel('True Labels', fontsize=18, labelpad=12)
    gax.set_xticks(torch.arange(len(images)) * img_size + (img_size/1.8))
    gax.set_xticklabels([classes[labels[j]] 
                         for j in range(len(images))], fontsize=12, rotation=30)
    plt.show()

# %%
images, labels = dataiter.next()
imshow(images[:7], labels[:7])

# %% [markdown]
# ### This function was made by Dr Prashant to train the model that's built above

# %%
# A function to encapsulate the training loop
def batch_gd(model, loss_fn, optimizer, train_loader, test_loader, epochs):
  model.to(device)
  train_losses = np.zeros(epochs)
  test_losses = np.zeros(epochs)

  for it in range(epochs):
    model.train()
    t0 = datetime.now()
    train_loss = []
    n_correct = 0.
    n_total = 0.
    for inputs, targets in train_loader:
      # move data to GPU if available
      inputs, targets = inputs.to(device), targets.to(device)

      # zero the parameter gradients
      optimizer.zero_grad()

      # Forward pass
      outputs = model(inputs)
      
      # Get the predictions
      # torch.max returns both max and argmax
      __, out_label = outputs.max(dim=1)
      # Updates the accuracy with every pass
      n_correct += (out_label == targets).sum().item()
      n_total += targets.shape[0]
      tr_acc = n_correct / n_total

      loss = loss_fn(outputs, targets)
      # Backward and optimize
      loss.backward()
      optimizer.step()

      train_loss.append(loss.item())

    # Get train loss and test loss
    train_loss = np.mean(train_loss) # a little misleading
    
    model.eval()
    test_loss = []
    n_correct = 0.
    n_total = 0.
    for inputs, targets in test_loader:
      inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)

      # Get the predictions
      # torch.max returns both max and argmax
      __, out_label = outputs.max(dim=1)
      # Updates the accuracy with every pass
      n_correct += (out_label == targets).sum().item()
      n_total += targets.shape[0]
      te_acc = n_correct / n_total


      loss = loss_fn(outputs, targets)
      test_loss.append(loss.item())
    test_loss = np.mean(test_loss)

    # Save losses
    train_losses[it] = train_loss
    test_losses[it] = test_loss
    
    dt = datetime.now() - t0
    print(f'Epoch {it+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {(100*tr_acc):.3f} \
      Test Loss: {test_loss:.4f}, Test Accuracy: {(100*te_acc):.3f}, Duration: {dt}')
  
  return train_losses, test_losses

# %% [markdown]
# ### Initializes the Transformer and selects the loss function and optimizer we want

# %% [markdown]
# !!! Look up LAMB Optimizer !!!

# %%
model = CCT(
        img_size=img_size,      # Input image size
        in_channels=3,  # Number of channels for the image
        patch_size=4,   # How big our patches are
        embed_dim=44,   # Embedding dim
        n_layers=6,     # Number of transformer encoders
        n_conv=2,       # Number of convolutional layers
        n_heads=4,      # Number of attention heads
        attn_dropout=0.,        # Attention Dropout
        proj_dropout=0.,        # (MHA) Projection Dropout
        mlp_dropout=0.1,        # (MHA) last layer dropout
        mlp_ratio=2,    # (MHA) Projection FF dimension
        qkv_bias = True,
        n_classes=3     # Number of classes to classify
        )
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())

# %%
train_losses, test_losses = batch_gd(model, loss_fn, optimizer, Dtr, Dte, epochs=300)
# Out:
# Epoch 1/300, Train Loss: 0.7996, Train Accuracy: 62.355       Test Loss: 0.6831, Test Accuracy: 72.349, Duration: 0:00:40.983136
# Epoch 2/300, Train Loss: 0.6206, Train Accuracy: 74.982       Test Loss: 0.5370, Test Accuracy: 78.523, Duration: 0:00:38.257251
# Epoch 3/300, Train Loss: 0.5341, Train Accuracy: 79.697       Test Loss: 0.5174, Test Accuracy: 79.329, Duration: 0:00:38.463786
# Epoch 4/300, Train Loss: 0.4631, Train Accuracy: 82.966       Test Loss: 0.4467, Test Accuracy: 83.893, Duration: 0:00:38.447182
# Epoch 5/300, Train Loss: 0.4297, Train Accuracy: 83.464       Test Loss: 0.4475, Test Accuracy: 83.624, Duration: 0:00:38.449177
# Epoch 6/300, Train Loss: 0.4018, Train Accuracy: 84.317       Test Loss: 0.4327, Test Accuracy: 84.161, Duration: 0:00:38.434217
# Epoch 7/300, Train Loss: 0.3900, Train Accuracy: 84.648       Test Loss: 0.3827, Test Accuracy: 86.174, Duration: 0:00:38.545918
# Epoch 8/300, Train Loss: 0.3686, Train Accuracy: 86.733       Test Loss: 0.3557, Test Accuracy: 86.443, Duration: 0:00:38.559882
# Epoch 9/300, Train Loss: 0.3514, Train Accuracy: 87.207       Test Loss: 0.3536, Test Accuracy: 87.114, Duration: 0:00:38.499043
# Epoch 10/300, Train Loss: 0.3348, Train Accuracy: 87.373       Test Loss: 0.3254, Test Accuracy: 87.785, Duration: 0:00:38.489069
# Epoch 11/300, Train Loss: 0.3085, Train Accuracy: 88.320       Test Loss: 0.3437, Test Accuracy: 88.188, Duration: 0:00:38.485081
# Epoch 12/300, Train Loss: 0.2864, Train Accuracy: 89.244       Test Loss: 0.3130, Test Accuracy: 88.859, Duration: 0:00:38.483087
# Epoch 13/300, Train Loss: 0.2829, Train Accuracy: 89.647       Test Loss: 0.3174, Test Accuracy: 88.993, Duration: 0:00:38.474110
# Epoch 14/300, Train Loss: 0.2846, Train Accuracy: 89.694       Test Loss: 0.3423, Test Accuracy: 88.054, Duration: 0:00:38.468126
# Epoch 15/300, Train Loss: 0.2748, Train Accuracy: 89.647       Test Loss: 0.3312, Test Accuracy: 88.322, Duration: 0:00:38.461145
# Epoch 16/300, Train Loss: 0.2520, Train Accuracy: 91.021       Test Loss: 0.2982, Test Accuracy: 88.725, Duration: 0:00:38.459151
# Epoch 17/300, Train Loss: 0.2612, Train Accuracy: 90.097       Test Loss: 0.2879, Test Accuracy: 88.859, Duration: 0:00:38.479096
# Epoch 18/300, Train Loss: 0.2363, Train Accuracy: 91.211       Test Loss: 0.3448, Test Accuracy: 87.114, Duration: 0:00:38.513006
# Epoch 19/300, Train Loss: 0.2309, Train Accuracy: 91.376       Test Loss: 0.2700, Test Accuracy: 91.141, Duration: 0:00:38.491065
# Epoch 20/300, Train Loss: 0.2242, Train Accuracy: 91.471       Test Loss: 0.2850, Test Accuracy: 90.470, Duration: 0:00:38.469123
# Epoch 21/300, Train Loss: 0.2169, Train Accuracy: 91.661       Test Loss: 0.3081, Test Accuracy: 89.530, Duration: 0:00:38.446185
# Epoch 22/300, Train Loss: 0.2122, Train Accuracy: 92.419       Test Loss: 0.3198, Test Accuracy: 88.859, Duration: 0:00:38.584814
# Epoch 23/300, Train Loss: 0.1982, Train Accuracy: 92.206       Test Loss: 0.2478, Test Accuracy: 91.812, Duration: 0:00:38.570852
# Epoch 24/300, Train Loss: 0.1868, Train Accuracy: 93.130       Test Loss: 0.2917, Test Accuracy: 89.262, Duration: 0:00:38.545918
# Epoch 25/300, Train Loss: 0.1859, Train Accuracy: 93.153       Test Loss: 0.2653, Test Accuracy: 90.738, Duration: 0:00:38.579827
# Epoch 26/300, Train Loss: 0.1826, Train Accuracy: 93.485       Test Loss: 0.2290, Test Accuracy: 92.617, Duration: 0:00:38.430470
# Epoch 27/300, Train Loss: 0.1659, Train Accuracy: 93.627       Test Loss: 0.2669, Test Accuracy: 90.336, Duration: 0:00:37.029972
# Epoch 28/300, Train Loss: 0.1971, Train Accuracy: 92.419       Test Loss: 0.2384, Test Accuracy: 92.215, Duration: 0:00:36.974121
# Epoch 29/300, Train Loss: 0.1543, Train Accuracy: 94.504       Test Loss: 0.2078, Test Accuracy: 93.154, Duration: 0:00:36.963151
# Epoch 30/300, Train Loss: 0.1757, Train Accuracy: 93.532       Test Loss: 0.2402, Test Accuracy: 92.081, Duration: 0:00:36.996063
# Epoch 31/300, Train Loss: 0.1563, Train Accuracy: 94.125       Test Loss: 0.2557, Test Accuracy: 91.007, Duration: 0:00:36.979108
# Epoch 32/300, Train Loss: 0.1571, Train Accuracy: 94.125       Test Loss: 0.2728, Test Accuracy: 91.007, Duration: 0:00:36.996062
# Epoch 33/300, Train Loss: 0.1586, Train Accuracy: 94.219       Test Loss: 0.3014, Test Accuracy: 89.530, Duration: 0:00:37.001050
# Epoch 34/300, Train Loss: 0.1544, Train Accuracy: 94.314       Test Loss: 0.2465, Test Accuracy: 91.007, Duration: 0:00:37.006035
# Epoch 35/300, Train Loss: 0.1389, Train Accuracy: 94.504       Test Loss: 0.2420, Test Accuracy: 92.349, Duration: 0:00:37.014015
# Epoch 36/300, Train Loss: 0.1439, Train Accuracy: 94.646       Test Loss: 0.2138, Test Accuracy: 92.081, Duration: 0:00:36.992073
# Epoch 37/300, Train Loss: 0.1277, Train Accuracy: 95.285       Test Loss: 0.2409, Test Accuracy: 91.141, Duration: 0:00:36.991077
# Epoch 38/300, Train Loss: 0.1370, Train Accuracy: 95.333       Test Loss: 0.2014, Test Accuracy: 92.886, Duration: 0:00:36.994068
# Epoch 39/300, Train Loss: 0.1250, Train Accuracy: 95.214       Test Loss: 0.2507, Test Accuracy: 93.154, Duration: 0:00:36.997060
# Epoch 40/300, Train Loss: 0.1237, Train Accuracy: 95.357       Test Loss: 0.2314, Test Accuracy: 93.154, Duration: 0:00:37.028975
# Epoch 41/300, Train Loss: 0.1181, Train Accuracy: 95.688       Test Loss: 0.2337, Test Accuracy: 92.081, Duration: 0:00:37.013016
# Epoch 42/300, Train Loss: 0.1379, Train Accuracy: 95.096       Test Loss: 0.3434, Test Accuracy: 88.456, Duration: 0:00:37.026981
# Epoch 43/300, Train Loss: 0.1267, Train Accuracy: 95.262       Test Loss: 0.2870, Test Accuracy: 91.275, Duration: 0:00:38.192862
# Epoch 44/300, Train Loss: 0.1088, Train Accuracy: 96.138       Test Loss: 0.2418, Test Accuracy: 93.154, Duration: 0:00:38.354430
# Epoch 45/300, Train Loss: 0.1208, Train Accuracy: 95.593       Test Loss: 0.2230, Test Accuracy: 93.691, Duration: 0:00:38.391332
# Epoch 46/300, Train Loss: 0.0941, Train Accuracy: 96.683       Test Loss: 0.2025, Test Accuracy: 92.886, Duration: 0:00:38.369390
# Epoch 47/300, Train Loss: 0.1102, Train Accuracy: 96.067       Test Loss: 0.2390, Test Accuracy: 92.617, Duration: 0:00:38.478100
# Epoch 48/300, Train Loss: 0.1116, Train Accuracy: 95.712       Test Loss: 0.1998, Test Accuracy: 93.423, Duration: 0:00:38.474110
# Epoch 49/300, Train Loss: 0.0970, Train Accuracy: 96.636       Test Loss: 0.2398, Test Accuracy: 92.752, Duration: 0:00:38.434217
# Epoch 50/300, Train Loss: 0.1072, Train Accuracy: 95.901       Test Loss: 0.2204, Test Accuracy: 92.752, Duration: 0:00:38.370388
# Epoch 51/300, Train Loss: 0.0889, Train Accuracy: 96.707       Test Loss: 0.1683, Test Accuracy: 94.094, Duration: 0:00:38.396318
# Epoch 52/300, Train Loss: 0.0914, Train Accuracy: 96.825       Test Loss: 0.1973, Test Accuracy: 94.362, Duration: 0:00:38.369390
# Epoch 53/300, Train Loss: 0.0849, Train Accuracy: 97.110       Test Loss: 0.2710, Test Accuracy: 92.349, Duration: 0:00:38.424243
# Epoch 54/300, Train Loss: 0.0871, Train Accuracy: 96.802       Test Loss: 0.2903, Test Accuracy: 91.946, Duration: 0:00:38.410281
# Epoch 55/300, Train Loss: 0.1003, Train Accuracy: 96.281       Test Loss: 0.2508, Test Accuracy: 92.483, Duration: 0:00:38.467129
# Epoch 56/300, Train Loss: 0.0767, Train Accuracy: 97.181       Test Loss: 0.2176, Test Accuracy: 93.557, Duration: 0:00:38.391331
# Epoch 57/300, Train Loss: 0.1020, Train Accuracy: 96.399       Test Loss: 0.1991, Test Accuracy: 93.960, Duration: 0:00:38.378366
# Epoch 58/300, Train Loss: 0.0784, Train Accuracy: 97.062       Test Loss: 0.2122, Test Accuracy: 93.289, Duration: 0:00:38.393325
# Epoch 59/300, Train Loss: 0.0873, Train Accuracy: 97.157       Test Loss: 0.1971, Test Accuracy: 94.094, Duration: 0:00:38.414271
# Epoch 60/300, Train Loss: 0.0711, Train Accuracy: 97.726       Test Loss: 0.2489, Test Accuracy: 91.812, Duration: 0:00:38.395321
# Epoch 61/300, Train Loss: 0.0627, Train Accuracy: 97.560       Test Loss: 0.1964, Test Accuracy: 93.960, Duration: 0:00:38.449176
# Epoch 62/300, Train Loss: 0.0919, Train Accuracy: 96.470       Test Loss: 0.1867, Test Accuracy: 93.826, Duration: 0:00:38.479096
# Epoch 63/300, Train Loss: 0.0710, Train Accuracy: 97.441       Test Loss: 0.1711, Test Accuracy: 93.289, Duration: 0:00:38.488073
# Epoch 64/300, Train Loss: 0.0799, Train Accuracy: 96.920       Test Loss: 0.2285, Test Accuracy: 93.154, Duration: 0:00:38.484083
# Epoch 65/300, Train Loss: 0.0666, Train Accuracy: 97.915       Test Loss: 0.1599, Test Accuracy: 94.765, Duration: 0:00:38.425240
# Epoch 66/300, Train Loss: 0.0724, Train Accuracy: 97.512       Test Loss: 0.2037, Test Accuracy: 93.020, Duration: 0:00:38.462142
# Epoch 67/300, Train Loss: 0.0698, Train Accuracy: 97.276       Test Loss: 0.2352, Test Accuracy: 93.154, Duration: 0:00:37.679235
# Epoch 68/300, Train Loss: 0.0624, Train Accuracy: 97.773       Test Loss: 0.2051, Test Accuracy: 93.289, Duration: 0:00:37.062884
# Epoch 69/300, Train Loss: 0.0567, Train Accuracy: 97.844       Test Loss: 0.1692, Test Accuracy: 94.899, Duration: 0:00:37.061887
# Epoch 70/300, Train Loss: 0.0643, Train Accuracy: 97.584       Test Loss: 0.1608, Test Accuracy: 94.765, Duration: 0:00:37.058894
# Epoch 71/300, Train Loss: 0.0571, Train Accuracy: 97.844       Test Loss: 0.1773, Test Accuracy: 94.362, Duration: 0:00:37.064879
# Epoch 72/300, Train Loss: 0.0654, Train Accuracy: 97.370       Test Loss: 0.2145, Test Accuracy: 93.826, Duration: 0:00:37.068868
# Epoch 73/300, Train Loss: 0.0629, Train Accuracy: 97.678       Test Loss: 0.3382, Test Accuracy: 91.275, Duration: 0:00:37.073855
# Epoch 74/300, Train Loss: 0.0562, Train Accuracy: 97.891       Test Loss: 0.2139, Test Accuracy: 93.960, Duration: 0:00:37.071860
# Epoch 75/300, Train Loss: 0.0750, Train Accuracy: 97.228       Test Loss: 0.2089, Test Accuracy: 94.228, Duration: 0:00:37.996685
# Epoch 76/300, Train Loss: 0.0627, Train Accuracy: 97.797       Test Loss: 0.2042, Test Accuracy: 94.497, Duration: 0:00:38.429229
# Epoch 77/300, Train Loss: 0.0672, Train Accuracy: 97.607       Test Loss: 0.2179, Test Accuracy: 93.154, Duration: 0:00:38.467129
# Epoch 78/300, Train Loss: 0.0597, Train Accuracy: 97.820       Test Loss: 0.2057, Test Accuracy: 94.362, Duration: 0:00:38.557885
# Epoch 79/300, Train Loss: 0.0415, Train Accuracy: 98.602       Test Loss: 0.1983, Test Accuracy: 94.497, Duration: 0:00:38.459151
# Epoch 80/300, Train Loss: 0.0704, Train Accuracy: 97.441       Test Loss: 0.2033, Test Accuracy: 93.826, Duration: 0:00:38.426237
# Epoch 81/300, Train Loss: 0.0430, Train Accuracy: 98.555       Test Loss: 0.1867, Test Accuracy: 95.436, Duration: 0:00:38.437209
# Epoch 82/300, Train Loss: 0.0373, Train Accuracy: 98.650       Test Loss: 0.1893, Test Accuracy: 95.034, Duration: 0:00:38.430228
# Epoch 83/300, Train Loss: 0.0389, Train Accuracy: 98.650       Test Loss: 0.1925, Test Accuracy: 93.960, Duration: 0:00:38.458152
# Epoch 84/300, Train Loss: 0.0603, Train Accuracy: 97.844       Test Loss: 0.1945, Test Accuracy: 93.826, Duration: 0:00:38.461145
# Epoch 85/300, Train Loss: 0.0420, Train Accuracy: 98.484       Test Loss: 0.2897, Test Accuracy: 92.752, Duration: 0:00:38.549908
# Epoch 86/300, Train Loss: 0.0609, Train Accuracy: 98.010       Test Loss: 0.1597, Test Accuracy: 95.168, Duration: 0:00:38.562873
# Epoch 87/300, Train Loss: 0.0409, Train Accuracy: 98.673       Test Loss: 0.3159, Test Accuracy: 92.215, Duration: 0:00:38.536942
# Epoch 88/300, Train Loss: 0.0448, Train Accuracy: 98.436       Test Loss: 0.1782, Test Accuracy: 94.899, Duration: 0:00:38.470120
# Epoch 89/300, Train Loss: 0.0430, Train Accuracy: 98.579       Test Loss: 0.1529, Test Accuracy: 95.839, Duration: 0:00:38.783283
# Epoch 90/300, Train Loss: 0.0552, Train Accuracy: 97.820       Test Loss: 0.2370, Test Accuracy: 94.094, Duration: 0:00:39.043587
# Epoch 91/300, Train Loss: 0.0473, Train Accuracy: 98.389       Test Loss: 0.2405, Test Accuracy: 93.154, Duration: 0:00:38.500040
# Epoch 92/300, Train Loss: 0.0438, Train Accuracy: 98.389       Test Loss: 0.1911, Test Accuracy: 95.034, Duration: 0:00:38.497049
# Epoch 93/300, Train Loss: 0.0550, Train Accuracy: 98.081       Test Loss: 0.1857, Test Accuracy: 95.570, Duration: 0:00:38.568857
# Epoch 94/300, Train Loss: 0.0439, Train Accuracy: 98.176       Test Loss: 0.2098, Test Accuracy: 95.302, Duration: 0:00:38.491065
# Epoch 95/300, Train Loss: 0.0486, Train Accuracy: 98.365       Test Loss: 0.1868, Test Accuracy: 95.168, Duration: 0:00:38.456158
# Epoch 96/300, Train Loss: 0.0529, Train Accuracy: 98.436       Test Loss: 0.2423, Test Accuracy: 94.094, Duration: 0:00:38.483086
# Epoch 97/300, Train Loss: 0.0460, Train Accuracy: 98.271       Test Loss: 0.2077, Test Accuracy: 94.497, Duration: 0:00:38.459150
# Epoch 98/300, Train Loss: 0.0367, Train Accuracy: 98.673       Test Loss: 0.1634, Test Accuracy: 95.973, Duration: 0:00:38.635678
# Epoch 99/300, Train Loss: 0.0442, Train Accuracy: 98.318       Test Loss: 0.2680, Test Accuracy: 93.691, Duration: 0:00:37.232431
# Epoch 100/300, Train Loss: 0.0309, Train Accuracy: 98.768       Test Loss: 0.1684, Test Accuracy: 96.107, Duration: 0:00:37.116740
# Epoch 101/300, Train Loss: 0.0345, Train Accuracy: 98.697       Test Loss: 0.1709, Test Accuracy: 95.034, Duration: 0:00:37.055902
# Epoch 102/300, Train Loss: 0.0368, Train Accuracy: 98.792       Test Loss: 0.2091, Test Accuracy: 94.631, Duration: 0:00:36.959162
# Epoch 103/300, Train Loss: 0.0518, Train Accuracy: 98.271       Test Loss: 0.1730, Test Accuracy: 94.497, Duration: 0:00:36.948191
# Epoch 104/300, Train Loss: 0.0189, Train Accuracy: 99.313       Test Loss: 0.2784, Test Accuracy: 94.765, Duration: 0:00:36.946196
# Epoch 105/300, Train Loss: 0.0296, Train Accuracy: 99.029       Test Loss: 0.2066, Test Accuracy: 94.765, Duration: 0:00:36.964149
# Epoch 106/300, Train Loss: 0.0562, Train Accuracy: 97.891       Test Loss: 0.1654, Test Accuracy: 95.302, Duration: 0:00:36.961156
# Epoch 107/300, Train Loss: 0.0217, Train Accuracy: 99.455       Test Loss: 0.1647, Test Accuracy: 96.242, Duration: 0:00:36.961156
# Epoch 108/300, Train Loss: 0.0262, Train Accuracy: 98.981       Test Loss: 0.2191, Test Accuracy: 93.960, Duration: 0:00:36.975119
# Epoch 109/300, Train Loss: 0.0379, Train Accuracy: 98.673       Test Loss: 0.2579, Test Accuracy: 94.631, Duration: 0:00:36.959162
# Epoch 110/300, Train Loss: 0.0479, Train Accuracy: 98.318       Test Loss: 0.2095, Test Accuracy: 93.826, Duration: 0:00:36.961156
# Epoch 111/300, Train Loss: 0.0413, Train Accuracy: 98.531       Test Loss: 0.2066, Test Accuracy: 94.362, Duration: 0:00:36.971130
# Epoch 112/300, Train Loss: 0.0329, Train Accuracy: 98.792       Test Loss: 0.2065, Test Accuracy: 94.094, Duration: 0:00:36.965146
# Epoch 113/300, Train Loss: 0.0371, Train Accuracy: 98.721       Test Loss: 0.1980, Test Accuracy: 95.570, Duration: 0:00:36.981103
# Epoch 114/300, Train Loss: 0.0322, Train Accuracy: 98.839       Test Loss: 0.2284, Test Accuracy: 94.228, Duration: 0:00:36.976116
# Epoch 115/300, Train Loss: 0.0361, Train Accuracy: 98.887       Test Loss: 0.2170, Test Accuracy: 94.362, Duration: 0:00:36.967140
# Epoch 116/300, Train Loss: 0.0348, Train Accuracy: 98.768       Test Loss: 0.2680, Test Accuracy: 93.691, Duration: 0:00:36.981102
# Epoch 117/300, Train Loss: 0.0306, Train Accuracy: 98.887       Test Loss: 0.2148, Test Accuracy: 94.631, Duration: 0:00:37.016010
# Epoch 118/300, Train Loss: 0.0193, Train Accuracy: 99.431       Test Loss: 0.2284, Test Accuracy: 94.631, Duration: 0:00:36.974122
# Epoch 119/300, Train Loss: 0.0305, Train Accuracy: 98.958       Test Loss: 0.2911, Test Accuracy: 93.423, Duration: 0:00:36.979108
# Epoch 120/300, Train Loss: 0.0380, Train Accuracy: 98.721       Test Loss: 0.2804, Test Accuracy: 93.154, Duration: 0:00:36.996063
# Epoch 121/300, Train Loss: 0.0293, Train Accuracy: 99.005       Test Loss: 0.2451, Test Accuracy: 94.094, Duration: 0:00:36.980105
# Epoch 122/300, Train Loss: 0.0462, Train Accuracy: 98.436       Test Loss: 0.1846, Test Accuracy: 94.899, Duration: 0:00:37.186643
# Epoch 123/300, Train Loss: 0.0230, Train Accuracy: 99.171       Test Loss: 0.1886, Test Accuracy: 95.436, Duration: 0:00:37.022992
# Epoch 124/300, Train Loss: 0.0364, Train Accuracy: 98.768       Test Loss: 0.2247, Test Accuracy: 94.497, Duration: 0:00:36.985092
# Epoch 125/300, Train Loss: 0.0348, Train Accuracy: 98.981       Test Loss: 0.2002, Test Accuracy: 94.899, Duration: 0:00:36.982100
# Epoch 126/300, Train Loss: 0.0150, Train Accuracy: 99.550       Test Loss: 0.2154, Test Accuracy: 94.362, Duration: 0:00:36.990079
# Epoch 127/300, Train Loss: 0.0209, Train Accuracy: 99.266       Test Loss: 0.2128, Test Accuracy: 94.765, Duration: 0:00:36.988084
# Epoch 128/300, Train Loss: 0.0222, Train Accuracy: 99.171       Test Loss: 0.2107, Test Accuracy: 95.302, Duration: 0:00:36.986089
# Epoch 129/300, Train Loss: 0.0218, Train Accuracy: 99.384       Test Loss: 0.2069, Test Accuracy: 95.839, Duration: 0:00:37.019002
# Epoch 130/300, Train Loss: 0.0142, Train Accuracy: 99.597       Test Loss: 0.2985, Test Accuracy: 93.691, Duration: 0:00:37.015011
# Epoch 131/300, Train Loss: 0.0405, Train Accuracy: 98.365       Test Loss: 0.1657, Test Accuracy: 95.973, Duration: 0:00:37.008031
# Epoch 132/300, Train Loss: 0.0321, Train Accuracy: 98.768       Test Loss: 0.2282, Test Accuracy: 94.899, Duration: 0:00:36.993071
# Epoch 133/300, Train Loss: 0.0286, Train Accuracy: 98.981       Test Loss: 0.1948, Test Accuracy: 95.973, Duration: 0:00:36.998057
# Epoch 134/300, Train Loss: 0.0165, Train Accuracy: 99.502       Test Loss: 0.2321, Test Accuracy: 93.423, Duration: 0:00:37.010025
# Epoch 135/300, Train Loss: 0.0173, Train Accuracy: 99.479       Test Loss: 0.2710, Test Accuracy: 94.228, Duration: 0:00:37.009028
# Epoch 136/300, Train Loss: 0.0631, Train Accuracy: 97.820       Test Loss: 0.1865, Test Accuracy: 94.228, Duration: 0:00:37.000052
# Epoch 137/300, Train Loss: 0.0194, Train Accuracy: 99.218       Test Loss: 0.2579, Test Accuracy: 94.497, Duration: 0:00:37.011022
# Epoch 138/300, Train Loss: 0.0459, Train Accuracy: 98.199       Test Loss: 0.1539, Test Accuracy: 95.839, Duration: 0:00:37.023989
# Epoch 139/300, Train Loss: 0.0171, Train Accuracy: 99.408       Test Loss: 0.1827, Test Accuracy: 95.570, Duration: 0:00:37.023987
# Epoch 140/300, Train Loss: 0.0127, Train Accuracy: 99.597       Test Loss: 0.2193, Test Accuracy: 95.705, Duration: 0:00:37.032965
# Epoch 141/300, Train Loss: 0.0309, Train Accuracy: 98.981       Test Loss: 0.2101, Test Accuracy: 95.168, Duration: 0:00:37.033961
# Epoch 142/300, Train Loss: 0.0231, Train Accuracy: 99.076       Test Loss: 0.2330, Test Accuracy: 94.497, Duration: 0:00:37.022991
# Epoch 143/300, Train Loss: 0.0142, Train Accuracy: 99.360       Test Loss: 0.2427, Test Accuracy: 94.899, Duration: 0:00:37.026980
# Epoch 144/300, Train Loss: 0.0361, Train Accuracy: 98.887       Test Loss: 0.2415, Test Accuracy: 94.094, Duration: 0:00:37.034959
# Epoch 145/300, Train Loss: 0.0348, Train Accuracy: 98.626       Test Loss: 0.2045, Test Accuracy: 94.362, Duration: 0:00:37.051913
# Epoch 146/300, Train Loss: 0.0251, Train Accuracy: 98.981       Test Loss: 0.1850, Test Accuracy: 94.497, Duration: 0:00:37.014015
# Epoch 147/300, Train Loss: 0.0120, Train Accuracy: 99.550       Test Loss: 0.2080, Test Accuracy: 95.034, Duration: 0:00:37.041940
# Epoch 148/300, Train Loss: 0.0318, Train Accuracy: 98.839       Test Loss: 0.1794, Test Accuracy: 95.436, Duration: 0:00:37.021994
# Epoch 149/300, Train Loss: 0.0369, Train Accuracy: 98.673       Test Loss: 0.2069, Test Accuracy: 95.168, Duration: 0:00:37.032964
# Epoch 150/300, Train Loss: 0.0233, Train Accuracy: 99.195       Test Loss: 0.2407, Test Accuracy: 94.899, Duration: 0:00:37.033962
# Epoch 151/300, Train Loss: 0.0207, Train Accuracy: 99.360       Test Loss: 0.1997, Test Accuracy: 95.168, Duration: 0:00:37.035956
# Epoch 152/300, Train Loss: 0.0237, Train Accuracy: 99.266       Test Loss: 0.2000, Test Accuracy: 95.436, Duration: 0:00:37.051913
# Epoch 153/300, Train Loss: 0.0138, Train Accuracy: 99.502       Test Loss: 0.2886, Test Accuracy: 94.631, Duration: 0:00:37.028975
# Epoch 154/300, Train Loss: 0.0300, Train Accuracy: 98.887       Test Loss: 0.2109, Test Accuracy: 94.899, Duration: 0:00:37.051913
# Epoch 155/300, Train Loss: 0.0171, Train Accuracy: 99.550       Test Loss: 0.2026, Test Accuracy: 95.168, Duration: 0:00:37.051913
# Epoch 156/300, Train Loss: 0.0318, Train Accuracy: 99.029       Test Loss: 0.2345, Test Accuracy: 94.631, Duration: 0:00:37.033961
# Epoch 157/300, Train Loss: 0.0422, Train Accuracy: 98.484       Test Loss: 0.2715, Test Accuracy: 94.228, Duration: 0:00:37.042938
# Epoch 158/300, Train Loss: 0.0280, Train Accuracy: 99.171       Test Loss: 0.2084, Test Accuracy: 94.631, Duration: 0:00:37.041940
# Epoch 159/300, Train Loss: 0.0126, Train Accuracy: 99.597       Test Loss: 0.1831, Test Accuracy: 96.242, Duration: 0:00:37.038948
# Epoch 160/300, Train Loss: 0.0046, Train Accuracy: 99.953       Test Loss: 0.2347, Test Accuracy: 95.034, Duration: 0:00:37.050917
# Epoch 161/300, Train Loss: 0.0019, Train Accuracy: 99.976       Test Loss: 0.2104, Test Accuracy: 95.973, Duration: 0:00:37.065876
# Epoch 162/300, Train Loss: 0.0013, Train Accuracy: 99.976       Test Loss: 0.2378, Test Accuracy: 95.705, Duration: 0:00:37.059892
# Epoch 163/300, Train Loss: 0.0224, Train Accuracy: 99.289       Test Loss: 0.2399, Test Accuracy: 93.691, Duration: 0:00:37.047924
# Epoch 164/300, Train Loss: 0.0417, Train Accuracy: 98.342       Test Loss: 0.2233, Test Accuracy: 94.362, Duration: 0:00:37.054906
# Epoch 165/300, Train Loss: 0.0066, Train Accuracy: 99.787       Test Loss: 0.2125, Test Accuracy: 96.107, Duration: 0:00:37.045929
# Epoch 166/300, Train Loss: 0.0228, Train Accuracy: 99.029       Test Loss: 0.2016, Test Accuracy: 95.034, Duration: 0:00:37.059892
# Epoch 167/300, Train Loss: 0.0649, Train Accuracy: 97.749       Test Loss: 0.2699, Test Accuracy: 92.752, Duration: 0:00:37.050917
# Epoch 168/300, Train Loss: 0.0183, Train Accuracy: 99.313       Test Loss: 0.2436, Test Accuracy: 93.960, Duration: 0:00:37.049918
# Epoch 169/300, Train Loss: 0.0148, Train Accuracy: 99.550       Test Loss: 0.2936, Test Accuracy: 93.557, Duration: 0:00:37.063882
# Epoch 170/300, Train Loss: 0.0241, Train Accuracy: 99.076       Test Loss: 0.2589, Test Accuracy: 93.826, Duration: 0:00:37.072857
# Epoch 171/300, Train Loss: 0.0260, Train Accuracy: 99.147       Test Loss: 0.1884, Test Accuracy: 95.168, Duration: 0:00:37.066874
# Epoch 172/300, Train Loss: 0.0074, Train Accuracy: 99.739       Test Loss: 0.1864, Test Accuracy: 95.168, Duration: 0:00:37.072858
# Epoch 173/300, Train Loss: 0.0028, Train Accuracy: 99.953       Test Loss: 0.1805, Test Accuracy: 95.839, Duration: 0:00:37.110758
# Epoch 174/300, Train Loss: 0.0007, Train Accuracy: 100.000       Test Loss: 0.1913, Test Accuracy: 96.242, Duration: 0:00:37.101778
# Epoch 175/300, Train Loss: 0.0046, Train Accuracy: 99.858       Test Loss: 0.2903, Test Accuracy: 93.826, Duration: 0:00:37.075850
# Epoch 176/300, Train Loss: 0.0626, Train Accuracy: 97.939       Test Loss: 0.2006, Test Accuracy: 94.497, Duration: 0:00:37.081833
# Epoch 177/300, Train Loss: 0.0163, Train Accuracy: 99.313       Test Loss: 0.2249, Test Accuracy: 94.228, Duration: 0:00:37.127710
# Epoch 178/300, Train Loss: 0.0147, Train Accuracy: 99.455       Test Loss: 0.2562, Test Accuracy: 94.631, Duration: 0:00:37.132698
# Epoch 179/300, Train Loss: 0.0445, Train Accuracy: 98.507       Test Loss: 0.2080, Test Accuracy: 94.765, Duration: 0:00:37.086820
# Epoch 180/300, Train Loss: 0.0209, Train Accuracy: 99.242       Test Loss: 0.1740, Test Accuracy: 96.107, Duration: 0:00:37.086821
# Epoch 181/300, Train Loss: 0.0144, Train Accuracy: 99.455       Test Loss: 0.2098, Test Accuracy: 95.034, Duration: 0:00:37.093801
# Epoch 182/300, Train Loss: 0.0182, Train Accuracy: 99.360       Test Loss: 0.2504, Test Accuracy: 94.899, Duration: 0:00:37.104772
# Epoch 183/300, Train Loss: 0.0222, Train Accuracy: 99.195       Test Loss: 0.1883, Test Accuracy: 95.302, Duration: 0:00:37.094799
# Epoch 184/300, Train Loss: 0.0111, Train Accuracy: 99.645       Test Loss: 0.2658, Test Accuracy: 95.436, Duration: 0:00:37.102777
# Epoch 185/300, Train Loss: 0.0126, Train Accuracy: 99.479       Test Loss: 0.2473, Test Accuracy: 94.631, Duration: 0:00:37.086820
# Epoch 186/300, Train Loss: 0.0104, Train Accuracy: 99.668       Test Loss: 0.2112, Test Accuracy: 95.436, Duration: 0:00:37.108761
# Epoch 187/300, Train Loss: 0.0167, Train Accuracy: 99.502       Test Loss: 0.2217, Test Accuracy: 96.107, Duration: 0:00:37.107763
# Epoch 188/300, Train Loss: 0.0274, Train Accuracy: 99.052       Test Loss: 0.1611, Test Accuracy: 96.779, Duration: 0:00:37.120729
# Epoch 189/300, Train Loss: 0.0094, Train Accuracy: 99.692       Test Loss: 0.2269, Test Accuracy: 95.034, Duration: 0:00:37.107764
# Epoch 190/300, Train Loss: 0.0113, Train Accuracy: 99.621       Test Loss: 0.2212, Test Accuracy: 95.168, Duration: 0:00:37.111754
# Epoch 191/300, Train Loss: 0.0274, Train Accuracy: 99.195       Test Loss: 0.2551, Test Accuracy: 93.826, Duration: 0:00:37.124719
# Epoch 192/300, Train Loss: 0.0278, Train Accuracy: 98.981       Test Loss: 0.1708, Test Accuracy: 95.302, Duration: 0:00:37.104772
# Epoch 193/300, Train Loss: 0.0066, Train Accuracy: 99.739       Test Loss: 0.2197, Test Accuracy: 95.570, Duration: 0:00:37.116741
# Epoch 194/300, Train Loss: 0.0018, Train Accuracy: 99.953       Test Loss: 0.1908, Test Accuracy: 96.510, Duration: 0:00:37.112750
# Epoch 195/300, Train Loss: 0.0009, Train Accuracy: 99.976       Test Loss: 0.2316, Test Accuracy: 96.510, Duration: 0:00:37.109758
# Epoch 196/300, Train Loss: 0.0365, Train Accuracy: 99.029       Test Loss: 0.1988, Test Accuracy: 95.302, Duration: 0:00:37.123722
# Epoch 197/300, Train Loss: 0.0297, Train Accuracy: 98.934       Test Loss: 0.2100, Test Accuracy: 95.034, Duration: 0:00:37.136687
# Epoch 198/300, Train Loss: 0.0391, Train Accuracy: 98.792       Test Loss: 0.2092, Test Accuracy: 93.826, Duration: 0:00:37.102777
# Epoch 199/300, Train Loss: 0.0144, Train Accuracy: 99.526       Test Loss: 0.1981, Test Accuracy: 94.631, Duration: 0:00:37.123722
# Epoch 200/300, Train Loss: 0.0063, Train Accuracy: 99.834       Test Loss: 0.2613, Test Accuracy: 94.228, Duration: 0:00:37.184558
# Epoch 201/300, Train Loss: 0.0056, Train Accuracy: 99.834       Test Loss: 0.2313, Test Accuracy: 95.436, Duration: 0:00:36.940213
# Epoch 202/300, Train Loss: 0.0108, Train Accuracy: 99.668       Test Loss: 0.2313, Test Accuracy: 95.436, Duration: 0:00:36.955172
# Epoch 203/300, Train Loss: 0.0064, Train Accuracy: 99.763       Test Loss: 0.2583, Test Accuracy: 94.631, Duration: 0:00:36.971129
# Epoch 204/300, Train Loss: 0.0077, Train Accuracy: 99.739       Test Loss: 0.2544, Test Accuracy: 95.302, Duration: 0:00:36.972127
# Epoch 205/300, Train Loss: 0.0135, Train Accuracy: 99.526       Test Loss: 0.2691, Test Accuracy: 94.765, Duration: 0:00:36.947194
# Epoch 206/300, Train Loss: 0.0513, Train Accuracy: 98.294       Test Loss: 0.2120, Test Accuracy: 95.705, Duration: 0:00:36.973124
# Epoch 207/300, Train Loss: 0.0148, Train Accuracy: 99.455       Test Loss: 0.2037, Test Accuracy: 95.034, Duration: 0:00:36.956169
# Epoch 208/300, Train Loss: 0.0191, Train Accuracy: 99.360       Test Loss: 0.2573, Test Accuracy: 95.168, Duration: 0:00:36.952180
# Epoch 209/300, Train Loss: 0.0146, Train Accuracy: 99.597       Test Loss: 0.2132, Test Accuracy: 95.839, Duration: 0:00:36.970133
# Epoch 210/300, Train Loss: 0.0138, Train Accuracy: 99.574       Test Loss: 0.2401, Test Accuracy: 95.302, Duration: 0:00:36.948191
# Epoch 211/300, Train Loss: 0.0288, Train Accuracy: 99.123       Test Loss: 0.2249, Test Accuracy: 95.168, Duration: 0:00:36.970132
# Epoch 212/300, Train Loss: 0.0218, Train Accuracy: 99.431       Test Loss: 0.2140, Test Accuracy: 95.034, Duration: 0:00:36.980106
# Epoch 213/300, Train Loss: 0.0099, Train Accuracy: 99.645       Test Loss: 0.1448, Test Accuracy: 96.376, Duration: 0:00:36.974121
# Epoch 214/300, Train Loss: 0.0174, Train Accuracy: 99.502       Test Loss: 0.2263, Test Accuracy: 95.570, Duration: 0:00:36.959161
# Epoch 215/300, Train Loss: 0.0210, Train Accuracy: 99.289       Test Loss: 0.1980, Test Accuracy: 95.839, Duration: 0:00:36.976116
# Epoch 216/300, Train Loss: 0.0139, Train Accuracy: 99.621       Test Loss: 0.3222, Test Accuracy: 92.752, Duration: 0:00:36.986090
# Epoch 217/300, Train Loss: 0.0163, Train Accuracy: 99.384       Test Loss: 0.1686, Test Accuracy: 96.107, Duration: 0:00:36.977113
# Epoch 218/300, Train Loss: 0.0255, Train Accuracy: 99.052       Test Loss: 0.2635, Test Accuracy: 93.691, Duration: 0:00:36.972127
# Epoch 219/300, Train Loss: 0.0217, Train Accuracy: 99.360       Test Loss: 0.1836, Test Accuracy: 95.973, Duration: 0:00:36.998058
# Epoch 220/300, Train Loss: 0.0041, Train Accuracy: 99.882       Test Loss: 0.1949, Test Accuracy: 96.376, Duration: 0:00:37.150631
# Epoch 221/300, Train Loss: 0.0102, Train Accuracy: 99.621       Test Loss: 0.2609, Test Accuracy: 95.436, Duration: 0:00:37.008031
# Epoch 222/300, Train Loss: 0.0297, Train Accuracy: 99.171       Test Loss: 0.1653, Test Accuracy: 96.242, Duration: 0:00:36.973124
# Epoch 223/300, Train Loss: 0.0062, Train Accuracy: 99.739       Test Loss: 0.2048, Test Accuracy: 95.973, Duration: 0:00:36.988084
# Epoch 224/300, Train Loss: 0.0019, Train Accuracy: 99.953       Test Loss: 0.1824, Test Accuracy: 96.107, Duration: 0:00:36.978111
# Epoch 225/300, Train Loss: 0.0022, Train Accuracy: 99.953       Test Loss: 0.2047, Test Accuracy: 95.973, Duration: 0:00:36.981103
# Epoch 226/300, Train Loss: 0.0288, Train Accuracy: 99.029       Test Loss: 0.2643, Test Accuracy: 93.557, Duration: 0:00:37.001049
# Epoch 227/300, Train Loss: 0.0213, Train Accuracy: 99.195       Test Loss: 0.2088, Test Accuracy: 95.973, Duration: 0:00:36.999054
# Epoch 228/300, Train Loss: 0.0066, Train Accuracy: 99.810       Test Loss: 0.1622, Test Accuracy: 96.644, Duration: 0:00:36.993071
# Epoch 229/300, Train Loss: 0.0013, Train Accuracy: 99.976       Test Loss: 0.2147, Test Accuracy: 95.705, Duration: 0:00:36.989082
# Epoch 230/300, Train Loss: 0.0362, Train Accuracy: 98.650       Test Loss: 0.2055, Test Accuracy: 94.899, Duration: 0:00:36.988084
# Epoch 231/300, Train Loss: 0.0092, Train Accuracy: 99.692       Test Loss: 0.1803, Test Accuracy: 96.242, Duration: 0:00:36.999055
# Epoch 232/300, Train Loss: 0.0032, Train Accuracy: 99.929       Test Loss: 0.2214, Test Accuracy: 96.242, Duration: 0:00:36.990078
# Epoch 233/300, Train Loss: 0.0016, Train Accuracy: 99.953       Test Loss: 0.2064, Test Accuracy: 96.376, Duration: 0:00:36.985093
# Epoch 234/300, Train Loss: 0.0004, Train Accuracy: 100.000       Test Loss: 0.2333, Test Accuracy: 96.510, Duration: 0:00:36.996062
# Epoch 235/300, Train Loss: 0.0004, Train Accuracy: 100.000       Test Loss: 0.2570, Test Accuracy: 96.242, Duration: 0:00:36.991077
# Epoch 236/300, Train Loss: 0.0724, Train Accuracy: 97.607       Test Loss: 0.2349, Test Accuracy: 93.423, Duration: 0:00:37.013017
# Epoch 237/300, Train Loss: 0.0239, Train Accuracy: 99.029       Test Loss: 0.2401, Test Accuracy: 95.436, Duration: 0:00:36.986090
# Epoch 238/300, Train Loss: 0.0149, Train Accuracy: 99.550       Test Loss: 0.1948, Test Accuracy: 95.839, Duration: 0:00:36.991076
# Epoch 239/300, Train Loss: 0.0059, Train Accuracy: 99.858       Test Loss: 0.2202, Test Accuracy: 95.302, Duration: 0:00:36.999055
# Epoch 240/300, Train Loss: 0.0156, Train Accuracy: 99.574       Test Loss: 0.2097, Test Accuracy: 96.107, Duration: 0:00:37.009028
# Epoch 241/300, Train Loss: 0.0104, Train Accuracy: 99.668       Test Loss: 0.2262, Test Accuracy: 95.973, Duration: 0:00:36.996063
# Epoch 242/300, Train Loss: 0.0170, Train Accuracy: 99.408       Test Loss: 0.2309, Test Accuracy: 95.436, Duration: 0:00:37.012020
# Epoch 243/300, Train Loss: 0.0231, Train Accuracy: 99.195       Test Loss: 0.2536, Test Accuracy: 94.228, Duration: 0:00:37.009028
# Epoch 244/300, Train Loss: 0.0187, Train Accuracy: 99.289       Test Loss: 0.1972, Test Accuracy: 95.302, Duration: 0:00:37.021994
# Epoch 245/300, Train Loss: 0.0064, Train Accuracy: 99.763       Test Loss: 0.2400, Test Accuracy: 95.839, Duration: 0:00:37.015012
# Epoch 246/300, Train Loss: 0.0352, Train Accuracy: 98.839       Test Loss: 0.2267, Test Accuracy: 94.631, Duration: 0:00:37.027978
# Epoch 247/300, Train Loss: 0.0066, Train Accuracy: 99.834       Test Loss: 0.1922, Test Accuracy: 95.973, Duration: 0:00:37.021993
# Epoch 248/300, Train Loss: 0.0015, Train Accuracy: 100.000       Test Loss: 0.2310, Test Accuracy: 96.107, Duration: 0:00:37.022991
# Epoch 249/300, Train Loss: 0.0036, Train Accuracy: 99.905       Test Loss: 0.2331, Test Accuracy: 95.436, Duration: 0:00:37.026980
# Epoch 250/300, Train Loss: 0.0174, Train Accuracy: 99.574       Test Loss: 0.2054, Test Accuracy: 95.436, Duration: 0:00:37.053908
# Epoch 251/300, Train Loss: 0.0075, Train Accuracy: 99.645       Test Loss: 0.2010, Test Accuracy: 95.973, Duration: 0:00:37.026980
# Epoch 252/300, Train Loss: 0.0333, Train Accuracy: 98.887       Test Loss: 0.1641, Test Accuracy: 95.839, Duration: 0:00:37.028975
# Epoch 253/300, Train Loss: 0.0028, Train Accuracy: 99.976       Test Loss: 0.2214, Test Accuracy: 95.973, Duration: 0:00:37.038948
# Epoch 254/300, Train Loss: 0.0025, Train Accuracy: 99.953       Test Loss: 0.2086, Test Accuracy: 95.302, Duration: 0:00:37.044932
# Epoch 255/300, Train Loss: 0.0014, Train Accuracy: 99.976       Test Loss: 0.2213, Test Accuracy: 95.436, Duration: 0:00:37.025982
# Epoch 256/300, Train Loss: 0.0035, Train Accuracy: 99.858       Test Loss: 0.2435, Test Accuracy: 95.570, Duration: 0:00:37.029973
# Epoch 257/300, Train Loss: 0.0005, Train Accuracy: 100.000       Test Loss: 0.2175, Test Accuracy: 96.376, Duration: 0:00:37.029972
# Epoch 258/300, Train Loss: 0.0005, Train Accuracy: 100.000       Test Loss: 0.2272, Test Accuracy: 95.839, Duration: 0:00:37.030970
# Epoch 259/300, Train Loss: 0.0002, Train Accuracy: 100.000       Test Loss: 0.2247, Test Accuracy: 96.242, Duration: 0:00:37.040943
# Epoch 260/300, Train Loss: 0.0187, Train Accuracy: 99.502       Test Loss: 0.3240, Test Accuracy: 93.960, Duration: 0:00:37.041940
# Epoch 261/300, Train Loss: 0.0388, Train Accuracy: 98.839       Test Loss: 0.2652, Test Accuracy: 94.631, Duration: 0:00:37.034959
# Epoch 262/300, Train Loss: 0.0364, Train Accuracy: 98.910       Test Loss: 0.1495, Test Accuracy: 97.047, Duration: 0:00:37.038949
# Epoch 263/300, Train Loss: 0.0080, Train Accuracy: 99.716       Test Loss: 0.1892, Test Accuracy: 96.107, Duration: 0:00:37.043934
# Epoch 264/300, Train Loss: 0.0033, Train Accuracy: 99.905       Test Loss: 0.1847, Test Accuracy: 96.242, Duration: 0:00:37.041940
# Epoch 265/300, Train Loss: 0.0006, Train Accuracy: 100.000       Test Loss: 0.1833, Test Accuracy: 96.242, Duration: 0:00:37.038948
# Epoch 266/300, Train Loss: 0.0004, Train Accuracy: 100.000       Test Loss: 0.1959, Test Accuracy: 96.510, Duration: 0:00:37.047925
# Epoch 267/300, Train Loss: 0.0004, Train Accuracy: 100.000       Test Loss: 0.2015, Test Accuracy: 96.376, Duration: 0:00:37.043935
# Epoch 268/300, Train Loss: 0.0012, Train Accuracy: 99.976       Test Loss: 0.2012, Test Accuracy: 95.839, Duration: 0:00:37.050916
# Epoch 269/300, Train Loss: 0.0004, Train Accuracy: 100.000       Test Loss: 0.2376, Test Accuracy: 96.376, Duration: 0:00:37.069865
# Epoch 270/300, Train Loss: 0.0001, Train Accuracy: 100.000       Test Loss: 0.2149, Test Accuracy: 95.839, Duration: 0:00:37.042938
# Epoch 271/300, Train Loss: 0.0001, Train Accuracy: 100.000       Test Loss: 0.2185, Test Accuracy: 95.705, Duration: 0:00:37.035956
# Epoch 272/300, Train Loss: 0.0001, Train Accuracy: 100.000       Test Loss: 0.2156, Test Accuracy: 95.839, Duration: 0:00:37.046926
# Epoch 273/300, Train Loss: 0.0001, Train Accuracy: 100.000       Test Loss: 0.2163, Test Accuracy: 95.839, Duration: 0:00:37.055903
# Epoch 274/300, Train Loss: 0.0010, Train Accuracy: 99.953       Test Loss: 0.2392, Test Accuracy: 95.570, Duration: 0:00:37.069865
# Epoch 275/300, Train Loss: 0.0787, Train Accuracy: 97.276       Test Loss: 0.2371, Test Accuracy: 94.631, Duration: 0:00:37.068869
# Epoch 276/300, Train Loss: 0.0312, Train Accuracy: 98.815       Test Loss: 0.1490, Test Accuracy: 96.644, Duration: 0:00:37.080836
# Epoch 277/300, Train Loss: 0.0123, Train Accuracy: 99.692       Test Loss: 0.2350, Test Accuracy: 94.899, Duration: 0:00:37.061886
# Epoch 278/300, Train Loss: 0.0058, Train Accuracy: 99.810       Test Loss: 0.2096, Test Accuracy: 95.570, Duration: 0:00:37.065876
# Epoch 279/300, Train Loss: 0.0081, Train Accuracy: 99.763       Test Loss: 0.2678, Test Accuracy: 94.631, Duration: 0:00:37.080836
# Epoch 280/300, Train Loss: 0.0160, Train Accuracy: 99.384       Test Loss: 0.2411, Test Accuracy: 94.362, Duration: 0:00:37.072857
# Epoch 281/300, Train Loss: 0.0300, Train Accuracy: 99.029       Test Loss: 0.2337, Test Accuracy: 94.765, Duration: 0:00:37.064879
# Epoch 282/300, Train Loss: 0.0066, Train Accuracy: 99.739       Test Loss: 0.1993, Test Accuracy: 95.973, Duration: 0:00:37.109759
# Epoch 283/300, Train Loss: 0.0270, Train Accuracy: 99.123       Test Loss: 0.2085, Test Accuracy: 95.570, Duration: 0:00:37.069865
# Epoch 284/300, Train Loss: 0.0038, Train Accuracy: 99.882       Test Loss: 0.1809, Test Accuracy: 96.107, Duration: 0:00:37.091807
# Epoch 285/300, Train Loss: 0.0016, Train Accuracy: 99.976       Test Loss: 0.2122, Test Accuracy: 95.705, Duration: 0:00:37.094798
# Epoch 286/300, Train Loss: 0.0005, Train Accuracy: 100.000       Test Loss: 0.2156, Test Accuracy: 95.436, Duration: 0:00:37.080836
# Epoch 287/300, Train Loss: 0.0002, Train Accuracy: 100.000       Test Loss: 0.2013, Test Accuracy: 95.839, Duration: 0:00:37.083828
# Epoch 288/300, Train Loss: 0.0119, Train Accuracy: 99.597       Test Loss: 0.2394, Test Accuracy: 94.765, Duration: 0:00:37.088815
# Epoch 289/300, Train Loss: 0.0384, Train Accuracy: 98.673       Test Loss: 0.2361, Test Accuracy: 95.168, Duration: 0:00:37.120730
# Epoch 290/300, Train Loss: 0.0275, Train Accuracy: 98.934       Test Loss: 0.1931, Test Accuracy: 96.107, Duration: 0:00:37.234425
# Epoch 291/300, Train Loss: 0.0102, Train Accuracy: 99.621       Test Loss: 0.2744, Test Accuracy: 94.362, Duration: 0:00:37.101780
# Epoch 292/300, Train Loss: 0.0043, Train Accuracy: 99.905       Test Loss: 0.1770, Test Accuracy: 96.242, Duration: 0:00:37.113749
# Epoch 293/300, Train Loss: 0.0007, Train Accuracy: 100.000       Test Loss: 0.2016, Test Accuracy: 96.376, Duration: 0:00:37.121726
# Epoch 294/300, Train Loss: 0.0003, Train Accuracy: 100.000       Test Loss: 0.2055, Test Accuracy: 96.107, Duration: 0:00:37.096793
# Epoch 295/300, Train Loss: 0.0022, Train Accuracy: 99.905       Test Loss: 0.2347, Test Accuracy: 95.839, Duration: 0:00:37.109759
# Epoch 296/300, Train Loss: 0.0398, Train Accuracy: 98.721       Test Loss: 0.1966, Test Accuracy: 95.168, Duration: 0:00:37.114746
# Epoch 297/300, Train Loss: 0.0237, Train Accuracy: 99.100       Test Loss: 0.1989, Test Accuracy: 95.168, Duration: 0:00:37.113748
# Epoch 298/300, Train Loss: 0.0133, Train Accuracy: 99.550       Test Loss: 0.1851, Test Accuracy: 95.839, Duration: 0:00:37.094799
# Epoch 299/300, Train Loss: 0.0069, Train Accuracy: 99.668       Test Loss: 0.2074, Test Accuracy: 96.376, Duration: 0:00:37.101780
# Epoch 300/300, Train Loss: 0.0078, Train Accuracy: 99.668       Test Loss: 0.2234, Test Accuracy: 96.107, Duration: 0:00:37.123721

# %%
images, labels = test_dataiter.next()
out_img, predicted = torch.max(model(images.to(device)), 1)
imshow(images[:7], labels[:7], predicted[:7])

# %%
# Plot the train loss and test loss per iteration
plt.plot(train_losses, label='train loss')
plt.plot(test_losses, label='test loss')
plt.legend()
plt.show()

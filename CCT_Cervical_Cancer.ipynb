# %%
import os
from PIL import Image
import torch
from torch.utils.data import DataLoader,Dataset
import torch.nn as nn
from torch import Tensor
import torchvision
import torchvision.transforms as transforms
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import torch.nn.functional as F
import seaborn as sns
from datetime import datetime
from sklearn.model_selection import train_test_split

torch.manual_seed(17)

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
torch.backends.cudnn.benchmark = True

# %% [markdown]
# # A Compact Convolutional Vision Transformer or CCT
# *Created using the walkthrough from https://medium.com/pytorch/training-compact-transformers-from-scratch-in-30-minutes-with-pytorch-ff5c21668ed5 and Dr Prashant's Vision_Transformer file

# %% [markdown]
# ## Building the Transformer block by block

# %% [markdown]
# Every part/layer of the transformer is built using the Pytorch nn.module class which allows for easy creation of maching learning models. Each layer should be made up of at least two parts: An initialization function which uses the given information to build the class and then the 'Forward' function defines how the class will run when it is called.

# %% [markdown]
# ### Transformer Constructor
#
# First, the actual ViT Constructor which essentially acts as a hub. It ensures that each part of the transformer is called in the correct order and that local variables can be passed along.

# %% [markdown]
# ### What makes it more Compact/Lite than the CVT?
#
# The only difference between this and the original Vision Transformer is a Sequence Pooling layer and a convolutional layer instead of patching. Previously the classes were embedded separately and then passed to the MLP for classification. Sequence Pooling ties the class information in with every other parameter.. I think.

# %%
class CCT(nn.Module):
    '''
    Simplified implementation of the Vision transformer.

    Parameters
    ----------
    img_size: int
        Both height and width of the image (if it is a square)
    in_channels: int
        Number of input channels
    patch_size: int
        Both height and width of the patch (if it is a square)
    embed_dim: int
        The embedding size for each token
    n_layers: int
        Number of transformer blocks
    n_heads: int
        Number of attention heads
    attn_dropout, proj_dropout, mlp_dropout: float
        Dropout probability
    mlp_ratio: float
        Determine the hidden dimension of the MLP module
    qkv_bias: bool
        If true then we add bias to the query, key and value projections
    n_classes: int
        Number of classes

    Attributes
    -----------
    n_patches: int
        Number of patches that can be taken from each image based on size.
    patch_embed: PatchEmbed
        Sets up the `Patching' layer.
    class_embed: nn.Parameter
        Learnable parameter that will represent the first class token in the sequence.
        It has `embed_dim' elements.
    pos_embed: nn.Parameter
        Adds a positional encoding to every token.
    pos_drop: nn.Dropout
        Dropout layer.
    tr_block: nn.ModuleList
        Instance of 'TransformerEncoderLayer'.
    norm: nn.Layernorm
        Layer normalization.
    '''
    def __init__(self,
                 img_size=32,   # The square size of each image
                 in_channels=3, # Number of channels for each image (eg: Grayscale=1, RGB=3)
                 patch_size=4,  # The square size of each patch
                 embed_dim=768,  # Embedding dimension
                 n_layers=3, # How many times to run the transformer encoder
                 n_conv=2, # How many times to run the convolutional filter
                 n_heads=3,   # Number of attention heads,
                 attn_dropout=0.,  # Attention Dropout
                 proj_dropout=0.,   # (MHA) Projection Dropout
                 mlp_dropout=0.,   # (MHA) last layer dropout
                 mlp_ratio=4,   # (MHA) Projection FF dimension
                 qkv_bias = True,
                 n_classes=10   # Number of classes to classify
    ):
        super().__init__()
        # Provides an error if the patching size is not divisible by the image size.
        assert img_size % patch_size == 0, \
            print("Given image size ({}) has to be divisible by given patch size ({})".format(img_size, patch_size))
        
        self.conv_embed = Conv_Embed(img_size, in_channels, embed_dim, n_conv)
        n_patches = self.conv_embed.sequence_length(in_channels=in_channels, height=img_size, width=img_size)
        hidden_dim = int(embed_dim * mlp_ratio)
        
        
        self.pos_embed = nn.Parameter(torch.zeros(1, n_patches, embed_dim))
        
        # Can use this to enable Sinusoidal PE
        #self.pos_embed = PositionalEmbedding(1, n_patches + 1, embed_dim)

        self.pos_drop = nn.Dropout(p=proj_dropout)
        self.tr_block = nn.ModuleList(
            [
                TransformerEncoderLayer(
                    embed_dim,
                    n_heads,
                    qkv_bias,
                    attn_dropout,
                    proj_dropout,
                    mlp_dropout,
                    hidden_dim
                    )
                for _ in range(n_layers)
            ]   # Sends data through the encoder n times
        )
        self.norm = nn.LayerNorm(embed_dim, eps=1e-6)
        
        self.attention_pool = nn.Linear(embed_dim, 1)
                                    
        self.head = nn.Linear(embed_dim, n_classes)

    def forward(self, x):
        '''
        Defines how the class will run

        Parameters
        ----------
        x: torch.Tensor
            shape: n_samples, in_chains, img_size, img_size

        Returns
        ---------
        logits: torch.Tensor
            Logits over all the classes: n_samples, n_samples
        '''
        x = self.conv_embed(x)
        #x = self.pos_embed(x)
        
        x += self.pos_embed
        x = self.pos_drop(x)
        for tr_block in self.tr_block:
            x = tr_block(x)
        x = self.norm(x)
        #Added Sequence Pooling instead of Class embedding
        x = torch.matmul(F.softmax(self.attention_pool(x), dim=1).transpose(-1, -2), x).squeeze(-2)
        x = self.head(x)
        return x

# %% [markdown]
# ### Positional Embedding
#
# This is the sinusoidal positional encoding layer as seen in the original 'Attention is All You Need' paper. It basically uses a sin/cos waveform to provide a unique positional offset that is given to a token at the corresponding position in its embedding space.
#
# By default, this is disabled and we instead use a trainable matrix of zeros. This adds another dimension to our data that the model then uses to find the best weights for the data's position itself. This is called "learnable" positional encoding.
#
# There are pros-and-cons to either, but essentially: sinusoidal is better when there are not a lot of data samples to learn the positional data from but you can get better results from "learnable" with larger datasets.

# %%
class PositionalEmbedding(nn.Module):
    '''
    Applies Learnable Sinusoidal Positional Encoding

    Parameters
    ----------
    embed_dim: int
        The positional embedding dimension (How big embedding for each patch.Constant across entire network)
    max_len: int 
        Max number of instances for positions
    freq: int 
        The base frequency for Sin/Cos calculations. Higher values (eg 10000) are more stable
    '''
    def __init__(self, 
                 embed_dim,
                 max_len=5000,
                 freq=10000.,
                ):
        super().__init__()
        pe = torch.zeros(max_len, embed_dim)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div = torch.exp(torch.arange(0, embed_dim, 2).float() *
                        (-math.log(freq) / embed_dim))
        pe[:, 0::2] = torch.sin(position * div) # Even terms
        pe[:, 1::2] = torch.cos(position * div) # Odd terms
        pe = pe.unsqueeze(0).transpose(0,1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        '''
        Defines how the class will run

        Parameters
        -----------

        Returns
        -----------
        '''
        x = x + self.pe[:x.size(0), :]
        return x

# %% [markdown]
# ### Convolutional Embedding Layer
#
# The patching used by the previous models was a problem because, while it took more samples of the input data, it also created what were essentially bordered segments which made it harder for the model to learn how they connected to the other segments and the bigger picture.
#
# The new convolutional layer helps to eliminate that problem by using convolutional filters to create many different overlapping segments.

# %%
class Conv_Embed(nn.Module):
    def __init__(self,
                 img_size=32,
                 in_channels=3,
                 out_channels=64,
                 n_conv=2,
                 kernel_size=3,
                 stride=None,
                 padding=None,
                 pool_kernel_size=3,
                 pool_stride=2,
                 pool_padding=1
                 ):
        super().__init__()
        
        stride = stride if stride is not None else max(1, (kernel_size // 2) - 1)
        padding = padding if padding is not None else max(1, (kernel_size // 2))

        self.img_size = img_size
        if n_conv == 1:
            self.conv_layers = nn.Sequential(
                nn.Conv2d(in_channels,
                        out_channels,
                        kernel_size=kernel_size,
                        stride=stride,
                        padding=padding,
                        bias=False),
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=pool_kernel_size,
                            stride=pool_stride,
                            padding=pool_padding)
            )
        else:
            n_filter_list = [in_channels] + \
                            [64 for _ in range(n_conv - 1)] + \
                            [out_channels]

            self.conv_layers = nn.Sequential(
                *[nn.Sequential(
                    nn.Conv2d(n_filter_list[i],
                        n_filter_list[i+1],
                        kernel_size=kernel_size,
                        stride=stride,
                        padding=padding,
                        bias=False),
                    nn.ReLU(),
                    nn.MaxPool2d(kernel_size=pool_kernel_size,
                            stride=pool_stride,
                            padding=pool_padding)
                            )
                    for i in range(n_conv)
                ])
        self.flattener = nn.Flatten(2, 3)
        
        # This, along with the staticmethod below, help to normalize the convolutional filter by picking better starting weights for optimization.
        self.apply(self.init_weight)

    def sequence_length(self, in_channels=3, height=32, width=32):
        return self.forward(torch.zeros((1, in_channels, height, width))).shape[1]

    def forward(self, x):
        return self.flattener(self.conv_layers(x)).transpose(-2, -1)

    @staticmethod
    def init_weight(m):
        if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight)

# %% [markdown]
# ### This is the Transformer Encoder block which applies all of the actual normalization, attention, etc that make a Transformer what it is.

# %%
class TransformerEncoderLayer(nn.Module):
    '''
    Transformer Block/Encoder Layer

    Parameter
    ---------
    embed_dim: int
        embedding dimension
    n_heads: int
        number of attention heads
    mlp_ratio: float
        determines the hidden dimension size of the MLP module with respect to 'dim'
    qkv_bias: bool
        If true then we include bias to the query, key and value projections
    mlp_dropout, proj_dropout, attn_droupout: float
        dropout probability
    dim_feedforward: int
        The feature number of hidden layer of the FFN

    Attributes
    ----------
    norm_1, norm_2: LayerNorm
        Layer normalization
    MHA: Attention
        Multi-Headed Attention module
    mlp: MLP
        MLP module
    ''' 
    def __init__(self,
                 embed_dim=768,
                 n_heads=12,
                 qkv_bias=True,
                 attn_dropout=0.,
                 proj_dropout=0.,
                 mlp_dropout=0.,
                 hidden_dim=2048
    ):
        super().__init__()
        self.norm_1 = nn.LayerNorm(embed_dim, eps = 1e-6)
        self.norm_2 = nn.LayerNorm(embed_dim, eps = 1e-6)
        self.MHA = MultiheadedSelfAttention(embed_dim,
                                        n_heads,
                                        qkv_bias,
                                        attn_dropout,
                                        proj_dropout
        )
        self.MLP = MLP(embed_dim, hidden_dim, mlp_dropout)

    def forward(self, x):
        '''
        Defines how the class will run
        
        Parameter
        ---------
        x: torch.Tensor
            shape: n_samples, n_patches + 1, dim

        Returns
        --------
        torch.Tensor
            shape: n_samples, n_patches + 1, dim
        '''
        x = x + self.MHA(self.norm_1(x))    # Residual connection (Add)
        x = x + self.MLP(self.norm_2(x))    # Residual connection (Add)
        return x

# %% [markdown]
# ### Multiheaded Attention Layer
#
# The heart of the Transformer model; the reason behind the original title of "attention is all you need".

# %%
class MultiheadedSelfAttention(nn.Module):
    '''
    Multi-Headed Attention Mechanism

    Parameters
    ----------
    embed_dim: int
        The input and out dimension of per token feature
    n_heads: int
        Number of attention heads 
    qkv_bias: bool
        if true then we include bias to the query, key and value projections
    attn_p: float
        Dropout probability applied to the query, key and value tensors.
    proj_p: float
        Dropout probability applied to output tensor
        
    Attributes
    ----------
    scale: float
        Normalizing constant for the dot product
    qkv: nn.Linear
        Linear projection for the query, key and value
    proj: nn.Linear
        Linear mapping that takes in the concatenated output of all attention
        heads and maps into the new space
    attn_drop, proj_drop: nn.Dropout
        Dropout layers.
    '''
    def __init__(self, 
                 embed_dim, 
                 n_heads=2,
                 qkv_bias = True,
                 attn_dropout=0.,
                 proj_dropout=0.
    ):
        super().__init__()
        self.n_heads = n_heads
        assert embed_dim % n_heads == 0, \
            print('Embedding dim must be divisible by number of heads.')
        self.head_dim = embed_dim // n_heads
        self.scale = self.head_dim ** -0.5
        self.dim = embed_dim
        self.qkv = nn.Linear(embed_dim, embed_dim * 3, bias=qkv_bias)
        self.attn_dropout = nn.Dropout(attn_dropout)
        self.proj = nn.Linear(embed_dim, embed_dim)
        self.proj_dropout = nn.Dropout(proj_dropout)
        
    def forward(self, x):
        '''
        Defines how the class will run
        
        Parameters
        ----------
        x: torch.Tensor
            shape: n_samples (B), n_patches + 1 (N), embed_dim (C)
            N is also equal to the number of tokens.
        Returns
        --------
        torch.Tensor
            shape: n_samples, n_patches + 1, embed_dim
        '''
        B, N, C = x.shape
        qkv = self.qkv(x)
        qkv = qkv.reshape(B, N, 3,
            self.n_heads,
            self.head_dim
            )
        qkv = qkv.permute(
            2,    # qkv (3)
            0,    # batch (n_samples)
            3,    # channel (n_heads)
            1,    # n_patches + 1
            4     # head_dim (embed_dim / n_heads)
            )
        q, k, v = qkv[0], qkv[1], qkv[2]
        attn = (q @ k.transpose(-2, -1)) * self.scale # <q,k> / sqrt(d)
        attn = attn.softmax(dim=-1) # Softmax over embedding dim
        attn = self.attn_dropout(attn)

        weighted_avg = (attn @ v)
        weighted_avg = weighted_avg.transpose(1, 2)
        weighted_avg = weighted_avg.flatten(2)

        x = self.proj(weighted_avg)
        x = self.proj_dropout(x)

        return x

# %% [markdown]
# ### The MLP layer
#
# (At the end of the Transformer Encoder). Not to be confused with the mlp head which adds class encodings at the very end of the transformer.

# %%
class MLP(nn.Module):
    '''
    Multilayer perceptron 
    
    Parameters
    ----------
    embed_dim: int
        embedding dimension
    feedforward_dim: int
      Number of nodes in the hidden layer
    mlp_dropout: float
      Dropout probability

    Attribute
    ---------
    fc: nn.Linear
      The first linear layer
    act: nn. GELU
      GELU activation function
    fc2: nn.Linear
      The second linear layer
    drop: nn.Dropout
      Dropout layer
    '''

    def __init__(self, embed_dim, hidden_dim, mlp_dropout):
        super().__init__()
        self.fc1 = nn.Linear(embed_dim, hidden_dim)
        self.act = nn.GELU()
        self.fc2 = nn.Linear(hidden_dim, embed_dim)
        self.drop = nn.Dropout(mlp_dropout)

    def forward(self,x):
        '''
        Defines how the class will run
        
        Parameters
        ----------
        x: torch.Tensor
          shape: n_samples, n_patches + 1, in_features

        Returns
        ----------
        torch.Tensor
          n_samples, n_patches+ 1, out_features
        '''
        x = self.fc1(x) # n_samples, n_patches+1, hidden_features
        x = self.act(x) # n_samples, n_patches+1, hidden_features
        x = self.drop(x) # n_samples, n_patches+1, hidden_features
        x = self.fc2(x) # n_samples, n_patches+1, output_features
        x = self.drop(x) # n_samples, n_patches+1, output_features
        return x

# %% [markdown]
# ## Training with custom dataset

# %%
def sipakmed_prep():
    root = "../../Python Scripts/Datasets/CervicalCancer/Sipakmed/"

    all_img = []
    for path, subdirs, files in os.walk(root):
        for name in files:
            curr_img = os.path.join(path,name)
            all_img.append(curr_img)

    sipakmed_df = pd.DataFrame()
    sipakmed_df['LocalPath'] = all_img
    sipakmed_df['ID'] = sipakmed_df['LocalPath'].apply(lambda x: str(x.split("\\")[-1]))
    sipakmed_df['Slide'] = sipakmed_df['LocalPath'].apply(lambda x: 'False' if (str(x.split("\\")[1])) == 'CROPPED' else 'True')
    sipakmed_df['Specific_Status'] = sipakmed_df['LocalPath'].apply(lambda x: str((x.split("im_")[1]).split("\\")[0]))
    sipakmed_df['Status'] = sipakmed_df['Specific_Status'].apply(lambda x: 'Benign' if x == 'Metaplastic' else
    ('Normal' if x == 'Superficial-Intermediate' or x == 'Parabasal' else 'Abnormal'))

    sp_class = {'Metaplastic':4, 'Superficial-Intermediate':0, 'Parabasal':1, 'Koilocytotic':2, 'Dyskeratotic':3}
    sipakmed_df['Specific_Class'] = sipakmed_df['Specific_Status'].map(sp_class)
    gen_class = {'Benign':0, 'Normal':1, 'Abnormal':2}
    sipakmed_df['Class'] = sipakmed_df['Status'].map(gen_class)

    sipakmed_df = sipakmed_df.loc[sipakmed_df['ID'].str.contains('bmp')].reset_index(drop=True)
    
    #Uploads the created file for future use. Recommended to not use.
    #sipakmed_df.to_csv(root + '/results.csv')
    return sipakmed_df

# %%
def herlev_prep():
    root = '../../Python Scripts/Datasets/CervicalCancer/Herlev/smear2005/results.csv'
    img_folder = '../../Python Scripts/Datasets/CervicalCancer/Herlev/smear2005/Images/'

    herlev_df=pd.read_csv(root)
    herlev_df = herlev_df.rename(columns={'Class':'Specific_Class'})

    spec_class = {1:0, 2:1, 3:2, 4:3, 5:4, 6:5, 7:6}
    gen_class = {1:1, 2:1, 3:1, 4:2, 5:2, 6:2, 7:2}
    
    herlev_df['Class'] = herlev_df['Specific_Class'].map(gen_class)
    herlev_df['Specific_Class'] = herlev_df['Specific_Class'].map(spec_class)
    herlev_df['LocalPath'] = herlev_df['ID'].apply(lambda x: str(img_folder + x))
    return herlev_df

# %%
class DatasetSample(Dataset):
    def __init__(self, df, transform):
        # Initialization
        self.transform = transform
        
        self.image_names = df['LocalPath']
        self.img_class = np.array(df['Class'])

    def __len__(self):
        # Denotes the total number of samples
        return len(self.image_names)
    
    def __getitem__(self, index):
        # Retrieves the data
        image=cv2.imread(self.image_names.iloc[index])
        image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

        image = self.transform(image)
        label = self.img_class[index]

        x, y = image, label
        
        # Enable to output as single variable instead
        #sample = {'image': image,'labels':label}

        return x, y

# %%
def concat_data(batch_size=128, img_size=32):
    # Load the dataframes
    sipakmed_df = sipakmed_prep()
    herlev_df = herlev_prep()

    # Final adjustments to make sure they're attributes match
    sipakmed_df = sipakmed_df.loc[sipakmed_df['Slide'] == 'False']

    '''
    concat_df = pd.concat([sipakmed_df,herlev_df], ignore_index=True)
    concat_df = pd.DataFrame()
    concat_df['LocalPath'] = sipakmed_df['LocalPath']
    concat_df['Class'] = sipakmed_df['Specific_Class']

    '''
    concat_df = pd.DataFrame()
    concat_df['LocalPath'] = herlev_df['LocalPath']
    concat_df['Class'] = herlev_df['Specific_Class']

    # Split them into training, validation, and testing sets
    train_set,val_test_set = train_test_split(concat_df, random_state=1, test_size=0.40)
    val_set,test_set = train_test_split(val_test_set, random_state=1, test_size=0.50)
    
    # Set it up to alter random training images for better results
    train_transform = transforms.Compose([
                    transforms.ToPILImage(),
                    transforms.Resize((img_size, img_size)),
                    transforms.RandomHorizontalFlip(p=0.75),
                    transforms.RandomRotation(degrees=60),
                    #transforms.RandomAutocontrast(),
                    transforms.transforms.ColorJitter(brightness=.2, hue=.2),
                    #transforms.RandomGrayscale(),
                    transforms.ToTensor()])

    test_transform = transforms.Compose([
                    transforms.ToPILImage(),
                    transforms.Resize((img_size, img_size)),
                    transforms.ToTensor()])

    train_dataset = DatasetSample(train_set, train_transform)
    val_dataset = DatasetSample(val_set, test_transform)
    test_dataset = DatasetSample(test_set, test_transform)
    
    Dtr = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        generator=torch.Generator().manual_seed(17)
    )
    
    Dva = DataLoader(
        val_dataset, 
        batch_size=batch_size,
        shuffle=False
    )

    Dte = DataLoader(
        test_dataset, 
        batch_size=batch_size,
        shuffle=False
    )

    return(Dtr, Dva, Dte)

# %%
#The corresponding class labels
batch_size=128
img_size=64
#classes = ('Benign', 'Normal', 'Abnormal')
#classes = ('Superficial-Intermediate','Parabasal','Koilocytotic','Dyskeratotic','Metaplastic')
classes = ('Superficial-Squamous-Epithelial','Intermediate-Squamous-Epithelial','Columnar-Epithelial','Mild-Squamous-Non-Keratinizing-Dysplasia',
           'Moderate-Squamous-Non-Keratinizing-Dysplasia','Severe-Squamous-Non-Keratinizing-Dysplasia','Squamous-Cell-Carcinoma-in-situ-Intermediate')

n_classes = len(classes)
Dtr, Dva, Dte = concat_data(batch_size=batch_size, img_size=img_size)

# %% [markdown]
# ### Builds the dataloaders for training and testing

# %%
# Turns the dataloaders into iterable objects. Useful for viewing
dataiter = iter(Dtr)
val_dataiter = iter(Dva)
test_dataiter = iter(Dte)

# %% [markdown]
# ### Function for viewing batches of the dataset

# %%
def imshow(images, labels, predicted_labels=None):
    
    if images.is_cuda == True:
        images = images.to("cpu")
    if labels.is_cuda == True:
        labels = labels.to("cpu")

    # Using torchvision to make a grid of the images
    img = torchvision.utils.make_grid(images)

    # Inverting the normalization
    img = img.numpy().transpose((1, 2, 0))
    img = np.clip(img, 0, 1)

    # Plotting the grid
    fig, ax = plt.subplots(figsize=(12, 24))
    plt.imshow(img)

    if predicted_labels is not None:
        if predicted_labels.is_cuda == True:
            predicted_labels = predicted_labels.to("cpu")
        # Outputing the predicted labels
        ax.set_xlabel('Predicted labels', fontsize=18, labelpad=12)
        ax.set_xticks(torch.arange(len(images)) * img_size + (img_size/1.8))
        ax.set_xticklabels([classes[predicted_labels[j]] 
                            for j in range(len(images))], fontsize=12, rotation=30)
    
    # Outputing the True labels
    gax = ax.secondary_xaxis('top')
    gax.set_xlabel('True Labels', fontsize=18, labelpad=12)
    gax.set_xticks(torch.arange(len(images)) * img_size + (img_size/1.8))
    gax.set_xticklabels([classes[labels[j]] 
                         for j in range(len(images))], fontsize=12, rotation=30)
    plt.show()

# %%
images, labels = dataiter.next()
imshow(images[:7], labels[:7])

# %% [markdown]
# ### This function was made by Dr Prashant to train the model that's built above

# %%
# A function to encapsulate the training loop
def batch_gd(model, loss_fn, optimizer, train_loader, val_loader, epochs):
  model.to(device)
  train_losses = np.zeros(epochs)
  val_losses = np.zeros(epochs)
  avg_epoch = []
  
  for it in range(epochs):
    model.train()
    t0 = datetime.now()
    train_loss = []
    n_correct = 0.
    n_total = 0.
    for inputs, targets in train_loader:
      # move data to GPU if available
      inputs, targets = inputs.to(device), targets.to(device)

      # zero the parameter gradients
      optimizer.zero_grad()

      # Forward pass
      outputs = model(inputs)
      
      # Get the predictions
      # torch.max returns both max and argmax
      __, out_label = outputs.max(dim=1)
      # Updates the accuracy with every pass
      n_correct += (out_label == targets).sum().item()
      n_total += targets.shape[0]
      tr_acc = n_correct / n_total

      loss = loss_fn(outputs, targets)
      # Backward and optimize
      loss.backward()
      optimizer.step()

      train_loss.append(loss.item())

    # Get train loss and test loss
    train_loss = np.mean(train_loss) # a little misleading
    
    model.eval()
    val_loss = []
    n_correct = 0.
    n_total = 0.
    for inputs, targets in val_loader:
      inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)

      # Get the predictions
      # torch.max returns both max and argmax
      __, out_label = outputs.max(dim=1)
      # Updates the accuracy with every pass
      n_correct += (out_label == targets).sum().item()
      n_total += targets.shape[0]
      val_acc = n_correct / n_total

      loss = loss_fn(outputs, targets)
      val_loss.append(loss.item())
    val_loss = np.mean(val_loss)

    # Save losses
    train_losses[it] = train_loss
    val_losses[it] = val_loss
    
    dt = datetime.now() - t0
    avg_epoch.append(dt)

    print(f'Epoch {it+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {(100*tr_acc):.3f} \
      Val Loss: {val_loss:.4f}, Val Accuracy: {(100*val_acc):.3f}, Duration: {dt}, Avg_Epoch: {np.mean(avg_epoch)}')
  
  return train_losses, val_losses

# %% [markdown]
# ### Initializes the Transformer and selects the loss function and optimizer we want

# %%
model = CCT(
        img_size=img_size,      # Input image size
        in_channels=3,  # Number of channels for the image
        patch_size=4,   # How big our patches are
        embed_dim=128,   # Embedding dim
        n_layers=2,     # Number of transformer encoders
        n_conv=2,       # Number of convolutional layers
        n_heads=2,      # Number of attention heads
        attn_dropout=0.,        # Attention Dropout
        proj_dropout=0.,        # (MHA) Projection Dropout
        mlp_dropout=0.1,        # (MHA) last layer dropout
        mlp_ratio=1,    # (MHA) Projection FF dimension
        qkv_bias = True,
        n_classes=n_classes     # Number of classes to classify
        )
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())

# %%
train_losses, val_losses = batch_gd(model, loss_fn, optimizer, Dtr, Dva, epochs=300)
# Out:
# Epoch 1/300, Train Loss: 2.0496, Train Accuracy: 20.364       Val Loss: 1.9610, Val Accuracy: 21.858, Duration: 0:00:02.140007, Avg_Epoch: 0:00:02.140007
# Epoch 2/300, Train Loss: 1.9044, Train Accuracy: 16.364       Val Loss: 1.9219, Val Accuracy: 15.847, Duration: 0:00:01.953774, Avg_Epoch: 0:00:02.046890
# Epoch 3/300, Train Loss: 1.9009, Train Accuracy: 20.727       Val Loss: 1.9412, Val Accuracy: 15.847, Duration: 0:00:01.790215, Avg_Epoch: 0:00:01.961332
# Epoch 4/300, Train Loss: 1.8857, Train Accuracy: 20.727       Val Loss: 1.9063, Val Accuracy: 17.486, Duration: 0:00:01.880974, Avg_Epoch: 0:00:01.941242
# Epoch 5/300, Train Loss: 1.8608, Train Accuracy: 16.727       Val Loss: 1.9074, Val Accuracy: 20.219, Duration: 0:00:01.786225, Avg_Epoch: 0:00:01.910239
# Epoch 6/300, Train Loss: 1.8878, Train Accuracy: 21.636       Val Loss: 1.9337, Val Accuracy: 15.847, Duration: 0:00:01.774258, Avg_Epoch: 0:00:01.887576
# Epoch 7/300, Train Loss: 1.8740, Train Accuracy: 21.273       Val Loss: 1.9056, Val Accuracy: 20.219, Duration: 0:00:01.771266, Avg_Epoch: 0:00:01.870960
# Epoch 8/300, Train Loss: 1.8482, Train Accuracy: 20.909       Val Loss: 1.8944, Val Accuracy: 21.311, Duration: 0:00:01.983699, Avg_Epoch: 0:00:01.885052
# Epoch 9/300, Train Loss: 1.8657, Train Accuracy: 20.000       Val Loss: 1.8999, Val Accuracy: 24.590, Duration: 0:00:01.963752, Avg_Epoch: 0:00:01.893797
# Epoch 10/300, Train Loss: 1.8497, Train Accuracy: 24.000       Val Loss: 1.9113, Val Accuracy: 18.033, Duration: 0:00:01.935825, Avg_Epoch: 0:00:01.898000
# Epoch 11/300, Train Loss: 1.8744, Train Accuracy: 21.273       Val Loss: 1.8768, Val Accuracy: 20.765, Duration: 0:00:01.877981, Avg_Epoch: 0:00:01.896180
# Epoch 12/300, Train Loss: 1.8514, Train Accuracy: 21.818       Val Loss: 1.8694, Val Accuracy: 24.590, Duration: 0:00:01.888951, Avg_Epoch: 0:00:01.895577
# Epoch 13/300, Train Loss: 1.8422, Train Accuracy: 25.818       Val Loss: 1.8665, Val Accuracy: 25.683, Duration: 0:00:01.917873, Avg_Epoch: 0:00:01.897292
# Epoch 14/300, Train Loss: 1.8449, Train Accuracy: 24.545       Val Loss: 1.8734, Val Accuracy: 26.230, Duration: 0:00:01.870002, Avg_Epoch: 0:00:01.895343
# Epoch 15/300, Train Loss: 1.8170, Train Accuracy: 26.545       Val Loss: 1.8404, Val Accuracy: 21.311, Duration: 0:00:02.194697, Avg_Epoch: 0:00:01.915300
# Epoch 16/300, Train Loss: 1.8265, Train Accuracy: 25.636       Val Loss: 1.8345, Val Accuracy: 22.951, Duration: 0:00:02.076982, Avg_Epoch: 0:00:01.925405
# Epoch 17/300, Train Loss: 1.8099, Train Accuracy: 25.273       Val Loss: 1.7931, Val Accuracy: 26.230, Duration: 0:00:02.823283, Avg_Epoch: 0:00:01.978221
# Epoch 18/300, Train Loss: 1.7915, Train Accuracy: 27.091       Val Loss: 1.7548, Val Accuracy: 25.137, Duration: 0:00:02.518625, Avg_Epoch: 0:00:02.008244
# Epoch 19/300, Train Loss: 1.7880, Train Accuracy: 28.364       Val Loss: 1.7262, Val Accuracy: 26.230, Duration: 0:00:02.387601, Avg_Epoch: 0:00:02.028210
# Epoch 20/300, Train Loss: 1.7782, Train Accuracy: 28.727       Val Loss: 1.7367, Val Accuracy: 25.137, Duration: 0:00:02.281919, Avg_Epoch: 0:00:02.040895
# Epoch 21/300, Train Loss: 1.7921, Train Accuracy: 25.818       Val Loss: 1.7481, Val Accuracy: 26.230, Duration: 0:00:02.063484, Avg_Epoch: 0:00:02.041971
# Epoch 22/300, Train Loss: 1.7618, Train Accuracy: 25.636       Val Loss: 1.7298, Val Accuracy: 25.683, Duration: 0:00:02.138286, Avg_Epoch: 0:00:02.046349
# Epoch 23/300, Train Loss: 1.7806, Train Accuracy: 28.727       Val Loss: 1.7093, Val Accuracy: 29.508, Duration: 0:00:02.065479, Avg_Epoch: 0:00:02.047181
# Epoch 24/300, Train Loss: 1.7451, Train Accuracy: 28.727       Val Loss: 1.6927, Val Accuracy: 30.055, Duration: 0:00:01.884963, Avg_Epoch: 0:00:02.040422
# Epoch 25/300, Train Loss: 1.7424, Train Accuracy: 27.818       Val Loss: 1.6701, Val Accuracy: 29.508, Duration: 0:00:01.950785, Avg_Epoch: 0:00:02.036836
# Epoch 26/300, Train Loss: 1.6825, Train Accuracy: 28.000       Val Loss: 1.7518, Val Accuracy: 25.683, Duration: 0:00:01.861026, Avg_Epoch: 0:00:02.030074
# Epoch 27/300, Train Loss: 1.6834, Train Accuracy: 29.818       Val Loss: 1.7000, Val Accuracy: 29.508, Duration: 0:00:01.912887, Avg_Epoch: 0:00:02.025734
# Epoch 28/300, Train Loss: 1.6924, Train Accuracy: 32.182       Val Loss: 1.6770, Val Accuracy: 31.148, Duration: 0:00:01.912887, Avg_Epoch: 0:00:02.021704
# Epoch 29/300, Train Loss: 1.6728, Train Accuracy: 32.909       Val Loss: 1.5363, Val Accuracy: 41.530, Duration: 0:00:01.920865, Avg_Epoch: 0:00:02.018227
# Epoch 30/300, Train Loss: 1.6770, Train Accuracy: 33.091       Val Loss: 1.7993, Val Accuracy: 28.415, Duration: 0:00:01.871001, Avg_Epoch: 0:00:02.013319
# Epoch 31/300, Train Loss: 1.6934, Train Accuracy: 31.273       Val Loss: 1.5887, Val Accuracy: 38.798, Duration: 0:00:01.922860, Avg_Epoch: 0:00:02.010401
# Epoch 32/300, Train Loss: 1.6706, Train Accuracy: 31.455       Val Loss: 1.6570, Val Accuracy: 24.590, Duration: 0:00:02.021597, Avg_Epoch: 0:00:02.010751
# Epoch 33/300, Train Loss: 1.6694, Train Accuracy: 31.273       Val Loss: 1.5832, Val Accuracy: 33.333, Duration: 0:00:01.976716, Avg_Epoch: 0:00:02.009720
# Epoch 34/300, Train Loss: 1.6277, Train Accuracy: 34.182       Val Loss: 1.5454, Val Accuracy: 38.798, Duration: 0:00:01.947794, Avg_Epoch: 0:00:02.007898
# Epoch 35/300, Train Loss: 1.6497, Train Accuracy: 31.818       Val Loss: 1.5736, Val Accuracy: 36.612, Duration: 0:00:01.858034, Avg_Epoch: 0:00:02.003616
# Epoch 36/300, Train Loss: 1.5881, Train Accuracy: 36.545       Val Loss: 1.5699, Val Accuracy: 37.158, Duration: 0:00:01.861026, Avg_Epoch: 0:00:01.999656
# Epoch 37/300, Train Loss: 1.5285, Train Accuracy: 38.364       Val Loss: 1.3967, Val Accuracy: 45.902, Duration: 0:00:01.965746, Avg_Epoch: 0:00:01.998739
# Epoch 38/300, Train Loss: 1.4571, Train Accuracy: 42.182       Val Loss: 1.5546, Val Accuracy: 36.066, Duration: 0:00:01.934828, Avg_Epoch: 0:00:01.997057
# Epoch 39/300, Train Loss: 1.5433, Train Accuracy: 36.000       Val Loss: 1.6843, Val Accuracy: 35.519, Duration: 0:00:01.934829, Avg_Epoch: 0:00:01.995462
# Epoch 40/300, Train Loss: 1.6241, Train Accuracy: 34.364       Val Loss: 1.3709, Val Accuracy: 42.077, Duration: 0:00:01.949789, Avg_Epoch: 0:00:01.994320
# Epoch 41/300, Train Loss: 1.4771, Train Accuracy: 38.727       Val Loss: 1.4820, Val Accuracy: 34.973, Duration: 0:00:01.906903, Avg_Epoch: 0:00:01.992188
# Epoch 42/300, Train Loss: 1.4503, Train Accuracy: 39.455       Val Loss: 1.3403, Val Accuracy: 42.623, Duration: 0:00:01.870002, Avg_Epoch: 0:00:01.989278
# Epoch 43/300, Train Loss: 1.4163, Train Accuracy: 38.909       Val Loss: 1.3006, Val Accuracy: 40.984, Duration: 0:00:01.855043, Avg_Epoch: 0:00:01.986157
# Epoch 44/300, Train Loss: 1.3855, Train Accuracy: 45.818       Val Loss: 1.3099, Val Accuracy: 45.355, Duration: 0:00:01.797196, Avg_Epoch: 0:00:01.981862
# Epoch 45/300, Train Loss: 1.3474, Train Accuracy: 44.182       Val Loss: 1.2837, Val Accuracy: 46.995, Duration: 0:00:01.826120, Avg_Epoch: 0:00:01.978401
# Epoch 46/300, Train Loss: 1.2922, Train Accuracy: 48.364       Val Loss: 1.2651, Val Accuracy: 46.448, Duration: 0:00:01.866012, Avg_Epoch: 0:00:01.975958
# Epoch 47/300, Train Loss: 1.3362, Train Accuracy: 43.818       Val Loss: 1.2418, Val Accuracy: 47.541, Duration: 0:00:01.977714, Avg_Epoch: 0:00:01.975995
# Epoch 48/300, Train Loss: 1.3720, Train Accuracy: 46.000       Val Loss: 1.2505, Val Accuracy: 49.180, Duration: 0:00:01.836093, Avg_Epoch: 0:00:01.973081
# Epoch 49/300, Train Loss: 1.2922, Train Accuracy: 46.909       Val Loss: 1.3461, Val Accuracy: 38.251, Duration: 0:00:01.992674, Avg_Epoch: 0:00:01.973481
# Epoch 50/300, Train Loss: 1.3231, Train Accuracy: 46.182       Val Loss: 1.2431, Val Accuracy: 49.727, Duration: 0:00:01.895931, Avg_Epoch: 0:00:01.971930
# Epoch 51/300, Train Loss: 1.3050, Train Accuracy: 46.909       Val Loss: 1.2147, Val Accuracy: 50.273, Duration: 0:00:01.838087, Avg_Epoch: 0:00:01.969305
# Epoch 52/300, Train Loss: 1.2446, Train Accuracy: 52.000       Val Loss: 1.2142, Val Accuracy: 48.634, Duration: 0:00:01.823128, Avg_Epoch: 0:00:01.966494
# Epoch 53/300, Train Loss: 1.1984, Train Accuracy: 52.545       Val Loss: 1.1621, Val Accuracy: 53.552, Duration: 0:00:01.870001, Avg_Epoch: 0:00:01.964673
# Epoch 54/300, Train Loss: 1.2226, Train Accuracy: 49.091       Val Loss: 1.3009, Val Accuracy: 41.530, Duration: 0:00:02.012620, Avg_Epoch: 0:00:01.965561
# Epoch 55/300, Train Loss: 1.2492, Train Accuracy: 48.727       Val Loss: 1.2288, Val Accuracy: 51.913, Duration: 0:00:01.910893, Avg_Epoch: 0:00:01.964567
# Epoch 56/300, Train Loss: 1.2455, Train Accuracy: 47.636       Val Loss: 1.2112, Val Accuracy: 50.273, Duration: 0:00:02.127314, Avg_Epoch: 0:00:01.967474
# Epoch 57/300, Train Loss: 1.1825, Train Accuracy: 49.455       Val Loss: 1.3623, Val Accuracy: 41.530, Duration: 0:00:01.887954, Avg_Epoch: 0:00:01.966079
# Epoch 58/300, Train Loss: 1.2772, Train Accuracy: 43.818       Val Loss: 1.2617, Val Accuracy: 46.995, Duration: 0:00:01.878978, Avg_Epoch: 0:00:01.964577
# Epoch 59/300, Train Loss: 1.2136, Train Accuracy: 49.455       Val Loss: 1.2624, Val Accuracy: 43.169, Duration: 0:00:01.827117, Avg_Epoch: 0:00:01.962247
# Epoch 60/300, Train Loss: 1.1838, Train Accuracy: 50.000       Val Loss: 1.2278, Val Accuracy: 49.180, Duration: 0:00:01.928847, Avg_Epoch: 0:00:01.961690
# Epoch 61/300, Train Loss: 1.2153, Train Accuracy: 49.818       Val Loss: 1.1974, Val Accuracy: 53.005, Duration: 0:00:01.813153, Avg_Epoch: 0:00:01.959255
# Epoch 62/300, Train Loss: 1.1802, Train Accuracy: 54.182       Val Loss: 1.1750, Val Accuracy: 51.913, Duration: 0:00:01.837090, Avg_Epoch: 0:00:01.957285
# Epoch 63/300, Train Loss: 1.1850, Train Accuracy: 52.727       Val Loss: 1.2116, Val Accuracy: 51.913, Duration: 0:00:01.829111, Avg_Epoch: 0:00:01.955250
# Epoch 64/300, Train Loss: 1.1922, Train Accuracy: 51.273       Val Loss: 1.1728, Val Accuracy: 50.273, Duration: 0:00:01.868007, Avg_Epoch: 0:00:01.953887
# Epoch 65/300, Train Loss: 1.1888, Train Accuracy: 54.364       Val Loss: 1.1615, Val Accuracy: 46.995, Duration: 0:00:01.871000, Avg_Epoch: 0:00:01.952612
# Epoch 66/300, Train Loss: 1.1819, Train Accuracy: 49.636       Val Loss: 1.2252, Val Accuracy: 49.180, Duration: 0:00:01.822130, Avg_Epoch: 0:00:01.950635
# Epoch 67/300, Train Loss: 1.1700, Train Accuracy: 52.182       Val Loss: 1.1440, Val Accuracy: 48.634, Duration: 0:00:01.808167, Avg_Epoch: 0:00:01.948509
# Epoch 68/300, Train Loss: 1.1401, Train Accuracy: 53.818       Val Loss: 1.2270, Val Accuracy: 50.820, Duration: 0:00:01.803412, Avg_Epoch: 0:00:01.946375
# Epoch 69/300, Train Loss: 1.1479, Train Accuracy: 52.909       Val Loss: 1.1175, Val Accuracy: 50.273, Duration: 0:00:01.818140, Avg_Epoch: 0:00:01.944516
# Epoch 70/300, Train Loss: 1.1303, Train Accuracy: 55.091       Val Loss: 1.1800, Val Accuracy: 49.727, Duration: 0:00:01.896333, Avg_Epoch: 0:00:01.943828
# Epoch 71/300, Train Loss: 1.1298, Train Accuracy: 53.818       Val Loss: 1.1342, Val Accuracy: 49.180, Duration: 0:00:02.459132, Avg_Epoch: 0:00:01.951086
# Epoch 72/300, Train Loss: 1.0801, Train Accuracy: 55.273       Val Loss: 1.1623, Val Accuracy: 56.831, Duration: 0:00:01.831106, Avg_Epoch: 0:00:01.949419
# Epoch 73/300, Train Loss: 1.1371, Train Accuracy: 55.091       Val Loss: 1.0865, Val Accuracy: 55.738, Duration: 0:00:01.866012, Avg_Epoch: 0:00:01.948277
# Epoch 74/300, Train Loss: 1.0898, Train Accuracy: 54.182       Val Loss: 1.1352, Val Accuracy: 49.727, Duration: 0:00:01.885960, Avg_Epoch: 0:00:01.947435
# Epoch 75/300, Train Loss: 1.1007, Train Accuracy: 54.727       Val Loss: 1.0281, Val Accuracy: 55.738, Duration: 0:00:01.861025, Avg_Epoch: 0:00:01.946283
# Epoch 76/300, Train Loss: 1.0977, Train Accuracy: 56.727       Val Loss: 1.1160, Val Accuracy: 49.727, Duration: 0:00:02.000653, Avg_Epoch: 0:00:01.946998
# Epoch 77/300, Train Loss: 1.1320, Train Accuracy: 53.636       Val Loss: 1.3256, Val Accuracy: 44.809, Duration: 0:00:01.819139, Avg_Epoch: 0:00:01.945338
# Epoch 78/300, Train Loss: 1.1379, Train Accuracy: 53.273       Val Loss: 1.1434, Val Accuracy: 47.541, Duration: 0:00:01.839083, Avg_Epoch: 0:00:01.943975
# Epoch 79/300, Train Loss: 1.1254, Train Accuracy: 54.182       Val Loss: 1.1215, Val Accuracy: 54.645, Duration: 0:00:01.839085, Avg_Epoch: 0:00:01.942648
# Epoch 80/300, Train Loss: 1.1284, Train Accuracy: 55.818       Val Loss: 1.0504, Val Accuracy: 50.820, Duration: 0:00:01.840082, Avg_Epoch: 0:00:01.941365
# Epoch 81/300, Train Loss: 1.0962, Train Accuracy: 54.545       Val Loss: 1.0716, Val Accuracy: 54.098, Duration: 0:00:01.809165, Avg_Epoch: 0:00:01.939733
# Epoch 82/300, Train Loss: 1.1167, Train Accuracy: 54.182       Val Loss: 1.1271, Val Accuracy: 51.913, Duration: 0:00:01.804178, Avg_Epoch: 0:00:01.938080
# Epoch 83/300, Train Loss: 1.0753, Train Accuracy: 55.091       Val Loss: 1.1288, Val Accuracy: 50.820, Duration: 0:00:01.878978, Avg_Epoch: 0:00:01.937368
# Epoch 84/300, Train Loss: 1.0606, Train Accuracy: 56.909       Val Loss: 1.0420, Val Accuracy: 59.016, Duration: 0:00:01.892940, Avg_Epoch: 0:00:01.936839
# Epoch 85/300, Train Loss: 1.0089, Train Accuracy: 60.545       Val Loss: 1.0763, Val Accuracy: 51.366, Duration: 0:00:01.870002, Avg_Epoch: 0:00:01.936053
# Epoch 86/300, Train Loss: 1.0585, Train Accuracy: 59.091       Val Loss: 1.1460, Val Accuracy: 50.273, Duration: 0:00:01.872994, Avg_Epoch: 0:00:01.935320
# Epoch 87/300, Train Loss: 1.0198, Train Accuracy: 58.727       Val Loss: 1.1428, Val Accuracy: 53.005, Duration: 0:00:01.864019, Avg_Epoch: 0:00:01.934500
# Epoch 88/300, Train Loss: 0.9906, Train Accuracy: 59.818       Val Loss: 1.0704, Val Accuracy: 54.098, Duration: 0:00:01.854045, Avg_Epoch: 0:00:01.933586
# Epoch 89/300, Train Loss: 1.0319, Train Accuracy: 57.818       Val Loss: 1.1280, Val Accuracy: 53.552, Duration: 0:00:01.919867, Avg_Epoch: 0:00:01.933432
# Epoch 90/300, Train Loss: 1.0444, Train Accuracy: 57.455       Val Loss: 1.0721, Val Accuracy: 57.923, Duration: 0:00:01.844071, Avg_Epoch: 0:00:01.932439
# Epoch 91/300, Train Loss: 1.0436, Train Accuracy: 57.636       Val Loss: 1.0951, Val Accuracy: 53.552, Duration: 0:00:01.948312, Avg_Epoch: 0:00:01.932613
# Epoch 92/300, Train Loss: 0.9816, Train Accuracy: 61.818       Val Loss: 1.0118, Val Accuracy: 59.016, Duration: 0:00:01.983903, Avg_Epoch: 0:00:01.933171
# Epoch 93/300, Train Loss: 0.9533, Train Accuracy: 61.455       Val Loss: 1.0680, Val Accuracy: 58.470, Duration: 0:00:01.842076, Avg_Epoch: 0:00:01.932191
# Epoch 94/300, Train Loss: 0.9933, Train Accuracy: 58.545       Val Loss: 1.0947, Val Accuracy: 57.923, Duration: 0:00:02.100990, Avg_Epoch: 0:00:01.933987
# Epoch 95/300, Train Loss: 0.9694, Train Accuracy: 60.727       Val Loss: 1.0965, Val Accuracy: 57.923, Duration: 0:00:02.079443, Avg_Epoch: 0:00:01.935518
# Epoch 96/300, Train Loss: 0.9849, Train Accuracy: 61.636       Val Loss: 1.0970, Val Accuracy: 53.005, Duration: 0:00:02.428509, Avg_Epoch: 0:00:01.940653
# Epoch 97/300, Train Loss: 0.9472, Train Accuracy: 62.364       Val Loss: 1.1512, Val Accuracy: 52.459, Duration: 0:00:02.144270, Avg_Epoch: 0:00:01.942753
# Epoch 98/300, Train Loss: 0.9965, Train Accuracy: 57.273       Val Loss: 1.0831, Val Accuracy: 51.913, Duration: 0:00:01.831104, Avg_Epoch: 0:00:01.941613
# Epoch 99/300, Train Loss: 0.9500, Train Accuracy: 62.727       Val Loss: 1.1585, Val Accuracy: 51.913, Duration: 0:00:01.929842, Avg_Epoch: 0:00:01.941494
# Epoch 100/300, Train Loss: 0.9437, Train Accuracy: 62.545       Val Loss: 1.1161, Val Accuracy: 52.459, Duration: 0:00:01.916876, Avg_Epoch: 0:00:01.941248
# Epoch 101/300, Train Loss: 1.0234, Train Accuracy: 57.273       Val Loss: 1.0879, Val Accuracy: 57.923, Duration: 0:00:01.926851, Avg_Epoch: 0:00:01.941106
# Epoch 102/300, Train Loss: 0.9930, Train Accuracy: 60.727       Val Loss: 1.0988, Val Accuracy: 50.273, Duration: 0:00:01.920865, Avg_Epoch: 0:00:01.940907
# Epoch 103/300, Train Loss: 1.0195, Train Accuracy: 60.909       Val Loss: 1.0445, Val Accuracy: 54.098, Duration: 0:00:01.911890, Avg_Epoch: 0:00:01.940626
# Epoch 104/300, Train Loss: 0.9736, Train Accuracy: 60.364       Val Loss: 1.1411, Val Accuracy: 51.366, Duration: 0:00:01.972727, Avg_Epoch: 0:00:01.940934
# Epoch 105/300, Train Loss: 1.0506, Train Accuracy: 57.636       Val Loss: 1.0598, Val Accuracy: 54.098, Duration: 0:00:01.915881, Avg_Epoch: 0:00:01.940696
# Epoch 106/300, Train Loss: 0.9615, Train Accuracy: 62.727       Val Loss: 1.2750, Val Accuracy: 50.820, Duration: 0:00:01.926850, Avg_Epoch: 0:00:01.940565
# Epoch 107/300, Train Loss: 0.9661, Train Accuracy: 61.455       Val Loss: 1.0377, Val Accuracy: 55.191, Duration: 0:00:01.941809, Avg_Epoch: 0:00:01.940577
# Epoch 108/300, Train Loss: 0.9662, Train Accuracy: 62.909       Val Loss: 1.1318, Val Accuracy: 49.180, Duration: 0:00:01.922860, Avg_Epoch: 0:00:01.940413
# Epoch 109/300, Train Loss: 0.9959, Train Accuracy: 58.000       Val Loss: 1.0546, Val Accuracy: 55.738, Duration: 0:00:01.939815, Avg_Epoch: 0:00:01.940407
# Epoch 110/300, Train Loss: 0.9863, Train Accuracy: 59.636       Val Loss: 1.0869, Val Accuracy: 58.470, Duration: 0:00:01.905907, Avg_Epoch: 0:00:01.940093
# Epoch 111/300, Train Loss: 0.9472, Train Accuracy: 60.000       Val Loss: 1.0353, Val Accuracy: 56.831, Duration: 0:00:01.929842, Avg_Epoch: 0:00:01.940001
# Epoch 112/300, Train Loss: 0.9147, Train Accuracy: 61.091       Val Loss: 1.0794, Val Accuracy: 48.634, Duration: 0:00:01.907899, Avg_Epoch: 0:00:01.939714
# Epoch 113/300, Train Loss: 0.9786, Train Accuracy: 58.545       Val Loss: 1.0848, Val Accuracy: 55.191, Duration: 0:00:01.887954, Avg_Epoch: 0:00:01.939256
# Epoch 114/300, Train Loss: 0.8697, Train Accuracy: 64.909       Val Loss: 1.0479, Val Accuracy: 59.016, Duration: 0:00:01.908898, Avg_Epoch: 0:00:01.938990
# Epoch 115/300, Train Loss: 0.8706, Train Accuracy: 65.455       Val Loss: 1.0053, Val Accuracy: 57.377, Duration: 0:00:01.865015, Avg_Epoch: 0:00:01.938347
# Epoch 116/300, Train Loss: 1.0000, Train Accuracy: 60.545       Val Loss: 1.1493, Val Accuracy: 53.552, Duration: 0:00:01.823127, Avg_Epoch: 0:00:01.937354
# Epoch 117/300, Train Loss: 1.0036, Train Accuracy: 62.000       Val Loss: 1.2314, Val Accuracy: 51.913, Duration: 0:00:01.814151, Avg_Epoch: 0:00:01.936301
# Epoch 118/300, Train Loss: 0.9710, Train Accuracy: 60.909       Val Loss: 1.0345, Val Accuracy: 56.284, Duration: 0:00:01.888951, Avg_Epoch: 0:00:01.935899
# Epoch 119/300, Train Loss: 0.8930, Train Accuracy: 62.000       Val Loss: 1.0895, Val Accuracy: 53.552, Duration: 0:00:01.862024, Avg_Epoch: 0:00:01.935278
# Epoch 120/300, Train Loss: 0.8782, Train Accuracy: 64.000       Val Loss: 1.0450, Val Accuracy: 59.016, Duration: 0:00:01.875987, Avg_Epoch: 0:00:01.934784
# Epoch 121/300, Train Loss: 0.8651, Train Accuracy: 64.545       Val Loss: 1.0806, Val Accuracy: 56.284, Duration: 0:00:01.883964, Avg_Epoch: 0:00:01.934364
# Epoch 122/300, Train Loss: 0.8571, Train Accuracy: 66.727       Val Loss: 1.0216, Val Accuracy: 59.016, Duration: 0:00:01.866013, Avg_Epoch: 0:00:01.933804
# Epoch 123/300, Train Loss: 0.8496, Train Accuracy: 65.273       Val Loss: 1.0300, Val Accuracy: 56.284, Duration: 0:00:01.845068, Avg_Epoch: 0:00:01.933083
# Epoch 124/300, Train Loss: 0.8917, Train Accuracy: 64.727       Val Loss: 1.1333, Val Accuracy: 52.459, Duration: 0:00:01.939815, Avg_Epoch: 0:00:01.933137
# Epoch 125/300, Train Loss: 0.9182, Train Accuracy: 61.455       Val Loss: 1.1403, Val Accuracy: 52.459, Duration: 0:00:01.851052, Avg_Epoch: 0:00:01.932480
# Epoch 126/300, Train Loss: 0.8776, Train Accuracy: 66.909       Val Loss: 1.0846, Val Accuracy: 52.459, Duration: 0:00:01.856040, Avg_Epoch: 0:00:01.931874
# Epoch 127/300, Train Loss: 0.8867, Train Accuracy: 63.091       Val Loss: 1.0340, Val Accuracy: 54.098, Duration: 0:00:01.846067, Avg_Epoch: 0:00:01.931198
# Epoch 128/300, Train Loss: 0.8748, Train Accuracy: 64.727       Val Loss: 1.0783, Val Accuracy: 52.459, Duration: 0:00:01.854044, Avg_Epoch: 0:00:01.930595
# Epoch 129/300, Train Loss: 0.8645, Train Accuracy: 65.455       Val Loss: 1.1618, Val Accuracy: 54.645, Duration: 0:00:01.837091, Avg_Epoch: 0:00:01.929870
# Epoch 130/300, Train Loss: 0.9003, Train Accuracy: 63.818       Val Loss: 1.0475, Val Accuracy: 52.459, Duration: 0:00:01.843073, Avg_Epoch: 0:00:01.929203
# Epoch 131/300, Train Loss: 0.8842, Train Accuracy: 63.273       Val Loss: 1.0706, Val Accuracy: 56.831, Duration: 0:00:01.830108, Avg_Epoch: 0:00:01.928446
# Epoch 132/300, Train Loss: 0.8811, Train Accuracy: 65.273       Val Loss: 1.1179, Val Accuracy: 54.098, Duration: 0:00:01.812156, Avg_Epoch: 0:00:01.927565
# Epoch 133/300, Train Loss: 0.8451, Train Accuracy: 67.636       Val Loss: 1.0137, Val Accuracy: 56.284, Duration: 0:00:01.814151, Avg_Epoch: 0:00:01.926713
# Epoch 134/300, Train Loss: 0.8468, Train Accuracy: 64.182       Val Loss: 1.0426, Val Accuracy: 56.284, Duration: 0:00:01.814151, Avg_Epoch: 0:00:01.925873
# Epoch 135/300, Train Loss: 0.8737, Train Accuracy: 65.091       Val Loss: 1.0480, Val Accuracy: 56.284, Duration: 0:00:01.877980, Avg_Epoch: 0:00:01.925518
# Epoch 136/300, Train Loss: 0.9062, Train Accuracy: 64.727       Val Loss: 1.0472, Val Accuracy: 59.016, Duration: 0:00:01.835095, Avg_Epoch: 0:00:01.924853
# Epoch 137/300, Train Loss: 0.8991, Train Accuracy: 64.727       Val Loss: 1.0666, Val Accuracy: 59.016, Duration: 0:00:01.863021, Avg_Epoch: 0:00:01.924402
# Epoch 138/300, Train Loss: 0.8532, Train Accuracy: 64.364       Val Loss: 1.0154, Val Accuracy: 56.831, Duration: 0:00:01.817143, Avg_Epoch: 0:00:01.923624
# Epoch 139/300, Train Loss: 0.8453, Train Accuracy: 66.364       Val Loss: 0.9995, Val Accuracy: 61.749, Duration: 0:00:01.815148, Avg_Epoch: 0:00:01.922844
# Epoch 140/300, Train Loss: 0.8106, Train Accuracy: 69.273       Val Loss: 1.0913, Val Accuracy: 54.645, Duration: 0:00:01.820135, Avg_Epoch: 0:00:01.922110
# Epoch 141/300, Train Loss: 0.8116, Train Accuracy: 67.455       Val Loss: 1.0105, Val Accuracy: 59.016, Duration: 0:00:01.830108, Avg_Epoch: 0:00:01.921458
# Epoch 142/300, Train Loss: 0.8274, Train Accuracy: 65.091       Val Loss: 1.0824, Val Accuracy: 57.923, Duration: 0:00:01.893938, Avg_Epoch: 0:00:01.921264
# Epoch 143/300, Train Loss: 0.7718, Train Accuracy: 67.091       Val Loss: 1.1398, Val Accuracy: 58.470, Duration: 0:00:01.814150, Avg_Epoch: 0:00:01.920515
# Epoch 144/300, Train Loss: 0.8523, Train Accuracy: 63.818       Val Loss: 1.1913, Val Accuracy: 52.459, Duration: 0:00:01.821132, Avg_Epoch: 0:00:01.919825
# Epoch 145/300, Train Loss: 0.8670, Train Accuracy: 66.727       Val Loss: 1.0493, Val Accuracy: 57.923, Duration: 0:00:01.823127, Avg_Epoch: 0:00:01.919158
# Epoch 146/300, Train Loss: 0.8445, Train Accuracy: 67.455       Val Loss: 1.0281, Val Accuracy: 57.923, Duration: 0:00:01.870999, Avg_Epoch: 0:00:01.918828
# Epoch 147/300, Train Loss: 0.8016, Train Accuracy: 68.000       Val Loss: 1.1270, Val Accuracy: 54.098, Duration: 0:00:01.819138, Avg_Epoch: 0:00:01.918150
# Epoch 148/300, Train Loss: 0.7706, Train Accuracy: 69.455       Val Loss: 1.0567, Val Accuracy: 57.377, Duration: 0:00:01.824124, Avg_Epoch: 0:00:01.917515
# Epoch 149/300, Train Loss: 0.7726, Train Accuracy: 69.273       Val Loss: 1.1035, Val Accuracy: 52.459, Duration: 0:00:01.861025, Avg_Epoch: 0:00:01.917135
# Epoch 150/300, Train Loss: 0.7716, Train Accuracy: 66.727       Val Loss: 1.1271, Val Accuracy: 55.191, Duration: 0:00:01.941810, Avg_Epoch: 0:00:01.917300
# Epoch 151/300, Train Loss: 0.7850, Train Accuracy: 69.273       Val Loss: 1.0913, Val Accuracy: 55.191, Duration: 0:00:01.833101, Avg_Epoch: 0:00:01.916742
# Epoch 152/300, Train Loss: 0.8255, Train Accuracy: 65.636       Val Loss: 1.0716, Val Accuracy: 54.098, Duration: 0:00:01.861027, Avg_Epoch: 0:00:01.916376
# Epoch 153/300, Train Loss: 0.8024, Train Accuracy: 67.636       Val Loss: 1.1997, Val Accuracy: 53.552, Duration: 0:00:01.932834, Avg_Epoch: 0:00:01.916483
# Epoch 154/300, Train Loss: 0.8263, Train Accuracy: 67.273       Val Loss: 1.0541, Val Accuracy: 58.470, Duration: 0:00:01.948792, Avg_Epoch: 0:00:01.916693
# Epoch 155/300, Train Loss: 0.7659, Train Accuracy: 67.818       Val Loss: 1.0855, Val Accuracy: 57.923, Duration: 0:00:01.952779, Avg_Epoch: 0:00:01.916926
# Epoch 156/300, Train Loss: 0.8154, Train Accuracy: 69.636       Val Loss: 1.0129, Val Accuracy: 59.016, Duration: 0:00:01.825121, Avg_Epoch: 0:00:01.916337
# Epoch 157/300, Train Loss: 0.7373, Train Accuracy: 68.000       Val Loss: 1.0228, Val Accuracy: 55.191, Duration: 0:00:01.840083, Avg_Epoch: 0:00:01.915852
# Epoch 158/300, Train Loss: 0.7213, Train Accuracy: 68.909       Val Loss: 1.0299, Val Accuracy: 53.552, Duration: 0:00:01.809165, Avg_Epoch: 0:00:01.915177
# Epoch 159/300, Train Loss: 0.7306, Train Accuracy: 70.182       Val Loss: 1.0665, Val Accuracy: 54.645, Duration: 0:00:01.873991, Avg_Epoch: 0:00:01.914918
# Epoch 160/300, Train Loss: 0.7478, Train Accuracy: 72.545       Val Loss: 1.0367, Val Accuracy: 56.831, Duration: 0:00:01.830109, Avg_Epoch: 0:00:01.914387
# Epoch 161/300, Train Loss: 0.7973, Train Accuracy: 69.455       Val Loss: 1.1758, Val Accuracy: 56.284, Duration: 0:00:01.837090, Avg_Epoch: 0:00:01.913907
# Epoch 162/300, Train Loss: 0.7137, Train Accuracy: 68.000       Val Loss: 1.1207, Val Accuracy: 56.284, Duration: 0:00:01.801185, Avg_Epoch: 0:00:01.913212
# Epoch 163/300, Train Loss: 0.7491, Train Accuracy: 71.636       Val Loss: 1.1531, Val Accuracy: 58.470, Duration: 0:00:01.807170, Avg_Epoch: 0:00:01.912561
# Epoch 164/300, Train Loss: 0.7838, Train Accuracy: 66.909       Val Loss: 1.0140, Val Accuracy: 60.656, Duration: 0:00:01.803181, Avg_Epoch: 0:00:01.911894
# Epoch 165/300, Train Loss: 0.7447, Train Accuracy: 68.909       Val Loss: 1.0396, Val Accuracy: 58.470, Duration: 0:00:01.838087, Avg_Epoch: 0:00:01.911447
# Epoch 166/300, Train Loss: 0.7688, Train Accuracy: 67.455       Val Loss: 1.1388, Val Accuracy: 57.377, Duration: 0:00:01.823127, Avg_Epoch: 0:00:01.910915
# Epoch 167/300, Train Loss: 0.7415, Train Accuracy: 72.000       Val Loss: 1.0280, Val Accuracy: 60.109, Duration: 0:00:01.855044, Avg_Epoch: 0:00:01.910580
# Epoch 168/300, Train Loss: 0.7669, Train Accuracy: 69.636       Val Loss: 1.0418, Val Accuracy: 58.470, Duration: 0:00:01.814151, Avg_Epoch: 0:00:01.910006
# Epoch 169/300, Train Loss: 0.7314, Train Accuracy: 70.182       Val Loss: 1.1158, Val Accuracy: 56.284, Duration: 0:00:01.804177, Avg_Epoch: 0:00:01.909380
# Epoch 170/300, Train Loss: 0.7519, Train Accuracy: 70.000       Val Loss: 0.9968, Val Accuracy: 62.842, Duration: 0:00:01.810163, Avg_Epoch: 0:00:01.908796
# Epoch 171/300, Train Loss: 0.7244, Train Accuracy: 73.273       Val Loss: 1.3461, Val Accuracy: 53.552, Duration: 0:00:01.851052, Avg_Epoch: 0:00:01.908459
# Epoch 172/300, Train Loss: 0.7407, Train Accuracy: 70.727       Val Loss: 1.1822, Val Accuracy: 54.645, Duration: 0:00:01.851052, Avg_Epoch: 0:00:01.908125
# Epoch 173/300, Train Loss: 0.8170, Train Accuracy: 67.636       Val Loss: 1.0004, Val Accuracy: 64.481, Duration: 0:00:01.859031, Avg_Epoch: 0:00:01.907841
# Epoch 174/300, Train Loss: 0.7679, Train Accuracy: 67.818       Val Loss: 1.0683, Val Accuracy: 57.923, Duration: 0:00:01.871997, Avg_Epoch: 0:00:01.907635
# Epoch 175/300, Train Loss: 0.7562, Train Accuracy: 69.636       Val Loss: 0.9677, Val Accuracy: 66.120, Duration: 0:00:01.825121, Avg_Epoch: 0:00:01.907164
# Epoch 176/300, Train Loss: 0.7836, Train Accuracy: 69.636       Val Loss: 1.2606, Val Accuracy: 52.459, Duration: 0:00:01.848061, Avg_Epoch: 0:00:01.906828
# Epoch 177/300, Train Loss: 0.8131, Train Accuracy: 69.273       Val Loss: 1.1305, Val Accuracy: 55.191, Duration: 0:00:01.817143, Avg_Epoch: 0:00:01.906321
# Epoch 178/300, Train Loss: 0.7723, Train Accuracy: 68.364       Val Loss: 0.9713, Val Accuracy: 65.027, Duration: 0:00:01.941810, Avg_Epoch: 0:00:01.906520
# Epoch 179/300, Train Loss: 0.7451, Train Accuracy: 69.636       Val Loss: 1.0332, Val Accuracy: 56.831, Duration: 0:00:01.865016, Avg_Epoch: 0:00:01.906289
# Epoch 180/300, Train Loss: 0.7467, Train Accuracy: 68.364       Val Loss: 1.1757, Val Accuracy: 56.284, Duration: 0:00:01.831106, Avg_Epoch: 0:00:01.905871
# Epoch 181/300, Train Loss: 0.7724, Train Accuracy: 69.273       Val Loss: 1.0418, Val Accuracy: 62.295, Duration: 0:00:01.816146, Avg_Epoch: 0:00:01.905375
# Epoch 182/300, Train Loss: 0.6695, Train Accuracy: 72.545       Val Loss: 1.0734, Val Accuracy: 55.738, Duration: 0:00:01.809164, Avg_Epoch: 0:00:01.904847
# Epoch 183/300, Train Loss: 0.7400, Train Accuracy: 69.455       Val Loss: 1.0389, Val Accuracy: 58.470, Duration: 0:00:01.862023, Avg_Epoch: 0:00:01.904613
# Epoch 184/300, Train Loss: 0.6223, Train Accuracy: 73.273       Val Loss: 0.9797, Val Accuracy: 60.656, Duration: 0:00:01.834099, Avg_Epoch: 0:00:01.904229
# Epoch 185/300, Train Loss: 0.6302, Train Accuracy: 75.636       Val Loss: 1.0687, Val Accuracy: 59.016, Duration: 0:00:01.839083, Avg_Epoch: 0:00:01.903877
# Epoch 186/300, Train Loss: 0.6798, Train Accuracy: 72.364       Val Loss: 1.0005, Val Accuracy: 59.563, Duration: 0:00:01.849059, Avg_Epoch: 0:00:01.903582
# Epoch 187/300, Train Loss: 0.6198, Train Accuracy: 76.727       Val Loss: 0.9995, Val Accuracy: 60.109, Duration: 0:00:01.805176, Avg_Epoch: 0:00:01.903056
# Epoch 188/300, Train Loss: 0.6207, Train Accuracy: 75.091       Val Loss: 1.0551, Val Accuracy: 57.377, Duration: 0:00:01.827116, Avg_Epoch: 0:00:01.902652
# Epoch 189/300, Train Loss: 0.6070, Train Accuracy: 75.273       Val Loss: 1.1703, Val Accuracy: 59.016, Duration: 0:00:01.838088, Avg_Epoch: 0:00:01.902311
# Epoch 190/300, Train Loss: 0.6457, Train Accuracy: 75.455       Val Loss: 1.1957, Val Accuracy: 58.470, Duration: 0:00:01.815149, Avg_Epoch: 0:00:01.901852
# Epoch 191/300, Train Loss: 0.6403, Train Accuracy: 75.636       Val Loss: 1.1621, Val Accuracy: 54.645, Duration: 0:00:01.793207, Avg_Epoch: 0:00:01.901283
# Epoch 192/300, Train Loss: 0.6701, Train Accuracy: 73.455       Val Loss: 1.2481, Val Accuracy: 55.738, Duration: 0:00:01.799191, Avg_Epoch: 0:00:01.900751
# Epoch 193/300, Train Loss: 0.5898, Train Accuracy: 76.182       Val Loss: 0.9817, Val Accuracy: 66.667, Duration: 0:00:01.837091, Avg_Epoch: 0:00:01.900421
# Epoch 194/300, Train Loss: 0.7005, Train Accuracy: 71.636       Val Loss: 1.1085, Val Accuracy: 59.563, Duration: 0:00:01.813154, Avg_Epoch: 0:00:01.899972
# Epoch 195/300, Train Loss: 0.6486, Train Accuracy: 72.909       Val Loss: 1.0774, Val Accuracy: 59.016, Duration: 0:00:01.867009, Avg_Epoch: 0:00:01.899803
# Epoch 196/300, Train Loss: 0.6562, Train Accuracy: 73.273       Val Loss: 1.5860, Val Accuracy: 51.366, Duration: 0:00:01.801186, Avg_Epoch: 0:00:01.899299
# Epoch 197/300, Train Loss: 0.7794, Train Accuracy: 71.273       Val Loss: 1.1366, Val Accuracy: 55.738, Duration: 0:00:01.811160, Avg_Epoch: 0:00:01.898852
# Epoch 198/300, Train Loss: 0.7747, Train Accuracy: 67.818       Val Loss: 1.1056, Val Accuracy: 59.563, Duration: 0:00:01.798193, Avg_Epoch: 0:00:01.898344
# Epoch 199/300, Train Loss: 0.6451, Train Accuracy: 73.636       Val Loss: 1.2666, Val Accuracy: 56.284, Duration: 0:00:01.797197, Avg_Epoch: 0:00:01.897835
# Epoch 200/300, Train Loss: 0.6573, Train Accuracy: 74.182       Val Loss: 1.0345, Val Accuracy: 59.016, Duration: 0:00:01.816146, Avg_Epoch: 0:00:01.897427
# Epoch 201/300, Train Loss: 0.6633, Train Accuracy: 74.182       Val Loss: 1.2248, Val Accuracy: 53.552, Duration: 0:00:01.816146, Avg_Epoch: 0:00:01.897023
# Epoch 202/300, Train Loss: 0.7364, Train Accuracy: 72.000       Val Loss: 1.0566, Val Accuracy: 58.470, Duration: 0:00:01.823127, Avg_Epoch: 0:00:01.896657
# Epoch 203/300, Train Loss: 0.6273, Train Accuracy: 73.818       Val Loss: 1.0946, Val Accuracy: 57.923, Duration: 0:00:01.824124, Avg_Epoch: 0:00:01.896299
# Epoch 204/300, Train Loss: 0.6449, Train Accuracy: 74.000       Val Loss: 1.1979, Val Accuracy: 55.738, Duration: 0:00:01.802184, Avg_Epoch: 0:00:01.895838
# Epoch 205/300, Train Loss: 0.6588, Train Accuracy: 72.364       Val Loss: 1.2280, Val Accuracy: 53.005, Duration: 0:00:01.810162, Avg_Epoch: 0:00:01.895420
# Epoch 206/300, Train Loss: 0.6749, Train Accuracy: 74.545       Val Loss: 1.0267, Val Accuracy: 60.109, Duration: 0:00:01.824124, Avg_Epoch: 0:00:01.895074
# Epoch 207/300, Train Loss: 0.6675, Train Accuracy: 73.091       Val Loss: 1.0463, Val Accuracy: 57.923, Duration: 0:00:01.812157, Avg_Epoch: 0:00:01.894674
# Epoch 208/300, Train Loss: 0.6544, Train Accuracy: 73.636       Val Loss: 1.1317, Val Accuracy: 59.563, Duration: 0:00:01.864018, Avg_Epoch: 0:00:01.894526
# Epoch 209/300, Train Loss: 0.6393, Train Accuracy: 75.091       Val Loss: 1.1181, Val Accuracy: 59.563, Duration: 0:00:01.799192, Avg_Epoch: 0:00:01.894070
# Epoch 210/300, Train Loss: 0.6052, Train Accuracy: 73.273       Val Loss: 1.0576, Val Accuracy: 59.016, Duration: 0:00:01.797198, Avg_Epoch: 0:00:01.893609
# Epoch 211/300, Train Loss: 0.6704, Train Accuracy: 74.000       Val Loss: 1.0393, Val Accuracy: 61.749, Duration: 0:00:01.808167, Avg_Epoch: 0:00:01.893204
# Epoch 212/300, Train Loss: 0.5934, Train Accuracy: 77.455       Val Loss: 1.1650, Val Accuracy: 56.284, Duration: 0:00:01.807171, Avg_Epoch: 0:00:01.892798
# Epoch 213/300, Train Loss: 0.6023, Train Accuracy: 77.636       Val Loss: 1.0841, Val Accuracy: 59.563, Duration: 0:00:01.820134, Avg_Epoch: 0:00:01.892457
# Epoch 214/300, Train Loss: 0.6152, Train Accuracy: 76.182       Val Loss: 1.0213, Val Accuracy: 63.934, Duration: 0:00:01.820136, Avg_Epoch: 0:00:01.892119
# Epoch 215/300, Train Loss: 0.6063, Train Accuracy: 78.364       Val Loss: 1.1043, Val Accuracy: 57.923, Duration: 0:00:01.797196, Avg_Epoch: 0:00:01.891677
# Epoch 216/300, Train Loss: 0.5320, Train Accuracy: 78.545       Val Loss: 1.0641, Val Accuracy: 61.202, Duration: 0:00:01.797196, Avg_Epoch: 0:00:01.891240
# Epoch 217/300, Train Loss: 0.5839, Train Accuracy: 77.455       Val Loss: 1.0956, Val Accuracy: 61.202, Duration: 0:00:01.805175, Avg_Epoch: 0:00:01.890843
# Epoch 218/300, Train Loss: 0.6594, Train Accuracy: 75.273       Val Loss: 1.1478, Val Accuracy: 59.016, Duration: 0:00:01.813153, Avg_Epoch: 0:00:01.890487
# Epoch 219/300, Train Loss: 0.6352, Train Accuracy: 75.636       Val Loss: 1.2913, Val Accuracy: 60.109, Duration: 0:00:01.829111, Avg_Epoch: 0:00:01.890207
# Epoch 220/300, Train Loss: 0.6620, Train Accuracy: 75.636       Val Loss: 1.1723, Val Accuracy: 59.016, Duration: 0:00:01.847064, Avg_Epoch: 0:00:01.890011
# Epoch 221/300, Train Loss: 0.6180, Train Accuracy: 75.455       Val Loss: 1.2377, Val Accuracy: 58.470, Duration: 0:00:01.796199, Avg_Epoch: 0:00:01.889586
# Epoch 222/300, Train Loss: 0.5931, Train Accuracy: 74.364       Val Loss: 1.2233, Val Accuracy: 61.202, Duration: 0:00:01.802185, Avg_Epoch: 0:00:01.889192
# Epoch 223/300, Train Loss: 0.5951, Train Accuracy: 77.273       Val Loss: 1.1993, Val Accuracy: 60.656, Duration: 0:00:01.796198, Avg_Epoch: 0:00:01.888775
# Epoch 224/300, Train Loss: 0.4931, Train Accuracy: 80.909       Val Loss: 1.0925, Val Accuracy: 62.842, Duration: 0:00:01.806172, Avg_Epoch: 0:00:01.888407
# Epoch 225/300, Train Loss: 0.4731, Train Accuracy: 82.364       Val Loss: 1.2867, Val Accuracy: 59.016, Duration: 0:00:01.834098, Avg_Epoch: 0:00:01.888165
# Epoch 226/300, Train Loss: 0.5447, Train Accuracy: 81.273       Val Loss: 1.1037, Val Accuracy: 59.563, Duration: 0:00:01.809165, Avg_Epoch: 0:00:01.887816
# Epoch 227/300, Train Loss: 0.5139, Train Accuracy: 80.182       Val Loss: 1.1194, Val Accuracy: 57.923, Duration: 0:00:01.805177, Avg_Epoch: 0:00:01.887452
# Epoch 228/300, Train Loss: 0.5245, Train Accuracy: 79.273       Val Loss: 1.1794, Val Accuracy: 56.284, Duration: 0:00:01.800187, Avg_Epoch: 0:00:01.887069
# Epoch 229/300, Train Loss: 0.5613, Train Accuracy: 77.273       Val Loss: 1.2949, Val Accuracy: 54.098, Duration: 0:00:01.796200, Avg_Epoch: 0:00:01.886672
# Epoch 230/300, Train Loss: 0.6078, Train Accuracy: 76.727       Val Loss: 1.1617, Val Accuracy: 60.656, Duration: 0:00:01.816146, Avg_Epoch: 0:00:01.886365
# Epoch 231/300, Train Loss: 0.6619, Train Accuracy: 72.545       Val Loss: 1.2248, Val Accuracy: 55.191, Duration: 0:00:01.828113, Avg_Epoch: 0:00:01.886113
# Epoch 232/300, Train Loss: 0.6255, Train Accuracy: 75.636       Val Loss: 1.2117, Val Accuracy: 53.552, Duration: 0:00:01.817143, Avg_Epoch: 0:00:01.885816
# Epoch 233/300, Train Loss: 0.5513, Train Accuracy: 78.000       Val Loss: 1.2086, Val Accuracy: 59.016, Duration: 0:00:01.813154, Avg_Epoch: 0:00:01.885504
# Epoch 234/300, Train Loss: 0.5381, Train Accuracy: 81.273       Val Loss: 1.1671, Val Accuracy: 60.109, Duration: 0:00:01.794205, Avg_Epoch: 0:00:01.885114
# Epoch 235/300, Train Loss: 0.5372, Train Accuracy: 79.273       Val Loss: 1.0993, Val Accuracy: 59.563, Duration: 0:00:01.798194, Avg_Epoch: 0:00:01.884744
# Epoch 236/300, Train Loss: 0.5097, Train Accuracy: 80.909       Val Loss: 1.0729, Val Accuracy: 64.481, Duration: 0:00:01.816146, Avg_Epoch: 0:00:01.884453
# Epoch 237/300, Train Loss: 0.4908, Train Accuracy: 81.636       Val Loss: 1.1552, Val Accuracy: 59.016, Duration: 0:00:01.849058, Avg_Epoch: 0:00:01.884304
# Epoch 238/300, Train Loss: 0.5198, Train Accuracy: 81.091       Val Loss: 1.3007, Val Accuracy: 60.656, Duration: 0:00:01.816145, Avg_Epoch: 0:00:01.884018
# Epoch 239/300, Train Loss: 0.5931, Train Accuracy: 77.273       Val Loss: 1.2510, Val Accuracy: 56.284, Duration: 0:00:01.796199, Avg_Epoch: 0:00:01.883650
# Epoch 240/300, Train Loss: 0.6169, Train Accuracy: 78.182       Val Loss: 1.2810, Val Accuracy: 56.284, Duration: 0:00:01.814150, Avg_Epoch: 0:00:01.883361
# Epoch 241/300, Train Loss: 0.5416, Train Accuracy: 81.273       Val Loss: 1.3747, Val Accuracy: 55.191, Duration: 0:00:01.810162, Avg_Epoch: 0:00:01.883057
# Epoch 242/300, Train Loss: 0.6216, Train Accuracy: 74.909       Val Loss: 1.0899, Val Accuracy: 62.295, Duration: 0:00:01.818141, Avg_Epoch: 0:00:01.882789
# Epoch 243/300, Train Loss: 0.5263, Train Accuracy: 80.182       Val Loss: 1.1470, Val Accuracy: 60.656, Duration: 0:00:01.865015, Avg_Epoch: 0:00:01.882716
# Epoch 244/300, Train Loss: 0.5087, Train Accuracy: 78.545       Val Loss: 1.2115, Val Accuracy: 59.016, Duration: 0:00:01.811160, Avg_Epoch: 0:00:01.882422
# Epoch 245/300, Train Loss: 0.5116, Train Accuracy: 81.273       Val Loss: 1.1590, Val Accuracy: 61.202, Duration: 0:00:01.806172, Avg_Epoch: 0:00:01.882111
# Epoch 246/300, Train Loss: 0.5225, Train Accuracy: 82.727       Val Loss: 1.0672, Val Accuracy: 60.656, Duration: 0:00:01.833100, Avg_Epoch: 0:00:01.881912
# Epoch 247/300, Train Loss: 0.4738, Train Accuracy: 81.818       Val Loss: 1.1807, Val Accuracy: 61.202, Duration: 0:00:01.824125, Avg_Epoch: 0:00:01.881678
# Epoch 248/300, Train Loss: 0.5128, Train Accuracy: 79.273       Val Loss: 1.1161, Val Accuracy: 58.470, Duration: 0:00:01.812157, Avg_Epoch: 0:00:01.881398
# Epoch 249/300, Train Loss: 0.5358, Train Accuracy: 79.636       Val Loss: 1.3197, Val Accuracy: 54.098, Duration: 0:00:01.805175, Avg_Epoch: 0:00:01.881091
# Epoch 250/300, Train Loss: 0.5494, Train Accuracy: 77.818       Val Loss: 1.3706, Val Accuracy: 57.923, Duration: 0:00:01.807169, Avg_Epoch: 0:00:01.880796
# Epoch 251/300, Train Loss: 0.5659, Train Accuracy: 77.818       Val Loss: 1.0949, Val Accuracy: 59.563, Duration: 0:00:01.846066, Avg_Epoch: 0:00:01.880657
# Epoch 252/300, Train Loss: 0.5018, Train Accuracy: 81.455       Val Loss: 1.3408, Val Accuracy: 59.016, Duration: 0:00:01.822130, Avg_Epoch: 0:00:01.880425
# Epoch 253/300, Train Loss: 0.4788, Train Accuracy: 80.000       Val Loss: 1.2907, Val Accuracy: 56.831, Duration: 0:00:01.829110, Avg_Epoch: 0:00:01.880222
# Epoch 254/300, Train Loss: 0.5212, Train Accuracy: 79.273       Val Loss: 1.0784, Val Accuracy: 61.749, Duration: 0:00:01.803182, Avg_Epoch: 0:00:01.879919
# Epoch 255/300, Train Loss: 0.4366, Train Accuracy: 84.000       Val Loss: 1.2629, Val Accuracy: 54.098, Duration: 0:00:01.874988, Avg_Epoch: 0:00:01.879900
# Epoch 256/300, Train Loss: 0.4422, Train Accuracy: 82.182       Val Loss: 1.2743, Val Accuracy: 60.109, Duration: 0:00:01.815148, Avg_Epoch: 0:00:01.879647
# Epoch 257/300, Train Loss: 0.3759, Train Accuracy: 85.455       Val Loss: 1.2145, Val Accuracy: 63.934, Duration: 0:00:01.828114, Avg_Epoch: 0:00:01.879446
# Epoch 258/300, Train Loss: 0.4255, Train Accuracy: 84.727       Val Loss: 1.0480, Val Accuracy: 66.667, Duration: 0:00:01.807170, Avg_Epoch: 0:00:01.879166
# Epoch 259/300, Train Loss: 0.4291, Train Accuracy: 82.909       Val Loss: 1.1073, Val Accuracy: 63.388, Duration: 0:00:01.813154, Avg_Epoch: 0:00:01.878911
# Epoch 260/300, Train Loss: 0.4335, Train Accuracy: 84.182       Val Loss: 1.2351, Val Accuracy: 61.202, Duration: 0:00:01.806174, Avg_Epoch: 0:00:01.878631
# Epoch 261/300, Train Loss: 0.4763, Train Accuracy: 83.455       Val Loss: 1.2575, Val Accuracy: 63.388, Duration: 0:00:01.813153, Avg_Epoch: 0:00:01.878381
# Epoch 262/300, Train Loss: 0.4759, Train Accuracy: 83.091       Val Loss: 1.2975, Val Accuracy: 61.202, Duration: 0:00:01.822130, Avg_Epoch: 0:00:01.878166
# Epoch 263/300, Train Loss: 0.4194, Train Accuracy: 84.364       Val Loss: 1.1129, Val Accuracy: 59.563, Duration: 0:00:01.861026, Avg_Epoch: 0:00:01.878101
# Epoch 264/300, Train Loss: 0.4517, Train Accuracy: 83.455       Val Loss: 1.2240, Val Accuracy: 62.295, Duration: 0:00:01.822129, Avg_Epoch: 0:00:01.877889
# Epoch 265/300, Train Loss: 0.3990, Train Accuracy: 85.091       Val Loss: 1.1137, Val Accuracy: 63.388, Duration: 0:00:01.801186, Avg_Epoch: 0:00:01.877599
# Epoch 266/300, Train Loss: 0.4376, Train Accuracy: 83.455       Val Loss: 1.2355, Val Accuracy: 60.109, Duration: 0:00:01.811159, Avg_Epoch: 0:00:01.877349
# Epoch 267/300, Train Loss: 0.4606, Train Accuracy: 81.273       Val Loss: 1.1940, Val Accuracy: 62.295, Duration: 0:00:01.851052, Avg_Epoch: 0:00:01.877251
# Epoch 268/300, Train Loss: 0.4407, Train Accuracy: 84.000       Val Loss: 1.3672, Val Accuracy: 59.016, Duration: 0:00:01.823127, Avg_Epoch: 0:00:01.877049
# Epoch 269/300, Train Loss: 0.4221, Train Accuracy: 84.182       Val Loss: 1.2616, Val Accuracy: 61.749, Duration: 0:00:01.830108, Avg_Epoch: 0:00:01.876875
# Epoch 270/300, Train Loss: 0.4273, Train Accuracy: 83.818       Val Loss: 1.2226, Val Accuracy: 63.934, Duration: 0:00:01.837090, Avg_Epoch: 0:00:01.876727
# Epoch 271/300, Train Loss: 0.5203, Train Accuracy: 80.727       Val Loss: 1.3775, Val Accuracy: 56.831, Duration: 0:00:01.802183, Avg_Epoch: 0:00:01.876452
# Epoch 272/300, Train Loss: 0.6550, Train Accuracy: 74.364       Val Loss: 1.5541, Val Accuracy: 55.191, Duration: 0:00:01.826119, Avg_Epoch: 0:00:01.876267
# Epoch 273/300, Train Loss: 0.7773, Train Accuracy: 70.000       Val Loss: 1.2696, Val Accuracy: 56.284, Duration: 0:00:01.819137, Avg_Epoch: 0:00:01.876058
# Epoch 274/300, Train Loss: 0.6522, Train Accuracy: 76.000       Val Loss: 1.4725, Val Accuracy: 56.284, Duration: 0:00:01.822131, Avg_Epoch: 0:00:01.875861
# Epoch 275/300, Train Loss: 0.6654, Train Accuracy: 74.364       Val Loss: 1.0978, Val Accuracy: 62.295, Duration: 0:00:01.831105, Avg_Epoch: 0:00:01.875698
# Epoch 276/300, Train Loss: 0.6556, Train Accuracy: 76.545       Val Loss: 1.2334, Val Accuracy: 53.005, Duration: 0:00:01.803181, Avg_Epoch: 0:00:01.875435
# Epoch 277/300, Train Loss: 0.6631, Train Accuracy: 75.091       Val Loss: 1.2703, Val Accuracy: 57.923, Duration: 0:00:01.812156, Avg_Epoch: 0:00:01.875207
# Epoch 278/300, Train Loss: 0.6245, Train Accuracy: 75.273       Val Loss: 1.0082, Val Accuracy: 59.563, Duration: 0:00:01.799191, Avg_Epoch: 0:00:01.874934
# Epoch 279/300, Train Loss: 0.4864, Train Accuracy: 80.545       Val Loss: 1.0533, Val Accuracy: 56.831, Duration: 0:00:01.796199, Avg_Epoch: 0:00:01.874651
# Epoch 280/300, Train Loss: 0.4526, Train Accuracy: 82.909       Val Loss: 1.0607, Val Accuracy: 61.749, Duration: 0:00:01.818141, Avg_Epoch: 0:00:01.874450
# Epoch 281/300, Train Loss: 0.4424, Train Accuracy: 83.818       Val Loss: 1.2942, Val Accuracy: 56.831, Duration: 0:00:01.834098, Avg_Epoch: 0:00:01.874306
# Epoch 282/300, Train Loss: 0.4528, Train Accuracy: 84.000       Val Loss: 1.0136, Val Accuracy: 64.481, Duration: 0:00:01.825121, Avg_Epoch: 0:00:01.874132
# Epoch 283/300, Train Loss: 0.4359, Train Accuracy: 84.364       Val Loss: 1.1766, Val Accuracy: 60.109, Duration: 0:00:01.810163, Avg_Epoch: 0:00:01.873906
# Epoch 284/300, Train Loss: 0.4531, Train Accuracy: 82.182       Val Loss: 1.2906, Val Accuracy: 58.470, Duration: 0:00:01.804177, Avg_Epoch: 0:00:01.873660
# Epoch 285/300, Train Loss: 0.4443, Train Accuracy: 81.091       Val Loss: 1.2249, Val Accuracy: 59.563, Duration: 0:00:01.803180, Avg_Epoch: 0:00:01.873413
# Epoch 286/300, Train Loss: 0.4585, Train Accuracy: 82.727       Val Loss: 1.1515, Val Accuracy: 60.656, Duration: 0:00:01.800189, Avg_Epoch: 0:00:01.873157
# Epoch 287/300, Train Loss: 0.3360, Train Accuracy: 88.364       Val Loss: 1.0765, Val Accuracy: 63.388, Duration: 0:00:01.810162, Avg_Epoch: 0:00:01.872937
# Epoch 288/300, Train Loss: 0.3552, Train Accuracy: 88.000       Val Loss: 1.1589, Val Accuracy: 63.934, Duration: 0:00:01.815148, Avg_Epoch: 0:00:01.872737
# Epoch 289/300, Train Loss: 0.4163, Train Accuracy: 84.000       Val Loss: 1.2901, Val Accuracy: 60.109, Duration: 0:00:01.828115, Avg_Epoch: 0:00:01.872582
# Epoch 290/300, Train Loss: 0.4171, Train Accuracy: 84.909       Val Loss: 1.1850, Val Accuracy: 59.563, Duration: 0:00:01.837091, Avg_Epoch: 0:00:01.872460
# Epoch 291/300, Train Loss: 0.3780, Train Accuracy: 84.545       Val Loss: 1.2849, Val Accuracy: 60.656, Duration: 0:00:01.810161, Avg_Epoch: 0:00:01.872246
# Epoch 292/300, Train Loss: 0.3996, Train Accuracy: 85.091       Val Loss: 1.0949, Val Accuracy: 62.842, Duration: 0:00:01.802183, Avg_Epoch: 0:00:01.872006
# Epoch 293/300, Train Loss: 0.5393, Train Accuracy: 78.909       Val Loss: 1.2635, Val Accuracy: 61.202, Duration: 0:00:01.803182, Avg_Epoch: 0:00:01.871771
# Epoch 294/300, Train Loss: 0.4084, Train Accuracy: 83.455       Val Loss: 1.3426, Val Accuracy: 54.645, Duration: 0:00:01.805175, Avg_Epoch: 0:00:01.871544
# Epoch 295/300, Train Loss: 0.4614, Train Accuracy: 85.273       Val Loss: 1.4285, Val Accuracy: 59.016, Duration: 0:00:01.805175, Avg_Epoch: 0:00:01.871319
# Epoch 296/300, Train Loss: 0.6009, Train Accuracy: 76.909       Val Loss: 1.1354, Val Accuracy: 55.191, Duration: 0:00:01.824123, Avg_Epoch: 0:00:01.871160
# Epoch 297/300, Train Loss: 0.4753, Train Accuracy: 82.545       Val Loss: 1.0653, Val Accuracy: 63.388, Duration: 0:00:01.834098, Avg_Epoch: 0:00:01.871035
# Epoch 298/300, Train Loss: 0.4209, Train Accuracy: 81.091       Val Loss: 1.1200, Val Accuracy: 59.016, Duration: 0:00:01.818141, Avg_Epoch: 0:00:01.870858
# Epoch 299/300, Train Loss: 0.4031, Train Accuracy: 83.091       Val Loss: 1.2121, Val Accuracy: 60.109, Duration: 0:00:01.821131, Avg_Epoch: 0:00:01.870691
# Epoch 300/300, Train Loss: 0.4106, Train Accuracy: 86.182       Val Loss: 1.1580, Val Accuracy: 61.202, Duration: 0:00:01.799192, Avg_Epoch: 0:00:01.870453

# %%
images, labels = val_dataiter.next()
out_img, predicted = torch.max(model(images.to(device)), 1)
imshow(images[:7], labels[:7], predicted[:7])

# %%
# Plot the train loss and test loss per iteration
plt.figure(figsize=(12, 6))
plt.plot(train_losses, label='train loss')
plt.plot(val_losses, label='val loss')
plt.title('Training vs Validation Cross-Entropy Loss')
plt.xlabel('Epochs')
plt.ylabel('Average Loss')
plt.legend()
plt.show()

# %%
test_loss = []
test_acc = []
n_correct = 0.
n_total = 0.
confusion_matrix = np.zeros((n_classes, n_classes))

model.eval()
with torch.no_grad():
    for inputs, targets in Dte:
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = model(inputs)

        # Get the predictions
        # torch.max returns both max and argmax
        __, out_label = outputs.max(dim=1)
        # Updates the accuracy with every pass
        n_correct += (out_label == targets).sum().item()
        n_total += targets.shape[0]
        for t, p in zip(targets.view(-1), out_label.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1
        test_acc.append(n_correct / n_total)

        loss = loss_fn(outputs, targets)
        test_loss.append(loss.item())
test_loss = np.mean(test_loss)
avg_acc = np.mean(test_acc)*100
print('The total number of samples for Training is: {}, Validation: {}, and Testing: {}'.format(len(Dtr)*batch_size, len(Dva)*batch_size, len(Dte)*batch_size))
print('Average loss across the testing data: {}, Average testing accuracy: {}'.format(test_loss, avg_acc))
# Out:
# The total number of samples for Training is: 640, Validation: 256, and Testing: 256
# Average loss across the testing data: 1.3257624506950378, Average testing accuracy: 64.09646739130434

# %%
plt.figure(figsize=(15,10))

class_names = list(classes)
cm_df = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(cm_df, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# ### 5 Class Sipakmed
#
# batches = 96, image size = 160
# model = CCT(
#         img_size=img_size,      # Input image size
#         in_channels=3,  # Number of channels for the image
#         patch_size=4,   # How big our patches are
#         embed_dim=42,   # Embedding dim
#         n_layers=4,     # Number of transformer encoders
#         n_conv=2,       # Number of convolutional layers
#         n_heads=6,      # Number of attention heads
#         attn_dropout=0.,        # Attention Dropout
#         proj_dropout=0.,        # (MHA) Projection Dropout
#         mlp_dropout=0.1,        # (MHA) last layer dropout
#         mlp_ratio=2,    # (MHA) Projection FF dimension
#         qkv_bias = True,
#         n_classes=5     # Number of classes to classify
#         )
# epochs = 300, avg loss = 0.1707, avg acc = 95.27
#
# ### 3 Class Sipakmed and Herlev
#
# batches = 96, image size = 160
# model = CCT(
#         img_size=img_size,      # Input image size
#         in_channels=3,  # Number of channels for the image
#         patch_size=4,   # How big our patches are
#         embed_dim=42,   # Embedding dim
#         n_layers=4,     # Number of transformer encoders
#         n_conv=2,       # Number of convolutional layers
#         n_heads=6,      # Number of attention heads
#         attn_dropout=0.,        # Attention Dropout
#         proj_dropout=0.,        # (MHA) Projection Dropout
#         mlp_dropout=0.1,        # (MHA) last layer dropout
#         mlp_ratio=2,    # (MHA) Projection FF dimension
#         qkv_bias = True,
#         n_classes=3     # Number of classes to classify
#         )
# epochs = 300, avg loss = 0.1668, avg acc = 95.41
#
# ### 7 Class Herlev
#
# batches = 64, image size = 84
# model = CCT(
#         img_size=img_size,      # Input image size
#         in_channels=3,  # Number of channels for the image
#         patch_size=4,   # How big our patches are
#         embed_dim=128,   # Embedding dim
#         n_layers=2,     # Number of transformer encoders
#         n_conv=2,       # Number of convolutional layers
#         n_heads=2,      # Number of attention heads
#         attn_dropout=0.,        # Attention Dropout
#         proj_dropout=0.,        # (MHA) Projection Dropout
#         mlp_dropout=0.1,        # (MHA) last layer dropout
#         mlp_ratio=1,    # (MHA) Projection FF dimension
#         qkv_bias = True,
#         n_classes=7     # Number of classes to classify
#         )
# epochs = 100, avg loss = 1.520, avg acc = 62.20

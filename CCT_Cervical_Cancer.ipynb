# %%
import os
from PIL import Image
import torch
from torch.utils.data import DataLoader,Dataset
import torch.nn as nn
from torch import Tensor
import torchvision
import torchvision.transforms as transforms
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import torch.nn.functional as F
import seaborn as sns
from datetime import datetime
from sklearn.model_selection import train_test_split

torch.manual_seed(17)

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
torch.backends.cudnn.benchmark = True

# %% [markdown]
# # A Compact Convolutional Vision Transformer or CCT
# *Created using the walkthrough from https://medium.com/pytorch/training-compact-transformers-from-scratch-in-30-minutes-with-pytorch-ff5c21668ed5 and Dr Prashant's Vision_Transformer file

# %% [markdown]
# ## Building the Transformer block by block

# %% [markdown]
# Every part/layer of the transformer is built using the Pytorch nn.module class which allows for easy creation of maching learning models. Each layer should be made up of at least two parts: An initialization function which uses the given information to build the class and then the 'Forward' function defines how the class will run when it is called.

# %% [markdown]
# ### Transformer Constructor
#
# First, the actual ViT Constructor which essentially acts as a hub. It ensures that each part of the transformer is called in the correct order and that local variables can be passed along.

# %% [markdown]
# ### What makes it more Compact/Lite than the CVT?
#
# The only difference between this and the original Vision Transformer is a Sequence Pooling layer and a convolutional layer instead of patching. Previously the classes were embedded separately and then passed to the MLP for classification. Sequence Pooling ties the class information in with every other parameter.. I think.

# %%
class CCT(nn.Module):
    '''
    Simplified implementation of the Vision transformer.

    Parameters
    ----------
    img_size: int
        Both height and width of the image (if it is a square)
    in_channels: int
        Number of input channels
    patch_size: int
        Both height and width of the patch (if it is a square)
    embed_dim: int
        The embedding size for each token
    n_layers: int
        Number of transformer blocks
    n_heads: int
        Number of attention heads
    attn_dropout, proj_dropout, mlp_dropout: float
        Dropout probability
    mlp_ratio: float
        Determine the hidden dimension of the MLP module
    qkv_bias: bool
        If true then we add bias to the query, key and value projections
    n_classes: int
        Number of classes

    Attributes
    -----------
    n_patches: int
        Number of patches that can be taken from each image based on size.
    patch_embed: PatchEmbed
        Sets up the `Patching' layer.
    class_embed: nn.Parameter
        Learnable parameter that will represent the first class token in the sequence.
        It has `embed_dim' elements.
    pos_embed: nn.Parameter
        Adds a positional encoding to every token.
    pos_drop: nn.Dropout
        Dropout layer.
    tr_block: nn.ModuleList
        Instance of 'TransformerEncoderLayer'.
    norm: nn.Layernorm
        Layer normalization.
    '''
    def __init__(self,
                 img_size=32,   # The square size of each image
                 in_channels=3, # Number of channels for each image (eg: Grayscale=1, RGB=3)
                 patch_size=4,  # The square size of each patch
                 embed_dim=768,  # Embedding dimension
                 n_layers=3, # How many times to run the transformer encoder
                 n_conv=2, # How many times to run the convolutional filter
                 n_heads=3,   # Number of attention heads,
                 attn_dropout=0.,  # Attention Dropout
                 proj_dropout=0.,   # (MHA) Projection Dropout
                 mlp_dropout=0.,   # (MHA) last layer dropout
                 mlp_ratio=4,   # (MHA) Projection FF dimension
                 qkv_bias = True,
                 n_class=10   # Number of classes to classify
    ):
        super().__init__()
        # Provides an error if the patching size is not divisible by the image size.
        assert img_size % patch_size == 0, \
            print("Given image size ({}) has to be divisible by given patch size ({})".format(img_size, patch_size))
        
        self.conv_embed = Conv_Embed(img_size, in_channels, embed_dim, n_conv)
        n_patches = self.conv_embed.sequence_length(in_channels=in_channels, height=img_size, width=img_size)
        hidden_dim = int(embed_dim * mlp_ratio)
        
        
        self.pos_embed = nn.Parameter(torch.zeros(1, n_patches, embed_dim)) # nn.Parameter makes this learnable weights
        
        # Can use this to enable Sinusoidal PE
        #self.pos_embed = PositionalEmbedding(1, n_patches + 1, embed_dim)

        self.pos_drop = nn.Dropout(p=proj_dropout)
        self.tr_block = nn.ModuleList(
            [
                TransformerEncoderLayer(
                    embed_dim,
                    n_heads,
                    qkv_bias,
                    attn_dropout,
                    proj_dropout,
                    mlp_dropout,
                    hidden_dim
                    )
                for _ in range(n_layers)
            ]   # Sends data through the encoder n times
        )
        self.norm = nn.LayerNorm(embed_dim, eps=1e-6)
        
        self.attention_pool = nn.Linear(embed_dim, 1)
                                    
        self.head = nn.Linear(embed_dim, n_class)

    def forward(self, x):
        '''
        Defines how the class will run

        Parameters
        ----------
        x: torch.Tensor
            shape: n_samples, in_chains, img_size, img_size

        Returns
        ---------
        logits: torch.Tensor
            Logits over all the classes: n_samples, n_samples
        '''
        x = self.conv_embed(x)
        #x = self.pos_embed(x)
        
        x += self.pos_embed
        x = self.pos_drop(x)
        for tr_block in self.tr_block:
            x = tr_block(x)
        x = self.norm(x)
        
        #Added Sequence Pooling instead of Class embedding
        x = torch.matmul(F.softmax(self.attention_pool(x), dim=1).transpose(-1, -2), x).squeeze(-2)
    
        x = self.head(x)
        return x

# %% [markdown]
# ### Positional Embedding
#
# This is the sinusoidal positional encoding layer as seen in the original 'Attention is All You Need' paper. It basically uses a sin/cos waveform to provide a unique positional offset that is given to a token at the corresponding position in its embedding space.
#
# By default, this is disabled and we instead use a trainable matrix of zeros. This adds another dimension to our data that the model then uses to find the best weights for the data's position itself. This is called "learnable" positional encoding.
#
# There are pros-and-cons to either, but essentially: sinusoidal is better when there are not a lot of data samples to learn the positional data from but you can get better results from "learnable" with larger datasets.

# %%
class PositionalEmbedding(nn.Module):
    '''
    Applies Learnable Sinusoidal Positional Encoding

    Parameters
    ----------
    embed_dim: int
        The positional embedding dimension (How big embedding for each patch.Constant across entire network)
    max_len: int 
        Max number of instances for positions
    freq: int 
        The base frequency for Sin/Cos calculations. Higher values (eg 10000) are more stable
    '''
    def __init__(self, 
                 embed_dim,
                 max_len=5000,
                 freq=10000.,
                ):
        super().__init__()
        pe = torch.zeros(max_len, embed_dim)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div = torch.exp(torch.arange(0, embed_dim, 2).float() *
                        (-math.log(freq) / embed_dim))
        pe[:, 0::2] = torch.sin(position * div) # Even terms
        pe[:, 1::2] = torch.cos(position * div) # Odd terms
        pe = pe.unsqueeze(0).transpose(0,1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        '''
        Defines how the class will run

        Parameters
        -----------

        Returns
        -----------
        '''
        x = x + self.pe[:x.size(0), :]
        return x

# %% [markdown]
# ### Convolutional Embedding Layer
#
# The patching used by the previous models was a problem because, while it took more samples of the input data, it also created what were essentially bordered segments which made it harder for the model to learn how they connected to the other segments and the bigger picture.
#
# The new convolutional layer helps to eliminate that problem by using convolutional filters to create many different overlapping segments.

# %%
class Conv_Embed(nn.Module):
    def __init__(self,
                 img_size=32,
                 in_channels=3,
                 out_channels=64,
                 n_conv=2,
                 kernel_size=3,
                 stride=None,
                 padding=None,
                 pool_kernel_size=3,
                 pool_stride=2,
                 pool_padding=1
                 ):
        super().__init__()
        
        stride = stride if stride is not None else max(1, (kernel_size // 2) - 1)
        padding = padding if padding is not None else max(1, (kernel_size // 2))

        self.img_size = img_size
        if n_conv == 1:
            self.conv_layers = nn.Sequential(
                nn.Conv2d(in_channels,
                        out_channels,
                        kernel_size=kernel_size,
                        stride=stride,
                        padding=padding,
                        bias=False),
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=pool_kernel_size,
                            stride=pool_stride,
                            padding=pool_padding)
            )
        else:
            n_filter_list = [in_channels] + \
                            [64 for _ in range(n_conv - 1)] + \
                            [out_channels]
            
            self.conv_layers = nn.Sequential(
                *[nn.Sequential(
                    nn.Conv2d(n_filter_list[i],
                        n_filter_list[i+1],
                        kernel_size=kernel_size,
                        stride=stride,
                        padding=padding,
                        bias=False),
                    nn.ReLU(),
                    nn.MaxPool2d(kernel_size=pool_kernel_size,
                            stride=pool_stride,
                            padding=pool_padding)
                            )
                    for i in range(n_conv)
                ])
        self.flattener = nn.Flatten(2, 3)
        
        # This, along with the @staticmethod below, help to normalize the convolutional filter by picking better starting weights for optimization.
        self.apply(self.init_weight)

    def sequence_length(self, in_channels=3, height=32, width=32):
        return self.forward(torch.zeros((1, in_channels, height, width))).shape[1]

    def forward(self, x):
        return self.flattener(self.conv_layers(x)).transpose(-2, -1)

    @staticmethod
    def init_weight(m):
        if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight)

# %% [markdown]
# ### This is the Transformer Encoder block which applies all of the actual normalization, attention, etc that make a Transformer what it is.

# %%
class TransformerEncoderLayer(nn.Module):
    '''
    Transformer Block/Encoder Layer

    Parameter
    ---------
    embed_dim: int
        embedding dimension
    n_heads: int
        number of attention heads
    mlp_ratio: float
        determines the hidden dimension size of the MLP module with respect to 'dim'
    qkv_bias: bool
        If true then we include bias to the query, key and value projections
    mlp_dropout, proj_dropout, attn_droupout: float
        dropout probability
    dim_feedforward: int
        The feature number of hidden layer of the FFN

    Attributes
    ----------
    norm_1, norm_2: LayerNorm
        Layer normalization
    MHA: Attention
        Multi-Headed Attention module
    mlp: MLP
        MLP module
    ''' 
    def __init__(self,
                 embed_dim=768,
                 n_heads=12,
                 qkv_bias=True,
                 attn_dropout=0.,
                 proj_dropout=0.,
                 mlp_dropout=0.,
                 hidden_dim=2048
    ):
        super().__init__()
        self.norm_1 = nn.LayerNorm(embed_dim, eps = 1e-6)
        self.norm_2 = nn.LayerNorm(embed_dim, eps = 1e-6)
        self.MHA = MultiheadedSelfAttention(embed_dim,
                                        n_heads,
                                        qkv_bias,
                                        attn_dropout,
                                        proj_dropout
        )
        self.MLP = MLP(embed_dim, hidden_dim, mlp_dropout)

    def forward(self, x):
        '''
        Defines how the class will run
        
        Parameter
        ---------
        x: torch.Tensor
            shape: n_samples, n_patches + 1, dim

        Returns
        --------
        torch.Tensor
            shape: n_samples, n_patches + 1, dim
        '''
        x = x + self.MHA(self.norm_1(x))    # Residual connection (Add)
        x = x + self.MLP(self.norm_2(x))    # Residual connection (Add)
        return x

# %% [markdown]
# ### Multiheaded Attention Layer
#
# The heart of the Transformer model; the reason behind the original title of "attention is all you need".

# %%
class MultiheadedSelfAttention(nn.Module):
    '''
    Multi-Headed Attention Mechanism

    Parameters
    ----------
    embed_dim: int
        The input and out dimension of per token feature
    n_heads: int
        Number of attention heads 
    qkv_bias: bool
        if true then we include bias to the query, key and value projections
    attn_p: float
        Dropout probability applied to the query, key and value tensors.
    proj_p: float
        Dropout probability applied to output tensor
        
    Attributes
    ----------
    scale: float
        Normalizing constant for the dot product
    qkv: nn.Linear
        Linear projection for the query, key and value
    proj: nn.Linear
        Linear mapping that takes in the concatenated output of all attention
        heads and maps into the new space
    attn_drop, proj_drop: nn.Dropout
        Dropout layers.
    '''
    def __init__(self, 
                 embed_dim, 
                 n_heads=2,
                 qkv_bias = True,
                 attn_dropout=0.,
                 proj_dropout=0.
    ):
        super().__init__()
        self.n_heads = n_heads
        assert embed_dim % n_heads == 0, \
            print('Embedding dim must be divisible by number of heads.')
        self.head_dim = embed_dim // n_heads
        self.scale = self.head_dim ** -0.5
        self.dim = embed_dim
        self.qkv = nn.Linear(embed_dim, embed_dim * 3, bias=qkv_bias)
        self.attn_dropout = nn.Dropout(attn_dropout)
        self.proj = nn.Linear(embed_dim, embed_dim)
        self.proj_dropout = nn.Dropout(proj_dropout)
        
    def forward(self, x):
        '''
        Defines how the class will run
        
        Parameters
        ----------
        x: torch.Tensor
            shape: n_samples (B), n_patches + 1 (N), embed_dim (C)
            N is also equal to the number of tokens.
        Returns
        --------
        torch.Tensor
            shape: n_samples, n_patches + 1, embed_dim
        '''
        B, N, C = x.shape
        qkv = self.qkv(x)
        qkv = qkv.reshape(B, N, 3,
            self.n_heads,
            self.head_dim
            )
        qkv = qkv.permute(
            2,    # qkv (3)
            0,    # batch (n_samples)
            3,    # channel (n_heads)
            1,    # n_patches + 1
            4     # head_dim (embed_dim / n_heads)
            )
        q, k, v = qkv[0], qkv[1], qkv[2]
        attn = (q @ k.transpose(-2, -1)) * self.scale # <q,k> / sqrt(d)
        attn = attn.softmax(dim=-1) # Softmax over embedding dim
        attn = self.attn_dropout(attn)

        weighted_avg = (attn @ v)
        weighted_avg = weighted_avg.transpose(1, 2)
        weighted_avg = weighted_avg.flatten(2)

        x = self.proj(weighted_avg)
        x = self.proj_dropout(x)

        return x

# %% [markdown]
# ### The MLP layer
#
# (At the end of the Transformer Encoder). Not to be confused with the mlp head which adds class encodings at the very end of the transformer.

# %%
class MLP(nn.Module):
    '''
    Multilayer perceptron 
    
    Parameters
    ----------
    embed_dim: int
        embedding dimension
    feedforward_dim: int
      Number of nodes in the hidden layer
    mlp_dropout: float
      Dropout probability

    Attribute
    ---------
    fc: nn.Linear
      The first linear layer
    act: nn. GELU
      GELU activation function
    fc2: nn.Linear
      The second linear layer
    drop: nn.Dropout
      Dropout layer
    '''

    def __init__(self, embed_dim, hidden_dim, mlp_dropout):
        super().__init__()
        self.fc1 = nn.Linear(embed_dim, hidden_dim)
        self.act = nn.GELU()
        self.fc2 = nn.Linear(hidden_dim, embed_dim)
        self.drop = nn.Dropout(mlp_dropout)

    def forward(self,x):
        '''
        Defines how the class will run
        
        Parameters
        ----------
        x: torch.Tensor
          shape: n_samples, n_patches + 1, in_features

        Returns
        ----------
        torch.Tensor
          n_samples, n_patches+ 1, out_features
        '''
        x = self.fc1(x) # n_samples, n_patches+1, hidden_features
        x = self.act(x) # n_samples, n_patches+1, hidden_features
        x = self.drop(x) # n_samples, n_patches+1, hidden_features
        x = self.fc2(x) # n_samples, n_patches+1, output_features
        x = self.drop(x) # n_samples, n_patches+1, output_features
        return x

# %% [markdown]
# ## Training with custom dataset

# %%
def sipakmed_prep():
    root = "../../Python Scripts/Datasets/CervicalCancer/Sipakmed/"

    all_img = []
    for path, subdirs, files in os.walk(root):
        for name in files:
            curr_img = os.path.join(path,name)
            all_img.append(curr_img)

    sipakmed_df = pd.DataFrame()
    sipakmed_df['LocalPath'] = all_img
    sipakmed_df['ID'] = sipakmed_df['LocalPath'].apply(lambda x: str(x.split("\\")[-1]))
    sipakmed_df['Slide'] = sipakmed_df['LocalPath'].apply(lambda x: 'False' if (str(x.split("\\")[1])) == 'CROPPED' else 'True')
    sipakmed_df['Specific_Status'] = sipakmed_df['LocalPath'].apply(lambda x: str((x.split("im_")[1]).split("\\")[0]))
    sipakmed_df['Status'] = sipakmed_df['Specific_Status'].apply(lambda x: 'Benign' if x == 'Metaplastic' else
    ('Normal' if x == 'Superficial-Intermediate' or x == 'Parabasal' else 'Abnormal'))

    sp_class = {'Metaplastic':4, 'Superficial-Intermediate':0, 'Parabasal':1, 'Koilocytotic':2, 'Dyskeratotic':3}
    sipakmed_df['Specific_Class'] = sipakmed_df['Specific_Status'].map(sp_class)
    gen_class = {'Benign':0, 'Normal':1, 'Abnormal':2}
    sipakmed_df['Class'] = sipakmed_df['Status'].map(gen_class)

    sipakmed_df = sipakmed_df.loc[sipakmed_df['ID'].str.contains('bmp')].reset_index(drop=True)
    
    return sipakmed_df

# %%
def herlev_prep(n_class):
    root = '../../Python Scripts/Datasets/CervicalCancer/Herlev/smear2005/results.csv'
    img_folder = '../../Python Scripts/Datasets/CervicalCancer/Herlev/smear2005/Images/'

    herlev_df=pd.read_csv(root)
    herlev_df = herlev_df.rename(columns={'Class':'Specific_Class'})

    if n_class == 12:
        spec_class = {1:5, 2:6, 3:7, 4:8, 5:9, 6:10, 7:11}
    else:
        spec_class = {1:0, 2:1, 3:2, 4:3, 5:4, 6:5, 7:6}

    gen_class = {1:1, 2:1, 3:1, 4:2, 5:2, 6:2, 7:2}
    herlev_df['Class'] = herlev_df['Specific_Class'].map(gen_class)
    herlev_df['Specific_Class'] = herlev_df['Specific_Class'].map(spec_class)
    herlev_df['LocalPath'] = herlev_df['ID'].apply(lambda x: str(img_folder + x))
    return herlev_df

# %%
class DatasetSample(Dataset):
    def __init__(self, df, transform):
        # Initialization
        self.transform = transform
        
        self.image_names = df['LocalPath']
        self.img_class = np.array(df['Class'])

    def __len__(self):
        # Denotes the total number of samples
        return len(self.image_names)
    
    def __getitem__(self, index):
        # Retrieves the data
        image=cv2.imread(self.image_names.iloc[index])
        image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

        image = self.transform(image)
        label = self.img_class[index]

        return image, label

# %%
def concat_data(batch_size=128, img_size=32, n_class=3):
    kwargs = {'num_workers': 1, 'pin_memory': True} if device=='cuda' else {}
    # Load the dataframes
    sipakmed_df = sipakmed_prep()
    herlev_df = herlev_prep(n_class)

    # Final adjustments to make sure they're attributes match
    sipakmed_df = sipakmed_df.loc[sipakmed_df['Slide'] == 'False']

    if n_class == 2:
        classes = ('Normal', 'Abnormal')
        herlev_df = herlev_df.loc[:,['LocalPath', 'Class']]
        sipakmed_df = sipakmed_df.loc[:,['LocalPath', 'Class']]
        concat_df = pd.concat([sipakmed_df,herlev_df], ignore_index=True)
        bin_class = {1:0, 2:0, 3:1}
        concat_df['Class'] = concat_df['Class'].map(bin_class)

    elif n_class == 3:
        classes = ('Benign', 'Normal', 'Abnormal')
        herlev_df = herlev_df.loc[:,['LocalPath', 'Class']]
        sipakmed_df = sipakmed_df.loc[:,['LocalPath', 'Class']]
        concat_df = pd.concat([sipakmed_df,herlev_df], ignore_index=True)

    elif n_class == 5:
        classes = ('Superficial-Intermediate','Parabasal','Koilocytotic','Dyskeratotic','Metaplastic')
        concat_df = pd.DataFrame()
        concat_df['LocalPath'] = sipakmed_df['LocalPath']
        concat_df['Class'] = sipakmed_df['Specific_Class']

    elif n_class == 7:
        classes = ('Superficial-Squamous-Epithelial','Intermediate-Squamous-Epithelial','Columnar-Epithelial','Mild-Squamous-Non-Keratinizing-Dysplasia',
           'Moderate-Squamous-Non-Keratinizing-Dysplasia','Severe-Squamous-Non-Keratinizing-Dysplasia','Squamous-Cell-Carcinoma-in-situ-Intermediate')
        concat_df = pd.DataFrame()
        concat_df['LocalPath'] = herlev_df['LocalPath']
        concat_df['Class'] = herlev_df['Specific_Class']

    elif n_class == 12:
        classes = ('Superficial-Intermediate','Parabasal','Koilocytotic','Dyskeratotic','Metaplastic','Superficial-Squamous-Epithelial','Intermediate-Squamous-Epithelial','Columnar-Epithelial','Mild-Squamous-Non-Keratinizing-Dysplasia',
           'Moderate-Squamous-Non-Keratinizing-Dysplasia','Severe-Squamous-Non-Keratinizing-Dysplasia','Squamous-Cell-Carcinoma-in-situ-Intermediate')
        herlev_df = herlev_df.loc[:,['LocalPath', 'Specific_Class']]
        sipakmed_df = sipakmed_df.loc[:,['LocalPath', 'Specific_Class']]
        concat_df = pd.concat([sipakmed_df,herlev_df], ignore_index=True).rename(columns={'Specific_Class':'Class'})

    # Split them into training, validation, and testing sets
    train_set,val_test_set = train_test_split(concat_df, random_state=1, test_size=0.40)
    val_set,test_set = train_test_split(val_test_set, random_state=1, test_size=0.50)
    
    # Set it up to alter random training images for better results
    train_transform = transforms.Compose([
                    transforms.ToPILImage(),
                    transforms.Resize((img_size, img_size)),
                    transforms.RandomHorizontalFlip(p=0.75),
                    transforms.RandomRotation(degrees=60),
                    transforms.transforms.ColorJitter(brightness=.2, hue=.2),
                    transforms.ToTensor()])

    test_transform = transforms.Compose([
                    transforms.ToPILImage(),
                    transforms.Resize((img_size, img_size)),
                    transforms.ToTensor()])

    train_dataset = DatasetSample(train_set, train_transform)
    val_dataset = DatasetSample(val_set, test_transform)
    test_dataset = DatasetSample(test_set, test_transform)
    
    Dtr = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        generator=torch.Generator().manual_seed(17),
        **kwargs
    )
    
    Dva = DataLoader(
        val_dataset, 
        batch_size=batch_size,
        shuffle=False,
        **kwargs
    )

    Dte = DataLoader(
        test_dataset, 
        batch_size=batch_size,
        shuffle=False,
        **kwargs
    )

    return(Dtr, Dva, Dte, classes)

# %%
batch_size=191
img_size=64
# This sets up which dataset(s) to use and their corresponding class labels
n_class=12

'''
2 uses both datasets. Classes are normal and abnormal.
3 uses both datasets. Classes are benign, normal, and abnormal.
5 uses the Sipakmed dataset. Classes are Superficial-Intermediate, Parabasal, Koilocytotic, Dyskeratotic, and Metaplastic.
7 uses the Herlev dataset. Classes are Superficial Squamous Epithelial, Intermediate Squamous Epithelial, Columnar Epithelial, Mild Squamous Non-Keratinizing Dysplasia,
            Moderate Squamous Non-Keratinizing Dysplasia, Severe Squamous Non-Keratinizing Dysplasia, and Squamous Cell Carcinoma in-situ Intermediate.
12 uses both datasets. Classes are the two above.
'''

Dtr, Dva, Dte, classes = concat_data(batch_size=batch_size, img_size=img_size, n_class=n_class)

# %% [markdown]
# ### Builds the dataloaders for training and testing

# %%
# Turns the dataloaders into iterable objects. Useful for viewing
dataiter = iter(Dtr)
val_dataiter = iter(Dva)
test_dataiter = iter(Dte)

# %% [markdown]
# ### Function for viewing batches of the dataset

# %%
def imshow(images, labels, predicted_labels=None):
    
    if images.is_cuda == True:
        images = images.to("cpu")
    if labels.is_cuda == True:
        labels = labels.to("cpu")

    # Using torchvision to make a grid of the images
    img = torchvision.utils.make_grid(images)

    # Inverting the normalization
    img = img.numpy().transpose((1, 2, 0))
    img = np.clip(img, 0, 1)

    # Plotting the grid
    fig, ax = plt.subplots(figsize=(12, 24))
    plt.imshow(img)

    if predicted_labels is not None:
        if predicted_labels.is_cuda == True:
            predicted_labels = predicted_labels.to("cpu")
        # Outputing the predicted labels
        ax.set_xlabel('Predicted labels', fontsize=18, labelpad=12)
        ax.set_xticks(torch.arange(len(images)) * img_size + (img_size/1.8))
        ax.set_xticklabels([classes[predicted_labels[j]] 
                            for j in range(len(images))], fontsize=12, rotation=30)
    
    # Outputing the True labels
    gax = ax.secondary_xaxis('top')
    gax.set_xlabel('True Labels', fontsize=18, labelpad=12)
    gax.set_xticks(torch.arange(len(images)) * img_size + (img_size/1.8))
    gax.set_xticklabels([classes[labels[j]] 
                         for j in range(len(images))], fontsize=12, rotation=30)
    plt.show()

# %%
images, labels = dataiter.next()
imshow(images[:7], labels[:7])

# %% [markdown]
# ### This function was made by Dr Prashant to train the model that's built above

# %%
# A function to encapsulate the training loop
def batch_gd(model, loss_fn, optimizer, train_loader, val_loader, epochs):
  model.to(device)
  train_losses = np.zeros(epochs)
  val_losses = np.zeros(epochs)
  avg_epoch = []
  
  for it in range(epochs):
    model.train()
    t0 = datetime.now()
    train_loss = []
    n_correct = 0.
    n_total = 0.
    for inputs, targets in train_loader:
      # move data to GPU if available
      inputs, targets = inputs.to(device), targets.to(device)

      # zero the parameter gradients
      optimizer.zero_grad()

      # Forward pass
      outputs = model(inputs)
      
      # Get the predictions
      # torch.max returns both max and argmax
      __, out_label = outputs.max(dim=1)
      # Updates the accuracy with every pass
      n_correct += (out_label == targets).sum().item()
      n_total += targets.shape[0]
      tr_acc = n_correct / n_total

      loss = loss_fn(outputs, targets)
      # Backward and optimize
      loss.backward()
      optimizer.step()

      train_loss.append(loss.item())

    # Get train loss and test loss
    train_loss = np.mean(train_loss) # a little misleading
    
    model.eval()
    val_loss = []
    n_correct = 0.
    n_total = 0.
    for inputs, targets in val_loader:
      inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)

      # Get the predictions
      # torch.max returns both max and argmax
      __, out_label = outputs.max(dim=1)
      # Updates the accuracy with every pass
      n_correct += (out_label == targets).sum().item()
      n_total += targets.shape[0]
      val_acc = n_correct / n_total

      loss = loss_fn(outputs, targets)
      val_loss.append(loss.item())
    val_loss = np.mean(val_loss)

    # Save losses
    train_losses[it] = train_loss
    val_losses[it] = val_loss
    
    dt = datetime.now() - t0
    avg_epoch.append(dt)

    print(f'Epoch {it+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {(100*tr_acc):.3f} \
      Val Loss: {val_loss:.4f}, Val Accuracy: {(100*val_acc):.3f}, Duration: {dt}, Avg_Epoch: {np.mean(avg_epoch)}')
  
  return train_losses, val_losses

# %% [markdown]
# ### Initializes the Transformer and selects the loss function and optimizer we want

# %%
model = CCT(
        img_size=img_size,      # Input image size
        in_channels=3,  # Number of channels for the image
        patch_size=4,   # How big our patches are
        embed_dim=128,   # Embedding dim
        n_layers=2,     # Number of transformer encoders
        n_conv=2,       # Number of convolutional layers
        n_heads=2,      # Number of attention heads
        attn_dropout=0.,        # Attention Dropout
        proj_dropout=0.,        # (MHA) Projection Dropout
        mlp_dropout=0.1,        # (MHA) last layer dropout
        mlp_ratio=1,    # (MHA) Projection FF dimension
        qkv_bias = True,
        n_class=n_class     # Number of classes to classify
        )
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())

# %%
train_losses, val_losses = batch_gd(model, loss_fn, optimizer, Dtr, Dva, epochs=100)
# Out:
# Epoch 1/100, Train Loss: 2.0361, Train Accuracy: 31.185       Val Loss: 1.6423, Val Accuracy: 47.734, Duration: 0:00:15.728686, Avg_Epoch: 0:00:15.728686
# Epoch 2/100, Train Loss: 1.7872, Train Accuracy: 41.591       Val Loss: 1.5828, Val Accuracy: 53.072, Duration: 0:00:07.800005, Avg_Epoch: 0:00:11.764346
# Epoch 3/100, Train Loss: 1.6727, Train Accuracy: 47.701       Val Loss: 1.4445, Val Accuracy: 56.193, Duration: 0:00:07.622999, Avg_Epoch: 0:00:10.383897
# Epoch 4/100, Train Loss: 1.5924, Train Accuracy: 49.178       Val Loss: 1.3912, Val Accuracy: 56.395, Duration: 0:00:07.657000, Avg_Epoch: 0:00:09.702172
# Epoch 5/100, Train Loss: 1.4826, Train Accuracy: 52.064       Val Loss: 1.3942, Val Accuracy: 56.395, Duration: 0:00:07.594999, Avg_Epoch: 0:00:09.280738
# Epoch 6/100, Train Loss: 1.4705, Train Accuracy: 52.635       Val Loss: 1.3398, Val Accuracy: 61.531, Duration: 0:00:07.747067, Avg_Epoch: 0:00:09.025126
# Epoch 7/100, Train Loss: 1.3818, Train Accuracy: 54.314       Val Loss: 1.2626, Val Accuracy: 60.423, Duration: 0:00:08.139002, Avg_Epoch: 0:00:08.898537
# Epoch 8/100, Train Loss: 1.3281, Train Accuracy: 57.301       Val Loss: 1.2491, Val Accuracy: 62.236, Duration: 0:00:08.204997, Avg_Epoch: 0:00:08.811844
# Epoch 9/100, Train Loss: 1.2437, Train Accuracy: 60.591       Val Loss: 1.1208, Val Accuracy: 65.559, Duration: 0:00:08.065001, Avg_Epoch: 0:00:08.728862
# Epoch 10/100, Train Loss: 1.1382, Train Accuracy: 62.773       Val Loss: 1.2228, Val Accuracy: 63.545, Duration: 0:00:08.295514, Avg_Epoch: 0:00:08.685527
# Epoch 11/100, Train Loss: 1.1093, Train Accuracy: 64.552       Val Loss: 0.9900, Val Accuracy: 68.379, Duration: 0:00:07.902999, Avg_Epoch: 0:00:08.614388
# Epoch 12/100, Train Loss: 1.0135, Train Accuracy: 66.700       Val Loss: 0.9306, Val Accuracy: 69.789, Duration: 0:00:07.959997, Avg_Epoch: 0:00:08.559856
# Epoch 13/100, Train Loss: 0.9614, Train Accuracy: 68.077       Val Loss: 0.8934, Val Accuracy: 70.493, Duration: 0:00:08.233999, Avg_Epoch: 0:00:08.534790
# Epoch 14/100, Train Loss: 0.9393, Train Accuracy: 68.144       Val Loss: 0.9461, Val Accuracy: 70.493, Duration: 0:00:08.035661, Avg_Epoch: 0:00:08.499138
# Epoch 15/100, Train Loss: 0.9235, Train Accuracy: 69.251       Val Loss: 0.8538, Val Accuracy: 72.910, Duration: 0:00:07.479998, Avg_Epoch: 0:00:08.431195
# Epoch 16/100, Train Loss: 0.8437, Train Accuracy: 71.769       Val Loss: 0.8239, Val Accuracy: 74.320, Duration: 0:00:07.675003, Avg_Epoch: 0:00:08.383933
# Epoch 17/100, Train Loss: 0.7889, Train Accuracy: 72.541       Val Loss: 0.8243, Val Accuracy: 73.615, Duration: 0:00:09.196998, Avg_Epoch: 0:00:08.431760
# Epoch 18/100, Train Loss: 0.7610, Train Accuracy: 73.649       Val Loss: 0.7193, Val Accuracy: 76.536, Duration: 0:00:08.021999, Avg_Epoch: 0:00:08.408996
# Epoch 19/100, Train Loss: 0.7186, Train Accuracy: 75.730       Val Loss: 0.6760, Val Accuracy: 76.234, Duration: 0:00:08.099001, Avg_Epoch: 0:00:08.392680
# Epoch 20/100, Train Loss: 0.6877, Train Accuracy: 76.401       Val Loss: 0.7406, Val Accuracy: 76.234, Duration: 0:00:08.229002, Avg_Epoch: 0:00:08.384496
# Epoch 21/100, Train Loss: 0.6498, Train Accuracy: 77.140       Val Loss: 0.7385, Val Accuracy: 76.939, Duration: 0:00:08.086000, Avg_Epoch: 0:00:08.370282
# Epoch 22/100, Train Loss: 0.7423, Train Accuracy: 74.555       Val Loss: 0.6415, Val Accuracy: 78.852, Duration: 0:00:07.760000, Avg_Epoch: 0:00:08.342542
# Epoch 23/100, Train Loss: 0.6062, Train Accuracy: 79.288       Val Loss: 0.6258, Val Accuracy: 79.557, Duration: 0:00:07.938002, Avg_Epoch: 0:00:08.324953
# Epoch 24/100, Train Loss: 0.6114, Train Accuracy: 77.946       Val Loss: 0.6340, Val Accuracy: 78.953, Duration: 0:00:08.491001, Avg_Epoch: 0:00:08.331872
# Epoch 25/100, Train Loss: 0.6484, Train Accuracy: 77.610       Val Loss: 0.5530, Val Accuracy: 81.470, Duration: 0:00:07.864999, Avg_Epoch: 0:00:08.313197
# Epoch 26/100, Train Loss: 0.5993, Train Accuracy: 78.348       Val Loss: 0.6476, Val Accuracy: 78.348, Duration: 0:00:08.399000, Avg_Epoch: 0:00:08.316497
# Epoch 27/100, Train Loss: 0.6138, Train Accuracy: 78.818       Val Loss: 0.6040, Val Accuracy: 79.255, Duration: 0:00:08.140000, Avg_Epoch: 0:00:08.309960
# Epoch 28/100, Train Loss: 0.6036, Train Accuracy: 78.886       Val Loss: 0.7157, Val Accuracy: 77.241, Duration: 0:00:07.960001, Avg_Epoch: 0:00:08.297462
# Epoch 29/100, Train Loss: 0.5966, Train Accuracy: 79.154       Val Loss: 0.6026, Val Accuracy: 79.859, Duration: 0:00:08.281998, Avg_Epoch: 0:00:08.296929
# Epoch 30/100, Train Loss: 0.5702, Train Accuracy: 80.195       Val Loss: 0.5958, Val Accuracy: 80.765, Duration: 0:00:07.946999, Avg_Epoch: 0:00:08.285264
# Epoch 31/100, Train Loss: 0.5302, Train Accuracy: 81.437       Val Loss: 0.5658, Val Accuracy: 80.262, Duration: 0:00:07.711885, Avg_Epoch: 0:00:08.266768
# Epoch 32/100, Train Loss: 0.5305, Train Accuracy: 80.631       Val Loss: 0.5330, Val Accuracy: 82.175, Duration: 0:00:08.094663, Avg_Epoch: 0:00:08.261390
# Epoch 33/100, Train Loss: 0.5109, Train Accuracy: 81.302       Val Loss: 0.5617, Val Accuracy: 82.075, Duration: 0:00:08.304338, Avg_Epoch: 0:00:08.262691
# Epoch 34/100, Train Loss: 0.5184, Train Accuracy: 81.571       Val Loss: 0.5987, Val Accuracy: 81.168, Duration: 0:00:07.994998, Avg_Epoch: 0:00:08.254818
# Epoch 35/100, Train Loss: 0.5034, Train Accuracy: 82.343       Val Loss: 0.5550, Val Accuracy: 81.470, Duration: 0:00:09.966003, Avg_Epoch: 0:00:08.303709
# Epoch 36/100, Train Loss: 0.4790, Train Accuracy: 82.175       Val Loss: 0.5643, Val Accuracy: 81.672, Duration: 0:00:09.782996, Avg_Epoch: 0:00:08.344800
# Epoch 37/100, Train Loss: 0.4894, Train Accuracy: 82.578       Val Loss: 0.6035, Val Accuracy: 81.470, Duration: 0:00:09.663004, Avg_Epoch: 0:00:08.380427
# Epoch 38/100, Train Loss: 0.4808, Train Accuracy: 82.477       Val Loss: 0.5085, Val Accuracy: 83.686, Duration: 0:00:08.941999, Avg_Epoch: 0:00:08.395206
# Epoch 39/100, Train Loss: 0.4888, Train Accuracy: 81.940       Val Loss: 0.5176, Val Accuracy: 82.779, Duration: 0:00:09.976998, Avg_Epoch: 0:00:08.435764
# Epoch 40/100, Train Loss: 0.4990, Train Accuracy: 82.712       Val Loss: 0.5473, Val Accuracy: 81.672, Duration: 0:00:09.254002, Avg_Epoch: 0:00:08.456220
# Epoch 41/100, Train Loss: 0.4704, Train Accuracy: 83.249       Val Loss: 0.5653, Val Accuracy: 82.175, Duration: 0:00:07.700000, Avg_Epoch: 0:00:08.437776
# Epoch 42/100, Train Loss: 0.4416, Train Accuracy: 83.954       Val Loss: 0.5251, Val Accuracy: 82.679, Duration: 0:00:08.710515, Avg_Epoch: 0:00:08.444270
# Epoch 43/100, Train Loss: 0.4324, Train Accuracy: 83.820       Val Loss: 0.5394, Val Accuracy: 82.377, Duration: 0:00:09.291999, Avg_Epoch: 0:00:08.463984
# Epoch 44/100, Train Loss: 0.4477, Train Accuracy: 83.585       Val Loss: 0.5226, Val Accuracy: 83.484, Duration: 0:00:09.410004, Avg_Epoch: 0:00:08.485485
# Epoch 45/100, Train Loss: 0.4588, Train Accuracy: 83.484       Val Loss: 0.6093, Val Accuracy: 82.175, Duration: 0:00:09.914998, Avg_Epoch: 0:00:08.517252
# Epoch 46/100, Train Loss: 0.4513, Train Accuracy: 83.552       Val Loss: 0.5313, Val Accuracy: 83.585, Duration: 0:00:09.450002, Avg_Epoch: 0:00:08.537529
# Epoch 47/100, Train Loss: 0.4323, Train Accuracy: 84.089       Val Loss: 0.5240, Val Accuracy: 83.182, Duration: 0:00:08.781999, Avg_Epoch: 0:00:08.542730
# Epoch 48/100, Train Loss: 0.4102, Train Accuracy: 85.230       Val Loss: 0.5420, Val Accuracy: 83.887, Duration: 0:00:08.821997, Avg_Epoch: 0:00:08.548548
# Epoch 49/100, Train Loss: 0.4185, Train Accuracy: 85.096       Val Loss: 0.5169, Val Accuracy: 83.283, Duration: 0:00:10.333692, Avg_Epoch: 0:00:08.584980
# Epoch 50/100, Train Loss: 0.3865, Train Accuracy: 85.801       Val Loss: 0.4889, Val Accuracy: 84.391, Duration: 0:00:10.132000, Avg_Epoch: 0:00:08.615920
# Epoch 51/100, Train Loss: 0.4045, Train Accuracy: 84.928       Val Loss: 0.6539, Val Accuracy: 81.269, Duration: 0:00:09.175001, Avg_Epoch: 0:00:08.626883
# Epoch 52/100, Train Loss: 0.4983, Train Accuracy: 82.645       Val Loss: 0.7100, Val Accuracy: 77.845, Duration: 0:00:08.745997, Avg_Epoch: 0:00:08.629173
# Epoch 53/100, Train Loss: 0.4358, Train Accuracy: 84.760       Val Loss: 0.5241, Val Accuracy: 83.887, Duration: 0:00:09.244002, Avg_Epoch: 0:00:08.640774
# Epoch 54/100, Train Loss: 0.4292, Train Accuracy: 84.626       Val Loss: 0.5369, Val Accuracy: 83.484, Duration: 0:00:08.652000, Avg_Epoch: 0:00:08.640982
# Epoch 55/100, Train Loss: 0.4244, Train Accuracy: 84.894       Val Loss: 0.6080, Val Accuracy: 81.873, Duration: 0:00:09.165998, Avg_Epoch: 0:00:08.650528
# Epoch 56/100, Train Loss: 0.4256, Train Accuracy: 84.021       Val Loss: 0.5059, Val Accuracy: 84.794, Duration: 0:00:09.041997, Avg_Epoch: 0:00:08.657518
# Epoch 57/100, Train Loss: 0.3959, Train Accuracy: 85.935       Val Loss: 0.5349, Val Accuracy: 83.787, Duration: 0:00:09.789995, Avg_Epoch: 0:00:08.677386
# Epoch 58/100, Train Loss: 0.3993, Train Accuracy: 85.633       Val Loss: 0.4670, Val Accuracy: 84.995, Duration: 0:00:09.126997, Avg_Epoch: 0:00:08.685138
# Epoch 59/100, Train Loss: 0.3761, Train Accuracy: 86.472       Val Loss: 0.5299, Val Accuracy: 81.974, Duration: 0:00:09.012003, Avg_Epoch: 0:00:08.690678
# Epoch 60/100, Train Loss: 0.3950, Train Accuracy: 85.801       Val Loss: 0.4994, Val Accuracy: 83.484, Duration: 0:00:10.155998, Avg_Epoch: 0:00:08.715100
# Epoch 61/100, Train Loss: 0.3760, Train Accuracy: 86.573       Val Loss: 0.5331, Val Accuracy: 83.182, Duration: 0:00:09.532999, Avg_Epoch: 0:00:08.728508
# Epoch 62/100, Train Loss: 0.3581, Train Accuracy: 86.438       Val Loss: 0.4618, Val Accuracy: 84.491, Duration: 0:00:09.193000, Avg_Epoch: 0:00:08.736000
# Epoch 63/100, Train Loss: 0.3450, Train Accuracy: 87.210       Val Loss: 0.5115, Val Accuracy: 84.894, Duration: 0:00:08.897001, Avg_Epoch: 0:00:08.738556
# Epoch 64/100, Train Loss: 0.3428, Train Accuracy: 87.210       Val Loss: 0.5034, Val Accuracy: 84.894, Duration: 0:00:09.526001, Avg_Epoch: 0:00:08.750860
# Epoch 65/100, Train Loss: 0.3338, Train Accuracy: 87.580       Val Loss: 0.5416, Val Accuracy: 83.384, Duration: 0:00:09.247001, Avg_Epoch: 0:00:08.758492
# Epoch 66/100, Train Loss: 0.3586, Train Accuracy: 86.808       Val Loss: 0.5264, Val Accuracy: 84.189, Duration: 0:00:10.392997, Avg_Epoch: 0:00:08.783258
# Epoch 67/100, Train Loss: 0.3619, Train Accuracy: 86.472       Val Loss: 0.5231, Val Accuracy: 83.787, Duration: 0:00:08.650002, Avg_Epoch: 0:00:08.781269
# Epoch 68/100, Train Loss: 0.3486, Train Accuracy: 87.076       Val Loss: 0.5080, Val Accuracy: 83.686, Duration: 0:00:09.002998, Avg_Epoch: 0:00:08.784530
# Epoch 69/100, Train Loss: 0.3164, Train Accuracy: 88.050       Val Loss: 0.5369, Val Accuracy: 83.787, Duration: 0:00:08.672004, Avg_Epoch: 0:00:08.782899
# Epoch 70/100, Train Loss: 0.3322, Train Accuracy: 87.278       Val Loss: 0.5098, Val Accuracy: 83.988, Duration: 0:00:09.156998, Avg_Epoch: 0:00:08.788243
# Epoch 71/100, Train Loss: 0.3081, Train Accuracy: 88.419       Val Loss: 0.4852, Val Accuracy: 85.196, Duration: 0:00:08.863029, Avg_Epoch: 0:00:08.789296
# Epoch 72/100, Train Loss: 0.3462, Train Accuracy: 87.580       Val Loss: 0.5008, Val Accuracy: 84.794, Duration: 0:00:09.920489, Avg_Epoch: 0:00:08.805007
# Epoch 73/100, Train Loss: 0.3334, Train Accuracy: 87.445       Val Loss: 0.5850, Val Accuracy: 82.578, Duration: 0:00:09.527000, Avg_Epoch: 0:00:08.814898
# Epoch 74/100, Train Loss: 0.3774, Train Accuracy: 86.405       Val Loss: 0.4906, Val Accuracy: 84.592, Duration: 0:00:08.583999, Avg_Epoch: 0:00:08.811777
# Epoch 75/100, Train Loss: 0.2993, Train Accuracy: 88.788       Val Loss: 0.5009, Val Accuracy: 86.002, Duration: 0:00:08.491001, Avg_Epoch: 0:00:08.807500
# Epoch 76/100, Train Loss: 0.3183, Train Accuracy: 88.218       Val Loss: 0.4900, Val Accuracy: 84.693, Duration: 0:00:08.609000, Avg_Epoch: 0:00:08.804888
# Epoch 77/100, Train Loss: 0.3002, Train Accuracy: 88.822       Val Loss: 0.5054, Val Accuracy: 83.988, Duration: 0:00:09.350000, Avg_Epoch: 0:00:08.811968
# Epoch 78/100, Train Loss: 0.3241, Train Accuracy: 87.848       Val Loss: 0.4956, Val Accuracy: 84.794, Duration: 0:00:08.727000, Avg_Epoch: 0:00:08.810879
# Epoch 79/100, Train Loss: 0.3092, Train Accuracy: 88.721       Val Loss: 0.4607, Val Accuracy: 85.801, Duration: 0:00:08.840412, Avg_Epoch: 0:00:08.811252
# Epoch 80/100, Train Loss: 0.3126, Train Accuracy: 88.419       Val Loss: 0.5023, Val Accuracy: 84.290, Duration: 0:00:08.794001, Avg_Epoch: 0:00:08.811037
# Epoch 81/100, Train Loss: 0.2926, Train Accuracy: 88.520       Val Loss: 0.5015, Val Accuracy: 84.794, Duration: 0:00:08.507999, Avg_Epoch: 0:00:08.807296
# Epoch 82/100, Train Loss: 0.2902, Train Accuracy: 89.560       Val Loss: 0.5112, Val Accuracy: 84.995, Duration: 0:00:08.525000, Avg_Epoch: 0:00:08.803853
# Epoch 83/100, Train Loss: 0.3207, Train Accuracy: 88.352       Val Loss: 0.4904, Val Accuracy: 85.498, Duration: 0:00:09.035999, Avg_Epoch: 0:00:08.806650
# Epoch 84/100, Train Loss: 0.2991, Train Accuracy: 88.822       Val Loss: 0.4669, Val Accuracy: 85.398, Duration: 0:00:08.855002, Avg_Epoch: 0:00:08.807225
# Epoch 85/100, Train Loss: 0.2854, Train Accuracy: 90.064       Val Loss: 0.4884, Val Accuracy: 85.700, Duration: 0:00:08.750998, Avg_Epoch: 0:00:08.806564
# Epoch 86/100, Train Loss: 0.3075, Train Accuracy: 89.057       Val Loss: 0.5110, Val Accuracy: 85.096, Duration: 0:00:08.591999, Avg_Epoch: 0:00:08.804069
# Epoch 87/100, Train Loss: 0.2772, Train Accuracy: 89.829       Val Loss: 0.5272, Val Accuracy: 84.391, Duration: 0:00:09.087001, Avg_Epoch: 0:00:08.807321
# Epoch 88/100, Train Loss: 0.3008, Train Accuracy: 88.788       Val Loss: 0.5485, Val Accuracy: 84.089, Duration: 0:00:08.605998, Avg_Epoch: 0:00:08.805033
# Epoch 89/100, Train Loss: 0.3287, Train Accuracy: 88.083       Val Loss: 0.4848, Val Accuracy: 86.304, Duration: 0:00:07.995998, Avg_Epoch: 0:00:08.795943
# Epoch 90/100, Train Loss: 0.3248, Train Accuracy: 88.419       Val Loss: 0.5032, Val Accuracy: 84.391, Duration: 0:00:07.730002, Avg_Epoch: 0:00:08.784099
# Epoch 91/100, Train Loss: 0.3604, Train Accuracy: 86.606       Val Loss: 0.5198, Val Accuracy: 82.075, Duration: 0:00:08.090999, Avg_Epoch: 0:00:08.776483
# Epoch 92/100, Train Loss: 0.3104, Train Accuracy: 88.520       Val Loss: 0.5593, Val Accuracy: 83.787, Duration: 0:00:10.699515, Avg_Epoch: 0:00:08.797385
# Epoch 93/100, Train Loss: 0.2719, Train Accuracy: 90.097       Val Loss: 0.5399, Val Accuracy: 85.700, Duration: 0:00:10.568999, Avg_Epoch: 0:00:08.816435
# Epoch 94/100, Train Loss: 0.2605, Train Accuracy: 90.232       Val Loss: 0.5031, Val Accuracy: 84.491, Duration: 0:00:08.309000, Avg_Epoch: 0:00:08.811037
# Epoch 95/100, Train Loss: 0.2739, Train Accuracy: 90.097       Val Loss: 0.4981, Val Accuracy: 85.096, Duration: 0:00:08.111508, Avg_Epoch: 0:00:08.803673
# Epoch 96/100, Train Loss: 0.2594, Train Accuracy: 90.601       Val Loss: 0.4749, Val Accuracy: 86.405, Duration: 0:00:07.901999, Avg_Epoch: 0:00:08.794281
# Epoch 97/100, Train Loss: 0.2595, Train Accuracy: 90.198       Val Loss: 0.5355, Val Accuracy: 84.290, Duration: 0:00:07.669997, Avg_Epoch: 0:00:08.782690
# Epoch 98/100, Train Loss: 0.2711, Train Accuracy: 90.299       Val Loss: 0.4664, Val Accuracy: 85.901, Duration: 0:00:08.081004, Avg_Epoch: 0:00:08.775530
# Epoch 99/100, Train Loss: 0.2549, Train Accuracy: 90.500       Val Loss: 0.5024, Val Accuracy: 84.894, Duration: 0:00:07.751999, Avg_Epoch: 0:00:08.765191
# Epoch 100/100, Train Loss: 0.2676, Train Accuracy: 90.467       Val Loss: 0.5113, Val Accuracy: 85.700, Duration: 0:00:07.974999, Avg_Epoch: 0:00:08.757290

# %%
dataiter = iter(Dtr)
val_dataiter = iter(Dva)
test_dataiter = iter(Dte)
images, labels = val_dataiter.next()
out_img, predicted = torch.max(model(images.to(device)), 1)
imshow(images[:7], labels[:7], predicted[:7])

# %%
# Plot the train loss and test loss per iteration
plt.figure(figsize=(12, 6))
plt.plot(train_losses, label='train loss')
plt.plot(val_losses, label='val loss')
plt.title('Training vs Validation Cross-Entropy Loss')
plt.xlabel('Epochs')
plt.ylabel('Average Loss')
plt.legend()
plt.show()

# %%
test_loss = []
test_acc = []
n_correct = 0.
n_total = 0.
confusion_matrix = np.zeros((n_class, n_class))

model.eval()
with torch.no_grad():
    for inputs, targets in Dte:
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = model(inputs)

        # Get the predictions
        # torch.max returns both max and argmax
        __, out_label = outputs.max(dim=1)
        # Updates the accuracy with every pass
        n_correct += (out_label == targets).sum().item()
        n_total += targets.shape[0]
        for t, p in zip(targets.view(-1), out_label.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1
        test_acc.append(n_correct / n_total)

        loss = loss_fn(outputs, targets)
        test_loss.append(loss.item())
test_loss = np.mean(test_loss)
avg_acc = np.mean(test_acc)*100
print('The total number of samples for Training is: {}, Validation: {}, and Testing: {}'.format(len(Dtr)*batch_size, len(Dva)*batch_size, len(Dte)*batch_size))
print('Average loss across the testing data: {}, Average testing accuracy: {}'.format(test_loss, avg_acc))
# Out:
# The total number of samples for Training is: 3056, Validation: 1146, and Testing: 1146
# Average loss across the testing data: 0.4712546517451604, Average testing accuracy: 87.43973439239274

# %%
plt.figure(figsize=(15,10))

class_names = list(classes)
cm_df = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(cm_df, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# Average loss across the testing data: 0.21944445930421352, Average testing accuracy: 93.91791504233736
# Average loss across the testing data: 0.1878853254020214, Average testing accuracy: 93.70940814155769

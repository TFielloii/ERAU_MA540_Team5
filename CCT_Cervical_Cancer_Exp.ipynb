# %%
import os
from PIL import Image
import torch
from torch.utils.data import DataLoader,Dataset
import torch.nn as nn
from torch import Tensor
import torchvision
import torchvision.transforms as transforms
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import torch.nn.functional as F
import seaborn as sns
from datetime import datetime
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from einops import rearrange
from sklearn import svm
from sklearn.metrics import classification_report, accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF, Matern
from torch.autograd import Variable
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense
import warnings
warnings.filterwarnings("ignore")

torch.manual_seed(17)

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
torch.backends.cudnn.benchmark = True

# %% [markdown]
# # A Compact Convolutional Vision Transformer or CCT
# *Created using the walkthrough from https://medium.com/pytorch/training-compact-transformers-from-scratch-in-30-minutes-with-pytorch-ff5c21668ed5 and Dr Prashant's Vision_Transformer file

# %% [markdown]
# ## Building the Transformer block by block

# %% [markdown]
# Every part/layer of the transformer is built using the Pytorch nn.module class which allows for easy creation of maching learning models. Each layer should be made up of at least two parts: An initialization function which uses the given information to build the class and then the 'Forward' function defines how the class will run when it is called.

# %% [markdown]
# ### Transformer Constructor
#
# First, the actual ViT Constructor which essentially acts as a hub. It ensures that each part of the transformer is called in the correct order and that local variables can be passed along.

# %% [markdown]
# ### What makes it more Compact/Lite than the CVT?
#
# The only difference between this and the original Vision Transformer is a Sequence Pooling layer and a convolutional layer instead of patching. Previously the classes were embedded separately and then passed to the MLP for classification. Sequence Pooling ties the class information in with every other parameter.. I think.

# %%
class CCT(nn.Module):
    '''
    Simplified implementation of the Vision transformer.

    Parameters
    ----------
    img_size: int
        Both height and width of the image (if it is a square)
    in_channels: int
        Number of input channels
    patch_size: int
        Both height and width of the patch (if it is a square)
    embed_dim: int
        The embedding size for each token
    n_layers: int
        Number of transformer blocks
    n_heads: int
        Number of attention heads
    attn_dropout, proj_dropout, mlp_dropout: float
        Dropout probability
    mlp_ratio: float
        Determine the hidden dimension of the MLP module
    qkv_bias: bool
        If true then we add bias to the query, key and value projections
    n_classes: int
        Number of classes

    Attributes
    -----------
    n_patches: int
        Number of patches that can be taken from each image based on size.
    patch_embed: PatchEmbed
        Sets up the `Patching' layer.
    class_embed: nn.Parameter
        Learnable parameter that will represent the first class token in the sequence.
        It has `embed_dim' elements.
    pos_embed: nn.Parameter
        Adds a positional encoding to every token.
    pos_drop: nn.Dropout
        Dropout layer.
    tr_block: nn.ModuleList
        Instance of 'TransformerEncoderLayer'.
    norm: nn.Layernorm
        Layer normalization.
    '''
    def __init__(self,
                 img_size=32,   # The square size of each image
                 in_channels=3, # Number of channels for each image (eg: Grayscale=1, RGB=3)
                 patch_size=4,  # The square size of each patch
                 embed_dim=768,  # Embedding dimension
                 n_layers=3, # How many times to run the transformer encoder
                 n_conv=2, # How many times to run the convolutional filter
                 n_heads=3,   # Number of attention heads,
                 attn_dropout=0.,  # Attention Dropout
                 proj_dropout=0.,   # (MHA) Projection Dropout
                 mlp_dropout=0.,   # (MHA) last layer dropout
                 mlp_ratio=4,   # (MHA) Projection FF dimension
                 qkv_bias = True,
                 n_class=10   # Number of classes to classify
    ):
        super().__init__()
        # Provides an error if the patching size is not divisible by the image size.
        assert img_size % patch_size == 0, \
            print("Given image size ({}) has to be divisible by given patch size ({})".format(img_size, patch_size))
        
        self.conv_embed = Conv_Embed(img_size, in_channels, embed_dim, n_conv)
        n_patches = self.conv_embed.sequence_length(in_channels=in_channels, height=img_size, width=img_size)
        hidden_dim = int(embed_dim * mlp_ratio)
        
        
        self.pos_embed = nn.Parameter(torch.zeros(1, n_patches, embed_dim)) # nn.Parameter makes this learnable weights
        
        # Can use this to enable Sinusoidal PE
        #self.pos_embed = PositionalEmbedding(1, n_patches + 1, embed_dim)

        self.pos_drop = nn.Dropout(p=proj_dropout)
        self.tr_block = nn.ModuleList(
            [
                TransformerEncoderLayer(
                    embed_dim,
                    n_heads,
                    qkv_bias,
                    attn_dropout,
                    proj_dropout,
                    mlp_dropout,
                    hidden_dim
                    )
                for _ in range(n_layers)
            ]   # Sends data through the encoder n times
        )
        self.norm = nn.LayerNorm(embed_dim, eps=1e-6)
        
        self.attention_pool = nn.Linear(embed_dim, 1)
                                    
        self.head = nn.Linear(embed_dim, n_class)

    def forward(self, x):
        '''
        Defines how the class will run

        Parameters
        ----------
        x: torch.Tensor
            shape: n_samples, in_chains, img_size, img_size

        Returns
        ---------
        logits: torch.Tensor
            Logits over all the classes: n_samples, n_samples
        '''
        x = self.conv_embed(x)
        #x = self.pos_embed(x)
        
        x += self.pos_embed
        x = self.pos_drop(x)
        for tr_block in self.tr_block:
            x = tr_block(x)
        x = self.norm(x)
        
        #Added Sequence Pooling instead of Class embedding
        x = torch.matmul(F.softmax(self.attention_pool(x), dim=1).transpose(-1, -2), x).squeeze(-2)
        y = self.head(x)
        
        return [y, x]

# %% [markdown]
# ### Positional Embedding
#
# This is the sinusoidal positional encoding layer as seen in the original 'Attention is All You Need' paper. It basically uses a sin/cos waveform to provide a unique positional offset that is given to a token at the corresponding position in its embedding space.
#
# By default, this is disabled and we instead use a trainable matrix of zeros. This adds another dimension to our data that the model then uses to find the best weights for the data's position itself. This is called "learnable" positional encoding.
#
# There are pros-and-cons to either, but essentially: sinusoidal is better when there are not a lot of data samples to learn the positional data from but you can get better results from "learnable" with larger datasets.

# %%
class PositionalEmbedding(nn.Module):
    '''
    Applies Learnable Sinusoidal Positional Encoding

    Parameters
    ----------
    embed_dim: int
        The positional embedding dimension (How big embedding for each patch.Constant across entire network)
    max_len: int 
        Max number of instances for positions
    freq: int 
        The base frequency for Sin/Cos calculations. Higher values (eg 10000) are more stable
    '''
    def __init__(self, 
                 embed_dim,
                 max_len=5000,
                 freq=10000.,
                ):
        super().__init__()
        pe = torch.zeros(max_len, embed_dim)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div = torch.exp(torch.arange(0, embed_dim, 2).float() *
                        (-math.log(freq) / embed_dim))
        pe[:, 0::2] = torch.sin(position * div) # Even terms
        pe[:, 1::2] = torch.cos(position * div) # Odd terms
        pe = pe.unsqueeze(0).transpose(0,1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        '''
        Defines how the class will run

        Parameters
        -----------

        Returns
        -----------
        '''
        x = x + self.pe[:x.size(0), :]
        return x

# %% [markdown]
# ### Convolutional Embedding Layer
#
# The patching used by the previous models was a problem because, while it took more samples of the input data, it also created what were essentially bordered segments which made it harder for the model to learn how they connected to the other segments and the bigger picture.
#
# The new convolutional layer helps to eliminate that problem by using convolutional filters to create many different overlapping segments.

# %%
class Conv_Embed(nn.Module):
    def __init__(self,
                 img_size=32,
                 in_channels=3,
                 out_channels=64,
                 n_conv=2,
                 kernel_size=3,
                 stride=None,
                 padding=None,
                 pool_kernel_size=3,
                 pool_stride=2,
                 pool_padding=1
                 ):
        super().__init__()
        
        stride = stride if stride is not None else max(1, (kernel_size // 2) - 1)
        padding = padding if padding is not None else max(1, (kernel_size // 2))

        self.img_size = img_size
        if n_conv == 1:
            self.conv_layers = nn.Sequential(
                nn.Conv2d(in_channels,
                        out_channels,
                        kernel_size=kernel_size,
                        stride=stride,
                        padding=padding,
                        bias=False),
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=pool_kernel_size,
                            stride=pool_stride,
                            padding=pool_padding)
            )
        else:
            n_filter_list = [in_channels] + \
                            [64 for _ in range(n_conv - 1)] + \
                            [out_channels]
            
            self.conv_layers = nn.Sequential(
                *[nn.Sequential(
                    nn.Conv2d(n_filter_list[i],
                        n_filter_list[i+1],
                        kernel_size=kernel_size,
                        stride=stride,
                        padding=padding,
                        bias=False),
                    nn.ReLU(),
                    nn.MaxPool2d(kernel_size=pool_kernel_size,
                            stride=pool_stride,
                            padding=pool_padding)
                            )
                    for i in range(n_conv)
                ])
        self.flattener = nn.Flatten(2, 3)
        
        # This, along with the @staticmethod below, help to normalize the convolutional filter by picking better starting weights for optimization.
        self.apply(self.init_weight)

    def sequence_length(self, in_channels=3, height=32, width=32):
        return self.forward(torch.zeros((1, in_channels, height, width))).shape[1]

    def forward(self, x):
        return self.flattener(self.conv_layers(x)).transpose(-2, -1)

    @staticmethod
    def init_weight(m):
        if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight)

# %% [markdown]
# ### This is the Transformer Encoder block which applies all of the actual normalization, attention, etc that make a Transformer what it is.

# %%
class TransformerEncoderLayer(nn.Module):
    '''
    Transformer Block/Encoder Layer

    Parameter
    ---------
    embed_dim: int
        embedding dimension
    n_heads: int
        number of attention heads
    mlp_ratio: float
        determines the hidden dimension size of the MLP module with respect to 'dim'
    qkv_bias: bool
        If true then we include bias to the query, key and value projections
    mlp_dropout, proj_dropout, attn_droupout: float
        dropout probability
    dim_feedforward: int
        The feature number of hidden layer of the FFN

    Attributes
    ----------
    norm_1, norm_2: LayerNorm
        Layer normalization
    MHA: Attention
        Multi-Headed Attention module
    mlp: MLP
        MLP module
    ''' 
    def __init__(self,
                 embed_dim=768,
                 n_heads=12,
                 qkv_bias=True,
                 attn_dropout=0.,
                 proj_dropout=0.,
                 mlp_dropout=0.,
                 hidden_dim=2048
    ):
        super().__init__()
        self.norm_1 = nn.LayerNorm(embed_dim, eps = 1e-6)
        self.norm_2 = nn.LayerNorm(embed_dim, eps = 1e-6)
        self.MHA = MultiheadedSelfAttention(embed_dim,
                                        n_heads,
                                        qkv_bias,
                                        attn_dropout,
                                        proj_dropout
        )
        self.MLP = MLP(embed_dim, hidden_dim, mlp_dropout)

    def forward(self, x):
        '''
        Defines how the class will run
        
        Parameter
        ---------
        x: torch.Tensor
            shape: n_samples, n_patches + 1, dim

        Returns
        --------
        torch.Tensor
            shape: n_samples, n_patches + 1, dim
        '''
        x = x + self.MHA(self.norm_1(x))    # Residual connection (Add)
        x = x + self.MLP(self.norm_2(x))    # Residual connection (Add)
        return x

# %% [markdown]
# ### Multiheaded Attention Layer
#
# The heart of the Transformer model; the reason behind the original title of "attention is all you need".

# %%
class MultiheadedSelfAttention(nn.Module):
    '''
    Multi-Headed Attention Mechanism

    Parameters
    ----------
    embed_dim: int
        The input and out dimension of per token feature
    n_heads: int
        Number of attention heads 
    qkv_bias: bool
        if true then we include bias to the query, key and value projections
    attn_p: float
        Dropout probability applied to the query, key and value tensors.
    proj_p: float
        Dropout probability applied to output tensor
        
    Attributes
    ----------
    scale: float
        Normalizing constant for the dot product
    qkv: nn.Linear
        Linear projection for the query, key and value
    proj: nn.Linear
        Linear mapping that takes in the concatenated output of all attention
        heads and maps into the new space
    attn_drop, proj_drop: nn.Dropout
        Dropout layers.
    '''
    def __init__(self, 
                 embed_dim, 
                 n_heads=2,
                 qkv_bias = True,
                 attn_dropout=0.,
                 proj_dropout=0.
    ):
        super().__init__()
        self.n_heads = n_heads
        assert embed_dim % n_heads == 0, \
            print('Embedding dim must be divisible by number of heads.')
        self.head_dim = embed_dim // n_heads
        self.scale = self.head_dim ** -0.5
        self.dim = embed_dim
        self.qkv = nn.Linear(embed_dim, embed_dim * 3, bias=qkv_bias)
        self.attn_dropout = nn.Dropout(attn_dropout)
        self.proj = nn.Linear(embed_dim, embed_dim)
        self.proj_dropout = nn.Dropout(proj_dropout)
        
    def forward(self, x):
        '''
        Defines how the class will run
        
        Parameters
        ----------
        x: torch.Tensor
            shape: n_samples (B), n_patches + 1 (N), embed_dim (C)
            N is also equal to the number of tokens.
        Returns
        --------
        torch.Tensor
            shape: n_samples, n_patches + 1, embed_dim
        '''
        B, N, C = x.shape
        qkv = self.qkv(x)
        qkv = qkv.reshape(B, N, 3,
            self.n_heads,
            self.head_dim
            )
        qkv = qkv.permute(
            2,    # qkv (3)
            0,    # batch (n_samples)
            3,    # channel (n_heads)
            1,    # n_patches + 1
            4     # head_dim (embed_dim / n_heads)
            )
        q, k, v = qkv[0], qkv[1], qkv[2]
        attn = (q @ k.transpose(-2, -1)) * self.scale # <q,k> / sqrt(d)
        attn = attn.softmax(dim=-1) # Softmax over embedding dim
        attn = self.attn_dropout(attn)

        weighted_avg = (attn @ v)
        weighted_avg = weighted_avg.transpose(1, 2)
        weighted_avg = weighted_avg.flatten(2)

        x = self.proj(weighted_avg)
        x = self.proj_dropout(x)

        return x

# %% [markdown]
# ### The MLP layer
#
# (At the end of the Transformer Encoder). Not to be confused with the mlp head which adds class encodings at the very end of the transformer.

# %%
class MLP(nn.Module):
    '''
    Multilayer perceptron 
    
    Parameters
    ----------
    embed_dim: int
        embedding dimension
    feedforward_dim: int
      Number of nodes in the hidden layer
    mlp_dropout: float
      Dropout probability

    Attribute
    ---------
    fc: nn.Linear
      The first linear layer
    act: nn. GELU
      GELU activation function
    fc2: nn.Linear
      The second linear layer
    drop: nn.Dropout
      Dropout layer
    '''

    def __init__(self, embed_dim, hidden_dim, mlp_dropout):
        super().__init__()
        self.fc1 = nn.Linear(embed_dim, hidden_dim)
        self.act = nn.GELU()
        self.fc2 = nn.Linear(hidden_dim, embed_dim)
        self.drop = nn.Dropout(mlp_dropout)

    def forward(self,x):
        '''
        Defines how the class will run
        
        Parameters
        ----------
        x: torch.Tensor
          shape: n_samples, n_patches + 1, in_features

        Returns
        ----------
        torch.Tensor
          n_samples, n_patches+ 1, out_features
        '''
        x = self.fc1(x) # n_samples, n_patches+1, hidden_features
        x = self.act(x) # n_samples, n_patches+1, hidden_features
        x = self.drop(x) # n_samples, n_patches+1, hidden_features
        x = self.fc2(x) # n_samples, n_patches+1, output_features
        x = self.drop(x) # n_samples, n_patches+1, output_features
        return x

# %% [markdown]
# ## Training with custom dataset

# %%
def sipakmed_prep():
    root = "../../Python Scripts/Datasets/CervicalCancer/Sipakmed/"

    all_img = []
    for path, subdirs, files in os.walk(root):
        for name in files:
            curr_img = os.path.join(path,name)
            all_img.append(curr_img)

    sipakmed_df = pd.DataFrame()
    sipakmed_df['LocalPath'] = all_img
    sipakmed_df['ID'] = sipakmed_df['LocalPath'].apply(lambda x: str(x.split("\\")[-1]))
    sipakmed_df['Slide'] = sipakmed_df['LocalPath'].apply(lambda x: 'False' if (str(x.split("\\")[1])) == 'CROPPED' else 'True')
    sipakmed_df['Specific_Status'] = sipakmed_df['LocalPath'].apply(lambda x: str((x.split("im_")[1]).split("\\")[0]))
    sipakmed_df['Status'] = sipakmed_df['Specific_Status'].apply(lambda x: 'Benign' if x == 'Metaplastic' else
    ('Normal' if x == 'Superficial-Intermediate' or x == 'Parabasal' else 'Abnormal'))

    sp_class = {'Metaplastic':4, 'Superficial-Intermediate':0, 'Parabasal':1, 'Koilocytotic':2, 'Dyskeratotic':3}
    sipakmed_df['Specific_Class'] = sipakmed_df['Specific_Status'].map(sp_class)
    gen_class = {'Benign':0, 'Normal':1, 'Abnormal':2}
    sipakmed_df['Class'] = sipakmed_df['Status'].map(gen_class)
    
    sipakmed_df = sipakmed_df.loc[sipakmed_df['ID'].str.contains('bmp')].reset_index(drop=True)
    
    return sipakmed_df

# %%
def herlev_prep(n_class):
    root = '../../Python Scripts/Datasets/CervicalCancer/Herlev/smear2005/results.csv'
    img_folder = '../../Python Scripts/Datasets/CervicalCancer/Herlev/smear2005/Images/'

    herlev_df=pd.read_csv(root)
    herlev_df = herlev_df.rename(columns={'Class':'Specific_Class'})

    if n_class == 12:
        spec_class = {1:5, 2:6, 3:7, 4:8, 5:9, 6:10, 7:11}
    else:
        spec_class = {1:0, 2:1, 3:2, 4:3, 5:4, 6:5, 7:6}
    
    gen_class = {1:1, 2:1, 3:1, 4:2, 5:2, 6:2, 7:2}
    herlev_df['Class'] = herlev_df['Specific_Class'].map(gen_class)
    herlev_df['Specific_Class'] = herlev_df['Specific_Class'].map(spec_class)
    herlev_df['LocalPath'] = herlev_df['ID'].apply(lambda x: str(img_folder + x))
    return herlev_df

# %%
class DatasetSample(Dataset):
    def __init__(self, df, transform):
        # Initialization
        self.transform = transform
        
        self.image_names = df['LocalPath']
        self.img_class = np.array(df['Class'])

    def __len__(self):
        # Denotes the total number of samples
        return len(self.image_names)
    
    def __getitem__(self, index):
        # Retrieves the data
        image=cv2.imread(self.image_names.iloc[index])
        image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

        image = self.transform(image)
        label = self.img_class[index]

        return image, label

# %%
def concat_data(batch_size=128, img_size=32, n_class=3):
    kwargs = {'num_workers': 1, 'pin_memory': True} if device=='cuda' else {}
    # Load the dataframes
    sipakmed_df = sipakmed_prep()
    herlev_df = herlev_prep(n_class)

    # Final adjustments to make sure they're attributes match
    sipakmed_df = sipakmed_df.loc[sipakmed_df['Slide'] == 'False']

    if n_class == 2:
        classes = ('Normal', 'Abnormal')
        herlev_df = herlev_df.loc[:,['LocalPath', 'Class']]
        sipakmed_df = sipakmed_df.loc[:,['LocalPath', 'Class']]
        concat_df = pd.concat([sipakmed_df,herlev_df], ignore_index=True)
        bin_class = {1:0, 2:0, 3:1}
        concat_df['Class'] = concat_df['Class'].map(bin_class)

    elif n_class == 3:
        classes = ('Benign', 'Normal', 'Abnormal')
        herlev_df = herlev_df.loc[:,['LocalPath', 'Class']]
        sipakmed_df = sipakmed_df.loc[:,['LocalPath', 'Class']]
        concat_df = pd.concat([sipakmed_df,herlev_df], ignore_index=True)

    elif n_class == 5:
        classes = ('Superficial-Intermediate','Parabasal','Koilocytotic','Dyskeratotic','Metaplastic')
        concat_df = pd.DataFrame()
        concat_df['LocalPath'] = sipakmed_df['LocalPath']
        concat_df['Class'] = sipakmed_df['Specific_Class']

    elif n_class == 7:
        classes = ('Superficial-Squamous-Epithelial','Intermediate-Squamous-Epithelial','Columnar-Epithelial','Mild-Squamous-Non-Keratinizing-Dysplasia',
           'Moderate-Squamous-Non-Keratinizing-Dysplasia','Severe-Squamous-Non-Keratinizing-Dysplasia','Squamous-Cell-Carcinoma-in-situ-Intermediate')
        concat_df = pd.DataFrame()
        concat_df['LocalPath'] = herlev_df['LocalPath']
        concat_df['Class'] = herlev_df['Specific_Class']

    elif n_class == 12:
        classes = ('Superficial-Intermediate','Parabasal','Koilocytotic','Dyskeratotic','Metaplastic','Superficial-Squamous-Epithelial','Intermediate-Squamous-Epithelial','Columnar-Epithelial','Mild-Squamous-Non-Keratinizing-Dysplasia',
           'Moderate-Squamous-Non-Keratinizing-Dysplasia','Severe-Squamous-Non-Keratinizing-Dysplasia','Squamous-Cell-Carcinoma-in-situ-Intermediate')
        herlev_df = herlev_df.loc[:,['LocalPath', 'Specific_Class']]
        sipakmed_df = sipakmed_df.loc[:,['LocalPath', 'Specific_Class']]
        concat_df = pd.concat([sipakmed_df,herlev_df], ignore_index=True).rename(columns={'Specific_Class':'Class'})

    # Split them into training, validation, and testing sets
    train_set,val_test_set = train_test_split(concat_df, random_state=1, test_size=0.40)
    val_set,test_set = train_test_split(val_test_set, random_state=1, test_size=0.50)
    
    # Set it up to alter random training images for better results
    train_transform = transforms.Compose([
                    transforms.ToPILImage(),
                    transforms.Resize((img_size, img_size)),
                    transforms.RandomHorizontalFlip(p=0.75),
                    transforms.RandomRotation(degrees=60),
                    transforms.transforms.ColorJitter(brightness=.2, hue=.2),
                    transforms.ToTensor()])

    test_transform = transforms.Compose([
                    transforms.ToPILImage(),
                    transforms.Resize((img_size, img_size)),
                    transforms.ToTensor()])

    train_dataset = DatasetSample(train_set, train_transform)
    val_dataset = DatasetSample(val_set, test_transform)
    test_dataset = DatasetSample(test_set, test_transform)
    
    Dtr = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        generator=torch.Generator().manual_seed(17),
        **kwargs
    )
    
    Dva = DataLoader(
        val_dataset, 
        batch_size=batch_size,
        shuffle=False,
        **kwargs
    )

    Dte = DataLoader(
        test_dataset, 
        batch_size=batch_size,
        shuffle=False,
        **kwargs
    )

    return(Dtr, Dva, Dte, classes, train_set, val_set, test_set)

# %%
batch_size=192
img_size=64
# This sets up which dataset(s) to use and their corresponding class labels
n_class=12

'''
2 uses both datasets. Classes are normal and abnormal.
3 uses both datasets. Classes are benign, normal, and abnormal.
5 uses the Sipakmed dataset. Classes are Superficial-Intermediate, Parabasal, Koilocytotic, Dyskeratotic, and Metaplastic.
7 uses the Herlev dataset. Classes are Superficial Squamous Epithelial, Intermediate Squamous Epithelial, Columnar Epithelial, Mild Squamous Non-Keratinizing Dysplasia,
            Moderate Squamous Non-Keratinizing Dysplasia, Severe Squamous Non-Keratinizing Dysplasia, and Squamous Cell Carcinoma in-situ Intermediate.
12 uses both datasets. Classes are the two above.
'''

Dtr, Dva, Dte, classes, train_set, val_set, test_set = concat_data(batch_size=batch_size, img_size=img_size, n_class=n_class)

# %% [markdown]
# ### Builds the dataloaders for training and testing

# %%
# Turns the dataloaders into iterable objects. Useful for viewing
dataiter = iter(Dtr)
val_dataiter = iter(Dva)
test_dataiter = iter(Dte)

# %% [markdown]
# ### Function for viewing batches of the dataset

# %%
def imshow(images, labels, predicted_labels=None):
    
    if images.is_cuda == True:
        images = images.to("cpu")
    if labels.is_cuda == True:
        labels = labels.to("cpu")

    # Using torchvision to make a grid of the images
    img = torchvision.utils.make_grid(images)

    # Inverting the normalization
    img = img.numpy().transpose((1, 2, 0))
    img = np.clip(img, 0, 1)

    # Plotting the grid
    fig, ax = plt.subplots(figsize=(12, 24))
    plt.imshow(img)

    if predicted_labels is not None:
        if predicted_labels.is_cuda == True:
            predicted_labels = predicted_labels.to("cpu")
        # Outputing the predicted labels
        ax.set_xlabel('Predicted labels', fontsize=18, labelpad=12)
        ax.set_xticks(torch.arange(len(images)) * img_size + (img_size/1.8))
        ax.set_xticklabels([classes[predicted_labels[j]] 
                            for j in range(len(images))], fontsize=12, rotation=30)
    
    # Outputing the True labels
    gax = ax.secondary_xaxis('top')
    gax.set_xlabel('True Labels', fontsize=18, labelpad=12)
    gax.set_xticks(torch.arange(len(images)) * img_size + (img_size/1.8))
    gax.set_xticklabels([classes[labels[j]] 
                         for j in range(len(images))], fontsize=12, rotation=30)
    plt.show()

# %%
images, labels = dataiter.next()
imshow(images[:7], labels[:7])

# %% [markdown]
# ### This function was made by Dr Prashant to train the model that's built above

# %%
# A function to encapsulate the training loop
def batch_gd(model, loss_fn, optimizer, train_loader, val_loader, epochs):
  model.to(device)
  train_losses = np.zeros(epochs)
  val_losses = np.zeros(epochs)
  avg_epoch = []
  
  for it in range(epochs):
    model.train()
    t0 = datetime.now()
    train_loss = []
    n_correct = 0.
    n_total = 0.
    for inputs, targets in train_loader:
      # move data to GPU if available
      inputs, targets = inputs.to(device), targets.to(device)

      # zero the parameter gradients
      optimizer.zero_grad()

      # Forward pass
      outputs = model(inputs)[0]
      
      # Get the predictions
      # torch.max returns both max and argmax
      __, out_label = outputs.max(dim=1)
      # Updates the accuracy with every pass
      n_correct += (out_label == targets).sum().item()
      n_total += targets.shape[0]
      tr_acc = n_correct / n_total

      loss = loss_fn(outputs, targets)
      # Backward and optimize
      loss.backward()
      optimizer.step()

      train_loss.append(loss.item())

    # Get train loss and test loss
    train_loss = np.mean(train_loss) # a little misleading
    
    model.eval()
    val_loss = []
    n_correct = 0.
    n_total = 0.
    for inputs, targets in val_loader:
      inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)[0]

      # Get the predictions
      # torch.max returns both max and argmax
      __, out_label = outputs.max(dim=1)
      # Updates the accuracy with every pass
      n_correct += (out_label == targets).sum().item()
      n_total += targets.shape[0]
      val_acc = n_correct / n_total

      loss = loss_fn(outputs, targets)
      val_loss.append(loss.item())
    val_loss = np.mean(val_loss)

    # Save losses
    train_losses[it] = train_loss
    val_losses[it] = val_loss
    
    dt = datetime.now() - t0
    avg_epoch.append(dt)

    print(f'Epoch {it+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {(100*tr_acc):.3f} \
      Val Loss: {val_loss:.4f}, Val Accuracy: {(100*val_acc):.3f}, Duration: {dt}, Avg_Epoch: {np.mean(avg_epoch)}')
  
  return train_losses, val_losses

# %% [markdown]
# ### Initializes the Transformer and selects the loss function and optimizer we want

# %%
model = CCT(
        img_size=img_size,      # Input image size
        in_channels=3,  # Number of channels for the image
        patch_size=16,   # Patch Size
        embed_dim=129,   # Embedding dim
        n_layers=3,     # Number of transformer encoders
        n_conv=2,       # Number of convolutional layers
        n_heads=3,      # Number of attention heads
        attn_dropout=0.,        # Attention Dropout
        proj_dropout=0.,        # (MHA) Projection Dropout
        mlp_dropout=0.1,        # (MHA) last layer dropout
        mlp_ratio=1,    # (MHA) Projection FF dimension
        qkv_bias = True,
        n_class=n_class     # Number of classes to classify
        )
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())

# %%
train_losses, val_losses = batch_gd(model, loss_fn, optimizer, Dtr, Dva, epochs=100)
# Out:
# Epoch 1/100, Train Loss: 2.1023, Train Accuracy: 28.600       Val Loss: 1.7261, Val Accuracy: 44.512, Duration: 0:00:13.689001, Avg_Epoch: 0:00:13.689001
# Epoch 2/100, Train Loss: 1.7939, Train Accuracy: 39.745       Val Loss: 1.5981, Val Accuracy: 50.252, Duration: 0:00:09.262998, Avg_Epoch: 0:00:11.476000
# Epoch 3/100, Train Loss: 1.7390, Train Accuracy: 43.907       Val Loss: 1.5682, Val Accuracy: 51.158, Duration: 0:00:09.913003, Avg_Epoch: 0:00:10.955001
# Epoch 4/100, Train Loss: 1.6306, Train Accuracy: 47.835       Val Loss: 1.3870, Val Accuracy: 56.999, Duration: 0:00:10.532996, Avg_Epoch: 0:00:10.849500
# Epoch 5/100, Train Loss: 1.5457, Train Accuracy: 50.050       Val Loss: 1.3165, Val Accuracy: 56.999, Duration: 0:00:09.219999, Avg_Epoch: 0:00:10.523599
# Epoch 6/100, Train Loss: 1.4540, Train Accuracy: 53.139       Val Loss: 1.3640, Val Accuracy: 56.596, Duration: 0:00:09.430999, Avg_Epoch: 0:00:10.341499
# Epoch 7/100, Train Loss: 1.4239, Train Accuracy: 53.709       Val Loss: 1.1715, Val Accuracy: 64.552, Duration: 0:00:09.157001, Avg_Epoch: 0:00:10.172285
# Epoch 8/100, Train Loss: 1.3188, Train Accuracy: 57.234       Val Loss: 1.1874, Val Accuracy: 62.941, Duration: 0:00:10.246000, Avg_Epoch: 0:00:10.181500
# Epoch 9/100, Train Loss: 1.2238, Train Accuracy: 60.289       Val Loss: 1.0782, Val Accuracy: 64.753, Duration: 0:00:09.639999, Avg_Epoch: 0:00:10.121333
# Epoch 10/100, Train Loss: 1.1302, Train Accuracy: 63.679       Val Loss: 1.0618, Val Accuracy: 68.882, Duration: 0:00:09.517000, Avg_Epoch: 0:00:10.060900
# Epoch 11/100, Train Loss: 1.1079, Train Accuracy: 64.015       Val Loss: 0.9065, Val Accuracy: 69.889, Duration: 0:00:09.558001, Avg_Epoch: 0:00:10.015182
# Epoch 12/100, Train Loss: 1.0140, Train Accuracy: 67.842       Val Loss: 1.0049, Val Accuracy: 66.566, Duration: 0:00:09.866000, Avg_Epoch: 0:00:10.002750
# Epoch 13/100, Train Loss: 0.9364, Train Accuracy: 69.386       Val Loss: 0.8208, Val Accuracy: 74.018, Duration: 0:00:09.682997, Avg_Epoch: 0:00:09.978153
# Epoch 14/100, Train Loss: 0.8683, Train Accuracy: 70.628       Val Loss: 0.8829, Val Accuracy: 72.508, Duration: 0:00:08.101001, Avg_Epoch: 0:00:09.844071
# Epoch 15/100, Train Loss: 0.8163, Train Accuracy: 71.836       Val Loss: 0.8250, Val Accuracy: 75.126, Duration: 0:00:08.754000, Avg_Epoch: 0:00:09.771400
# Epoch 16/100, Train Loss: 0.8145, Train Accuracy: 72.373       Val Loss: 0.8387, Val Accuracy: 75.629, Duration: 0:00:08.698001, Avg_Epoch: 0:00:09.704312
# Epoch 17/100, Train Loss: 0.7724, Train Accuracy: 74.186       Val Loss: 0.7310, Val Accuracy: 77.644, Duration: 0:00:09.141001, Avg_Epoch: 0:00:09.671176
# Epoch 18/100, Train Loss: 0.7072, Train Accuracy: 76.099       Val Loss: 0.6999, Val Accuracy: 79.355, Duration: 0:00:08.680997, Avg_Epoch: 0:00:09.616166
# Epoch 19/100, Train Loss: 0.6360, Train Accuracy: 77.912       Val Loss: 0.6407, Val Accuracy: 81.269, Duration: 0:00:08.173002, Avg_Epoch: 0:00:09.540210
# Epoch 20/100, Train Loss: 0.5991, Train Accuracy: 78.953       Val Loss: 0.6561, Val Accuracy: 79.960, Duration: 0:00:09.011000, Avg_Epoch: 0:00:09.513750
# Epoch 21/100, Train Loss: 0.6078, Train Accuracy: 78.886       Val Loss: 0.6627, Val Accuracy: 79.758, Duration: 0:00:08.197000, Avg_Epoch: 0:00:09.451047
# Epoch 22/100, Train Loss: 0.6423, Train Accuracy: 77.375       Val Loss: 0.6428, Val Accuracy: 79.658, Duration: 0:00:08.578999, Avg_Epoch: 0:00:09.411409
# Epoch 23/100, Train Loss: 0.6343, Train Accuracy: 78.013       Val Loss: 0.6237, Val Accuracy: 81.873, Duration: 0:00:08.411001, Avg_Epoch: 0:00:09.367913
# Epoch 24/100, Train Loss: 0.6087, Train Accuracy: 79.355       Val Loss: 0.6064, Val Accuracy: 79.758, Duration: 0:00:08.711005, Avg_Epoch: 0:00:09.340542
# Epoch 25/100, Train Loss: 0.6343, Train Accuracy: 77.341       Val Loss: 0.6534, Val Accuracy: 79.355, Duration: 0:00:08.128999, Avg_Epoch: 0:00:09.292080
# Epoch 26/100, Train Loss: 0.5465, Train Accuracy: 80.933       Val Loss: 0.5249, Val Accuracy: 82.578, Duration: 0:00:08.183998, Avg_Epoch: 0:00:09.249461
# Epoch 27/100, Train Loss: 0.5293, Train Accuracy: 81.235       Val Loss: 0.6024, Val Accuracy: 82.377, Duration: 0:00:08.101000, Avg_Epoch: 0:00:09.206926
# Epoch 28/100, Train Loss: 0.5294, Train Accuracy: 80.564       Val Loss: 0.6831, Val Accuracy: 78.953, Duration: 0:00:08.851998, Avg_Epoch: 0:00:09.194250
# Epoch 29/100, Train Loss: 0.5221, Train Accuracy: 81.302       Val Loss: 0.5921, Val Accuracy: 83.585, Duration: 0:00:08.828999, Avg_Epoch: 0:00:09.181655
# Epoch 30/100, Train Loss: 0.5105, Train Accuracy: 82.041       Val Loss: 0.6699, Val Accuracy: 80.967, Duration: 0:00:08.263000, Avg_Epoch: 0:00:09.151033
# Epoch 31/100, Train Loss: 0.4965, Train Accuracy: 82.108       Val Loss: 0.5311, Val Accuracy: 82.477, Duration: 0:00:07.928000, Avg_Epoch: 0:00:09.111580
# Epoch 32/100, Train Loss: 0.4446, Train Accuracy: 83.350       Val Loss: 0.5766, Val Accuracy: 82.779, Duration: 0:00:08.095002, Avg_Epoch: 0:00:09.079812
# Epoch 33/100, Train Loss: 0.4123, Train Accuracy: 85.163       Val Loss: 0.5534, Val Accuracy: 83.988, Duration: 0:00:07.959999, Avg_Epoch: 0:00:09.045879
# Epoch 34/100, Train Loss: 0.4299, Train Accuracy: 84.424       Val Loss: 0.5952, Val Accuracy: 80.866, Duration: 0:00:08.587999, Avg_Epoch: 0:00:09.032412
# Epoch 35/100, Train Loss: 0.4527, Train Accuracy: 83.182       Val Loss: 0.4822, Val Accuracy: 84.491, Duration: 0:00:08.439000, Avg_Epoch: 0:00:09.015457
# Epoch 36/100, Train Loss: 0.4157, Train Accuracy: 84.458       Val Loss: 0.4860, Val Accuracy: 85.398, Duration: 0:00:08.380001, Avg_Epoch: 0:00:08.997805
# Epoch 37/100, Train Loss: 0.4083, Train Accuracy: 85.431       Val Loss: 0.5374, Val Accuracy: 84.290, Duration: 0:00:09.021998, Avg_Epoch: 0:00:08.998459
# Epoch 38/100, Train Loss: 0.4187, Train Accuracy: 84.827       Val Loss: 0.5230, Val Accuracy: 83.384, Duration: 0:00:09.192001, Avg_Epoch: 0:00:09.003552
# Epoch 39/100, Train Loss: 0.4182, Train Accuracy: 85.096       Val Loss: 0.4984, Val Accuracy: 83.887, Duration: 0:00:08.295000, Avg_Epoch: 0:00:08.985384
# Epoch 40/100, Train Loss: 0.4295, Train Accuracy: 84.693       Val Loss: 0.4751, Val Accuracy: 85.801, Duration: 0:00:08.526001, Avg_Epoch: 0:00:08.973900
# Epoch 41/100, Train Loss: 0.4624, Train Accuracy: 83.518       Val Loss: 0.5178, Val Accuracy: 83.686, Duration: 0:00:08.319997, Avg_Epoch: 0:00:08.957951
# Epoch 42/100, Train Loss: 0.4102, Train Accuracy: 85.230       Val Loss: 0.4974, Val Accuracy: 84.391, Duration: 0:00:08.587000, Avg_Epoch: 0:00:08.949119
# Epoch 43/100, Train Loss: 0.4146, Train Accuracy: 84.592       Val Loss: 0.4841, Val Accuracy: 85.297, Duration: 0:00:08.485999, Avg_Epoch: 0:00:08.938349
# Epoch 44/100, Train Loss: 0.3845, Train Accuracy: 85.868       Val Loss: 0.4999, Val Accuracy: 84.693, Duration: 0:00:08.585002, Avg_Epoch: 0:00:08.930318
# Epoch 45/100, Train Loss: 0.4017, Train Accuracy: 85.230       Val Loss: 0.5559, Val Accuracy: 83.283, Duration: 0:00:08.370002, Avg_Epoch: 0:00:08.917867
# Epoch 46/100, Train Loss: 0.3831, Train Accuracy: 85.834       Val Loss: 0.4738, Val Accuracy: 86.203, Duration: 0:00:08.554999, Avg_Epoch: 0:00:08.909978
# Epoch 47/100, Train Loss: 0.3795, Train Accuracy: 87.076       Val Loss: 0.4944, Val Accuracy: 86.103, Duration: 0:00:08.607999, Avg_Epoch: 0:00:08.903553
# Epoch 48/100, Train Loss: 0.3767, Train Accuracy: 86.271       Val Loss: 0.5206, Val Accuracy: 85.096, Duration: 0:00:09.471002, Avg_Epoch: 0:00:08.915375
# Epoch 49/100, Train Loss: 0.3480, Train Accuracy: 86.942       Val Loss: 0.5349, Val Accuracy: 85.498, Duration: 0:00:08.152998, Avg_Epoch: 0:00:08.899816
# Epoch 50/100, Train Loss: 0.3480, Train Accuracy: 86.506       Val Loss: 0.5077, Val Accuracy: 84.592, Duration: 0:00:08.057002, Avg_Epoch: 0:00:08.882960
# Epoch 51/100, Train Loss: 0.3429, Train Accuracy: 87.647       Val Loss: 0.4799, Val Accuracy: 86.103, Duration: 0:00:08.051001, Avg_Epoch: 0:00:08.866647
# Epoch 52/100, Train Loss: 0.3548, Train Accuracy: 86.908       Val Loss: 0.4839, Val Accuracy: 84.491, Duration: 0:00:08.262998, Avg_Epoch: 0:00:08.855038
# Epoch 53/100, Train Loss: 0.3510, Train Accuracy: 86.707       Val Loss: 0.4895, Val Accuracy: 86.405, Duration: 0:00:08.018001, Avg_Epoch: 0:00:08.839245
# Epoch 54/100, Train Loss: 0.3277, Train Accuracy: 88.218       Val Loss: 0.5204, Val Accuracy: 85.096, Duration: 0:00:07.984998, Avg_Epoch: 0:00:08.823426
# Epoch 55/100, Train Loss: 0.3651, Train Accuracy: 86.304       Val Loss: 0.4838, Val Accuracy: 84.794, Duration: 0:00:07.947003, Avg_Epoch: 0:00:08.807491
# Epoch 56/100, Train Loss: 0.3357, Train Accuracy: 87.647       Val Loss: 0.4725, Val Accuracy: 85.700, Duration: 0:00:08.001000, Avg_Epoch: 0:00:08.793089
# Epoch 57/100, Train Loss: 0.3114, Train Accuracy: 88.755       Val Loss: 0.5454, Val Accuracy: 83.887, Duration: 0:00:08.065999, Avg_Epoch: 0:00:08.780333
# Epoch 58/100, Train Loss: 0.3353, Train Accuracy: 87.983       Val Loss: 0.4989, Val Accuracy: 85.297, Duration: 0:00:08.048999, Avg_Epoch: 0:00:08.767724
# Epoch 59/100, Train Loss: 0.2963, Train Accuracy: 88.788       Val Loss: 0.4627, Val Accuracy: 85.901, Duration: 0:00:07.938998, Avg_Epoch: 0:00:08.753678
# Epoch 60/100, Train Loss: 0.3123, Train Accuracy: 88.654       Val Loss: 0.4434, Val Accuracy: 85.901, Duration: 0:00:07.970003, Avg_Epoch: 0:00:08.740617
# Epoch 61/100, Train Loss: 0.3118, Train Accuracy: 88.318       Val Loss: 0.4440, Val Accuracy: 86.506, Duration: 0:00:08.106996, Avg_Epoch: 0:00:08.730229
# Epoch 62/100, Train Loss: 0.3110, Train Accuracy: 88.620       Val Loss: 0.4517, Val Accuracy: 85.498, Duration: 0:00:07.990001, Avg_Epoch: 0:00:08.718290
# Epoch 63/100, Train Loss: 0.3299, Train Accuracy: 87.647       Val Loss: 0.5212, Val Accuracy: 84.491, Duration: 0:00:08.010999, Avg_Epoch: 0:00:08.707063
# Epoch 64/100, Train Loss: 0.3033, Train Accuracy: 88.251       Val Loss: 0.4361, Val Accuracy: 85.700, Duration: 0:00:07.971999, Avg_Epoch: 0:00:08.695578
# Epoch 65/100, Train Loss: 0.3082, Train Accuracy: 88.687       Val Loss: 0.5201, Val Accuracy: 84.089, Duration: 0:00:08.187001, Avg_Epoch: 0:00:08.687754
# Epoch 66/100, Train Loss: 0.3058, Train Accuracy: 89.157       Val Loss: 0.4788, Val Accuracy: 85.297, Duration: 0:00:08.081999, Avg_Epoch: 0:00:08.678576
# Epoch 67/100, Train Loss: 0.2817, Train Accuracy: 89.225       Val Loss: 0.5682, Val Accuracy: 83.283, Duration: 0:00:07.917999, Avg_Epoch: 0:00:08.667224
# Epoch 68/100, Train Loss: 0.2773, Train Accuracy: 89.829       Val Loss: 0.4850, Val Accuracy: 85.700, Duration: 0:00:07.946000, Avg_Epoch: 0:00:08.656618
# Epoch 69/100, Train Loss: 0.2731, Train Accuracy: 89.795       Val Loss: 0.4683, Val Accuracy: 87.110, Duration: 0:00:08.123999, Avg_Epoch: 0:00:08.648898
# Epoch 70/100, Train Loss: 0.2545, Train Accuracy: 90.332       Val Loss: 0.5601, Val Accuracy: 83.585, Duration: 0:00:07.942000, Avg_Epoch: 0:00:08.638800
# Epoch 71/100, Train Loss: 0.2821, Train Accuracy: 89.460       Val Loss: 0.5413, Val Accuracy: 84.189, Duration: 0:00:07.911000, Avg_Epoch: 0:00:08.628549
# Epoch 72/100, Train Loss: 0.2715, Train Accuracy: 89.695       Val Loss: 0.4607, Val Accuracy: 87.412, Duration: 0:00:08.012998, Avg_Epoch: 0:00:08.620000
# Epoch 73/100, Train Loss: 0.2679, Train Accuracy: 90.131       Val Loss: 0.5387, Val Accuracy: 86.808, Duration: 0:00:07.991000, Avg_Epoch: 0:00:08.611383
# Epoch 74/100, Train Loss: 0.2670, Train Accuracy: 90.601       Val Loss: 0.4348, Val Accuracy: 87.009, Duration: 0:00:08.111998, Avg_Epoch: 0:00:08.604635
# Epoch 75/100, Train Loss: 0.2629, Train Accuracy: 90.366       Val Loss: 0.4342, Val Accuracy: 87.009, Duration: 0:00:07.977000, Avg_Epoch: 0:00:08.596266
# Epoch 76/100, Train Loss: 0.2553, Train Accuracy: 90.467       Val Loss: 0.5263, Val Accuracy: 84.089, Duration: 0:00:07.955001, Avg_Epoch: 0:00:08.587829
# Epoch 77/100, Train Loss: 0.2881, Train Accuracy: 89.023       Val Loss: 0.4790, Val Accuracy: 86.103, Duration: 0:00:07.987999, Avg_Epoch: 0:00:08.580039
# Epoch 78/100, Train Loss: 0.2583, Train Accuracy: 90.869       Val Loss: 0.4481, Val Accuracy: 86.304, Duration: 0:00:08.210000, Avg_Epoch: 0:00:08.575295
# Epoch 79/100, Train Loss: 0.2361, Train Accuracy: 91.574       Val Loss: 0.4652, Val Accuracy: 87.412, Duration: 0:00:08.160000, Avg_Epoch: 0:00:08.570038
# Epoch 80/100, Train Loss: 0.2228, Train Accuracy: 92.615       Val Loss: 0.5107, Val Accuracy: 83.384, Duration: 0:00:08.547001, Avg_Epoch: 0:00:08.569750
# Epoch 81/100, Train Loss: 0.2452, Train Accuracy: 91.138       Val Loss: 0.4484, Val Accuracy: 87.210, Duration: 0:00:08.700998, Avg_Epoch: 0:00:08.571370
# Epoch 82/100, Train Loss: 0.2314, Train Accuracy: 91.339       Val Loss: 0.4838, Val Accuracy: 85.801, Duration: 0:00:08.822998, Avg_Epoch: 0:00:08.574439
# Epoch 83/100, Train Loss: 0.2277, Train Accuracy: 91.641       Val Loss: 0.4677, Val Accuracy: 86.506, Duration: 0:00:08.540000, Avg_Epoch: 0:00:08.574024
# Epoch 84/100, Train Loss: 0.2196, Train Accuracy: 92.078       Val Loss: 0.4700, Val Accuracy: 86.405, Duration: 0:00:08.568001, Avg_Epoch: 0:00:08.573952
# Epoch 85/100, Train Loss: 0.2355, Train Accuracy: 91.172       Val Loss: 0.4784, Val Accuracy: 87.210, Duration: 0:00:08.679001, Avg_Epoch: 0:00:08.575188
# Epoch 86/100, Train Loss: 0.2205, Train Accuracy: 91.239       Val Loss: 0.4370, Val Accuracy: 87.009, Duration: 0:00:08.666998, Avg_Epoch: 0:00:08.576256
# Epoch 87/100, Train Loss: 0.2342, Train Accuracy: 91.306       Val Loss: 0.4795, Val Accuracy: 85.901, Duration: 0:00:08.635998, Avg_Epoch: 0:00:08.576942
# Epoch 88/100, Train Loss: 0.2318, Train Accuracy: 91.239       Val Loss: 0.4841, Val Accuracy: 85.096, Duration: 0:00:08.611000, Avg_Epoch: 0:00:08.577329
# Epoch 89/100, Train Loss: 0.2256, Train Accuracy: 91.742       Val Loss: 0.5115, Val Accuracy: 86.808, Duration: 0:00:09.021006, Avg_Epoch: 0:00:08.582314
# Epoch 90/100, Train Loss: 0.2145, Train Accuracy: 92.044       Val Loss: 0.4650, Val Accuracy: 85.801, Duration: 0:00:08.606993, Avg_Epoch: 0:00:08.582589
# Epoch 91/100, Train Loss: 0.2101, Train Accuracy: 92.514       Val Loss: 0.4771, Val Accuracy: 84.995, Duration: 0:00:08.590000, Avg_Epoch: 0:00:08.582670
# Epoch 92/100, Train Loss: 0.2224, Train Accuracy: 92.481       Val Loss: 0.4547, Val Accuracy: 87.110, Duration: 0:00:08.669000, Avg_Epoch: 0:00:08.583608
# Epoch 93/100, Train Loss: 0.2035, Train Accuracy: 92.481       Val Loss: 0.4489, Val Accuracy: 87.110, Duration: 0:00:08.790001, Avg_Epoch: 0:00:08.585828
# Epoch 94/100, Train Loss: 0.2055, Train Accuracy: 92.447       Val Loss: 0.4847, Val Accuracy: 87.110, Duration: 0:00:08.654000, Avg_Epoch: 0:00:08.586553
# Epoch 95/100, Train Loss: 0.2071, Train Accuracy: 92.111       Val Loss: 0.4559, Val Accuracy: 87.110, Duration: 0:00:08.587999, Avg_Epoch: 0:00:08.586568
# Epoch 96/100, Train Loss: 0.2026, Train Accuracy: 92.313       Val Loss: 0.4604, Val Accuracy: 85.498, Duration: 0:00:08.713001, Avg_Epoch: 0:00:08.587885
# Epoch 97/100, Train Loss: 0.1995, Train Accuracy: 92.481       Val Loss: 0.4748, Val Accuracy: 86.506, Duration: 0:00:08.590998, Avg_Epoch: 0:00:08.587917
# Epoch 98/100, Train Loss: 0.2134, Train Accuracy: 92.313       Val Loss: 0.4064, Val Accuracy: 85.700, Duration: 0:00:08.619001, Avg_Epoch: 0:00:08.588234
# Epoch 99/100, Train Loss: 0.1925, Train Accuracy: 92.850       Val Loss: 0.4836, Val Accuracy: 86.002, Duration: 0:00:08.636999, Avg_Epoch: 0:00:08.588727
# Epoch 100/100, Train Loss: 0.1934, Train Accuracy: 93.018       Val Loss: 0.4349, Val Accuracy: 87.412, Duration: 0:00:08.836000, Avg_Epoch: 0:00:08.591200

# %%
dataiter = iter(Dtr)
val_dataiter = iter(Dva)
test_dataiter = iter(Dte)
images, labels = val_dataiter.next()
out_img, predicted = torch.max(model(images.to(device))[0], 1)
imshow(images[:7], labels[:7], predicted[:7])

# %%
# Plot the train loss and test loss per iteration
plt.figure(figsize=(12, 6))
plt.plot(train_losses, label='train loss')
plt.plot(val_losses, label='val loss')
plt.title('Training vs Validation Cross-Entropy Loss')
plt.xlabel('Epochs')
plt.ylabel('Average Loss')
plt.legend()
plt.show()

# %%
test_loss = []
test_acc = []
n_correct = 0.
n_total = 0.
confusion_matrix = np.zeros((n_class, n_class))
raw_train = []
true_train = []
raw_val = []
true_val = []
raw_test = []
true_test = []

model.eval()
with torch.no_grad():
    for inputs, targets in Dtr:
        inputs, targets = inputs.to(device), targets.to(device)
        raw_train.append(model(inputs)[1].to('cpu')) # List of 128 x 12 matrices
        true_train.append(targets.to('cpu'))

    for inputs, targets in Dva:
        inputs, targets = inputs.to(device), targets.to(device)
        raw_val.append(model(inputs)[1].to('cpu')) # List of 128 x 12 matrices
        true_val.append(targets.to('cpu'))

    for inputs, targets in Dte:
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = model(inputs)[0]
        raw_test.append(model(inputs)[1].to('cpu')) # List of 128 x 12 matrices
        true_test.append(targets.to('cpu'))
        # Get the predictions
        # torch.max returns both max and argmax
        __, out_label = outputs.max(dim=1)
        # Updates the accuracy with every pass
        n_correct += (out_label == targets).sum().item()
        n_total += targets.shape[0]
        for t, p in zip(targets.view(-1), out_label.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1
        test_acc.append(n_correct / n_total)

        loss = loss_fn(outputs, targets)
        test_loss.append(loss.item())

x_tr = np.array(raw_train[0])
for i in range(1,len(raw_train)):
        x_tr = np.concatenate((x_tr, raw_train[i]), axis=0)
y_tr = np.array(true_train[0])
for i in range(1,len(true_train)):
        y_tr = np.concatenate((y_tr, true_train[i]), axis=0)

x_va = np.array(raw_val[0])
for i in range(1,len(raw_val)):
        x_va = np.concatenate((x_va, raw_val[i]), axis=0)
y_va = np.array(true_val[0])
for i in range(1,len(true_val)):
        y_va = np.concatenate((y_va, true_val[i]), axis=0)

x_te = np.array(raw_test[0])
for i in range(1,len(raw_test)):
        x_te = np.concatenate((x_te, raw_test[i]), axis=0)
y_te = np.array(true_test[0])
for i in range(1,len(true_test)):
        y_te = np.concatenate((y_te, true_test[i]), axis=0)

test_loss = np.mean(test_loss)
avg_acc = np.mean(test_acc)*100
print('The total number of samples for Training is: {}, Validation: {}, and Testing: {}'.format(len(Dtr)*batch_size, len(Dva)*batch_size, len(Dte)*batch_size))
print('Average loss across the testing data: {}, Average testing accuracy: {}'.format(test_loss, avg_acc))
# Out:
# The total number of samples for Training is: 3072, Validation: 1152, and Testing: 1152
# Average loss across the testing data: 0.4441873182853063, Average testing accuracy: 88.18817418399286

# %%
plt.figure(figsize=(15,10))

class_names = list(classes)
cm_df = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(cm_df, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# If the CCT was trained on 12 classes, this changes the classification back to 3

# %%
if n_class == 12:
    generalize = {0:1, 1:1, 2:2, 3:2, 4:0, 5:1, 6:1, 7:1, 8:2, 9:2, 10:2, 11:2}
    y_tr = pd.DataFrame(y_tr, columns=['y'])
    y_tr['y'] = y_tr['y'].map(generalize).to_numpy()
    y_va = pd.DataFrame(y_va, columns=['y'])
    y_va['y'] = y_va['y'].map(generalize).to_numpy()
    y_te = pd.DataFrame(y_te, columns=['y'])
    y_te['y'] = y_te['y'].map(generalize).to_numpy()
    y_tr = y_tr['y'].to_numpy()
    y_va = y_va['y'].to_numpy()
    y_te = y_te['y'].to_numpy()

# %%
def conf_mat(y_te,y_pred):
    plt.figure(figsize=(15,10))

    confusion_matrix = np.zeros((3, 3))
    for i in range(len(y_pred)):
        confusion_matrix[y_te[i]][y_pred[i]] += 1

    three_class = ['Benign', 'Normal', 'Abnormal']
    cm_df = pd.DataFrame(confusion_matrix, index=three_class, columns=three_class).astype(int)
    heatmap = sns.heatmap(cm_df, annot=True, fmt="d")

    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

    print(accuracy_score(y_pred,y_te))

# %% [markdown]
# ## Support Vector Classification

# %%
clf = svm.SVC()
clf.fit(x_tr, y_tr)
y_pred = clf.predict(x_te)
conf_mat(y_te,y_pred)
# Out:
# 0.9537223340040242

# %% [markdown]
# ## Random Forest Classification

# %%
clf = RandomForestClassifier(random_state=0)
clf.fit(x_tr, y_tr)
y_pred = clf.predict(x_te)
conf_mat(y_te,y_pred)
# Out:
# 0.9486921529175051

# %% [markdown]
# ## Gaussian Process Classification

# %% [markdown]
# ### RBF

# %%
kernel = 1.0 * RBF(1.0)
gpc = GaussianProcessClassifier(kernel=kernel,random_state=0)
gpc.fit(x_tr, y_tr)
y_pred = gpc.predict(x_te)
conf_mat(y_te,y_pred)
# Out:
# 0.9496981891348089

# %% [markdown]
# ### Matern

# %%
kernel = 1.0 * Matern(length_scale=1.0, nu=1.5)
gpc = GaussianProcessClassifier(kernel=kernel,random_state=0)
gpc.fit(x_tr, y_tr)
y_pred = gpc.predict(x_te)
conf_mat(y_te,y_pred)
# Out:
# 0.9537223340040242

# %% [markdown]
# ## ANN

# %% [markdown]
# -Get training data to Wairimu
# -Try gaussian process classification
# Adjust hp of above models for best results using val first
# Simple ANN at the end set to 3 classes
# Plot data to show feature representation

# %%
# Plot the train loss and test loss per iteration
plt.figure(figsize=(12, 6))
plt.plot(train_losses, label='train loss')
plt.plot(val_losses, label='val loss')
plt.title('Training vs Validation Cross-Entropy Loss')
plt.xlabel('Epochs')
plt.ylabel('Average Loss')
plt.legend()
plt.show()

# %%
y = np_utils.to_categorical(y_tr)

# %%
def Simple_ANN():
        model = Sequential()
        model.add(Dense(1489, input_dim=128, activation='relu'))
        model.add(Dense(744, activation='relu'))
        model.add(Dense(372, activation='relu'))
        model.add(Dense(186, activation='relu'))
        model.add(Dense(3, activation='softmax'))
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
        return(model)
estimator = KerasClassifier(build_fn=Simple_ANN, epochs=10, batch_size=64, verbose=0)
kfold = KFold(n_splits=10, shuffle=True)
results = cross_val_score(estimator, x_tr, y, cv=kfold)
print('The ANN was {}% accurate.'.format(round(results.mean(),4)*100))
# Out:
# The ANN was nan% accurate.

# %%
import os
from PIL import Image
import torch
from torch.utils.data import DataLoader,Dataset
import torch.nn as nn
from torch import Tensor
import torchvision
import torchvision.transforms as transforms
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import seaborn as sns
import torch.nn.functional as F
from datetime import datetime
from sklearn.model_selection import train_test_split

torch.manual_seed(17)

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
torch.backends.cudnn.benchmark = True

# %% [markdown]
# # The 'An Image is Worth 16x16 Words' Vision Transformer
# *Created using the walkthrough from https://medium.com/pytorch/training-compact-transformers-from-scratch-in-30-minutes-with-pytorch-ff5c21668ed5 and Dr Prashant's Vision_Transformer file

# %% [markdown]
# ## Building the Transformer block by block

# %% [markdown]
# Every part/layer of the transformer is built using the Pytorch nn.module class which allows for easy creation of maching learning models. Each layer should be made up of at least two parts: An initialization function which uses the given information to build the class and then the 'Forward' function defines how the class will run when it is called.

# %% [markdown]
# ### Transformer Constructor
#
# First, the actual ViT Constructor which essentially acts as a hub. It ensures that each part of the transformer is called in the correct order and that local variables can be passed along.

# %%
class ViT(nn.Module):
    '''
    Simplified implementation of the Vision transformer.

    Parameters
    ----------
    img_size: int
        Both height and width of the image (if it is a square)
    in_channels: int
        Number of input channels
    patch_size: int
        Both height and width of the patch (if it is a square)
    embed_dim: int
        The embedding size for each token
    n_layers: int
        Number of transformer blocks
    n_heads: int
        Number of attention heads
    attn_dropout, proj_dropout, mlp_dropout: float
        Dropout probability
    mlp_ratio: float
        Determine the hidden dimension of the MLP module
    qkv_bias: bool
        If true then we add bias to the query, key and value projections
    n_classes: int
        Number of classes

    Attributes
    -----------
    n_patches: int
        Number of patches that can be taken from each image based on size.
    patch_embed: PatchEmbed
        Sets up the `Patching' layer.
    class_embed: nn.Parameter
        Learnable parameter that will represent the first class token in the sequence.
        It has `embed_dim' elements.
    pos_embed: nn.Parameter
        Adds a positional encoding to every token.
    pos_drop: nn.Dropout
        Dropout layer.
    tr_block: nn.ModuleList
        Instance of 'TransformerEncoderLayer'.
    norm: nn.Layernorm
        Layer normalization.
    '''
    def __init__(self,
                 img_size=32,   # The square size of each image
                 in_channels=3, # Number of channels for each image (eg: Grayscale=1, RGB=3)
                 patch_size=4,  # The square size of each patch
                 embed_dim=42,  # Embedding dimension
                 n_layers=3, # How many times to run the transformer encoder
                 n_heads=3,   # Number of attention heads
                 attn_dropout=0.,  # Attention Dropout
                 proj_dropout=0.,   # (MHA) Projection Dropout
                 mlp_dropout=0.,   # (MHA) last layer dropout
                 mlp_ratio=4,   # (MHA) Projection FF dimension
                 qkv_bias = True,
                 n_classes=10   # Number of classes to classify
    ):
        super().__init__()
        # Provides an error if the patching size is not divisible by the image size.
        assert img_size % patch_size == 0, \
            print("Given image size ({}) has to be divisible by given patch size ({})".format(img_size, patch_size))
            
        n_patches = (img_size // patch_size) ** 2
        hidden_dim = int(embed_dim * mlp_ratio)
        
        self.patch_embed = Patching(
            in_channels,
            patch_size,
            embed_dim
        )

        self.class_embed = nn.Parameter(torch.zeros(1,1, embed_dim))
        self.pos_embed = nn.Parameter(torch.zeros(1, n_patches+1, embed_dim))
        # Can use this to enable Sinusoidal PE
        #self.pos_embed = PositionalEmbedding(1, n_patches + 1, embed_dim)

        self.pos_drop = nn.Dropout(p=proj_dropout)
        self.tr_block = nn.ModuleList(
            [
                TransformerEncoderLayer(
                    embed_dim,
                    n_heads,
                    qkv_bias,
                    attn_dropout,
                    proj_dropout,
                    mlp_dropout,
                    hidden_dim
                    )
                for _ in range(n_layers)
            ]   # Sends data through the encoder n times
        )
                                    
        self.norm = nn.LayerNorm(embed_dim, eps=1e-6)
        self.head = nn.Linear(embed_dim, n_classes)

    def forward(self, x):
        '''
        Defines how the class will run

        Parameters
        ----------
        x: torch.Tensor
            shape: n_samples, in_chains, img_size, img_size

        Returns
        ---------
        logits: torch.Tensor
            Logits over all the classes: n_samples, n_samples
        '''
        x = self.patch_embed(x)
        class_token = self.class_embed.expand(x.shape[0], -1, -1)
        x = torch.cat((class_token, x), dim=1)
        #x = self.pos_embed(x)
        x += self.pos_embed
        x = self.pos_drop(x)
        for tr_block in self.tr_block:
            x = tr_block(x)
        x = self.norm(x)
        x = x[:, 0]
        x = self.head(x)
        return x

# %% [markdown]
# ### Positional Embedding
#
# This is the sinusoidal positional encoding layer as seen in the original 'Attention is All You Need' paper. It basically uses a sin/cos waveform to provide a unique positional offset that is given to a token at the corresponding position in its embedding space.
#
# By default, this is disabled and we instead use a trainable matrix of zeros. This adds another dimension to our data that the model then uses to find the best weights for the data's position itself. This is called "learnable" positional encoding.
#
# There are pros-and-cons to either, but essentially: sinusoidal is better when there are not a lot of data samples to learn the positional data from but you can get better results from "learnable" with larger datasets.

# %%
class PositionalEmbedding(nn.Module):
    '''
    Applies Learnable Sinusoidal Positional Encoding

    Parameters
    ----------
    embed_dim: int
        The positional embedding dimension (How big embedding for each patch.Constant across entire network)
    max_len: int 
        Max number of instances for positions
    freq: int 
        The base frequency for Sin/Cos calculations. Higher values (eg 10000) are more stable
    '''
    def __init__(self, 
                 embed_dim,
                 max_len=5000,
                 freq=10000.,
                ):
        super().__init__()
        pe = torch.zeros(max_len, embed_dim)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div = torch.exp(torch.arange(0, embed_dim, 2).float() *
                        (-math.log(freq) / embed_dim))
        pe[:, 0::2] = torch.sin(position * div) # Even terms
        pe[:, 1::2] = torch.cos(position * div) # Odd terms
        pe = pe.unsqueeze(0).transpose(0,1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        '''
        Defines how the class will run

        Parameters
        -----------

        Returns
        -----------
        '''
        x = x + self.pe[:x.size(0), :]
        return x

# %% [markdown]
# ### Patching Layer
#
# This patching layer uses a convolutional filter to segment the input image into patch_size segments, but it does NOT produce convolutional samples. It's just a convenient way to produce patches. It accomplishes this by making the kernel and stride the same size as a patch so that it moves across the image grabbing segments with no overlap.

# %%
class Patching(nn.Module):
    '''
    Splits the image into patches

    Parameters
    ----------
    in_channels: int 
        Number of input channels (eg: Grayscale=1, RGB = 3)
    patch_size: int 
        Size of the patch (it is a square; it doesnt have to be) (Sometimes called kernel_size)
    embed_dim: int
        The positional embedding dimension (How big embedding for each patch.Constant across entire network)

    Attributes
    ----------
    proj: nn.Conv2d
        Convolutional layer that does both the splitting into patches and embedding
    '''
    def __init__(self,
                 in_channels=3,
                 patch_size=16,
                 embed_dim=768,
    ):

        super().__init__()

        self.proj = nn.Conv2d(
            in_channels,
            embed_dim,
            kernel_size=patch_size,
            stride=patch_size
        )

    def forward(self, x):
        '''
        Defines how the class will run

        Parameters
        -----------
        x: torch.Tensor
        Shape: (n_samples, in_channels, img_size, img_size)

        Returns
        -----------
        torch.Tensor
        Shape: (n_samples, n_patches, embed_dim)
        '''
        x = self.proj(x)
        x = x.flatten(2)
        x = x.transpose(1,2)
        return x

# %% [markdown]
# ### This is the Transformer Encoder block which applies all of the actual normalization, attention, etc that make a Transformer what it is.

# %%
class TransformerEncoderLayer(nn.Module):
    '''
    Transformer Block/Encoder Layer

    Parameter
    ---------
    embed_dim: int
        embedding dimension
    n_heads: int
        number of attention heads
    mlp_ratio: float
        determines the hidden dimension size of the MLP module with respect to 'dim'
    qkv_bias: bool
        If true then we include bias to the query, key and value projections
    mlp_dropout, proj_dropout, attn_droupout: float
        dropout probability
    dim_feedforward: int
        The feature number of hidden layer of the FFN

    Attributes
    ----------
    norm_1, norm_2: LayerNorm
        Layer normalization
    MHA: Attention
        Multi-Headed Attention module
    mlp: MLP
        MLP module
    ''' 
    def __init__(self,
                 embed_dim=768,
                 n_heads=12,
                 qkv_bias=True,
                 attn_dropout=0.,
                 proj_dropout=0.,
                 mlp_dropout=0.,
                 hidden_dim=2048
    ):
        super().__init__()
        self.norm_1 = nn.LayerNorm(embed_dim, eps = 1e-6)
        self.norm_2 = nn.LayerNorm(embed_dim, eps = 1e-6)
        self.MHA = MultiheadedSelfAttention(embed_dim,
                                        n_heads,
                                        qkv_bias,
                                        attn_dropout,
                                        proj_dropout
        )
        self.MLP = MLP(embed_dim, hidden_dim, mlp_dropout)

    def forward(self, x):
        '''
        Defines how the class will run
        
        Parameter
        ---------
        x: torch.Tensor
            shape: n_samples, n_patches + 1, dim

        Returns
        --------
        torch.Tensor
            shape: n_samples, n_patches + 1, dim
        '''
        x = x + self.MHA(self.norm_1(x))    # Residual connection (Add)
        x = x + self.MLP(self.norm_2(x))    # Residual connection (Add)
        return x

# %% [markdown]
# ### Multiheaded Attention Layer
#
# The heart of the Transformer model; the reason behind the original title of "attention is all you need".

# %%
class MultiheadedSelfAttention(nn.Module):
    '''
    Multi-Headed Attention Mechanism

    Parameters
    ----------
    embed_dim: int
        The input and out dimension of per token feature
    n_heads: int
        Number of attention heads 
    qkv_bias: bool
        if true then we include bias to the query, key and value projections
    attn_p: float
        Dropout probability applied to the query, key and value tensors.
    proj_p: float
        Dropout probability applied to output tensor
        
    Attributes
    ----------
    scale: float
        Normalizing constant for the dot product
    qkv: nn.Linear
        Linear projection for the query, key and value
    proj: nn.Linear
        Linear mapping that takes in the concatenated output of all attention
        heads and maps into the new space
    attn_drop, proj_drop: nn.Dropout
        Dropout layers.
    '''
    def __init__(self, 
                 embed_dim, 
                 n_heads=2,
                 qkv_bias = True,
                 attn_dropout=0.,
                 proj_dropout=0.
    ):
        super().__init__()
        self.n_heads = n_heads
        assert embed_dim % n_heads == 0, \
            print('Embedding dim must be divisible by number of heads.')
        self.head_dim = embed_dim // n_heads
        self.scale = self.head_dim ** -0.5
        self.dim = embed_dim
        self.qkv = nn.Linear(embed_dim, embed_dim * 3, bias=qkv_bias)
        self.attn_dropout = nn.Dropout(attn_dropout)
        self.proj = nn.Linear(embed_dim, embed_dim)
        self.proj_dropout = nn.Dropout(proj_dropout)
        
    def forward(self, x):
        '''
        Defines how the class will run
        
        Parameters
        ----------
        x: torch.Tensor
            shape: n_samples (B), n_patches + 1 (N), embed_dim (C)
            N is also equal to the number of tokens.
        Returns
        --------
        torch.Tensor
            shape: n_samples, n_patches + 1, embed_dim
        '''
        B, N, C = x.shape
        qkv = self.qkv(x)
        qkv = qkv.reshape(B, N, 3,
            self.n_heads,
            self.head_dim
            )
        qkv = qkv.permute(
            2,    # qkv (3)
            0,    # batch (n_samples)
            3,    # channel (n_heads)
            1,    # n_patches + 1
            4     # head_dim (embed_dim / n_heads)
            )
        q, k, v = qkv[0], qkv[1], qkv[2]
        attn = (q @ k.transpose(-2, -1)) * self.scale # <q,k> / sqrt(d)
        attn = attn.softmax(dim=-1) # Softmax over embedding dim
        attn = self.attn_dropout(attn)

        weighted_avg = (attn @ v)
        weighted_avg = weighted_avg.transpose(1, 2)
        weighted_avg = weighted_avg.flatten(2)

        x = self.proj(weighted_avg)
        x = self.proj_dropout(x)

        return x

# %% [markdown]
# ### The MLP layer
#
# (At the end of the Transformer Encoder). Not to be confused with the mlp head which adds class encodings at the very end of the transformer.

# %%
class MLP(nn.Module):
    '''
    Multilayer perceptron 
    
    Parameters
    ----------
    embed_dim: int
        embedding dimension
    feedforward_dim: int
      Number of nodes in the hidden layer
    mlp_dropout: float
      Dropout probability

    Attribute
    ---------
    fc: nn.Linear
      The first linear layer
    act: nn. GELU
      GELU activation function
    fc2: nn.Linear
      The second linear layer
    drop: nn.Dropout
      Dropout layer
    '''

    def __init__(self, embed_dim, hidden_dim, mlp_dropout):
        super().__init__()
        self.fc1 = nn.Linear(embed_dim, hidden_dim)
        self.act = nn.GELU()
        self.fc2 = nn.Linear(hidden_dim, embed_dim)
        self.drop = nn.Dropout(mlp_dropout)

    def forward(self,x):
        '''
        Defines how the class will run
        
        Parameters
        ----------
        x: torch.Tensor
          shape: n_samples, n_patches + 1, in_features

        Returns
        ----------
        torch.Tensor
          n_samples, n_patches+ 1, out_features
        '''
        x = self.fc1(x) # n_samples, n_patches+1, hidden_features
        x = self.act(x) # n_samples, n_patches+1, hidden_features
        x = self.drop(x) # n_samples, n_patches+1, hidden_features
        x = self.fc2(x) # n_samples, n_patches+1, output_features
        x = self.drop(x) # n_samples, n_patches+1, output_features
        return x

# %% [markdown]
# # Training the ViT with our Cervical Cancer Dataset

# %% [markdown]
# ### Setup needed variables

# %%
def sipakmed_prep():
    root = "../../Python Scripts/Datasets/CervicalCancer/Sipakmed/"

    all_img = []
    for path, subdirs, files in os.walk(root):
        for name in files:
            curr_img = os.path.join(path,name)
            all_img.append(curr_img)

    sipakmed_df = pd.DataFrame()
    sipakmed_df['LocalPath'] = all_img
    sipakmed_df['ID'] = sipakmed_df['LocalPath'].apply(lambda x: str(x.split("\\")[-1]))
    sipakmed_df['Slide'] = sipakmed_df['LocalPath'].apply(lambda x: 'False' if (str(x.split("\\")[1])) == 'CROPPED' else 'True')
    sipakmed_df['Specific_Status'] = sipakmed_df['LocalPath'].apply(lambda x: str((x.split("im_")[1]).split("\\")[0]))
    sipakmed_df['Status'] = sipakmed_df['Specific_Status'].apply(lambda x: 'Benign' if x == 'Metaplastic' else
    ('Normal' if x == 'Superficial-Intermediate' or x == 'Parabasal' else 'Abnormal'))

    sp_class = {'Metaplastic':4, 'Superficial-Intermediate':0, 'Parabasal':1, 'Koilocytotic':2, 'Dyskeratotic':3}
    sipakmed_df['Specific_Class'] = sipakmed_df['Specific_Status'].map(sp_class)
    gen_class = {'Benign':0, 'Normal':1, 'Abnormal':2}
    sipakmed_df['Class'] = sipakmed_df['Status'].map(gen_class)

    sipakmed_df = sipakmed_df.loc[sipakmed_df['ID'].str.contains('bmp')].reset_index(drop=True)
    
    #Uploads the created file for future use. Recommended to not use.
    #sipakmed_df.to_csv(root + '/results.csv')
    return sipakmed_df

# %%
def herlev_prep():
    root = '../../Python Scripts/Datasets/CervicalCancer/Herlev/smear2005/results.csv'
    img_folder = '../../Python Scripts/Datasets/CervicalCancer/Herlev/smear2005/Images/'

    herlev_df=pd.read_csv(root)
    herlev_df = herlev_df.rename(columns={'Class':'Specific_Class'})

    spec_class = {1:0, 2:1, 3:2, 4:3, 5:4, 6:5, 7:6}
    gen_class = {1:1, 2:1, 3:1, 4:2, 5:2, 6:2, 7:2}
    
    herlev_df['Class'] = herlev_df['Specific_Class'].map(gen_class)
    herlev_df['Specific_Class'] = herlev_df['Specific_Class'].map(spec_class)
    herlev_df['LocalPath'] = herlev_df['ID'].apply(lambda x: str(img_folder + x))
    return herlev_df

# %%
class DatasetSample(Dataset):
    def __init__(self, df, transform):
        # Initialization
        self.transform = transform
        
        self.image_names = df['LocalPath']
        self.img_class = np.array(df['Class'])

    def __len__(self):
        # Denotes the total number of samples
        return len(self.image_names)
    
    def __getitem__(self, index):
        # Retrieves the data
        image=cv2.imread(self.image_names.iloc[index])
        image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

        image = self.transform(image)
        label = self.img_class[index]

        x, y = image, label
        
        # Enable to output as single variable instead
        #sample = {'image': image,'labels':label}

        return x, y

# %%
def concat_data(batch_size=128, img_size=32):
    # Load the dataframes
    sipakmed_df = sipakmed_prep()
    herlev_df = herlev_prep()

    # Final adjustments to make sure they're attributes match
    sipakmed_df = sipakmed_df.loc[sipakmed_df['Slide'] == 'False']
    herlev_df = herlev_df.loc[:,['LocalPath', 'Class']]
    sipakmed_df = sipakmed_df.loc[:,['LocalPath', 'Class']]
    
    concat_df = pd.concat([sipakmed_df,herlev_df], ignore_index=True)
    
    '''
    concat_df = pd.DataFrame()
    concat_df['LocalPath'] = sipakmed_df['LocalPath']
    concat_df['Class'] = sipakmed_df['Specific_Class']
    concat_df = pd.DataFrame()
    concat_df['LocalPath'] = herlev_df['LocalPath']
    concat_df['Class'] = herlev_df['Specific_Class']
    '''


    # Split them into training, validation, and testing sets
    train_set,val_test_set = train_test_split(concat_df, random_state=1, test_size=0.30)
    val_set,test_set = train_test_split(val_test_set, random_state=1, test_size=0.50)
    
    # Set it up to alter random training images for better results
    train_transform = transforms.Compose([
                    transforms.ToPILImage(),
                    transforms.Resize((img_size, img_size)),
                    #transforms.RandomHorizontalFlip(p=0.75),
                    #transforms.RandomRotation(degrees=60),
                    #transforms.RandomApply(transforms=[transforms.ColorJitter(brightness=.2, hue=.2)], p=0.75),
                    transforms.ToTensor()])

    test_transform = transforms.Compose([
                    transforms.ToPILImage(),
                    transforms.Resize((img_size, img_size)),
                    transforms.ToTensor()])

    train_dataset = DatasetSample(train_set, train_transform)
    val_dataset = DatasetSample(val_set, test_transform)
    test_dataset = DatasetSample(test_set, test_transform)
    
    Dtr = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        generator=torch.Generator().manual_seed(17)
    )
    
    Dva = DataLoader(
        val_dataset, 
        batch_size=batch_size,
        shuffle=False
    )

    Dte = DataLoader(
        test_dataset, 
        batch_size=batch_size,
        shuffle=False
    )

    return(Dtr, Dva, Dte)

# %%
#The corresponding class labels
batch_size=128
img_size=64
classes = ('Benign', 'Normal', 'Abnormal')
#classes = ('Superficial-Intermediate','Parabasal','Koilocytotic','Dyskeratotic','Metaplastic')
#classes = ('Superficial-Squamous-Epithelial','Intermediate-Squamous-Epithelial','Columnar-Epithelial','Mild-Squamous-Non-Keratinizing-Dysplasia',
#           'Moderate-Squamous-Non-Keratinizing-Dysplasia','Severe-Squamous-Non-Keratinizing-Dysplasia','Squamous-Cell-Carcinoma-in-situ-Intermediate')
Dtr, Dva, Dte = concat_data(batch_size=batch_size, img_size=img_size)

# %%
# Turns the dataloaders into iterable objects. Useful for viewing
dataiter = iter(Dtr)
val_dataiter = iter(Dva)
test_dataiter = iter(Dte)

# %% [markdown]
# ### Function for viewing batches of the dataset

# %%
def imshow(images, labels, predicted_labels=None):
    
    if images.is_cuda == True:
        images = images.to("cpu")
    if labels.is_cuda == True:
        labels = labels.to("cpu")

    # Using torchvision to make a grid of the images
    img = torchvision.utils.make_grid(images)

    # Inverting the normalization
    img = img.numpy().transpose((1, 2, 0))
    img = np.clip(img, 0, 1)

    # Plotting the grid
    fig, ax = plt.subplots(figsize=(12, 24))
    plt.imshow(img)

    if predicted_labels is not None:
        if predicted_labels.is_cuda == True:
            predicted_labels = predicted_labels.to("cpu")
        # Outputing the predicted labels
        ax.set_xlabel('Predicted labels', fontsize=18, labelpad=12)
        ax.set_xticks(torch.arange(len(images)) * img_size + (img_size/1.8))
        ax.set_xticklabels([classes[predicted_labels[j]] 
                            for j in range(len(images))], fontsize=12, rotation=30)
    
    # Outputing the True labels
    gax = ax.secondary_xaxis('top')
    gax.set_xlabel('True Labels', fontsize=18, labelpad=12)
    gax.set_xticks(torch.arange(len(images)) * img_size + (img_size/1.8))
    gax.set_xticklabels([classes[labels[j]] 
                         for j in range(len(images))], fontsize=12, rotation=30)
    plt.show()

# %%
images, labels = dataiter.next()
imshow(images[:7], labels[:7])

# %% [markdown]
# ### This function was made by Dr Prashant to train the model that's built above

# %%
# A function to encapsulate the training loop
def batch_gd(model, loss_fn, optimizer, train_loader, val_loader, epochs):
  model.to(device)
  train_losses = np.zeros(epochs)
  val_losses = np.zeros(epochs)
  avg_epoch = []
  
  for it in range(epochs):
    model.train()
    t0 = datetime.now()
    train_loss = []
    n_correct = 0.
    n_total = 0.
    for inputs, targets in train_loader:
      # move data to GPU if available
      inputs, targets = inputs.to(device), targets.to(device)

      # zero the parameter gradients
      optimizer.zero_grad()

      # Forward pass
      outputs = model(inputs)
      
      # Get the predictions
      # torch.max returns both max and argmax
      __, out_label = outputs.max(dim=1)
      # Updates the accuracy with every pass
      n_correct += (out_label == targets).sum().item()
      n_total += targets.shape[0]
      tr_acc = n_correct / n_total

      loss = loss_fn(outputs, targets)
      # Backward and optimize
      loss.backward()
      optimizer.step()

      train_loss.append(loss.item())

    # Get train loss and test loss
    train_loss = np.mean(train_loss) # a little misleading
    
    model.eval()
    val_loss = []
    n_correct = 0.
    n_total = 0.
    for inputs, targets in val_loader:
      inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)

      # Get the predictions
      # torch.max returns both max and argmax
      __, out_label = outputs.max(dim=1)
      # Updates the accuracy with every pass
      n_correct += (out_label == targets).sum().item()
      n_total += targets.shape[0]
      val_acc = n_correct / n_total

      loss = loss_fn(outputs, targets)
      val_loss.append(loss.item())
    val_loss = np.mean(val_loss)

    # Save losses
    train_losses[it] = train_loss
    val_losses[it] = val_loss
    
    dt = datetime.now() - t0
    avg_epoch.append(dt)

    print(f'Epoch {it+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {(100*tr_acc):.3f} \
      Val Loss: {val_loss:.4f}, Val Accuracy: {(100*val_acc):.3f}, Duration: {dt}, Avg_Epoch: {np.mean(avg_epoch)}')
  
  return train_losses, val_losses

# %% [markdown]
# ### Initializes the Transformer and selects the loss function and optimizer we want

# %%
model = ViT(
        img_size=img_size,          # Input image size
        in_channels=3,		# Number of channels for the image
        patch_size=4,         # How big our patches are
        embed_dim=128,		# Embedding dim
        n_layers=2,         # Number of transformer encoders
        n_heads=2,          # Number of attention heads
        attn_dropout=0.,       # Attention Dropout
        proj_dropout=0.,       # (MHA) Projection Dropout
        mlp_dropout=0.1,       # (MHA) last layer dropout
        mlp_ratio=1,           # (MHA) Projection FF dimension
        qkv_bias = True,
        n_classes=3       # Number of classes to classify
        )
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())

# %%
train_losses, val_losses = batch_gd(model, loss_fn, optimizer, Dtr, Dva, epochs=100)
# Out:
# Epoch 1/100, Train Loss: 0.8990, Train Accuracy: 57.710       Val Loss: 0.6840, Val Accuracy: 73.423, Duration: 0:00:10.554776, Avg_Epoch: 0:00:10.554776
# Epoch 2/100, Train Loss: 0.6112, Train Accuracy: 74.914       Val Loss: 0.6464, Val Accuracy: 72.081, Duration: 0:00:07.560335, Avg_Epoch: 0:00:09.057556
# Epoch 3/100, Train Loss: 0.5481, Train Accuracy: 78.107       Val Loss: 0.5320, Val Accuracy: 80.403, Duration: 0:00:07.659195, Avg_Epoch: 0:00:08.591435
# Epoch 4/100, Train Loss: 0.5166, Train Accuracy: 79.488       Val Loss: 0.5945, Val Accuracy: 77.987, Duration: 0:00:08.301741, Avg_Epoch: 0:00:08.519012
# Epoch 5/100, Train Loss: 0.5101, Train Accuracy: 79.862       Val Loss: 0.4966, Val Accuracy: 81.477, Duration: 0:00:07.814792, Avg_Epoch: 0:00:08.378168
# Epoch 6/100, Train Loss: 0.4701, Train Accuracy: 82.077       Val Loss: 0.5096, Val Accuracy: 80.671, Duration: 0:00:07.923764, Avg_Epoch: 0:00:08.302434
# Epoch 7/100, Train Loss: 0.4119, Train Accuracy: 84.005       Val Loss: 0.4490, Val Accuracy: 84.430, Duration: 0:00:08.017160, Avg_Epoch: 0:00:08.261680
# Epoch 8/100, Train Loss: 0.4108, Train Accuracy: 84.206       Val Loss: 0.4225, Val Accuracy: 84.966, Duration: 0:00:07.723806, Avg_Epoch: 0:00:08.194446
# Epoch 9/100, Train Loss: 0.3860, Train Accuracy: 84.465       Val Loss: 0.4380, Val Accuracy: 83.624, Duration: 0:00:07.763148, Avg_Epoch: 0:00:08.146524
# Epoch 10/100, Train Loss: 0.3940, Train Accuracy: 85.673       Val Loss: 0.4073, Val Accuracy: 85.369, Duration: 0:00:07.795648, Avg_Epoch: 0:00:08.111436
# Epoch 11/100, Train Loss: 0.3322, Train Accuracy: 86.795       Val Loss: 0.3982, Val Accuracy: 84.966, Duration: 0:00:07.647834, Avg_Epoch: 0:00:08.069291
# Epoch 12/100, Train Loss: 0.3033, Train Accuracy: 89.068       Val Loss: 0.3504, Val Accuracy: 87.383, Duration: 0:00:07.550616, Avg_Epoch: 0:00:08.026068
# Epoch 13/100, Train Loss: 0.2755, Train Accuracy: 90.161       Val Loss: 0.4300, Val Accuracy: 85.503, Duration: 0:00:07.603698, Avg_Epoch: 0:00:07.993578
# Epoch 14/100, Train Loss: 0.2827, Train Accuracy: 89.643       Val Loss: 0.3816, Val Accuracy: 85.638, Duration: 0:00:07.589930, Avg_Epoch: 0:00:07.964746
# Epoch 15/100, Train Loss: 0.2940, Train Accuracy: 88.636       Val Loss: 0.4198, Val Accuracy: 85.638, Duration: 0:00:07.569804, Avg_Epoch: 0:00:07.938416
# Epoch 16/100, Train Loss: 0.2642, Train Accuracy: 89.672       Val Loss: 0.4119, Val Accuracy: 84.698, Duration: 0:00:07.592808, Avg_Epoch: 0:00:07.916816
# Epoch 17/100, Train Loss: 0.2334, Train Accuracy: 90.880       Val Loss: 0.3321, Val Accuracy: 88.859, Duration: 0:00:07.683243, Avg_Epoch: 0:00:07.903076
# Epoch 18/100, Train Loss: 0.2194, Train Accuracy: 92.060       Val Loss: 0.3028, Val Accuracy: 88.591, Duration: 0:00:07.529974, Avg_Epoch: 0:00:07.882348
# Epoch 19/100, Train Loss: 0.1887, Train Accuracy: 93.096       Val Loss: 0.3991, Val Accuracy: 86.174, Duration: 0:00:07.583154, Avg_Epoch: 0:00:07.866601
# Epoch 20/100, Train Loss: 0.2000, Train Accuracy: 92.232       Val Loss: 0.3583, Val Accuracy: 88.456, Duration: 0:00:07.797195, Avg_Epoch: 0:00:07.863131
# Epoch 21/100, Train Loss: 0.1916, Train Accuracy: 92.434       Val Loss: 0.4003, Val Accuracy: 84.966, Duration: 0:00:07.769307, Avg_Epoch: 0:00:07.858663
# Epoch 22/100, Train Loss: 0.1834, Train Accuracy: 93.211       Val Loss: 0.3855, Val Accuracy: 88.591, Duration: 0:00:07.623089, Avg_Epoch: 0:00:07.847955
# Epoch 23/100, Train Loss: 0.1584, Train Accuracy: 94.189       Val Loss: 0.3669, Val Accuracy: 88.322, Duration: 0:00:07.657346, Avg_Epoch: 0:00:07.839668
# Epoch 24/100, Train Loss: 0.1353, Train Accuracy: 95.196       Val Loss: 0.3880, Val Accuracy: 86.980, Duration: 0:00:07.691673, Avg_Epoch: 0:00:07.833502
# Epoch 25/100, Train Loss: 0.1401, Train Accuracy: 95.081       Val Loss: 0.3577, Val Accuracy: 88.322, Duration: 0:00:07.799397, Avg_Epoch: 0:00:07.832137
# Epoch 26/100, Train Loss: 0.1697, Train Accuracy: 93.901       Val Loss: 0.3731, Val Accuracy: 86.174, Duration: 0:00:07.665173, Avg_Epoch: 0:00:07.825716
# Epoch 27/100, Train Loss: 0.2698, Train Accuracy: 89.068       Val Loss: 0.3318, Val Accuracy: 86.846, Duration: 0:00:07.673318, Avg_Epoch: 0:00:07.820071
# Epoch 28/100, Train Loss: 0.1489, Train Accuracy: 94.649       Val Loss: 0.3992, Val Accuracy: 87.248, Duration: 0:00:07.828854, Avg_Epoch: 0:00:07.820385
# Epoch 29/100, Train Loss: 0.1670, Train Accuracy: 93.441       Val Loss: 0.3381, Val Accuracy: 88.859, Duration: 0:00:07.859156, Avg_Epoch: 0:00:07.821722
# Epoch 30/100, Train Loss: 0.1274, Train Accuracy: 95.196       Val Loss: 0.3378, Val Accuracy: 88.859, Duration: 0:00:07.734942, Avg_Epoch: 0:00:07.818829
# Epoch 31/100, Train Loss: 0.1068, Train Accuracy: 96.519       Val Loss: 0.3887, Val Accuracy: 88.859, Duration: 0:00:08.520701, Avg_Epoch: 0:00:07.841470
# Epoch 32/100, Train Loss: 0.1265, Train Accuracy: 95.368       Val Loss: 0.3627, Val Accuracy: 89.396, Duration: 0:00:07.593152, Avg_Epoch: 0:00:07.833710
# Epoch 33/100, Train Loss: 0.0869, Train Accuracy: 96.663       Val Loss: 0.3860, Val Accuracy: 90.067, Duration: 0:00:07.915771, Avg_Epoch: 0:00:07.836197
# Epoch 34/100, Train Loss: 0.0760, Train Accuracy: 97.382       Val Loss: 0.4137, Val Accuracy: 89.530, Duration: 0:00:07.761624, Avg_Epoch: 0:00:07.834004
# Epoch 35/100, Train Loss: 0.1302, Train Accuracy: 94.793       Val Loss: 0.4132, Val Accuracy: 88.993, Duration: 0:00:07.564490, Avg_Epoch: 0:00:07.826303
# Epoch 36/100, Train Loss: 0.0959, Train Accuracy: 96.749       Val Loss: 0.4437, Val Accuracy: 87.383, Duration: 0:00:08.644668, Avg_Epoch: 0:00:07.849036
# Epoch 37/100, Train Loss: 0.0966, Train Accuracy: 96.375       Val Loss: 0.5082, Val Accuracy: 85.369, Duration: 0:00:08.164367, Avg_Epoch: 0:00:07.857558
# Epoch 38/100, Train Loss: 0.0875, Train Accuracy: 97.267       Val Loss: 0.4375, Val Accuracy: 88.456, Duration: 0:00:07.948823, Avg_Epoch: 0:00:07.859960
# Epoch 39/100, Train Loss: 0.0736, Train Accuracy: 97.152       Val Loss: 0.5163, Val Accuracy: 88.188, Duration: 0:00:07.960510, Avg_Epoch: 0:00:07.862538
# Epoch 40/100, Train Loss: 0.0674, Train Accuracy: 97.641       Val Loss: 0.4946, Val Accuracy: 87.651, Duration: 0:00:07.982940, Avg_Epoch: 0:00:07.865548
# Epoch 41/100, Train Loss: 0.0667, Train Accuracy: 97.526       Val Loss: 0.4287, Val Accuracy: 88.725, Duration: 0:00:07.936375, Avg_Epoch: 0:00:07.867276
# Epoch 42/100, Train Loss: 0.0625, Train Accuracy: 97.785       Val Loss: 0.4099, Val Accuracy: 89.664, Duration: 0:00:07.773189, Avg_Epoch: 0:00:07.865035
# Epoch 43/100, Train Loss: 0.0582, Train Accuracy: 98.015       Val Loss: 0.5204, Val Accuracy: 86.980, Duration: 0:00:07.913630, Avg_Epoch: 0:00:07.866165
# Epoch 44/100, Train Loss: 0.0845, Train Accuracy: 97.181       Val Loss: 0.4472, Val Accuracy: 88.188, Duration: 0:00:08.035961, Avg_Epoch: 0:00:07.870024
# Epoch 45/100, Train Loss: 0.1164, Train Accuracy: 95.915       Val Loss: 0.4445, Val Accuracy: 86.711, Duration: 0:00:07.595438, Avg_Epoch: 0:00:07.863923
# Epoch 46/100, Train Loss: 0.0935, Train Accuracy: 96.318       Val Loss: 0.4003, Val Accuracy: 89.128, Duration: 0:00:07.965836, Avg_Epoch: 0:00:07.866138
# Epoch 47/100, Train Loss: 0.0793, Train Accuracy: 96.864       Val Loss: 0.4621, Val Accuracy: 89.664, Duration: 0:00:07.626184, Avg_Epoch: 0:00:07.861033
# Epoch 48/100, Train Loss: 0.0605, Train Accuracy: 97.468       Val Loss: 0.5497, Val Accuracy: 88.188, Duration: 0:00:07.445871, Avg_Epoch: 0:00:07.852383
# Epoch 49/100, Train Loss: 0.0650, Train Accuracy: 97.526       Val Loss: 0.4348, Val Accuracy: 89.664, Duration: 0:00:07.435157, Avg_Epoch: 0:00:07.843869
# Epoch 50/100, Train Loss: 0.0481, Train Accuracy: 98.159       Val Loss: 0.5112, Val Accuracy: 88.859, Duration: 0:00:07.427956, Avg_Epoch: 0:00:07.835550
# Epoch 51/100, Train Loss: 0.0379, Train Accuracy: 98.475       Val Loss: 0.4953, Val Accuracy: 88.859, Duration: 0:00:07.408021, Avg_Epoch: 0:00:07.827167
# Epoch 52/100, Train Loss: 0.0347, Train Accuracy: 98.792       Val Loss: 0.5813, Val Accuracy: 88.993, Duration: 0:00:07.497480, Avg_Epoch: 0:00:07.820827
# Epoch 53/100, Train Loss: 0.0465, Train Accuracy: 98.216       Val Loss: 0.4775, Val Accuracy: 88.725, Duration: 0:00:07.410791, Avg_Epoch: 0:00:07.813091
# Epoch 54/100, Train Loss: 0.0994, Train Accuracy: 96.346       Val Loss: 0.4107, Val Accuracy: 88.725, Duration: 0:00:07.389644, Avg_Epoch: 0:00:07.805249
# Epoch 55/100, Train Loss: 0.0587, Train Accuracy: 97.814       Val Loss: 0.4520, Val Accuracy: 88.859, Duration: 0:00:07.500961, Avg_Epoch: 0:00:07.799717
# Epoch 56/100, Train Loss: 0.0371, Train Accuracy: 98.907       Val Loss: 0.5378, Val Accuracy: 88.993, Duration: 0:00:07.542518, Avg_Epoch: 0:00:07.795124
# Epoch 57/100, Train Loss: 0.1195, Train Accuracy: 95.713       Val Loss: 0.4074, Val Accuracy: 87.651, Duration: 0:00:07.457569, Avg_Epoch: 0:00:07.789202
# Epoch 58/100, Train Loss: 0.0593, Train Accuracy: 97.756       Val Loss: 0.4201, Val Accuracy: 89.933, Duration: 0:00:07.517878, Avg_Epoch: 0:00:07.784524
# Epoch 59/100, Train Loss: 0.0358, Train Accuracy: 98.820       Val Loss: 0.5342, Val Accuracy: 87.919, Duration: 0:00:07.813481, Avg_Epoch: 0:00:07.785015
# Epoch 60/100, Train Loss: 0.0434, Train Accuracy: 98.274       Val Loss: 0.4942, Val Accuracy: 89.262, Duration: 0:00:07.523967, Avg_Epoch: 0:00:07.780664
# Epoch 61/100, Train Loss: 0.0725, Train Accuracy: 97.670       Val Loss: 0.4830, Val Accuracy: 88.054, Duration: 0:00:07.754955, Avg_Epoch: 0:00:07.780242
# Epoch 62/100, Train Loss: 0.0528, Train Accuracy: 97.900       Val Loss: 0.3852, Val Accuracy: 89.933, Duration: 0:00:07.486750, Avg_Epoch: 0:00:07.775509
# Epoch 63/100, Train Loss: 0.0226, Train Accuracy: 99.281       Val Loss: 0.5585, Val Accuracy: 88.456, Duration: 0:00:07.435177, Avg_Epoch: 0:00:07.770107
# Epoch 64/100, Train Loss: 0.0203, Train Accuracy: 99.281       Val Loss: 0.4654, Val Accuracy: 90.201, Duration: 0:00:07.244821, Avg_Epoch: 0:00:07.761899
# Epoch 65/100, Train Loss: 0.0248, Train Accuracy: 99.108       Val Loss: 0.5284, Val Accuracy: 89.530, Duration: 0:00:07.211925, Avg_Epoch: 0:00:07.753438
# Epoch 66/100, Train Loss: 0.0216, Train Accuracy: 99.223       Val Loss: 0.5662, Val Accuracy: 89.396, Duration: 0:00:07.171250, Avg_Epoch: 0:00:07.744617
# Epoch 67/100, Train Loss: 0.0252, Train Accuracy: 98.993       Val Loss: 0.4617, Val Accuracy: 90.738, Duration: 0:00:07.166469, Avg_Epoch: 0:00:07.735988
# Epoch 68/100, Train Loss: 0.0384, Train Accuracy: 98.504       Val Loss: 0.5413, Val Accuracy: 87.651, Duration: 0:00:07.289225, Avg_Epoch: 0:00:07.729418
# Epoch 69/100, Train Loss: 0.0375, Train Accuracy: 98.648       Val Loss: 0.4916, Val Accuracy: 88.591, Duration: 0:00:07.810013, Avg_Epoch: 0:00:07.730586
# Epoch 70/100, Train Loss: 0.0152, Train Accuracy: 99.597       Val Loss: 0.4843, Val Accuracy: 89.396, Duration: 0:00:07.619710, Avg_Epoch: 0:00:07.729002
# Epoch 71/100, Train Loss: 0.0109, Train Accuracy: 99.684       Val Loss: 0.5121, Val Accuracy: 89.530, Duration: 0:00:07.692080, Avg_Epoch: 0:00:07.728482
# Epoch 72/100, Train Loss: 0.0089, Train Accuracy: 99.856       Val Loss: 0.5159, Val Accuracy: 91.007, Duration: 0:00:07.803767, Avg_Epoch: 0:00:07.729527
# Epoch 73/100, Train Loss: 0.0657, Train Accuracy: 97.785       Val Loss: 0.4898, Val Accuracy: 88.859, Duration: 0:00:07.934641, Avg_Epoch: 0:00:07.732337
# Epoch 74/100, Train Loss: 0.0422, Train Accuracy: 98.216       Val Loss: 0.4906, Val Accuracy: 89.128, Duration: 0:00:07.667950, Avg_Epoch: 0:00:07.731467
# Epoch 75/100, Train Loss: 0.0199, Train Accuracy: 99.338       Val Loss: 0.5352, Val Accuracy: 90.604, Duration: 0:00:07.510791, Avg_Epoch: 0:00:07.728525
# Epoch 76/100, Train Loss: 0.0210, Train Accuracy: 99.166       Val Loss: 0.5155, Val Accuracy: 90.336, Duration: 0:00:07.426645, Avg_Epoch: 0:00:07.724553
# Epoch 77/100, Train Loss: 0.0238, Train Accuracy: 99.425       Val Loss: 0.5897, Val Accuracy: 88.591, Duration: 0:00:07.420607, Avg_Epoch: 0:00:07.720605
# Epoch 78/100, Train Loss: 0.1147, Train Accuracy: 96.059       Val Loss: 0.4403, Val Accuracy: 87.919, Duration: 0:00:07.510912, Avg_Epoch: 0:00:07.717917
# Epoch 79/100, Train Loss: 0.0370, Train Accuracy: 98.562       Val Loss: 0.5761, Val Accuracy: 88.993, Duration: 0:00:07.423973, Avg_Epoch: 0:00:07.714196
# Epoch 80/100, Train Loss: 0.0200, Train Accuracy: 99.223       Val Loss: 0.5330, Val Accuracy: 88.725, Duration: 0:00:07.447448, Avg_Epoch: 0:00:07.710862
# Epoch 81/100, Train Loss: 0.0124, Train Accuracy: 99.511       Val Loss: 0.5519, Val Accuracy: 89.664, Duration: 0:00:07.576089, Avg_Epoch: 0:00:07.709198
# Epoch 82/100, Train Loss: 0.0140, Train Accuracy: 99.482       Val Loss: 0.5878, Val Accuracy: 88.993, Duration: 0:00:07.613300, Avg_Epoch: 0:00:07.708028
# Epoch 83/100, Train Loss: 0.0078, Train Accuracy: 99.770       Val Loss: 0.6942, Val Accuracy: 88.591, Duration: 0:00:07.918249, Avg_Epoch: 0:00:07.710561
# Epoch 84/100, Train Loss: 0.0137, Train Accuracy: 99.453       Val Loss: 0.6737, Val Accuracy: 88.054, Duration: 0:00:07.566031, Avg_Epoch: 0:00:07.708841
# Epoch 85/100, Train Loss: 0.0161, Train Accuracy: 99.453       Val Loss: 0.6318, Val Accuracy: 89.128, Duration: 0:00:07.501699, Avg_Epoch: 0:00:07.706404
# Epoch 86/100, Train Loss: 0.0194, Train Accuracy: 99.281       Val Loss: 0.6242, Val Accuracy: 88.993, Duration: 0:00:07.634717, Avg_Epoch: 0:00:07.705570
# Epoch 87/100, Train Loss: 0.0245, Train Accuracy: 99.166       Val Loss: 0.6110, Val Accuracy: 88.993, Duration: 0:00:07.593008, Avg_Epoch: 0:00:07.704276
# Epoch 88/100, Train Loss: 0.0590, Train Accuracy: 97.756       Val Loss: 0.6128, Val Accuracy: 87.651, Duration: 0:00:07.455605, Avg_Epoch: 0:00:07.701450
# Epoch 89/100, Train Loss: 0.0386, Train Accuracy: 98.677       Val Loss: 0.5592, Val Accuracy: 88.456, Duration: 0:00:07.455406, Avg_Epoch: 0:00:07.698686
# Epoch 90/100, Train Loss: 0.0511, Train Accuracy: 98.015       Val Loss: 0.4850, Val Accuracy: 88.859, Duration: 0:00:07.681742, Avg_Epoch: 0:00:07.698498
# Epoch 91/100, Train Loss: 0.0192, Train Accuracy: 99.281       Val Loss: 0.5836, Val Accuracy: 88.993, Duration: 0:00:07.523102, Avg_Epoch: 0:00:07.696570
# Epoch 92/100, Train Loss: 0.0102, Train Accuracy: 99.684       Val Loss: 0.5236, Val Accuracy: 90.067, Duration: 0:00:07.503768, Avg_Epoch: 0:00:07.694474
# Epoch 93/100, Train Loss: 0.0068, Train Accuracy: 99.856       Val Loss: 0.6272, Val Accuracy: 88.456, Duration: 0:00:07.444187, Avg_Epoch: 0:00:07.691783
# Epoch 94/100, Train Loss: 0.0212, Train Accuracy: 99.367       Val Loss: 0.6749, Val Accuracy: 87.114, Duration: 0:00:07.406792, Avg_Epoch: 0:00:07.688751
# Epoch 95/100, Train Loss: 0.0408, Train Accuracy: 98.504       Val Loss: 0.5103, Val Accuracy: 89.933, Duration: 0:00:07.498017, Avg_Epoch: 0:00:07.686744
# Epoch 96/100, Train Loss: 0.0355, Train Accuracy: 98.763       Val Loss: 0.5691, Val Accuracy: 88.456, Duration: 0:00:07.394716, Avg_Epoch: 0:00:07.683702
# Epoch 97/100, Train Loss: 0.0409, Train Accuracy: 98.504       Val Loss: 0.6118, Val Accuracy: 88.456, Duration: 0:00:07.446546, Avg_Epoch: 0:00:07.681257
# Epoch 98/100, Train Loss: 0.0636, Train Accuracy: 97.727       Val Loss: 0.4939, Val Accuracy: 88.993, Duration: 0:00:07.712656, Avg_Epoch: 0:00:07.681577
# Epoch 99/100, Train Loss: 0.0220, Train Accuracy: 99.223       Val Loss: 0.5781, Val Accuracy: 89.933, Duration: 0:00:07.535451, Avg_Epoch: 0:00:07.680101
# Epoch 100/100, Train Loss: 0.0054, Train Accuracy: 99.827       Val Loss: 0.6292, Val Accuracy: 88.993, Duration: 0:00:07.671787, Avg_Epoch: 0:00:07.680018

# %%
images, labels = val_dataiter.next()
out_img, predicted = torch.max(model(images.to(device)), 1)
imshow(images[:7], labels[:7], predicted[:7])

# %%
# Plot the train loss and test loss per iteration
plt.figure(figsize=(12, 6))
plt.plot(train_losses, label='train loss')
plt.plot(val_losses, label='val loss')
plt.title('Training vs Validation Cross-Entropy Loss')
plt.xlabel('Epochs')
plt.ylabel('Average Loss')
plt.legend()
plt.show()

# %%
test_loss = []
test_acc = []
n_correct = 0.
n_total = 0.
n_classes = 3
confusion_matrix = np.zeros((n_classes, n_classes))

model.eval()
with torch.no_grad():
    for inputs, targets in Dte:
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = model(inputs)

        # Get the predictions
        # torch.max returns both max and argmax
        __, out_label = outputs.max(dim=1)
        # Updates the accuracy with every pass
        n_correct += (out_label == targets).sum().item()
        n_total += targets.shape[0]
        for t, p in zip(targets.view(-1), out_label.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1
        test_acc.append(n_correct / n_total)

        loss = loss_fn(outputs, targets)
        test_loss.append(loss.item())
test_loss = np.mean(test_loss)
avg_acc = np.mean(test_acc)*100
print('The total number of samples for Training is: {}, Validation: {}, and Testing: {}'.format(len(Dtr)*batch_size, len(Dva)*batch_size, len(Dte)*batch_size))
print('Average loss across the testing data: {}, Average testing accuracy: {}'.format(test_loss, avg_acc))
# Out:
# The total number of samples for Training is: 3584, Validation: 768, and Testing: 768
# Average loss across the testing data: 0.5088795026143392, Average testing accuracy: 90.82099704045488

# %%
plt.figure(figsize=(15,10))

class_names = list(classes)
cm_df = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(cm_df, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# The total number of samples for Training is: 3584, Validation: 768, and Testing: 768
# torch.manual_seed(17)
#
#
# model = ViT(
#         img_size=img_size,          # Input image size
#         in_channels=3,		# Number of channels for the image
#         patch_size=4,         # How big our patches are
#         embed_dim=128,		# Embedding dim
#         n_layers=2,         # Number of transformer encoders
#         n_heads=2,          # Number of attention heads
#         attn_dropout=0.,       # Attention Dropout
#         proj_dropout=0.,       # (MHA) Projection Dropout
#         mlp_dropout=0.1,       # (MHA) last layer dropout
#         mlp_ratio=1,           # (MHA) Projection FF dimension
#         qkv_bias = True,
#         n_classes=3       # Number of classes to classify
#         )
# img_size=64, batch_size=128
# test_loss=0.5089, test_acc=90.82%, avg_epoch=7.68s, Total_Time=12m48.1s
# Computational Resources: cpu=36%, memory=2.82gb, gpu=54%, gpu_memory=3.1gb
#
# ---------------------
#
# model = CCT(
#         img_size=img_size,      # Input image size
#         in_channels=3,  # Number of channels for the image
#         patch_size=4,   # How big our patches are
#         embed_dim=128,   # Embedding dim
#         n_layers=2,     # Number of transformer encoders
#         n_conv=2,       # Number of convolutional layers
#         n_heads=2,      # Number of attention heads
#         attn_dropout=0.,        # Attention Dropout
#         proj_dropout=0.,        # (MHA) Projection Dropout
#         mlp_dropout=0.1,        # (MHA) last layer dropout
#         mlp_ratio=1,    # (MHA) Projection FF dimension
#         qkv_bias = True,
#         n_classes=3     # Number of classes to classify
#         )
# img_size=64, batch_size=128
# test_loss=0.4516, test_acc=88.47%, avg_epoch=9.22s, Total_Time=15m22.2s
# Computational Resources: cpu=46%, memory=3.93gb, gpu=42%, gpu_memory=3.4gb
#
# *CCT actually produces a model with less accuracy despite a better average loss measurement. Most likely due to poor optimization performance on the validation data, the graph shows the values jumping around much more sporadically than with the base model.
#
# ---------------------
#
# model = CCT(
#         img_size=img_size,      # Input image size
#         in_channels=3,  # Number of channels for the image
#         patch_size=4,   # How big our patches are
#         embed_dim=128,   # Embedding dim
#         n_layers=2,     # Number of transformer encoders
#         n_conv=2,       # Number of convolutional layers
#         n_heads=2,      # Number of attention heads
#         attn_dropout=0.,        # Attention Dropout
#         proj_dropout=0.,        # (MHA) Projection Dropout
#         mlp_dropout=0.1,        # (MHA) last layer dropout
#         mlp_ratio=1,    # (MHA) Projection FF dimension
#         qkv_bias = True,
#         n_classes=3     # Number of classes to classify
#         )
# img_size=64, batch_size=128
# test_loss=0.5067, test_acc=92.26%, avg_epoch=9.06s, Total_Time=15m5.7s
# Computational Resources: cpu=48%, memory=3.66gb, gpu=42%, gpu_memory=3.4gb
#
# *Normalizes the convolutional layer to make it more stable. Now produces better results than original model.
#
# ---------------------
#
# model = CCT(
#         img_size=img_size,      # Input image size
#         in_channels=3,  # Number of channels for the image
#         patch_size=4,   # How big our patches are
#         embed_dim=128,   # Embedding dim
#         n_layers=2,     # Number of transformer encoders
#         n_conv=2,       # Number of convolutional layers
#         n_heads=2,      # Number of attention heads
#         attn_dropout=0.,        # Attention Dropout
#         proj_dropout=0.,        # (MHA) Projection Dropout
#         mlp_dropout=0.1,        # (MHA) last layer dropout
#         mlp_ratio=1,    # (MHA) Projection FF dimension
#         qkv_bias = True,
#         n_classes=3     # Number of classes to classify
#         )
# img_size=64, batch_size=128
# test_loss=0.3304, test_acc=93.14%, avg_epoch=9.94s, Total_Time=16m34.1s
# Computational Resources: cpu=60%, memory=3.00gb, gpu=48%, gpu_memory=3.5gb
#
# *Introduced one random transformation on training data, with random horizontal flips. 75% chance of every image.
#
# ---------------------
#
# model = CCT(
#         img_size=img_size,      # Input image size
#         in_channels=3,  # Number of channels for the image
#         patch_size=4,   # How big our patches are
#         embed_dim=128,   # Embedding dim
#         n_layers=2,     # Number of transformer encoders
#         n_conv=2,       # Number of convolutional layers
#         n_heads=2,      # Number of attention heads
#         attn_dropout=0.,        # Attention Dropout
#         proj_dropout=0.,        # (MHA) Projection Dropout
#         mlp_dropout=0.1,        # (MHA) last layer dropout
#         mlp_ratio=1,    # (MHA) Projection FF dimension
#         qkv_bias = True,
#         n_classes=3     # Number of classes to classify
#         )
# img_size=64, batch_size=128
# test_loss=0.1755, test_acc=94.37%, avg_epoch=10.50s, Total_Time=17m30.9s
# Computational Resources: cpu=60%, memory=3.00gb, gpu=48%, gpu_memory=3.5gb
#
# *Introduced a second transformation. Random rotation between -60 and 60 degrees.
#
# ---------------------
#
# model = CCT(
#         img_size=img_size,      # Input image size
#         in_channels=3,  # Number of channels for the image
#         patch_size=4,   # How big our patches are
#         embed_dim=128,   # Embedding dim
#         n_layers=2,     # Number of transformer encoders
#         n_conv=2,       # Number of convolutional layers
#         n_heads=2,      # Number of attention heads
#         attn_dropout=0.,        # Attention Dropout
#         proj_dropout=0.,        # (MHA) Projection Dropout
#         mlp_dropout=0.1,        # (MHA) last layer dropout
#         mlp_ratio=1,    # (MHA) Projection FF dimension
#         qkv_bias = True,
#         n_classes=3     # Number of classes to classify
#         )
# img_size=64, batch_size=128
# test_loss=0.1597, test_acc=94.66%, avg_epoch=11.79s, Total_Time=19m39.8s
#
# *Introduced a third transformation. Using colorjitter to adjust the brightness between 0 and 20% and the hue between 0 and 20%.
# Then used a randomapply transform to give it a 75% chance of applying that to every image.
#
# ---------------------
#
# model = CCT(
#         img_size=img_size,      # Input image size
#         in_channels=3,  # Number of channels for the image
#         patch_size=4,   # How big our patches are
#         embed_dim=128,   # Embedding dim
#         n_layers=2,     # Number of transformer encoders
#         n_conv=2,       # Number of convolutional layers
#         n_heads=2,      # Number of attention heads
#         attn_dropout=0.,        # Attention Dropout
#         proj_dropout=0.,        # (MHA) Projection Dropout
#         mlp_dropout=0.1,        # (MHA) last layer dropout
#         mlp_ratio=1,    # (MHA) Projection FF dimension
#         qkv_bias = True,
#         n_classes=3     # Number of classes to classify
#         )
# img_size=64, batch_size=128
# test_loss=0.3392, test_acc=90.25%, avg_epoch=11.54s, Total_Time=19m14.1s
#
# *Went back and tested it using just the color transform since it had such an apparent impact.
#
# ---------------------
#
# model = CCT(
#         img_size=img_size,      # Input image size
#         in_channels=3,  # Number of channels for the image
#         patch_size=4,   # How big our patches are
#         embed_dim=128,   # Embedding dim
#         n_layers=2,     # Number of transformer encoders
#         n_conv=2,       # Number of convolutional layers
#         n_heads=2,      # Number of attention heads
#         attn_dropout=0.,        # Attention Dropout
#         proj_dropout=0.,        # (MHA) Projection Dropout
#         mlp_dropout=0.1,        # (MHA) last layer dropout
#         mlp_ratio=1,    # (MHA) Projection FF dimension
#         qkv_bias = True,
#         n_classes=3     # Number of classes to classify
#         )
# img_size=64, batch_size=128, epochs=600
# test_loss=0.2107, test_acc=96.22%, avg_epoch=10.89s, Total_Time=108m53.5s
# Computational Resources: cpu=61%, memory=3.24gb, gpu=43%, gpu_memory=3.6gb
#
# *Ran all three transformations out for extended number of epochs
#
# ---------------------
#
# model = CCT(
#         img_size=img_size,      # Input image size
#         in_channels=3,  # Number of channels for the image
#         patch_size=4,   # How big our patches are
#         embed_dim=128,   # Embedding dim
#         n_layers=2,     # Number of transformer encoders
#         n_conv=2,       # Number of convolutional layers
#         n_heads=2,      # Number of attention heads
#         attn_dropout=0.,        # Attention Dropout
#         proj_dropout=0.,        # (MHA) Projection Dropout
#         mlp_dropout=0.1,        # (MHA) last layer dropout
#         mlp_ratio=1,    # (MHA) Projection FF dimension
#         qkv_bias = True,
#         n_classes=3     # Number of classes to classify
#         )
# img_size=64, batch_size=128, epochs=600
# test_loss=0.1701, test_acc=94.40%, avg_epoch=15.61s, Total_Time=156m5.2s
# Computational Resources: cpu=61%, memory=3.24gb, gpu=43%, gpu_memory=3.6gb
#
# *Introduced a lot more augmentations to better mimmick the augmentation done on another paper.

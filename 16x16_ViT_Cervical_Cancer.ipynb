# %%
import os
from PIL import Image
import torch
from torch.utils.data import DataLoader,Dataset
import torch.nn as nn
from torch import Tensor
import torchvision
import torchvision.transforms as transforms
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import torch.nn.functional as F
from datetime import datetime
from sklearn.model_selection import train_test_split

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
torch.backends.cudnn.benchmark = True

# %% [markdown]
# # The 'An Image is Worth 16x16 Words' Vision Transformer
# *Created using the walkthrough from https://medium.com/pytorch/training-compact-transformers-from-scratch-in-30-minutes-with-pytorch-ff5c21668ed5 and Dr Prashant's Vision_Transformer file

# %% [markdown]
# ## Building the Transformer block by block

# %% [markdown]
# Every part/layer of the transformer is built using the Pytorch nn.module class which allows for easy creation of maching learning models. Each layer should be made up of at least two parts: An initialization function which uses the given information to build the class and then the 'Forward' function defines how the class will run when it is called.

# %% [markdown]
# ### Transformer Constructor
#
# First, the actual ViT Constructor which essentially acts as a hub. It ensures that each part of the transformer is called in the correct order and that local variables can be passed along.

# %%
class ViT(nn.Module):
    '''
    Simplified implementation of the Vision transformer.

    Parameters
    ----------
    img_size: int
        Both height and width of the image (if it is a square)
    in_channels: int
        Number of input channels
    patch_size: int
        Both height and width of the patch (if it is a square)
    embed_dim: int
        The embedding size for each token
    n_layers: int
        Number of transformer blocks
    n_heads: int
        Number of attention heads
    attn_dropout, proj_dropout, mlp_dropout: float
        Dropout probability
    mlp_ratio: float
        Determine the hidden dimension of the MLP module
    qkv_bias: bool
        If true then we add bias to the query, key and value projections
    n_classes: int
        Number of classes

    Attributes
    -----------
    n_patches: int
        Number of patches that can be taken from each image based on size.
    patch_embed: PatchEmbed
        Sets up the `Patching' layer.
    class_embed: nn.Parameter
        Learnable parameter that will represent the first class token in the sequence.
        It has `embed_dim' elements.
    pos_embed: nn.Parameter
        Adds a positional encoding to every token.
    pos_drop: nn.Dropout
        Dropout layer.
    tr_block: nn.ModuleList
        Instance of 'TransformerEncoderLayer'.
    norm: nn.Layernorm
        Layer normalization.
    '''
    def __init__(self,
                 img_size=32,   # The square size of each image
                 in_channels=3, # Number of channels for each image (eg: Grayscale=1, RGB=3)
                 patch_size=4,  # The square size of each patch
                 embed_dim=42,  # Embedding dimension
                 n_layers=3, # How many times to run the transformer encoder
                 n_heads=3,   # Number of attention heads
                 attn_dropout=0.,  # Attention Dropout
                 proj_dropout=0.,   # (MHA) Projection Dropout
                 mlp_dropout=0.,   # (MHA) last layer dropout
                 mlp_ratio=4,   # (MHA) Projection FF dimension
                 qkv_bias = True,
                 n_classes=10   # Number of classes to classify
    ):
        super().__init__()
        # Provides an error if the patching size is not divisible by the image size.
        assert img_size % patch_size == 0, \
            print("Given image size ({}) has to be divisible by given patch size ({})".format(img_size, patch_size))
        n_patches = (img_size // patch_size) ** 2
        hidden_dim = int(embed_dim * mlp_ratio)
        
        self.patch_embed = Patching(
            in_channels,
            patch_size,
            embed_dim
        )

        self.class_embed = nn.Parameter(torch.zeros(1,1, embed_dim))
        self.pos_embed = nn.Parameter(torch.zeros(1, n_patches+1, embed_dim))
        # Can use this to enable Sinusoidal PE
        #self.pos_embed = PositionalEmbedding(1, n_patches + 1, embed_dim)

        self.pos_drop = nn.Dropout(p=proj_dropout)
        self.tr_block = nn.ModuleList(
            [
                TransformerEncoderLayer(
                    embed_dim,
                    n_heads,
                    qkv_bias,
                    attn_dropout,
                    proj_dropout,
                    mlp_dropout,
                    hidden_dim
                    )
                for _ in range(n_layers)
            ]   # Sends data through the encoder n times
        )
                                    
        self.norm = nn.LayerNorm(embed_dim, eps=1e-6)
        self.head = nn.Linear(embed_dim, n_classes)

    def forward(self, x):
        '''
        Defines how the class will run

        Parameters
        ----------
        x: torch.Tensor
            shape: n_samples, in_chains, img_size, img_size

        Returns
        ---------
        logits: torch.Tensor
            Logits over all the classes: n_samples, n_samples
        '''
        x = self.patch_embed(x)
        class_token = self.class_embed.expand(x.shape[0], -1, -1)
        x = torch.cat((class_token, x), dim=1)
        #x = self.pos_embed(x)
        x += self.pos_embed
        x = self.pos_drop(x)
        for tr_block in self.tr_block:
            x = tr_block(x)
        x = self.norm(x)
        x = x[:, 0]
        x = self.head(x)
        return x

# %% [markdown]
# ### Positional Embedding
#
# This is the sinusoidal positional encoding layer as seen in the original 'Attention is All You Need' paper. It basically uses a sin/cos waveform to provide a unique positional offset that is given to a token at the corresponding position in its embedding space.
#
# By default, this is disabled and we instead use a trainable matrix of zeros. This adds another dimension to our data that the model then uses to find the best weights for the data's position itself. This is called "learnable" positional encoding.
#
# There are pros-and-cons to either, but essentially: sinusoidal is better when there are not a lot of data samples to learn the positional data from but you can get better results from "learnable" with larger datasets.

# %%
class PositionalEmbedding(nn.Module):
    '''
    Applies Learnable Sinusoidal Positional Encoding

    Parameters
    ----------
    embed_dim: int
        The positional embedding dimension (How big embedding for each patch.Constant across entire network)
    max_len: int 
        Max number of instances for positions
    freq: int 
        The base frequency for Sin/Cos calculations. Higher values (eg 10000) are more stable
    '''
    def __init__(self, 
                 embed_dim,
                 max_len=5000,
                 freq=10000.,
                ):
        super().__init__()
        pe = torch.zeros(max_len, embed_dim)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div = torch.exp(torch.arange(0, embed_dim, 2).float() *
                        (-math.log(freq) / embed_dim))
        pe[:, 0::2] = torch.sin(position * div) # Even terms
        pe[:, 1::2] = torch.cos(position * div) # Odd terms
        pe = pe.unsqueeze(0).transpose(0,1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        '''
        Defines how the class will run

        Parameters
        -----------

        Returns
        -----------
        '''
        x = x + self.pe[:x.size(0), :]
        return x

# %% [markdown]
# ### Patching Layer
#
# This patching layer uses a convolutional filter to segment the input image into patch_size segments, but it does NOT produce convolutional samples. It's just a convenient way to produce patches. It accomplishes this by making the kernel and stride the same size as a patch so that it moves across the image grabbing segments with no overlap.

# %%
class Patching(nn.Module):
    '''
    Splits the image into patches

    Parameters
    ----------
    in_channels: int 
        Number of input channels (eg: Grayscale=1, RGB = 3)
    patch_size: int 
        Size of the patch (it is a square; it doesnt have to be) (Sometimes called kernel_size)
    embed_dim: int
        The positional embedding dimension (How big embedding for each patch.Constant across entire network)

    Attributes
    ----------
    proj: nn.Conv2d
        Convolutional layer that does both the splitting into patches and embedding
    '''
    def __init__(self,
                 in_channels=3,
                 patch_size=16,
                 embed_dim=768,
    ):

        super().__init__()

        self.proj = nn.Conv2d(
            in_channels,
            embed_dim,
            kernel_size=patch_size,
            stride=patch_size
        )

    def forward(self, x):
        '''
        Defines how the class will run

        Parameters
        -----------
        x: torch.Tensor
        Shape: (n_samples, in_channels, img_size, img_size)

        Returns
        -----------
        torch.Tensor
        Shape: (n_samples, n_patches, embed_dim)
        '''
        x = self.proj(x)
        x = x.flatten(2)
        x = x.transpose(1,2)
        return x

# %% [markdown]
# ### This is the Transformer Encoder block which applies all of the actual normalization, attention, etc that make a Transformer what it is.

# %%
class TransformerEncoderLayer(nn.Module):
    '''
    Transformer Block/Encoder Layer

    Parameter
    ---------
    embed_dim: int
        embedding dimension
    n_heads: int
        number of attention heads
    mlp_ratio: float
        determines the hidden dimension size of the MLP module with respect to 'dim'
    qkv_bias: bool
        If true then we include bias to the query, key and value projections
    mlp_dropout, proj_dropout, attn_droupout: float
        dropout probability
    dim_feedforward: int
        The feature number of hidden layer of the FFN

    Attributes
    ----------
    norm_1, norm_2: LayerNorm
        Layer normalization
    MHA: Attention
        Multi-Headed Attention module
    mlp: MLP
        MLP module
    ''' 
    def __init__(self,
                 embed_dim=768,
                 n_heads=12,
                 qkv_bias=True,
                 attn_dropout=0.,
                 proj_dropout=0.,
                 mlp_dropout=0.,
                 hidden_dim=2048
    ):
        super().__init__()
        self.norm_1 = nn.LayerNorm(embed_dim, eps = 1e-6)
        self.norm_2 = nn.LayerNorm(embed_dim, eps = 1e-6)
        self.MHA = MultiheadedSelfAttention(embed_dim,
                                        n_heads,
                                        qkv_bias,
                                        attn_dropout,
                                        proj_dropout
        )
        self.MLP = MLP(embed_dim, hidden_dim, mlp_dropout)

    def forward(self, x):
        '''
        Defines how the class will run
        
        Parameter
        ---------
        x: torch.Tensor
            shape: n_samples, n_patches + 1, dim

        Returns
        --------
        torch.Tensor
            shape: n_samples, n_patches + 1, dim
        '''
        x = x + self.MHA(self.norm_1(x))    # Residual connection (Add)
        x = x + self.MLP(self.norm_2(x))    # Residual connection (Add)
        return x

# %% [markdown]
# ### Multiheaded Attention Layer
#
# The heart of the Transformer model; the reason behind the original title of "attention is all you need".

# %%
class MultiheadedSelfAttention(nn.Module):
    '''
    Multi-Headed Attention Mechanism

    Parameters
    ----------
    embed_dim: int
        The input and out dimension of per token feature
    n_heads: int
        Number of attention heads 
    qkv_bias: bool
        if true then we include bias to the query, key and value projections
    attn_p: float
        Dropout probability applied to the query, key and value tensors.
    proj_p: float
        Dropout probability applied to output tensor
        
    Attributes
    ----------
    scale: float
        Normalizing constant for the dot product
    qkv: nn.Linear
        Linear projection for the query, key and value
    proj: nn.Linear
        Linear mapping that takes in the concatenated output of all attention
        heads and maps into the new space
    attn_drop, proj_drop: nn.Dropout
        Dropout layers.
    '''
    def __init__(self, 
                 embed_dim, 
                 n_heads=2,
                 qkv_bias = True,
                 attn_dropout=0.,
                 proj_dropout=0.
    ):
        super().__init__()
        self.n_heads = n_heads
        assert embed_dim % n_heads == 0, \
            print('Embedding dim must be divisible by number of heads.')
        self.head_dim = embed_dim // n_heads
        self.scale = self.head_dim ** -0.5
        self.dim = embed_dim
        self.qkv = nn.Linear(embed_dim, embed_dim * 3, bias=qkv_bias)
        self.attn_dropout = nn.Dropout(attn_dropout)
        self.proj = nn.Linear(embed_dim, embed_dim)
        self.proj_dropout = nn.Dropout(proj_dropout)
        
    def forward(self, x):
        '''
        Defines how the class will run
        
        Parameters
        ----------
        x: torch.Tensor
            shape: n_samples (B), n_patches + 1 (N), embed_dim (C)
            N is also equal to the number of tokens.
        Returns
        --------
        torch.Tensor
            shape: n_samples, n_patches + 1, embed_dim
        '''
        B, N, C = x.shape
        qkv = self.qkv(x)
        qkv = qkv.reshape(B, N, 3,
            self.n_heads,
            self.head_dim
            )
        qkv = qkv.permute(
            2,    # qkv (3)
            0,    # batch (n_samples)
            3,    # channel (n_heads)
            1,    # n_patches + 1
            4     # head_dim (embed_dim / n_heads)
            )
        q, k, v = qkv[0], qkv[1], qkv[2]
        attn = (q @ k.transpose(-2, -1)) * self.scale # <q,k> / sqrt(d)
        attn = attn.softmax(dim=-1) # Softmax over embedding dim
        attn = self.attn_dropout(attn)

        weighted_avg = (attn @ v)
        weighted_avg = weighted_avg.transpose(1, 2)
        weighted_avg = weighted_avg.flatten(2)

        x = self.proj(weighted_avg)
        x = self.proj_dropout(x)

        return x

# %% [markdown]
# ### The MLP layer
#
# (At the end of the Transformer Encoder). Not to be confused with the mlp head which adds class encodings at the very end of the transformer.

# %%
class MLP(nn.Module):
    '''
    Multilayer perceptron 
    
    Parameters
    ----------
    embed_dim: int
        embedding dimension
    feedforward_dim: int
      Number of nodes in the hidden layer
    mlp_dropout: float
      Dropout probability

    Attribute
    ---------
    fc: nn.Linear
      The first linear layer
    act: nn. GELU
      GELU activation function
    fc2: nn.Linear
      The second linear layer
    drop: nn.Dropout
      Dropout layer
    '''

    def __init__(self, embed_dim, hidden_dim, mlp_dropout):
        super().__init__()
        self.fc1 = nn.Linear(embed_dim, hidden_dim)
        self.act = nn.GELU()
        self.fc2 = nn.Linear(hidden_dim, embed_dim)
        self.drop = nn.Dropout(mlp_dropout)

    def forward(self,x):
        '''
        Defines how the class will run
        
        Parameters
        ----------
        x: torch.Tensor
          shape: n_samples, n_patches + 1, in_features

        Returns
        ----------
        torch.Tensor
          n_samples, n_patches+ 1, out_features
        '''
        x = self.fc1(x) # n_samples, n_patches+1, hidden_features
        x = self.act(x) # n_samples, n_patches+1, hidden_features
        x = self.drop(x) # n_samples, n_patches+1, hidden_features
        x = self.fc2(x) # n_samples, n_patches+1, output_features
        x = self.drop(x) # n_samples, n_patches+1, output_features
        return x

# %% [markdown]
# # Training the ViT with the CIFAR10 dataset

# %% [markdown]
# ### Setup needed variables

# %%
def sipakmed_prep():
    root = "../../Python Scripts/Datasets/CervicalCancer/Sipakmed/"

    all_img = []
    for path, subdirs, files in os.walk(root):
        for name in files:
            curr_img = os.path.join(path,name)
            all_img.append(curr_img)

    sipakmed_df = pd.DataFrame()
    sipakmed_df['LocalPath'] = all_img
    sipakmed_df['ID'] = sipakmed_df['LocalPath'].apply(lambda x: str(x.split("\\")[-1]))
    sipakmed_df['Slide'] = sipakmed_df['LocalPath'].apply(lambda x: 'False' if (str(x.split("\\")[1])) == 'CROPPED' else 'True')
    sipakmed_df['Specific_Status'] = sipakmed_df['LocalPath'].apply(lambda x: str((x.split("im_")[1]).split("\\")[0]))
    sipakmed_df['Status'] = sipakmed_df['Specific_Status'].apply(lambda x: 'Benign' if x == 'Metaplastic' else
    ('Normal' if x == 'Superficial-Intermediate' or x == 'Parabasal' else 'Abnormal'))

    sp_class = {'Metaplastic':4, 'Superficial-Intermediate':0, 'Parabasal':1, 'Koilocytotic':2, 'Dyskeratotic':3}
    sipakmed_df['Specific_Class'] = sipakmed_df['Specific_Status'].map(sp_class)
    gen_class = {'Benign':0, 'Normal':1, 'Abnormal':2}
    sipakmed_df['Class'] = sipakmed_df['Status'].map(gen_class)

    sipakmed_df = sipakmed_df.loc[sipakmed_df['ID'].str.contains('bmp')].reset_index(drop=True)
    
    #Uploads the created file for future use. Recommended to not use.
    #sipakmed_df.to_csv(root + '/results.csv')
    return sipakmed_df

# %%
def herlev_prep():
    root = '../../Python Scripts/Datasets/CervicalCancer/Herlev/smear2005/results.csv'
    img_folder = '../../Python Scripts/Datasets/CervicalCancer/Herlev/smear2005/Images/'

    herlev_df=pd.read_csv(root)
    herlev_df = herlev_df.rename(columns={'Class':'Specific_Class'})

    spec_class = {1:0, 2:1, 3:2, 4:3, 5:4, 6:5, 7:6}
    gen_class = {1:1, 2:1, 3:1, 4:2, 5:2, 6:2, 7:2}
    
    herlev_df['Class'] = herlev_df['Specific_Class'].map(gen_class)
    herlev_df['Specific_Class'] = herlev_df['Specific_Class'].map(spec_class)
    herlev_df['LocalPath'] = herlev_df['ID'].apply(lambda x: str(img_folder + x))
    return herlev_df

# %%
class DatasetSample(Dataset):
    def __init__(self, df, transform):
        # Initialization
        self.transform = transform
        
        self.image_names = df['LocalPath']
        self.img_class = np.array(df['Class'])

    def __len__(self):
        # Denotes the total number of samples
        return len(self.image_names)
    
    def __getitem__(self, index):
        # Retrieves the data
        image=cv2.imread(self.image_names.iloc[index])
        image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

        image = self.transform(image)
        label = self.img_class[index]

        x, y = image, label
        
        # Enable to output as single variable instead
        #sample = {'image': image,'labels':label}

        return x, y

# %%
def concat_data(batch_size=128, img_size=32):
    # Load the dataframes
    sipakmed_df = sipakmed_prep()
    herlev_df = herlev_prep()

    # Final adjustments to make sure they're attributes match
    sipakmed_df = sipakmed_df.loc[sipakmed_df['Slide'] == 'False']
    herlev_df = herlev_df.loc[:,['LocalPath', 'Class']]
    sipakmed_df = sipakmed_df.loc[:,['LocalPath', 'Class']]
    
    concat_df = pd.concat([sipakmed_df,herlev_df], ignore_index=True)
    
    '''
    concat_df = pd.DataFrame()
    concat_df['LocalPath'] = sipakmed_df['LocalPath']
    concat_df['Class'] = sipakmed_df['Specific_Class']
    concat_df = pd.DataFrame()
    concat_df['LocalPath'] = herlev_df['LocalPath']
    concat_df['Class'] = herlev_df['Specific_Class']
    '''


    # Split them into training, validation, and testing sets
    train_set,val_test_set = train_test_split(concat_df, random_state=1, test_size=0.30)
    val_set,test_set = train_test_split(val_test_set, random_state=1, test_size=0.50)
    
    # Set it up to alter random training images for better results
    train_transform = transforms.Compose([
                    transforms.ToPILImage(),
                    transforms.Resize((img_size, img_size)),
                    transforms.RandomHorizontalFlip(p=0.75),
                    transforms.RandomRotation(degrees=60),
                    transforms.ToTensor()])

    test_transform = transforms.Compose([
                    transforms.ToPILImage(),
                    transforms.Resize((img_size, img_size)),
                    transforms.ToTensor()])

    train_dataset = DatasetSample(train_set, train_transform)
    val_dataset = DatasetSample(val_set, test_transform)
    test_dataset = DatasetSample(test_set, test_transform)
    
    Dtr = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True
    )
    
    Dva = DataLoader(
        val_dataset, 
        batch_size=batch_size,
        shuffle=True
    )

    Dte = DataLoader(
        test_dataset, 
        batch_size=batch_size,
        shuffle=True
    )

    return(Dtr, Dva, Dte)

# %%
#The corresponding class labels
batch_size=64
img_size=84
classes = ('Benign', 'Normal', 'Abnormal')
#classes = ('Superficial-Intermediate','Parabasal','Koilocytotic','Dyskeratotic','Metaplastic')
#classes = ('Superficial-Squamous-Epithelial','Intermediate-Squamous-Epithelial','Columnar-Epithelial','Mild-Squamous-Non-Keratinizing-Dysplasia',
#           'Moderate-Squamous-Non-Keratinizing-Dysplasia','Severe-Squamous-Non-Keratinizing-Dysplasia','Squamous-Cell-Carcinoma-in-situ-Intermediate')
Dtr, Dva, Dte = concat_data(batch_size=batch_size, img_size=img_size)
print('The total number of samples for Training is: {}, Validation: {}, and Testing: {}'.format(len(Dtr)*batch_size, len(Dva)*batch_size, len(Dte)*batch_size))
# Out:
# The total number of samples for Training is: 3520, Validation: 768, and Testing: 768

# %%
# Turns the dataloaders into iterable objects. Useful for viewing
dataiter = iter(Dtr)
val_dataiter = iter(Dva)
test_dataiter = iter(Dte)

# %% [markdown]
# ### Function for viewing batches of the dataset

# %%
def imshow(images, labels, predicted_labels=None):
    
    if images.is_cuda == True:
        images = images.to("cpu")
    if labels.is_cuda == True:
        labels = labels.to("cpu")

    # Using torchvision to make a grid of the images
    img = torchvision.utils.make_grid(images)

    # Inverting the normalization
    img = img.numpy().transpose((1, 2, 0))
    img = np.clip(img, 0, 1)

    # Plotting the grid
    fig, ax = plt.subplots(figsize=(12, 24))
    plt.imshow(img)

    if predicted_labels is not None:
        if predicted_labels.is_cuda == True:
            predicted_labels = predicted_labels.to("cpu")
        # Outputing the predicted labels
        ax.set_xlabel('Predicted labels', fontsize=18, labelpad=12)
        ax.set_xticks(torch.arange(len(images)) * img_size + (img_size/1.8))
        ax.set_xticklabels([classes[predicted_labels[j]] 
                            for j in range(len(images))], fontsize=12, rotation=30)
    
    # Outputing the True labels
    gax = ax.secondary_xaxis('top')
    gax.set_xlabel('True Labels', fontsize=18, labelpad=12)
    gax.set_xticks(torch.arange(len(images)) * img_size + (img_size/1.8))
    gax.set_xticklabels([classes[labels[j]] 
                         for j in range(len(images))], fontsize=12, rotation=30)
    plt.show()

# %%
images, labels = dataiter.next()
imshow(images[:7], labels[:7])

# %% [markdown]
# ### This function was made by Dr Prashant to train the model that's built above

# %%
# A function to encapsulate the training loop
def batch_gd(model, loss_fn, optimizer, train_loader, val_loader, epochs):
  model.to(device)
  train_losses = np.zeros(epochs)
  val_losses = np.zeros(epochs)
  
  for it in range(epochs):
    model.train()
    t0 = datetime.now()
    train_loss = []
    n_correct = 0.
    n_total = 0.
    for inputs, targets in train_loader:
      # move data to GPU if available
      inputs, targets = inputs.to(device), targets.to(device)

      # zero the parameter gradients
      optimizer.zero_grad()

      # Forward pass
      outputs = model(inputs)
      
      # Get the predictions
      # torch.max returns both max and argmax
      __, out_label = outputs.max(dim=1)
      # Updates the accuracy with every pass
      n_correct += (out_label == targets).sum().item()
      n_total += targets.shape[0]
      tr_acc = n_correct / n_total

      loss = loss_fn(outputs, targets)
      # Backward and optimize
      loss.backward()
      optimizer.step()

      train_loss.append(loss.item())

    # Get train loss and test loss
    train_loss = np.mean(train_loss) # a little misleading
    
    model.eval()
    val_loss = []
    n_correct = 0.
    n_total = 0.
    for inputs, targets in val_loader:
      inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)

      # Get the predictions
      # torch.max returns both max and argmax
      __, out_label = outputs.max(dim=1)
      # Updates the accuracy with every pass
      n_correct += (out_label == targets).sum().item()
      n_total += targets.shape[0]
      val_acc = n_correct / n_total

      loss = loss_fn(outputs, targets)
      val_loss.append(loss.item())
    val_loss = np.mean(val_loss)

    # Save losses
    train_losses[it] = train_loss
    val_losses[it] = val_loss
    
    dt = datetime.now() - t0

    print(f'Epoch {it+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {(100*tr_acc):.3f} \
      Val Loss: {val_loss:.4f}, Val Accuracy: {(100*val_acc):.3f}, Duration: {dt}')
  
  return train_losses, val_losses

# %% [markdown]
# ### Initializes the Transformer and selects the loss function and optimizer we want

# %%
model = ViT(
        img_size=img_size,          # Input image size
        in_channels=3,		# Number of channels for the image
        patch_size=4,         # How big our patches are
        embed_dim=128,		# Embedding dim
        n_layers=2,         # Number of transformer encoders
        n_heads=2,          # Number of attention heads
        attn_dropout=0.,       # Attention Dropout
        proj_dropout=0.,       # (MHA) Projection Dropout
        mlp_dropout=0.1,       # (MHA) last layer dropout
        mlp_ratio=1,           # (MHA) Projection FF dimension
        qkv_bias = True,
        n_classes=3       # Number of classes to classify
        )
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())

# %%
train_losses, val_losses = batch_gd(model, loss_fn, optimizer, Dtr, Dva, epochs=400)
# Out:
# Epoch 1/400, Train Loss: 0.9081, Train Accuracy: 55.898       Val Loss: 0.6338, Val Accuracy: 74.497, Duration: 0:00:15.424745
# Epoch 2/400, Train Loss: 0.5980, Train Accuracy: 75.978       Val Loss: 0.5337, Val Accuracy: 79.329, Duration: 0:00:12.495655
# Epoch 3/400, Train Loss: 0.5402, Train Accuracy: 78.797       Val Loss: 0.5127, Val Accuracy: 79.329, Duration: 0:00:12.514551
# Epoch 4/400, Train Loss: 0.4919, Train Accuracy: 80.466       Val Loss: 0.4630, Val Accuracy: 81.074, Duration: 0:00:12.453715
# Epoch 5/400, Train Loss: 0.4538, Train Accuracy: 82.250       Val Loss: 0.4553, Val Accuracy: 82.953, Duration: 0:00:12.476653
# Epoch 6/400, Train Loss: 0.4198, Train Accuracy: 84.350       Val Loss: 0.4066, Val Accuracy: 83.356, Duration: 0:00:12.513555
# Epoch 7/400, Train Loss: 0.4310, Train Accuracy: 83.774       Val Loss: 0.4145, Val Accuracy: 84.430, Duration: 0:00:12.500588
# Epoch 8/400, Train Loss: 0.3900, Train Accuracy: 85.501       Val Loss: 0.3796, Val Accuracy: 85.638, Duration: 0:00:12.455710
# Epoch 9/400, Train Loss: 0.3638, Train Accuracy: 86.306       Val Loss: 0.4477, Val Accuracy: 82.013, Duration: 0:00:12.543475
# Epoch 10/400, Train Loss: 0.3351, Train Accuracy: 87.342       Val Loss: 0.4077, Val Accuracy: 84.698, Duration: 0:00:12.552450
# Epoch 11/400, Train Loss: 0.3442, Train Accuracy: 87.342       Val Loss: 0.3520, Val Accuracy: 86.711, Duration: 0:00:12.486628
# Epoch 12/400, Train Loss: 0.3459, Train Accuracy: 87.025       Val Loss: 0.3682, Val Accuracy: 85.772, Duration: 0:00:12.505574
# Epoch 13/400, Train Loss: 0.3398, Train Accuracy: 86.795       Val Loss: 0.4154, Val Accuracy: 82.685, Duration: 0:00:12.518541
# Epoch 14/400, Train Loss: 0.3301, Train Accuracy: 87.428       Val Loss: 0.4287, Val Accuracy: 81.879, Duration: 0:00:12.602317
# Epoch 15/400, Train Loss: 0.3458, Train Accuracy: 86.220       Val Loss: 0.3359, Val Accuracy: 87.114, Duration: 0:00:12.566414
# Epoch 16/400, Train Loss: 0.3068, Train Accuracy: 88.550       Val Loss: 0.5331, Val Accuracy: 80.403, Duration: 0:00:12.543474
# Epoch 17/400, Train Loss: 0.2984, Train Accuracy: 88.234       Val Loss: 0.3661, Val Accuracy: 86.846, Duration: 0:00:12.531506
# Epoch 18/400, Train Loss: 0.2944, Train Accuracy: 89.068       Val Loss: 0.3559, Val Accuracy: 86.711, Duration: 0:00:12.573395
# Epoch 19/400, Train Loss: 0.3119, Train Accuracy: 87.514       Val Loss: 0.3732, Val Accuracy: 84.698, Duration: 0:00:12.540482
# Epoch 20/400, Train Loss: 0.2797, Train Accuracy: 89.327       Val Loss: 0.3329, Val Accuracy: 87.517, Duration: 0:00:12.552451
# Epoch 21/400, Train Loss: 0.2780, Train Accuracy: 89.183       Val Loss: 0.3619, Val Accuracy: 87.651, Duration: 0:00:12.536492
# Epoch 22/400, Train Loss: 0.2938, Train Accuracy: 89.097       Val Loss: 0.3294, Val Accuracy: 88.859, Duration: 0:00:12.852649
# Epoch 23/400, Train Loss: 0.2502, Train Accuracy: 90.478       Val Loss: 0.3309, Val Accuracy: 87.248, Duration: 0:00:13.305437
# Epoch 24/400, Train Loss: 0.2460, Train Accuracy: 90.391       Val Loss: 0.3636, Val Accuracy: 86.174, Duration: 0:00:13.365279
# Epoch 25/400, Train Loss: 0.2350, Train Accuracy: 90.823       Val Loss: 0.3281, Val Accuracy: 88.993, Duration: 0:00:12.805773
# Epoch 26/400, Train Loss: 0.2624, Train Accuracy: 90.161       Val Loss: 0.2976, Val Accuracy: 88.725, Duration: 0:00:12.613288
# Epoch 27/400, Train Loss: 0.2486, Train Accuracy: 90.995       Val Loss: 0.2770, Val Accuracy: 90.336, Duration: 0:00:12.618275
# Epoch 28/400, Train Loss: 0.2240, Train Accuracy: 91.283       Val Loss: 0.2968, Val Accuracy: 89.128, Duration: 0:00:12.580375
# Epoch 29/400, Train Loss: 0.2250, Train Accuracy: 91.341       Val Loss: 0.2882, Val Accuracy: 89.799, Duration: 0:00:12.531508
# Epoch 30/400, Train Loss: 0.2281, Train Accuracy: 90.995       Val Loss: 0.3019, Val Accuracy: 89.664, Duration: 0:00:12.562422
# Epoch 31/400, Train Loss: 0.2255, Train Accuracy: 91.858       Val Loss: 0.3226, Val Accuracy: 88.725, Duration: 0:00:12.608300
# Epoch 32/400, Train Loss: 0.2313, Train Accuracy: 91.168       Val Loss: 0.3075, Val Accuracy: 88.591, Duration: 0:00:12.541481
# Epoch 33/400, Train Loss: 0.2073, Train Accuracy: 92.664       Val Loss: 0.3049, Val Accuracy: 87.919, Duration: 0:00:12.664151
# Epoch 34/400, Train Loss: 0.2170, Train Accuracy: 91.715       Val Loss: 0.2976, Val Accuracy: 89.262, Duration: 0:00:12.570403
# Epoch 35/400, Train Loss: 0.2058, Train Accuracy: 92.146       Val Loss: 0.2979, Val Accuracy: 90.872, Duration: 0:00:12.575389
# Epoch 36/400, Train Loss: 0.2218, Train Accuracy: 91.456       Val Loss: 0.3157, Val Accuracy: 88.188, Duration: 0:00:12.594340
# Epoch 37/400, Train Loss: 0.1946, Train Accuracy: 92.491       Val Loss: 0.2802, Val Accuracy: 90.336, Duration: 0:00:12.553447
# Epoch 38/400, Train Loss: 0.2187, Train Accuracy: 91.513       Val Loss: 0.2679, Val Accuracy: 90.201, Duration: 0:00:12.570402
# Epoch 39/400, Train Loss: 0.1829, Train Accuracy: 93.153       Val Loss: 0.3245, Val Accuracy: 89.530, Duration: 0:00:12.510563
# Epoch 40/400, Train Loss: 0.1894, Train Accuracy: 92.664       Val Loss: 0.3055, Val Accuracy: 89.396, Duration: 0:00:12.536493
# Epoch 41/400, Train Loss: 0.1927, Train Accuracy: 92.722       Val Loss: 0.2909, Val Accuracy: 89.933, Duration: 0:00:12.546467
# Epoch 42/400, Train Loss: 0.1656, Train Accuracy: 93.585       Val Loss: 0.3078, Val Accuracy: 89.530, Duration: 0:00:12.532504
# Epoch 43/400, Train Loss: 0.1878, Train Accuracy: 92.491       Val Loss: 0.2635, Val Accuracy: 91.007, Duration: 0:00:12.596333
# Epoch 44/400, Train Loss: 0.1774, Train Accuracy: 93.412       Val Loss: 0.2634, Val Accuracy: 90.738, Duration: 0:00:12.561426
# Epoch 45/400, Train Loss: 0.1826, Train Accuracy: 93.441       Val Loss: 0.2612, Val Accuracy: 90.604, Duration: 0:00:12.576387
# Epoch 46/400, Train Loss: 0.1733, Train Accuracy: 93.642       Val Loss: 0.2534, Val Accuracy: 91.409, Duration: 0:00:12.521533
# Epoch 47/400, Train Loss: 0.1694, Train Accuracy: 93.412       Val Loss: 0.2478, Val Accuracy: 91.141, Duration: 0:00:12.526520
# Epoch 48/400, Train Loss: 0.1931, Train Accuracy: 92.376       Val Loss: 0.3173, Val Accuracy: 89.530, Duration: 0:00:12.541480
# Epoch 49/400, Train Loss: 0.1700, Train Accuracy: 93.297       Val Loss: 0.2833, Val Accuracy: 90.067, Duration: 0:00:12.550456
# Epoch 50/400, Train Loss: 0.1566, Train Accuracy: 94.707       Val Loss: 0.2725, Val Accuracy: 91.007, Duration: 0:00:12.555442
# Epoch 51/400, Train Loss: 0.1559, Train Accuracy: 93.987       Val Loss: 0.2590, Val Accuracy: 91.141, Duration: 0:00:12.568408
# Epoch 52/400, Train Loss: 0.1384, Train Accuracy: 94.735       Val Loss: 0.3225, Val Accuracy: 89.530, Duration: 0:00:12.538487
# Epoch 53/400, Train Loss: 0.1460, Train Accuracy: 94.304       Val Loss: 0.3032, Val Accuracy: 88.859, Duration: 0:00:12.576386
# Epoch 54/400, Train Loss: 0.1399, Train Accuracy: 94.591       Val Loss: 0.3181, Val Accuracy: 90.604, Duration: 0:00:12.602318
# Epoch 55/400, Train Loss: 0.1320, Train Accuracy: 94.591       Val Loss: 0.2660, Val Accuracy: 90.872, Duration: 0:00:12.618274
# Epoch 56/400, Train Loss: 0.1339, Train Accuracy: 95.081       Val Loss: 0.2491, Val Accuracy: 92.081, Duration: 0:00:12.587357
# Epoch 57/400, Train Loss: 0.1404, Train Accuracy: 94.735       Val Loss: 0.2323, Val Accuracy: 92.617, Duration: 0:00:12.612291
# Epoch 58/400, Train Loss: 0.1343, Train Accuracy: 94.419       Val Loss: 0.2938, Val Accuracy: 89.933, Duration: 0:00:12.616280
# Epoch 59/400, Train Loss: 0.1438, Train Accuracy: 94.189       Val Loss: 0.2680, Val Accuracy: 91.812, Duration: 0:00:12.594338
# Epoch 60/400, Train Loss: 0.1888, Train Accuracy: 92.463       Val Loss: 0.2714, Val Accuracy: 90.872, Duration: 0:00:12.594340
# Epoch 61/400, Train Loss: 0.1516, Train Accuracy: 94.304       Val Loss: 0.2369, Val Accuracy: 91.812, Duration: 0:00:12.563421
# Epoch 62/400, Train Loss: 0.1129, Train Accuracy: 96.087       Val Loss: 0.2481, Val Accuracy: 91.678, Duration: 0:00:12.582370
# Epoch 63/400, Train Loss: 0.1162, Train Accuracy: 95.685       Val Loss: 0.3028, Val Accuracy: 91.275, Duration: 0:00:12.597330
# Epoch 64/400, Train Loss: 0.1465, Train Accuracy: 94.189       Val Loss: 0.2634, Val Accuracy: 90.738, Duration: 0:00:12.562425
# Epoch 65/400, Train Loss: 0.1481, Train Accuracy: 94.591       Val Loss: 0.2585, Val Accuracy: 91.275, Duration: 0:00:12.616280
# Epoch 66/400, Train Loss: 0.1305, Train Accuracy: 95.109       Val Loss: 0.2384, Val Accuracy: 93.020, Duration: 0:00:12.614285
# Epoch 67/400, Train Loss: 0.1146, Train Accuracy: 95.886       Val Loss: 0.2628, Val Accuracy: 91.409, Duration: 0:00:12.590349
# Epoch 68/400, Train Loss: 0.1148, Train Accuracy: 95.800       Val Loss: 0.2475, Val Accuracy: 92.215, Duration: 0:00:12.604311
# Epoch 69/400, Train Loss: 0.1332, Train Accuracy: 94.793       Val Loss: 0.2756, Val Accuracy: 91.275, Duration: 0:00:12.585363
# Epoch 70/400, Train Loss: 0.1198, Train Accuracy: 95.397       Val Loss: 0.2482, Val Accuracy: 91.544, Duration: 0:00:12.586360
# Epoch 71/400, Train Loss: 0.1137, Train Accuracy: 95.397       Val Loss: 0.2619, Val Accuracy: 91.678, Duration: 0:00:12.603314
# Epoch 72/400, Train Loss: 0.1233, Train Accuracy: 95.742       Val Loss: 0.2399, Val Accuracy: 92.752, Duration: 0:00:12.673128
# Epoch 73/400, Train Loss: 0.1190, Train Accuracy: 95.742       Val Loss: 0.2636, Val Accuracy: 92.215, Duration: 0:00:12.616281
# Epoch 74/400, Train Loss: 0.1032, Train Accuracy: 95.656       Val Loss: 0.3076, Val Accuracy: 90.470, Duration: 0:00:12.486665
# Epoch 75/400, Train Loss: 0.1221, Train Accuracy: 95.253       Val Loss: 0.3573, Val Accuracy: 88.725, Duration: 0:00:12.017879
# Epoch 76/400, Train Loss: 0.1249, Train Accuracy: 95.829       Val Loss: 0.2836, Val Accuracy: 92.081, Duration: 0:00:12.032840
# Epoch 77/400, Train Loss: 0.1050, Train Accuracy: 96.318       Val Loss: 0.2097, Val Accuracy: 92.886, Duration: 0:00:12.004914
# Epoch 78/400, Train Loss: 0.1086, Train Accuracy: 96.087       Val Loss: 0.2754, Val Accuracy: 91.409, Duration: 0:00:12.010898
# Epoch 79/400, Train Loss: 0.1225, Train Accuracy: 95.282       Val Loss: 0.2637, Val Accuracy: 91.275, Duration: 0:00:12.047799
# Epoch 80/400, Train Loss: 0.0933, Train Accuracy: 96.692       Val Loss: 0.2811, Val Accuracy: 92.349, Duration: 0:00:11.968013
# Epoch 81/400, Train Loss: 0.1240, Train Accuracy: 95.771       Val Loss: 0.2756, Val Accuracy: 91.946, Duration: 0:00:11.958039
# Epoch 82/400, Train Loss: 0.1305, Train Accuracy: 94.822       Val Loss: 0.2944, Val Accuracy: 91.275, Duration: 0:00:11.977986
# Epoch 83/400, Train Loss: 0.1050, Train Accuracy: 96.087       Val Loss: 0.2185, Val Accuracy: 93.020, Duration: 0:00:12.026855
# Epoch 84/400, Train Loss: 0.0954, Train Accuracy: 96.577       Val Loss: 0.2463, Val Accuracy: 92.349, Duration: 0:00:11.978983
# Epoch 85/400, Train Loss: 0.1188, Train Accuracy: 95.512       Val Loss: 0.2507, Val Accuracy: 91.812, Duration: 0:00:12.001922
# Epoch 86/400, Train Loss: 0.1205, Train Accuracy: 95.253       Val Loss: 0.2779, Val Accuracy: 91.812, Duration: 0:00:11.968013
# Epoch 87/400, Train Loss: 0.0833, Train Accuracy: 96.692       Val Loss: 0.2788, Val Accuracy: 91.812, Duration: 0:00:11.977986
# Epoch 88/400, Train Loss: 0.1046, Train Accuracy: 96.174       Val Loss: 0.2791, Val Accuracy: 91.141, Duration: 0:00:11.968012
# Epoch 89/400, Train Loss: 0.1159, Train Accuracy: 95.253       Val Loss: 0.3552, Val Accuracy: 90.738, Duration: 0:00:11.960034
# Epoch 90/400, Train Loss: 0.1022, Train Accuracy: 96.231       Val Loss: 0.2517, Val Accuracy: 91.544, Duration: 0:00:11.947070
# Epoch 91/400, Train Loss: 0.0891, Train Accuracy: 96.404       Val Loss: 0.2778, Val Accuracy: 90.738, Duration: 0:00:11.958039
# Epoch 92/400, Train Loss: 0.1048, Train Accuracy: 96.174       Val Loss: 0.2289, Val Accuracy: 92.081, Duration: 0:00:12.000924
# Epoch 93/400, Train Loss: 0.0938, Train Accuracy: 96.692       Val Loss: 0.2631, Val Accuracy: 92.752, Duration: 0:00:12.028850
# Epoch 94/400, Train Loss: 0.0797, Train Accuracy: 96.922       Val Loss: 0.2777, Val Accuracy: 91.678, Duration: 0:00:11.965021
# Epoch 95/400, Train Loss: 0.0816, Train Accuracy: 97.152       Val Loss: 0.2956, Val Accuracy: 92.349, Duration: 0:00:11.985964
# Epoch 96/400, Train Loss: 0.1276, Train Accuracy: 95.023       Val Loss: 0.2397, Val Accuracy: 93.154, Duration: 0:00:11.971004
# Epoch 97/400, Train Loss: 0.0938, Train Accuracy: 96.346       Val Loss: 0.2519, Val Accuracy: 93.557, Duration: 0:00:11.965021
# Epoch 98/400, Train Loss: 0.0665, Train Accuracy: 97.727       Val Loss: 0.3085, Val Accuracy: 90.470, Duration: 0:00:11.972999
# Epoch 99/400, Train Loss: 0.0868, Train Accuracy: 96.692       Val Loss: 0.2451, Val Accuracy: 93.154, Duration: 0:00:12.013890
# Epoch 100/400, Train Loss: 0.0797, Train Accuracy: 97.066       Val Loss: 0.2282, Val Accuracy: 94.094, Duration: 0:00:11.997932
# Epoch 101/400, Train Loss: 0.0887, Train Accuracy: 96.490       Val Loss: 0.2067, Val Accuracy: 93.691, Duration: 0:00:11.973998
# Epoch 102/400, Train Loss: 0.0761, Train Accuracy: 97.238       Val Loss: 0.2528, Val Accuracy: 91.409, Duration: 0:00:11.992945
# Epoch 103/400, Train Loss: 0.0934, Train Accuracy: 96.433       Val Loss: 0.2364, Val Accuracy: 93.289, Duration: 0:00:11.974994
# Epoch 104/400, Train Loss: 0.0670, Train Accuracy: 97.929       Val Loss: 0.2600, Val Accuracy: 91.409, Duration: 0:00:11.987959
# Epoch 105/400, Train Loss: 0.0784, Train Accuracy: 97.181       Val Loss: 0.2335, Val Accuracy: 92.752, Duration: 0:00:12.061762
# Epoch 106/400, Train Loss: 0.0807, Train Accuracy: 96.922       Val Loss: 0.2626, Val Accuracy: 91.946, Duration: 0:00:12.051789
# Epoch 107/400, Train Loss: 0.1181, Train Accuracy: 96.116       Val Loss: 0.2346, Val Accuracy: 92.886, Duration: 0:00:12.013890
# Epoch 108/400, Train Loss: 0.0895, Train Accuracy: 97.066       Val Loss: 0.2267, Val Accuracy: 92.349, Duration: 0:00:12.005911
# Epoch 109/400, Train Loss: 0.0783, Train Accuracy: 96.893       Val Loss: 0.2620, Val Accuracy: 92.617, Duration: 0:00:11.998930
# Epoch 110/400, Train Loss: 0.0786, Train Accuracy: 97.008       Val Loss: 0.2147, Val Accuracy: 93.020, Duration: 0:00:12.004913
# Epoch 111/400, Train Loss: 0.0718, Train Accuracy: 97.238       Val Loss: 0.3011, Val Accuracy: 91.678, Duration: 0:00:12.001922
# Epoch 112/400, Train Loss: 0.0721, Train Accuracy: 97.382       Val Loss: 0.2576, Val Accuracy: 92.081, Duration: 0:00:11.994941
# Epoch 113/400, Train Loss: 0.0717, Train Accuracy: 97.123       Val Loss: 0.3378, Val Accuracy: 91.409, Duration: 0:00:11.988956
# Epoch 114/400, Train Loss: 0.1102, Train Accuracy: 95.771       Val Loss: 0.2960, Val Accuracy: 91.409, Duration: 0:00:12.099661
# Epoch 115/400, Train Loss: 0.0845, Train Accuracy: 96.720       Val Loss: 0.2548, Val Accuracy: 92.886, Duration: 0:00:12.004915
# Epoch 116/400, Train Loss: 0.0828, Train Accuracy: 96.720       Val Loss: 0.2820, Val Accuracy: 92.349, Duration: 0:00:12.001921
# Epoch 117/400, Train Loss: 0.0863, Train Accuracy: 96.663       Val Loss: 0.2179, Val Accuracy: 93.826, Duration: 0:00:11.996936
# Epoch 118/400, Train Loss: 0.0636, Train Accuracy: 97.526       Val Loss: 0.2532, Val Accuracy: 93.691, Duration: 0:00:12.015884
# Epoch 119/400, Train Loss: 0.0775, Train Accuracy: 96.922       Val Loss: 0.2510, Val Accuracy: 93.020, Duration: 0:00:12.005911
# Epoch 120/400, Train Loss: 0.0799, Train Accuracy: 97.008       Val Loss: 0.2560, Val Accuracy: 92.886, Duration: 0:00:12.020871
# Epoch 121/400, Train Loss: 0.0757, Train Accuracy: 96.979       Val Loss: 0.2764, Val Accuracy: 93.154, Duration: 0:00:11.993943
# Epoch 122/400, Train Loss: 0.0634, Train Accuracy: 97.612       Val Loss: 0.2601, Val Accuracy: 92.215, Duration: 0:00:12.008903
# Epoch 123/400, Train Loss: 0.0809, Train Accuracy: 97.066       Val Loss: 0.2365, Val Accuracy: 92.752, Duration: 0:00:12.004914
# Epoch 124/400, Train Loss: 0.0620, Train Accuracy: 97.756       Val Loss: 0.2407, Val Accuracy: 93.557, Duration: 0:00:12.010898
# Epoch 125/400, Train Loss: 0.0878, Train Accuracy: 96.807       Val Loss: 0.2776, Val Accuracy: 93.020, Duration: 0:00:12.003917
# Epoch 126/400, Train Loss: 0.0673, Train Accuracy: 97.641       Val Loss: 0.2643, Val Accuracy: 94.094, Duration: 0:00:12.020872
# Epoch 127/400, Train Loss: 0.0436, Train Accuracy: 98.562       Val Loss: 0.2868, Val Accuracy: 92.886, Duration: 0:00:12.001921
# Epoch 128/400, Train Loss: 0.0643, Train Accuracy: 98.015       Val Loss: 0.2366, Val Accuracy: 93.960, Duration: 0:00:12.014887
# Epoch 129/400, Train Loss: 0.0982, Train Accuracy: 96.461       Val Loss: 0.2236, Val Accuracy: 92.215, Duration: 0:00:12.026855
# Epoch 130/400, Train Loss: 0.0797, Train Accuracy: 97.555       Val Loss: 0.3528, Val Accuracy: 91.141, Duration: 0:00:12.031841
# Epoch 131/400, Train Loss: 0.0889, Train Accuracy: 96.577       Val Loss: 0.2810, Val Accuracy: 92.215, Duration: 0:00:12.020871
# Epoch 132/400, Train Loss: 0.0572, Train Accuracy: 98.044       Val Loss: 0.2941, Val Accuracy: 92.483, Duration: 0:00:12.039821
# Epoch 133/400, Train Loss: 0.0720, Train Accuracy: 97.612       Val Loss: 0.2252, Val Accuracy: 93.020, Duration: 0:00:12.046802
# Epoch 134/400, Train Loss: 0.0861, Train Accuracy: 96.634       Val Loss: 0.3156, Val Accuracy: 91.544, Duration: 0:00:12.026855
# Epoch 135/400, Train Loss: 0.0669, Train Accuracy: 97.612       Val Loss: 0.2614, Val Accuracy: 93.020, Duration: 0:00:12.038823
# Epoch 136/400, Train Loss: 0.0566, Train Accuracy: 97.641       Val Loss: 0.2558, Val Accuracy: 92.617, Duration: 0:00:12.019874
# Epoch 137/400, Train Loss: 0.0633, Train Accuracy: 97.670       Val Loss: 0.2572, Val Accuracy: 92.081, Duration: 0:00:12.034834
# Epoch 138/400, Train Loss: 0.0657, Train Accuracy: 97.497       Val Loss: 0.2530, Val Accuracy: 93.691, Duration: 0:00:11.993944
# Epoch 139/400, Train Loss: 0.0559, Train Accuracy: 97.756       Val Loss: 0.2355, Val Accuracy: 93.960, Duration: 0:00:12.006908
# Epoch 140/400, Train Loss: 0.0477, Train Accuracy: 98.303       Val Loss: 0.2735, Val Accuracy: 93.289, Duration: 0:00:12.027853
# Epoch 141/400, Train Loss: 0.0876, Train Accuracy: 97.066       Val Loss: 0.3154, Val Accuracy: 91.678, Duration: 0:00:12.042813
# Epoch 142/400, Train Loss: 0.1274, Train Accuracy: 95.023       Val Loss: 0.2695, Val Accuracy: 91.946, Duration: 0:00:12.017879
# Epoch 143/400, Train Loss: 0.0684, Train Accuracy: 97.842       Val Loss: 0.2756, Val Accuracy: 92.349, Duration: 0:00:12.019874
# Epoch 144/400, Train Loss: 0.0432, Train Accuracy: 98.446       Val Loss: 0.2390, Val Accuracy: 93.557, Duration: 0:00:12.035831
# Epoch 145/400, Train Loss: 0.0545, Train Accuracy: 97.900       Val Loss: 0.2686, Val Accuracy: 92.483, Duration: 0:00:12.031842
# Epoch 146/400, Train Loss: 0.0490, Train Accuracy: 98.159       Val Loss: 0.2294, Val Accuracy: 93.289, Duration: 0:00:12.036829
# Epoch 147/400, Train Loss: 0.0542, Train Accuracy: 97.929       Val Loss: 0.2156, Val Accuracy: 94.497, Duration: 0:00:12.023863
# Epoch 148/400, Train Loss: 0.0718, Train Accuracy: 97.555       Val Loss: 0.2505, Val Accuracy: 92.752, Duration: 0:00:11.996935
# Epoch 149/400, Train Loss: 0.0901, Train Accuracy: 96.260       Val Loss: 0.2666, Val Accuracy: 92.483, Duration: 0:00:12.024860
# Epoch 150/400, Train Loss: 0.1036, Train Accuracy: 96.145       Val Loss: 0.2482, Val Accuracy: 93.020, Duration: 0:00:12.051789
# Epoch 151/400, Train Loss: 0.0629, Train Accuracy: 97.670       Val Loss: 0.2103, Val Accuracy: 93.826, Duration: 0:00:12.035831
# Epoch 152/400, Train Loss: 0.0611, Train Accuracy: 97.727       Val Loss: 0.2490, Val Accuracy: 92.349, Duration: 0:00:12.078717
# Epoch 153/400, Train Loss: 0.0581, Train Accuracy: 97.871       Val Loss: 0.2479, Val Accuracy: 93.020, Duration: 0:00:11.977986
# Epoch 154/400, Train Loss: 0.0731, Train Accuracy: 97.296       Val Loss: 0.2094, Val Accuracy: 93.826, Duration: 0:00:11.996935
# Epoch 155/400, Train Loss: 0.0444, Train Accuracy: 98.475       Val Loss: 0.2431, Val Accuracy: 93.423, Duration: 0:00:11.977986
# Epoch 156/400, Train Loss: 0.0675, Train Accuracy: 97.814       Val Loss: 0.2163, Val Accuracy: 93.557, Duration: 0:00:11.978983
# Epoch 157/400, Train Loss: 0.0572, Train Accuracy: 98.072       Val Loss: 0.2296, Val Accuracy: 93.691, Duration: 0:00:11.997933
# Epoch 158/400, Train Loss: 0.0587, Train Accuracy: 97.641       Val Loss: 0.2357, Val Accuracy: 93.960, Duration: 0:00:11.997932
# Epoch 159/400, Train Loss: 0.0606, Train Accuracy: 97.583       Val Loss: 0.2680, Val Accuracy: 91.678, Duration: 0:00:12.002920
# Epoch 160/400, Train Loss: 0.0677, Train Accuracy: 97.267       Val Loss: 0.2792, Val Accuracy: 91.946, Duration: 0:00:11.981975
# Epoch 161/400, Train Loss: 0.0753, Train Accuracy: 96.979       Val Loss: 0.2913, Val Accuracy: 93.289, Duration: 0:00:11.986962
# Epoch 162/400, Train Loss: 0.0598, Train Accuracy: 97.900       Val Loss: 0.2303, Val Accuracy: 93.020, Duration: 0:00:12.026855
# Epoch 163/400, Train Loss: 0.0553, Train Accuracy: 97.900       Val Loss: 0.2474, Val Accuracy: 93.020, Duration: 0:00:11.989954
# Epoch 164/400, Train Loss: 0.0583, Train Accuracy: 97.871       Val Loss: 0.2201, Val Accuracy: 94.631, Duration: 0:00:11.999927
# Epoch 165/400, Train Loss: 0.0562, Train Accuracy: 97.612       Val Loss: 0.2640, Val Accuracy: 93.020, Duration: 0:00:11.986962
# Epoch 166/400, Train Loss: 0.0655, Train Accuracy: 97.411       Val Loss: 0.2432, Val Accuracy: 93.154, Duration: 0:00:12.018876
# Epoch 167/400, Train Loss: 0.0513, Train Accuracy: 98.216       Val Loss: 0.2624, Val Accuracy: 93.154, Duration: 0:00:12.008904
# Epoch 168/400, Train Loss: 0.0393, Train Accuracy: 98.677       Val Loss: 0.3028, Val Accuracy: 92.752, Duration: 0:00:12.010898
# Epoch 169/400, Train Loss: 0.0506, Train Accuracy: 98.072       Val Loss: 0.2753, Val Accuracy: 93.691, Duration: 0:00:11.987959
# Epoch 170/400, Train Loss: 0.0410, Train Accuracy: 98.418       Val Loss: 0.3517, Val Accuracy: 91.678, Duration: 0:00:12.021869
# Epoch 171/400, Train Loss: 0.0754, Train Accuracy: 97.238       Val Loss: 0.2534, Val Accuracy: 93.423, Duration: 0:00:12.010898
# Epoch 172/400, Train Loss: 0.0638, Train Accuracy: 97.555       Val Loss: 0.2613, Val Accuracy: 93.423, Duration: 0:00:12.010898
# Epoch 173/400, Train Loss: 0.0497, Train Accuracy: 98.245       Val Loss: 0.2432, Val Accuracy: 93.423, Duration: 0:00:12.043810
# Epoch 174/400, Train Loss: 0.0418, Train Accuracy: 98.360       Val Loss: 0.2913, Val Accuracy: 92.081, Duration: 0:00:12.048796
# Epoch 175/400, Train Loss: 0.0576, Train Accuracy: 97.929       Val Loss: 0.2633, Val Accuracy: 93.423, Duration: 0:00:12.005912
# Epoch 176/400, Train Loss: 0.0893, Train Accuracy: 96.807       Val Loss: 0.3254, Val Accuracy: 92.081, Duration: 0:00:12.008903
# Epoch 177/400, Train Loss: 0.0638, Train Accuracy: 97.641       Val Loss: 0.2534, Val Accuracy: 93.289, Duration: 0:00:12.023863
# Epoch 178/400, Train Loss: 0.0671, Train Accuracy: 97.468       Val Loss: 0.2448, Val Accuracy: 93.289, Duration: 0:00:12.024860
# Epoch 179/400, Train Loss: 0.0415, Train Accuracy: 98.533       Val Loss: 0.2470, Val Accuracy: 93.691, Duration: 0:00:12.014888
# Epoch 180/400, Train Loss: 0.0405, Train Accuracy: 98.562       Val Loss: 0.2636, Val Accuracy: 93.289, Duration: 0:00:12.005911
# Epoch 181/400, Train Loss: 0.0450, Train Accuracy: 98.044       Val Loss: 0.2407, Val Accuracy: 94.362, Duration: 0:00:12.051788
# Epoch 182/400, Train Loss: 0.0413, Train Accuracy: 98.331       Val Loss: 0.2919, Val Accuracy: 92.886, Duration: 0:00:12.005912
# Epoch 183/400, Train Loss: 0.0508, Train Accuracy: 98.331       Val Loss: 0.2166, Val Accuracy: 94.094, Duration: 0:00:12.009901
# Epoch 184/400, Train Loss: 0.0322, Train Accuracy: 98.936       Val Loss: 0.3027, Val Accuracy: 93.691, Duration: 0:00:12.011894
# Epoch 185/400, Train Loss: 0.1284, Train Accuracy: 95.311       Val Loss: 0.2986, Val Accuracy: 92.349, Duration: 0:00:12.020872
# Epoch 186/400, Train Loss: 0.0582, Train Accuracy: 97.929       Val Loss: 0.2329, Val Accuracy: 93.289, Duration: 0:00:12.010897
# Epoch 187/400, Train Loss: 0.0477, Train Accuracy: 98.533       Val Loss: 0.2058, Val Accuracy: 93.423, Duration: 0:00:12.010898
# Epoch 188/400, Train Loss: 0.0600, Train Accuracy: 97.699       Val Loss: 0.2779, Val Accuracy: 93.020, Duration: 0:00:12.016882
# Epoch 189/400, Train Loss: 0.0421, Train Accuracy: 98.360       Val Loss: 0.2794, Val Accuracy: 92.752, Duration: 0:00:12.020872
# Epoch 190/400, Train Loss: 0.0268, Train Accuracy: 99.108       Val Loss: 0.2668, Val Accuracy: 93.289, Duration: 0:00:12.025858
# Epoch 191/400, Train Loss: 0.0295, Train Accuracy: 98.849       Val Loss: 0.2995, Val Accuracy: 92.483, Duration: 0:00:12.015884
# Epoch 192/400, Train Loss: 0.0665, Train Accuracy: 97.756       Val Loss: 0.2995, Val Accuracy: 92.752, Duration: 0:00:12.043809
# Epoch 193/400, Train Loss: 0.0958, Train Accuracy: 96.433       Val Loss: 0.2619, Val Accuracy: 93.557, Duration: 0:00:12.021870
# Epoch 194/400, Train Loss: 0.0425, Train Accuracy: 98.101       Val Loss: 0.3120, Val Accuracy: 91.812, Duration: 0:00:12.010897
# Epoch 195/400, Train Loss: 0.0786, Train Accuracy: 97.296       Val Loss: 0.2728, Val Accuracy: 92.349, Duration: 0:00:12.006909
# Epoch 196/400, Train Loss: 0.0370, Train Accuracy: 98.619       Val Loss: 0.2714, Val Accuracy: 92.215, Duration: 0:00:12.034834
# Epoch 197/400, Train Loss: 0.0320, Train Accuracy: 98.907       Val Loss: 0.2440, Val Accuracy: 93.691, Duration: 0:00:12.021868
# Epoch 198/400, Train Loss: 0.0318, Train Accuracy: 98.763       Val Loss: 0.2624, Val Accuracy: 93.289, Duration: 0:00:12.018877
# Epoch 199/400, Train Loss: 0.0366, Train Accuracy: 98.562       Val Loss: 0.3504, Val Accuracy: 92.081, Duration: 0:00:12.023864
# Epoch 200/400, Train Loss: 0.0441, Train Accuracy: 98.446       Val Loss: 0.2797, Val Accuracy: 93.423, Duration: 0:00:12.009900
# Epoch 201/400, Train Loss: 0.0366, Train Accuracy: 98.792       Val Loss: 0.3127, Val Accuracy: 92.483, Duration: 0:00:12.022866
# Epoch 202/400, Train Loss: 0.0369, Train Accuracy: 98.504       Val Loss: 0.2650, Val Accuracy: 93.826, Duration: 0:00:12.010898
# Epoch 203/400, Train Loss: 0.0383, Train Accuracy: 98.562       Val Loss: 0.2310, Val Accuracy: 92.752, Duration: 0:00:12.052786
# Epoch 204/400, Train Loss: 0.0526, Train Accuracy: 97.756       Val Loss: 0.2315, Val Accuracy: 93.154, Duration: 0:00:12.047799
# Epoch 205/400, Train Loss: 0.0624, Train Accuracy: 97.468       Val Loss: 0.2655, Val Accuracy: 93.423, Duration: 0:00:12.030845
# Epoch 206/400, Train Loss: 0.0671, Train Accuracy: 97.353       Val Loss: 0.2942, Val Accuracy: 93.423, Duration: 0:00:12.035831
# Epoch 207/400, Train Loss: 0.0585, Train Accuracy: 97.785       Val Loss: 0.2433, Val Accuracy: 93.826, Duration: 0:00:12.022866
# Epoch 208/400, Train Loss: 0.0431, Train Accuracy: 98.331       Val Loss: 0.2619, Val Accuracy: 94.362, Duration: 0:00:12.043810
# Epoch 209/400, Train Loss: 0.0445, Train Accuracy: 98.274       Val Loss: 0.3410, Val Accuracy: 93.423, Duration: 0:00:12.010898
# Epoch 210/400, Train Loss: 0.0484, Train Accuracy: 98.072       Val Loss: 0.3340, Val Accuracy: 93.020, Duration: 0:00:12.026855
# Epoch 211/400, Train Loss: 0.0425, Train Accuracy: 98.562       Val Loss: 0.2735, Val Accuracy: 92.483, Duration: 0:00:12.029847
# Epoch 212/400, Train Loss: 0.0535, Train Accuracy: 97.756       Val Loss: 0.3010, Val Accuracy: 93.423, Duration: 0:00:12.053784
# Epoch 213/400, Train Loss: 0.0375, Train Accuracy: 98.705       Val Loss: 0.2948, Val Accuracy: 93.557, Duration: 0:00:12.027852
# Epoch 214/400, Train Loss: 0.0405, Train Accuracy: 98.504       Val Loss: 0.2871, Val Accuracy: 92.483, Duration: 0:00:12.015886
# Epoch 215/400, Train Loss: 0.0420, Train Accuracy: 98.590       Val Loss: 0.2620, Val Accuracy: 93.960, Duration: 0:00:12.007905
# Epoch 216/400, Train Loss: 0.0208, Train Accuracy: 99.194       Val Loss: 0.2653, Val Accuracy: 94.362, Duration: 0:00:12.016882
# Epoch 217/400, Train Loss: 0.0305, Train Accuracy: 98.849       Val Loss: 0.2769, Val Accuracy: 93.423, Duration: 0:00:12.034834
# Epoch 218/400, Train Loss: 0.0559, Train Accuracy: 98.015       Val Loss: 0.4636, Val Accuracy: 90.604, Duration: 0:00:12.022866
# Epoch 219/400, Train Loss: 0.0979, Train Accuracy: 96.548       Val Loss: 0.2760, Val Accuracy: 93.423, Duration: 0:00:12.042812
# Epoch 220/400, Train Loss: 0.0706, Train Accuracy: 97.008       Val Loss: 0.2579, Val Accuracy: 93.289, Duration: 0:00:12.031842
# Epoch 221/400, Train Loss: 0.0467, Train Accuracy: 98.533       Val Loss: 0.2688, Val Accuracy: 93.423, Duration: 0:00:12.036828
# Epoch 222/400, Train Loss: 0.0365, Train Accuracy: 98.533       Val Loss: 0.2736, Val Accuracy: 93.154, Duration: 0:00:12.038824
# Epoch 223/400, Train Loss: 0.0434, Train Accuracy: 98.590       Val Loss: 0.2789, Val Accuracy: 93.289, Duration: 0:00:12.034834
# Epoch 224/400, Train Loss: 0.0289, Train Accuracy: 98.849       Val Loss: 0.2567, Val Accuracy: 94.094, Duration: 0:00:12.071735
# Epoch 225/400, Train Loss: 0.0339, Train Accuracy: 98.964       Val Loss: 0.3280, Val Accuracy: 91.946, Duration: 0:00:12.114621
# Epoch 226/400, Train Loss: 0.0400, Train Accuracy: 98.533       Val Loss: 0.2495, Val Accuracy: 94.228, Duration: 0:00:11.969009
# Epoch 227/400, Train Loss: 0.0270, Train Accuracy: 99.108       Val Loss: 0.2569, Val Accuracy: 93.289, Duration: 0:00:11.985965
# Epoch 228/400, Train Loss: 0.0463, Train Accuracy: 98.303       Val Loss: 0.2671, Val Accuracy: 93.020, Duration: 0:00:11.973000
# Epoch 229/400, Train Loss: 0.0699, Train Accuracy: 97.583       Val Loss: 0.2997, Val Accuracy: 92.752, Duration: 0:00:11.993943
# Epoch 230/400, Train Loss: 0.0351, Train Accuracy: 98.878       Val Loss: 0.2657, Val Accuracy: 94.094, Duration: 0:00:11.986962
# Epoch 231/400, Train Loss: 0.0401, Train Accuracy: 98.705       Val Loss: 0.2302, Val Accuracy: 93.960, Duration: 0:00:12.000925
# Epoch 232/400, Train Loss: 0.0434, Train Accuracy: 98.504       Val Loss: 0.3365, Val Accuracy: 92.752, Duration: 0:00:12.030844
# Epoch 233/400, Train Loss: 0.0769, Train Accuracy: 97.353       Val Loss: 0.2119, Val Accuracy: 94.094, Duration: 0:00:11.989954
# Epoch 234/400, Train Loss: 0.0443, Train Accuracy: 98.245       Val Loss: 0.2342, Val Accuracy: 93.691, Duration: 0:00:11.991949
# Epoch 235/400, Train Loss: 0.0257, Train Accuracy: 99.166       Val Loss: 0.2154, Val Accuracy: 94.497, Duration: 0:00:12.000924
# Epoch 236/400, Train Loss: 0.0277, Train Accuracy: 99.022       Val Loss: 0.2824, Val Accuracy: 94.228, Duration: 0:00:12.000924
# Epoch 237/400, Train Loss: 0.0385, Train Accuracy: 98.648       Val Loss: 0.2499, Val Accuracy: 94.362, Duration: 0:00:11.987959
# Epoch 238/400, Train Loss: 0.0313, Train Accuracy: 98.849       Val Loss: 0.2445, Val Accuracy: 93.557, Duration: 0:00:11.993943
# Epoch 239/400, Train Loss: 0.0345, Train Accuracy: 98.734       Val Loss: 0.2589, Val Accuracy: 94.362, Duration: 0:00:11.989954
# Epoch 240/400, Train Loss: 0.0293, Train Accuracy: 99.079       Val Loss: 0.2313, Val Accuracy: 94.362, Duration: 0:00:12.011895
# Epoch 241/400, Train Loss: 0.0389, Train Accuracy: 98.677       Val Loss: 0.2638, Val Accuracy: 93.423, Duration: 0:00:11.985965
# Epoch 242/400, Train Loss: 0.0425, Train Accuracy: 98.245       Val Loss: 0.2318, Val Accuracy: 94.094, Duration: 0:00:11.998929
# Epoch 243/400, Train Loss: 0.0347, Train Accuracy: 98.849       Val Loss: 0.2342, Val Accuracy: 94.497, Duration: 0:00:12.006908
# Epoch 244/400, Train Loss: 0.0352, Train Accuracy: 98.734       Val Loss: 0.2899, Val Accuracy: 92.886, Duration: 0:00:12.002920
# Epoch 245/400, Train Loss: 0.0596, Train Accuracy: 98.130       Val Loss: 0.2099, Val Accuracy: 94.899, Duration: 0:00:12.010898
# Epoch 246/400, Train Loss: 0.0333, Train Accuracy: 98.792       Val Loss: 0.3006, Val Accuracy: 93.154, Duration: 0:00:11.988956
# Epoch 247/400, Train Loss: 0.0801, Train Accuracy: 97.353       Val Loss: 0.2700, Val Accuracy: 93.154, Duration: 0:00:12.003917
# Epoch 248/400, Train Loss: 0.0369, Train Accuracy: 98.907       Val Loss: 0.2207, Val Accuracy: 94.497, Duration: 0:00:11.997932
# Epoch 249/400, Train Loss: 0.0310, Train Accuracy: 98.820       Val Loss: 0.2781, Val Accuracy: 93.154, Duration: 0:00:12.033837
# Epoch 250/400, Train Loss: 0.0673, Train Accuracy: 97.814       Val Loss: 0.2823, Val Accuracy: 91.946, Duration: 0:00:12.016882
# Epoch 251/400, Train Loss: 0.0345, Train Accuracy: 98.648       Val Loss: 0.2102, Val Accuracy: 94.094, Duration: 0:00:11.998930
# Epoch 252/400, Train Loss: 0.0191, Train Accuracy: 99.453       Val Loss: 0.2552, Val Accuracy: 93.826, Duration: 0:00:12.005911
# Epoch 253/400, Train Loss: 0.0254, Train Accuracy: 99.137       Val Loss: 0.2779, Val Accuracy: 93.691, Duration: 0:00:12.002920
# Epoch 254/400, Train Loss: 0.0257, Train Accuracy: 99.079       Val Loss: 0.2489, Val Accuracy: 93.423, Duration: 0:00:12.003918
# Epoch 255/400, Train Loss: 0.0236, Train Accuracy: 99.252       Val Loss: 0.2864, Val Accuracy: 92.617, Duration: 0:00:12.000923
# Epoch 256/400, Train Loss: 0.0307, Train Accuracy: 99.137       Val Loss: 0.2403, Val Accuracy: 93.691, Duration: 0:00:11.999928
# Epoch 257/400, Train Loss: 0.0304, Train Accuracy: 98.907       Val Loss: 0.2818, Val Accuracy: 93.423, Duration: 0:00:12.005911
# Epoch 258/400, Train Loss: 0.0521, Train Accuracy: 98.216       Val Loss: 0.2358, Val Accuracy: 93.020, Duration: 0:00:12.040818
# Epoch 259/400, Train Loss: 0.0468, Train Accuracy: 98.274       Val Loss: 0.2624, Val Accuracy: 93.691, Duration: 0:00:12.003917
# Epoch 260/400, Train Loss: 0.0732, Train Accuracy: 97.583       Val Loss: 0.2749, Val Accuracy: 94.228, Duration: 0:00:12.012892
# Epoch 261/400, Train Loss: 0.0653, Train Accuracy: 97.756       Val Loss: 0.2946, Val Accuracy: 92.483, Duration: 0:00:12.004914
# Epoch 262/400, Train Loss: 0.0600, Train Accuracy: 97.727       Val Loss: 0.2771, Val Accuracy: 92.483, Duration: 0:00:12.054781
# Epoch 263/400, Train Loss: 0.0384, Train Accuracy: 98.504       Val Loss: 0.2402, Val Accuracy: 94.631, Duration: 0:00:12.016882
# Epoch 264/400, Train Loss: 0.0245, Train Accuracy: 99.051       Val Loss: 0.2494, Val Accuracy: 94.362, Duration: 0:00:12.000925
# Epoch 265/400, Train Loss: 0.0185, Train Accuracy: 99.453       Val Loss: 0.3128, Val Accuracy: 93.154, Duration: 0:00:12.027852
# Epoch 266/400, Train Loss: 0.0247, Train Accuracy: 99.252       Val Loss: 0.2537, Val Accuracy: 94.765, Duration: 0:00:12.010898
# Epoch 267/400, Train Loss: 0.0220, Train Accuracy: 99.310       Val Loss: 0.3217, Val Accuracy: 94.094, Duration: 0:00:12.007906
# Epoch 268/400, Train Loss: 0.0313, Train Accuracy: 98.907       Val Loss: 0.2441, Val Accuracy: 94.497, Duration: 0:00:12.017879
# Epoch 269/400, Train Loss: 0.0269, Train Accuracy: 98.849       Val Loss: 0.3258, Val Accuracy: 93.826, Duration: 0:00:12.009901
# Epoch 270/400, Train Loss: 0.0207, Train Accuracy: 99.166       Val Loss: 0.2635, Val Accuracy: 94.094, Duration: 0:00:12.014887
# Epoch 271/400, Train Loss: 0.0272, Train Accuracy: 99.022       Val Loss: 0.3118, Val Accuracy: 94.094, Duration: 0:00:12.017880
# Epoch 272/400, Train Loss: 0.0503, Train Accuracy: 98.303       Val Loss: 0.2794, Val Accuracy: 92.215, Duration: 0:00:12.023863
# Epoch 273/400, Train Loss: 0.0805, Train Accuracy: 97.066       Val Loss: 0.3060, Val Accuracy: 92.349, Duration: 0:00:12.015885
# Epoch 274/400, Train Loss: 0.0437, Train Accuracy: 98.504       Val Loss: 0.2761, Val Accuracy: 93.557, Duration: 0:00:12.035831
# Epoch 275/400, Train Loss: 0.0331, Train Accuracy: 98.734       Val Loss: 0.3233, Val Accuracy: 92.752, Duration: 0:00:12.046802
# Epoch 276/400, Train Loss: 0.0400, Train Accuracy: 98.504       Val Loss: 0.2757, Val Accuracy: 93.154, Duration: 0:00:12.049794
# Epoch 277/400, Train Loss: 0.0262, Train Accuracy: 98.936       Val Loss: 0.2753, Val Accuracy: 94.094, Duration: 0:00:12.040818
# Epoch 278/400, Train Loss: 0.0273, Train Accuracy: 98.964       Val Loss: 0.2794, Val Accuracy: 93.557, Duration: 0:00:12.029847
# Epoch 279/400, Train Loss: 0.0199, Train Accuracy: 99.310       Val Loss: 0.2587, Val Accuracy: 94.631, Duration: 0:00:12.046802
# Epoch 280/400, Train Loss: 0.0177, Train Accuracy: 99.310       Val Loss: 0.2421, Val Accuracy: 94.631, Duration: 0:00:12.030844
# Epoch 281/400, Train Loss: 0.0180, Train Accuracy: 99.396       Val Loss: 0.2666, Val Accuracy: 93.557, Duration: 0:00:12.017880
# Epoch 282/400, Train Loss: 0.0530, Train Accuracy: 98.044       Val Loss: 0.2371, Val Accuracy: 94.497, Duration: 0:00:12.044807
# Epoch 283/400, Train Loss: 0.0283, Train Accuracy: 99.166       Val Loss: 0.2547, Val Accuracy: 94.094, Duration: 0:00:12.037826
# Epoch 284/400, Train Loss: 0.0608, Train Accuracy: 97.756       Val Loss: 0.2684, Val Accuracy: 93.289, Duration: 0:00:12.024862
# Epoch 285/400, Train Loss: 0.0571, Train Accuracy: 97.871       Val Loss: 0.2843, Val Accuracy: 93.423, Duration: 0:00:12.036828
# Epoch 286/400, Train Loss: 0.0463, Train Accuracy: 98.360       Val Loss: 0.2257, Val Accuracy: 95.302, Duration: 0:00:12.040818
# Epoch 287/400, Train Loss: 0.0258, Train Accuracy: 99.194       Val Loss: 0.2501, Val Accuracy: 94.228, Duration: 0:00:12.026855
# Epoch 288/400, Train Loss: 0.0351, Train Accuracy: 98.907       Val Loss: 0.2689, Val Accuracy: 92.886, Duration: 0:00:12.022866
# Epoch 289/400, Train Loss: 0.0239, Train Accuracy: 99.166       Val Loss: 0.2566, Val Accuracy: 94.362, Duration: 0:00:12.039820
# Epoch 290/400, Train Loss: 0.0249, Train Accuracy: 99.051       Val Loss: 0.2531, Val Accuracy: 93.960, Duration: 0:00:12.043811
# Epoch 291/400, Train Loss: 0.0365, Train Accuracy: 98.849       Val Loss: 0.3288, Val Accuracy: 92.886, Duration: 0:00:12.052786
# Epoch 292/400, Train Loss: 0.0367, Train Accuracy: 98.849       Val Loss: 0.2413, Val Accuracy: 94.228, Duration: 0:00:12.038823
# Epoch 293/400, Train Loss: 0.0472, Train Accuracy: 98.130       Val Loss: 0.2367, Val Accuracy: 94.362, Duration: 0:00:12.025858
# Epoch 294/400, Train Loss: 0.0446, Train Accuracy: 98.504       Val Loss: 0.2502, Val Accuracy: 94.362, Duration: 0:00:12.018876
# Epoch 295/400, Train Loss: 0.0480, Train Accuracy: 98.274       Val Loss: 0.2610, Val Accuracy: 93.557, Duration: 0:00:12.038824
# Epoch 296/400, Train Loss: 0.0414, Train Accuracy: 98.763       Val Loss: 0.2612, Val Accuracy: 93.557, Duration: 0:00:12.042813
# Epoch 297/400, Train Loss: 0.0338, Train Accuracy: 98.936       Val Loss: 0.2675, Val Accuracy: 93.960, Duration: 0:00:12.055207
# Epoch 298/400, Train Loss: 0.0143, Train Accuracy: 99.511       Val Loss: 0.3081, Val Accuracy: 94.765, Duration: 0:00:12.069740
# Epoch 299/400, Train Loss: 0.0320, Train Accuracy: 99.079       Val Loss: 0.2811, Val Accuracy: 94.094, Duration: 0:00:11.981976
# Epoch 300/400, Train Loss: 0.0213, Train Accuracy: 99.108       Val Loss: 0.2924, Val Accuracy: 93.826, Duration: 0:00:11.963026
# Epoch 301/400, Train Loss: 0.0159, Train Accuracy: 99.511       Val Loss: 0.3092, Val Accuracy: 94.228, Duration: 0:00:11.978983
# Epoch 302/400, Train Loss: 0.0178, Train Accuracy: 99.281       Val Loss: 0.2874, Val Accuracy: 94.362, Duration: 0:00:11.972998
# Epoch 303/400, Train Loss: 0.0433, Train Accuracy: 98.504       Val Loss: 0.2728, Val Accuracy: 94.497, Duration: 0:00:11.965021
# Epoch 304/400, Train Loss: 0.0318, Train Accuracy: 98.936       Val Loss: 0.2638, Val Accuracy: 94.094, Duration: 0:00:12.028849
# Epoch 305/400, Train Loss: 0.0313, Train Accuracy: 98.993       Val Loss: 0.2732, Val Accuracy: 94.094, Duration: 0:00:11.992946
# Epoch 306/400, Train Loss: 0.0269, Train Accuracy: 98.936       Val Loss: 0.2849, Val Accuracy: 94.497, Duration: 0:00:11.980978
# Epoch 307/400, Train Loss: 0.0331, Train Accuracy: 98.562       Val Loss: 0.3210, Val Accuracy: 93.423, Duration: 0:00:11.988956
# Epoch 308/400, Train Loss: 0.0378, Train Accuracy: 98.648       Val Loss: 0.2525, Val Accuracy: 93.423, Duration: 0:00:11.998931
# Epoch 309/400, Train Loss: 0.0681, Train Accuracy: 97.785       Val Loss: 0.2491, Val Accuracy: 92.483, Duration: 0:00:12.009900
# Epoch 310/400, Train Loss: 0.0320, Train Accuracy: 98.878       Val Loss: 0.2540, Val Accuracy: 93.826, Duration: 0:00:11.989954
# Epoch 311/400, Train Loss: 0.0268, Train Accuracy: 99.051       Val Loss: 0.2607, Val Accuracy: 93.557, Duration: 0:00:12.008903
# Epoch 312/400, Train Loss: 0.0226, Train Accuracy: 99.022       Val Loss: 0.2398, Val Accuracy: 93.154, Duration: 0:00:11.993943
# Epoch 313/400, Train Loss: 0.0197, Train Accuracy: 99.194       Val Loss: 0.2406, Val Accuracy: 94.362, Duration: 0:00:11.988957
# Epoch 314/400, Train Loss: 0.0307, Train Accuracy: 98.936       Val Loss: 0.3218, Val Accuracy: 92.349, Duration: 0:00:11.989953
# Epoch 315/400, Train Loss: 0.0364, Train Accuracy: 98.619       Val Loss: 0.3011, Val Accuracy: 92.886, Duration: 0:00:12.002920
# Epoch 316/400, Train Loss: 0.0147, Train Accuracy: 99.540       Val Loss: 0.2447, Val Accuracy: 94.228, Duration: 0:00:12.007906
# Epoch 317/400, Train Loss: 0.0196, Train Accuracy: 99.338       Val Loss: 0.3002, Val Accuracy: 93.289, Duration: 0:00:11.991948
# Epoch 318/400, Train Loss: 0.0542, Train Accuracy: 97.957       Val Loss: 0.3090, Val Accuracy: 92.752, Duration: 0:00:11.993943
# Epoch 319/400, Train Loss: 0.0141, Train Accuracy: 99.511       Val Loss: 0.2682, Val Accuracy: 95.168, Duration: 0:00:12.013890
# Epoch 320/400, Train Loss: 0.0177, Train Accuracy: 99.223       Val Loss: 0.2579, Val Accuracy: 95.436, Duration: 0:00:12.005912
# Epoch 321/400, Train Loss: 0.0348, Train Accuracy: 98.878       Val Loss: 0.2318, Val Accuracy: 95.034, Duration: 0:00:12.004914
# Epoch 322/400, Train Loss: 0.0283, Train Accuracy: 98.993       Val Loss: 0.2530, Val Accuracy: 94.228, Duration: 0:00:12.011894
# Epoch 323/400, Train Loss: 0.0542, Train Accuracy: 97.986       Val Loss: 0.3265, Val Accuracy: 93.557, Duration: 0:00:12.009901
# Epoch 324/400, Train Loss: 0.0304, Train Accuracy: 98.878       Val Loss: 0.2819, Val Accuracy: 93.826, Duration: 0:00:12.008904
# Epoch 325/400, Train Loss: 0.0132, Train Accuracy: 99.540       Val Loss: 0.2542, Val Accuracy: 94.899, Duration: 0:00:12.018876
# Epoch 326/400, Train Loss: 0.0189, Train Accuracy: 99.540       Val Loss: 0.2582, Val Accuracy: 94.228, Duration: 0:00:12.006909
# Epoch 327/400, Train Loss: 0.0131, Train Accuracy: 99.741       Val Loss: 0.2808, Val Accuracy: 93.691, Duration: 0:00:12.041816
# Epoch 328/400, Train Loss: 0.0236, Train Accuracy: 98.993       Val Loss: 0.2980, Val Accuracy: 94.094, Duration: 0:00:12.015885
# Epoch 329/400, Train Loss: 0.0395, Train Accuracy: 98.475       Val Loss: 0.2898, Val Accuracy: 93.960, Duration: 0:00:12.012892
# Epoch 330/400, Train Loss: 0.0291, Train Accuracy: 98.993       Val Loss: 0.2965, Val Accuracy: 93.826, Duration: 0:00:11.992946
# Epoch 331/400, Train Loss: 0.0304, Train Accuracy: 99.137       Val Loss: 0.2512, Val Accuracy: 94.497, Duration: 0:00:12.005911
# Epoch 332/400, Train Loss: 0.0367, Train Accuracy: 98.734       Val Loss: 0.3098, Val Accuracy: 93.691, Duration: 0:00:11.994941
# Epoch 333/400, Train Loss: 0.0279, Train Accuracy: 98.907       Val Loss: 0.2715, Val Accuracy: 93.960, Duration: 0:00:11.997932
# Epoch 334/400, Train Loss: 0.0286, Train Accuracy: 99.051       Val Loss: 0.2815, Val Accuracy: 94.228, Duration: 0:00:11.994941
# Epoch 335/400, Train Loss: 0.0207, Train Accuracy: 99.338       Val Loss: 0.2574, Val Accuracy: 94.362, Duration: 0:00:12.007906
# Epoch 336/400, Train Loss: 0.0102, Train Accuracy: 99.568       Val Loss: 0.2870, Val Accuracy: 94.899, Duration: 0:00:12.010898
# Epoch 337/400, Train Loss: 0.0188, Train Accuracy: 99.281       Val Loss: 0.3002, Val Accuracy: 93.423, Duration: 0:00:12.009900
# Epoch 338/400, Train Loss: 0.0441, Train Accuracy: 98.389       Val Loss: 0.2865, Val Accuracy: 94.094, Duration: 0:00:12.014887
# Epoch 339/400, Train Loss: 0.0459, Train Accuracy: 98.418       Val Loss: 0.2560, Val Accuracy: 94.362, Duration: 0:00:12.019875
# Epoch 340/400, Train Loss: 0.0175, Train Accuracy: 99.367       Val Loss: 0.3043, Val Accuracy: 94.362, Duration: 0:00:12.041816
# Epoch 341/400, Train Loss: 0.0288, Train Accuracy: 98.964       Val Loss: 0.2553, Val Accuracy: 95.168, Duration: 0:00:12.002918
# Epoch 342/400, Train Loss: 0.0397, Train Accuracy: 98.562       Val Loss: 0.2825, Val Accuracy: 93.423, Duration: 0:00:12.014887
# Epoch 343/400, Train Loss: 0.0596, Train Accuracy: 98.015       Val Loss: 0.3187, Val Accuracy: 93.289, Duration: 0:00:12.012892
# Epoch 344/400, Train Loss: 0.0170, Train Accuracy: 99.396       Val Loss: 0.2591, Val Accuracy: 94.228, Duration: 0:00:12.029848
# Epoch 345/400, Train Loss: 0.0106, Train Accuracy: 99.655       Val Loss: 0.3072, Val Accuracy: 93.826, Duration: 0:00:12.011895
# Epoch 346/400, Train Loss: 0.0165, Train Accuracy: 99.453       Val Loss: 0.2513, Val Accuracy: 93.960, Duration: 0:00:12.015885
# Epoch 347/400, Train Loss: 0.0205, Train Accuracy: 99.252       Val Loss: 0.2286, Val Accuracy: 95.302, Duration: 0:00:12.008903
# Epoch 348/400, Train Loss: 0.0192, Train Accuracy: 99.194       Val Loss: 0.2867, Val Accuracy: 93.423, Duration: 0:00:12.016881
# Epoch 349/400, Train Loss: 0.0160, Train Accuracy: 99.453       Val Loss: 0.3201, Val Accuracy: 94.899, Duration: 0:00:12.020872
# Epoch 350/400, Train Loss: 0.0253, Train Accuracy: 99.166       Val Loss: 0.2240, Val Accuracy: 95.168, Duration: 0:00:12.054780
# Epoch 351/400, Train Loss: 0.0324, Train Accuracy: 98.734       Val Loss: 0.2945, Val Accuracy: 94.094, Duration: 0:00:12.013891
# Epoch 352/400, Train Loss: 0.0412, Train Accuracy: 98.475       Val Loss: 0.2819, Val Accuracy: 93.826, Duration: 0:00:12.028849
# Epoch 353/400, Train Loss: 0.0319, Train Accuracy: 98.936       Val Loss: 0.2774, Val Accuracy: 94.094, Duration: 0:00:12.031842
# Epoch 354/400, Train Loss: 0.0205, Train Accuracy: 99.338       Val Loss: 0.2456, Val Accuracy: 95.168, Duration: 0:00:12.024861
# Epoch 355/400, Train Loss: 0.0518, Train Accuracy: 98.475       Val Loss: 0.2791, Val Accuracy: 94.228, Duration: 0:00:12.023863
# Epoch 356/400, Train Loss: 0.0213, Train Accuracy: 99.252       Val Loss: 0.2398, Val Accuracy: 94.631, Duration: 0:00:12.026855
# Epoch 357/400, Train Loss: 0.0256, Train Accuracy: 99.194       Val Loss: 0.3028, Val Accuracy: 93.960, Duration: 0:00:12.039821
# Epoch 358/400, Train Loss: 0.0654, Train Accuracy: 98.044       Val Loss: 0.2455, Val Accuracy: 93.289, Duration: 0:00:12.028849
# Epoch 359/400, Train Loss: 0.0643, Train Accuracy: 97.929       Val Loss: 0.2369, Val Accuracy: 94.362, Duration: 0:00:12.010897
# Epoch 360/400, Train Loss: 0.0243, Train Accuracy: 99.137       Val Loss: 0.1987, Val Accuracy: 93.826, Duration: 0:00:12.007906
# Epoch 361/400, Train Loss: 0.0316, Train Accuracy: 98.792       Val Loss: 0.2432, Val Accuracy: 94.899, Duration: 0:00:12.045805
# Epoch 362/400, Train Loss: 0.0425, Train Accuracy: 98.504       Val Loss: 0.2533, Val Accuracy: 93.289, Duration: 0:00:12.032840
# Epoch 363/400, Train Loss: 0.0194, Train Accuracy: 99.310       Val Loss: 0.2153, Val Accuracy: 93.826, Duration: 0:00:12.034834
# Epoch 364/400, Train Loss: 0.0184, Train Accuracy: 99.453       Val Loss: 0.2796, Val Accuracy: 94.362, Duration: 0:00:12.029847
# Epoch 365/400, Train Loss: 0.0247, Train Accuracy: 99.137       Val Loss: 0.3137, Val Accuracy: 92.483, Duration: 0:00:12.030844
# Epoch 366/400, Train Loss: 0.0463, Train Accuracy: 98.389       Val Loss: 0.2690, Val Accuracy: 93.826, Duration: 0:00:12.032840
# Epoch 367/400, Train Loss: 0.0341, Train Accuracy: 98.993       Val Loss: 0.2269, Val Accuracy: 94.765, Duration: 0:00:12.007906
# Epoch 368/400, Train Loss: 0.0171, Train Accuracy: 99.252       Val Loss: 0.2745, Val Accuracy: 93.691, Duration: 0:00:12.026855
# Epoch 369/400, Train Loss: 0.0110, Train Accuracy: 99.626       Val Loss: 0.2638, Val Accuracy: 94.362, Duration: 0:00:12.041816
# Epoch 370/400, Train Loss: 0.0147, Train Accuracy: 99.597       Val Loss: 0.4170, Val Accuracy: 92.081, Duration: 0:00:12.031841
# Epoch 371/400, Train Loss: 0.0455, Train Accuracy: 98.331       Val Loss: 0.2793, Val Accuracy: 94.094, Duration: 0:00:12.048797
# Epoch 372/400, Train Loss: 0.0805, Train Accuracy: 97.353       Val Loss: 0.2181, Val Accuracy: 94.899, Duration: 0:00:11.975991
# Epoch 373/400, Train Loss: 0.0367, Train Accuracy: 98.734       Val Loss: 0.2296, Val Accuracy: 95.436, Duration: 0:00:12.016882
# Epoch 374/400, Train Loss: 0.0249, Train Accuracy: 99.051       Val Loss: 0.2421, Val Accuracy: 94.631, Duration: 0:00:11.974994
# Epoch 375/400, Train Loss: 0.0234, Train Accuracy: 99.223       Val Loss: 0.2167, Val Accuracy: 94.765, Duration: 0:00:11.986962
# Epoch 376/400, Train Loss: 0.0234, Train Accuracy: 99.223       Val Loss: 0.2262, Val Accuracy: 93.691, Duration: 0:00:11.991949
# Epoch 377/400, Train Loss: 0.0128, Train Accuracy: 99.540       Val Loss: 0.2340, Val Accuracy: 95.168, Duration: 0:00:12.001922
# Epoch 378/400, Train Loss: 0.0145, Train Accuracy: 99.568       Val Loss: 0.2596, Val Accuracy: 93.826, Duration: 0:00:12.004914
# Epoch 379/400, Train Loss: 0.0128, Train Accuracy: 99.540       Val Loss: 0.2408, Val Accuracy: 94.631, Duration: 0:00:11.994940
# Epoch 380/400, Train Loss: 0.0197, Train Accuracy: 99.310       Val Loss: 0.2744, Val Accuracy: 94.497, Duration: 0:00:11.994940
# Epoch 381/400, Train Loss: 0.0309, Train Accuracy: 98.936       Val Loss: 0.2271, Val Accuracy: 94.497, Duration: 0:00:12.014887
# Epoch 382/400, Train Loss: 0.0222, Train Accuracy: 99.194       Val Loss: 0.2694, Val Accuracy: 95.034, Duration: 0:00:12.027853
# Epoch 383/400, Train Loss: 0.0161, Train Accuracy: 99.425       Val Loss: 0.2634, Val Accuracy: 93.826, Duration: 0:00:11.995937
# Epoch 384/400, Train Loss: 0.0050, Train Accuracy: 99.942       Val Loss: 0.2577, Val Accuracy: 95.168, Duration: 0:00:11.989954
# Epoch 385/400, Train Loss: 0.0198, Train Accuracy: 99.310       Val Loss: 0.3653, Val Accuracy: 92.081, Duration: 0:00:12.039820
# Epoch 386/400, Train Loss: 0.0356, Train Accuracy: 98.562       Val Loss: 0.3005, Val Accuracy: 93.423, Duration: 0:00:12.058771
# Epoch 387/400, Train Loss: 0.0292, Train Accuracy: 98.878       Val Loss: 0.2480, Val Accuracy: 93.423, Duration: 0:00:12.016881
# Epoch 388/400, Train Loss: 0.0301, Train Accuracy: 98.907       Val Loss: 0.2886, Val Accuracy: 93.826, Duration: 0:00:11.993944
# Epoch 389/400, Train Loss: 0.0147, Train Accuracy: 99.482       Val Loss: 0.2392, Val Accuracy: 95.034, Duration: 0:00:11.999927
# Epoch 390/400, Train Loss: 0.0156, Train Accuracy: 99.425       Val Loss: 0.2817, Val Accuracy: 94.497, Duration: 0:00:11.998930
# Epoch 391/400, Train Loss: 0.0100, Train Accuracy: 99.626       Val Loss: 0.2473, Val Accuracy: 94.497, Duration: 0:00:11.990951
# Epoch 392/400, Train Loss: 0.0068, Train Accuracy: 99.741       Val Loss: 0.2867, Val Accuracy: 94.228, Duration: 0:00:11.993942
# Epoch 393/400, Train Loss: 0.0463, Train Accuracy: 98.504       Val Loss: 0.2867, Val Accuracy: 92.752, Duration: 0:00:12.000924
# Epoch 394/400, Train Loss: 0.0713, Train Accuracy: 97.526       Val Loss: 0.3183, Val Accuracy: 93.154, Duration: 0:00:12.047800
# Epoch 395/400, Train Loss: 0.0313, Train Accuracy: 98.849       Val Loss: 0.2382, Val Accuracy: 94.497, Duration: 0:00:12.013890
# Epoch 396/400, Train Loss: 0.0190, Train Accuracy: 99.453       Val Loss: 0.3187, Val Accuracy: 92.752, Duration: 0:00:12.021869
# Epoch 397/400, Train Loss: 0.0210, Train Accuracy: 99.194       Val Loss: 0.2329, Val Accuracy: 94.765, Duration: 0:00:12.048796
# Epoch 398/400, Train Loss: 0.0090, Train Accuracy: 99.712       Val Loss: 0.2501, Val Accuracy: 94.899, Duration: 0:00:12.013891
# Epoch 399/400, Train Loss: 0.0164, Train Accuracy: 99.396       Val Loss: 0.2080, Val Accuracy: 94.362, Duration: 0:00:11.997932
# Epoch 400/400, Train Loss: 0.0466, Train Accuracy: 98.590       Val Loss: 0.2820, Val Accuracy: 93.423, Duration: 0:00:12.047800

# %%
images, labels = val_dataiter.next()
out_img, predicted = torch.max(model(images.to(device)), 1)
imshow(images[:7], labels[:7], predicted[:7])

# %%
# Plot the train loss and test loss per iteration
plt.plot(train_losses, label='train loss')
plt.plot(val_losses, label='val loss')
plt.legend()
plt.show()

# %%
test_loss = []
test_acc = []
n_correct = 0.
n_total = 0.
model.eval()
with torch.no_grad():
    for inputs, targets in Dte:
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = model(inputs)

        # Get the predictions
        # torch.max returns both max and argmax
        __, out_label = outputs.max(dim=1)
        # Updates the accuracy with every pass
        n_correct += (out_label == targets).sum().item()
        n_total += targets.shape[0]
        test_acc.append(n_correct / n_total)

        loss = loss_fn(outputs, targets)
        test_loss.append(loss.item())
test_loss = np.mean(test_loss)
avg_acc = np.mean(test_acc)*100
print('Average loss across the testing data: {}, Average testing accuracy: {}'.format(test_loss, avg_acc))
# Out:
# Average loss across the testing data: 0.23535114464660487, Average testing accuracy: 94.7811312567893
